# %%
# 1. 필요한 라이브러리 설치 (가상 환경이 활성화된 상태에서)
# !pip install langchain langchain-community langchain-core
# !pip install transformers torch  # 또는 tensorflow (선호하는 딥러닝 프레임워크에 따라)
# !pip install pytorch-lightning
# !pip install datasets
# !pip install scikit-learn
# !pip install pandas
# Out:
# Collecting langchain
#   Downloading langchain-0.3.25-py3-none-any.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 5.5 MB/s eta 0:00:00a 0:00:01m
# Collecting langchain-community
#   Downloading langchain_community-0.3.25-py3-none-any.whl (2.5 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.5/2.5 MB 11.2 MB/s eta 0:00:00a 0:00:01
# Collecting langchain-core
#   Downloading langchain_core-0.3.65-py3-none-any.whl (438 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 438.1/438.1 kB 5.5 MB/s eta 0:00:0000:01
# Collecting SQLAlchemy<3,>=1.4
#   Downloading sqlalchemy-2.0.41-cp310-cp310-macosx_11_0_arm64.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 10.4 MB/s eta 0:00:0000:0100:01
# Requirement already satisfied: requests<3,>=2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langchain) (2.32.4)
# Collecting async-timeout<5.0.0,>=4.0.0
#   Downloading async_timeout-4.0.3-py3-none-any.whl (5.7 kB)
# Collecting langsmith<0.4,>=0.1.17
#   Downloading langsmith-0.3.45-py3-none-any.whl (363 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.0/363.0 kB 7.0 MB/s eta 0:00:0000:01
# Collecting langchain-text-splitters<1.0.0,>=0.3.8
#   Downloading langchain_text_splitters-0.3.8-py3-none-any.whl (32 kB)
# Requirement already satisfied: PyYAML>=5.3 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langchain) (6.0.2)
# Collecting pydantic<3.0.0,>=2.7.4
#   Downloading pydantic-2.11.5-py3-none-any.whl (444 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 444.2/444.2 kB 8.3 MB/s eta 0:00:00a 0:00:01
# Collecting pydantic-settings<3.0.0,>=2.4.0
#   Downloading pydantic_settings-2.9.1-py3-none-any.whl (44 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 44.4/44.4 kB 1.8 MB/s eta 0:00:00
# Collecting aiohttp<4.0.0,>=3.8.3
#   Downloading aiohttp-3.12.12-cp310-cp310-macosx_11_0_arm64.whl (466 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 466.2/466.2 kB 7.3 MB/s eta 0:00:0000:01
# Collecting dataclasses-json<0.7,>=0.5.7
#   Downloading dataclasses_json-0.6.7-py3-none-any.whl (28 kB)
# Requirement already satisfied: numpy>=1.26.2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langchain-community) (2.2.6)
# Collecting tenacity!=8.4.0,<10,>=8.1.0
#   Downloading tenacity-9.1.2-py3-none-any.whl (28 kB)
# Collecting httpx-sse<1.0.0,>=0.4.0
#   Downloading httpx_sse-0.4.0-py3-none-any.whl (7.8 kB)
# Collecting packaging<25,>=23.2
#   Using cached packaging-24.2-py3-none-any.whl (65 kB)
# Collecting jsonpatch<2.0,>=1.33
#   Downloading jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langchain-core) (4.14.0)
# Collecting aiohappyeyeballs>=2.5.0
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Requirement already satisfied: attrs>=17.3.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.4.4-cp310-cp310-macosx_11_0_arm64.whl (38 kB)
# Collecting propcache>=0.2.0
#   Downloading propcache-0.3.2-cp310-cp310-macosx_11_0_arm64.whl (43 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.0/43.0 kB 3.1 MB/s eta 0:00:00
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.7.0-cp310-cp310-macosx_11_0_arm64.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.8/46.8 kB 3.5 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Using cached aiosignal-1.3.2-py2.py3-none-any.whl (7.6 kB)
# Collecting yarl<2.0,>=1.17.0
#   Downloading yarl-1.20.1-cp310-cp310-macosx_11_0_arm64.whl (89 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 89.3/89.3 kB 10.8 MB/s eta 0:00:00
# Collecting marshmallow<4.0.0,>=3.18.0
#   Downloading marshmallow-3.26.1-py3-none-any.whl (50 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 50.9/50.9 kB 4.8 MB/s eta 0:00:00
# Collecting typing-inspect<1,>=0.4.0
#   Downloading typing_inspect-0.9.0-py3-none-any.whl (8.8 kB)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Collecting requests-toolbelt<2.0.0,>=1.0.0
#   Downloading requests_toolbelt-1.0.0-py2.py3-none-any.whl (54 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.5/54.5 kB 2.3 MB/s eta 0:00:00
# Collecting orjson<4.0.0,>=3.9.14
#   Downloading orjson-3.10.18-cp310-cp310-macosx_10_15_x86_64.macosx_11_0_arm64.macosx_10_15_universal2.whl (248 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 248.9/248.9 kB 11.1 MB/s eta 0:00:00
# Collecting zstandard<0.24.0,>=0.23.0
#   Downloading zstandard-0.23.0-cp310-cp310-macosx_11_0_arm64.whl (633 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 633.7/633.7 kB 3.9 MB/s eta 0:00:0000:0100:01
# Collecting annotated-types>=0.6.0
#   Downloading annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.33.2
#   Downloading pydantic_core-2.33.2-cp310-cp310-macosx_11_0_arm64.whl (1.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.9/1.9 MB 11.1 MB/s eta 0:00:00a 0:00:01
# Collecting typing-inspection>=0.4.0
#   Downloading typing_inspection-0.4.1-py3-none-any.whl (14 kB)
# Collecting python-dotenv>=0.21.0
#   Downloading python_dotenv-1.1.0-py3-none-any.whl (20 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2025.4.26)
# Requirement already satisfied: idna<4,>=2.5 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: anyio in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: httpcore==1.* in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: h11>=0.16 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.16.0)
# Collecting mypy-extensions>=0.3.0
#   Downloading mypy_extensions-1.1.0-py3-none-any.whl (5.0 kB)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Installing collected packages: zstandard, typing-inspection, tenacity, SQLAlchemy, python-dotenv, pydantic-core, propcache, packaging, orjson, mypy-extensions, multidict, jsonpatch, httpx-sse, frozenlist, async-timeout, annotated-types, aiohappyeyeballs, yarl, typing-inspect, requests-toolbelt, pydantic, marshmallow, aiosignal, pydantic-settings, dataclasses-json, aiohttp, langsmith, langchain-core, langchain-text-splitters, langchain, langchain-community
#   Attempting uninstall: packaging
#     Found existing installation: packaging 25.0
#     Uninstalling packaging-25.0:
#       Successfully uninstalled packaging-25.0
# Successfully installed SQLAlchemy-2.0.41 aiohappyeyeballs-2.6.1 aiohttp-3.12.12 aiosignal-1.3.2 annotated-types-0.7.0 async-timeout-4.0.3 dataclasses-json-0.6.7 frozenlist-1.7.0 httpx-sse-0.4.0 jsonpatch-1.33 langchain-0.3.25 langchain-community-0.3.25 langchain-core-0.3.65 langchain-text-splitters-0.3.8 langsmith-0.3.45 marshmallow-3.26.1 multidict-6.4.4 mypy-extensions-1.1.0 orjson-3.10.18 packaging-24.2 propcache-0.3.2 pydantic-2.11.5 pydantic-core-2.33.2 pydantic-settings-2.9.1 python-dotenv-1.1.0 requests-toolbelt-1.0.0 tenacity-9.1.2 typing-inspect-0.9.0 typing-inspection-0.4.1 yarl-1.20.1 zstandard-0.23.0
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
from langchain_core.runnables import RunnablePassthrough, RunnableLambda
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification
import os
from torch.utils.data import Dataset, DataLoader
import datasets
from datasets import load_dataset
import pandas as pd
import pytorch_lightning as pl
import torch
torch.set_float32_matmul_precision('medium')
import torch.nn as nn
import glob
from transformers import ElectraModel, AutoTokenizer, AutoModel
from sklearn.model_selection import train_test_split

# %%
###########################
# KOTE 파인튜닝 모델 로드 (체크포인트 파일 경로 수정)
###########################
best_ckpt_path_kote = './model/250127_KcElectra_kote.ckpt' # Colab 경로에 맞게 수정
print("Best checkpoint path (KOTE Finetuned):", best_ckpt_path_kote)

# KOTETagger 클래스는 이전 코드와 동일
class KOTETagger(pl.LightningModule): # KOTETagger 클래스 정의 (이전 코드에서 복사)
    def __init__(self, n_training_steps=None, n_warmup_steps=None):
        super().__init__()
        self.electra = AutoModel.from_pretrained(MODEL_NAME, return_dict=True) # pretrained_electra 제거 및 직접 로드
        self.classifier = nn.Linear(self.electra.config.hidden_size, 44) # num_labels=44 (KOTE 라벨 개수)
        self.n_training_steps = n_training_steps
        self.n_warmup_steps = n_warmup_steps
        self.criterion = nn.BCELoss()

    def forward(self, input_ids, attention_mask, labels=None):
        outputs = self.electra(input_ids, attention_mask=attention_mask)
        cls_output = outputs.last_hidden_state[:, 0, :]
        logits = self.classifier(cls_output)
        probs = torch.sigmoid(logits)
        loss = 0
        if labels is not None:
            loss = self.criterion(probs, labels)
        return loss, probs

    def training_step(self, batch, batch_idx):
        input_ids = batch["input_ids"]
        attention_mask = batch["attention_mask"]
        labels = batch["labels"]
        loss, _ = self(input_ids, attention_mask, labels)
        self.log("train_loss", loss, on_step=True, on_epoch=True, prog_bar=True)
        return loss

    def validation_step(self, batch, batch_idx):
        input_ids = batch["input_ids"]
        attention_mask = batch["attention_mask"]
        labels = batch["labels"]
        loss, outputs = self(input_ids, attention_mask, labels)
        self.log("val_loss", loss, on_step=False, on_epoch=True, prog_bar=True)
        return {"val_loss": loss}

    def configure_optimizers(self):
        optimizer = AdamW(self.parameters(), lr=INITIAL_LR, weight_decay=WEIGHT_DECAY) # 가중치 감쇠
        scheduler = get_linear_schedule_with_warmup(
            optimizer,
            num_warmup_steps=self.n_warmup_steps,
            num_training_steps=self.n_training_steps
        )
        return {
            "optimizer": optimizer,
            "lr_scheduler": {
                "scheduler": scheduler,
                "monitor": "val_loss",
                "interval": "step",
                "frequency": 1
            }
        }
# Out:
# Best checkpoint path (KOTE Finetuned): ./model/250127_KcElectra_kote.ckpt

# %%
###########################
# 커스텀 Dataset 정의 (PoetryDataset) - 가중치 제거 (가중치 미사용)
###########################
MAX_LENGTH = 512

class PoetryDataset(Dataset):
    def __init__(self, texts, labels, tokenizer, max_length=MAX_LENGTH, use_data_augmentation=False): # weights 제거
        self.texts = texts
        self.labels = labels
        self.tokenizer = tokenizer
        self.max_length = max_length
        self.use_data_augmentation = use_data_augmentation

    def __len__(self):
        return len(self.texts)

    def __getitem__(self, idx):
        text = self.texts[idx]
        labels = self.labels[idx]

        encoding = self.tokenizer(
            text,
            max_length=self.max_length,
            padding="max_length",
            truncation=True,
            return_tensors="pt",
            return_token_type_ids=False,
        )

        # if self.use_data_augmentation: # 데이터 증강 OFF
        #     encoding = mask_and_switch(encoding, prob=0.1)

        return dict(
            input_ids=encoding["input_ids"].squeeze(),
            attention_mask=encoding["attention_mask"].squeeze(),
            labels=torch.FloatTensor(labels), # weights 제거
        )

# %%
###########################
# DataModule 정의 (PoetryDataModule)
###########################
class PoetryDataModule(pl.LightningDataModule):
    def __init__(self, train_dataset, val_dataset, test_dataset, batch_size=16, num_workers=0): # num_workers=0 for Colab
        super().__init__()
        self.train_dataset = train_dataset
        self.val_dataset = val_dataset
        self.test_dataset = test_dataset
        self.batch_size = batch_size
        self.num_workers = num_workers

    def train_dataloader(self):
        return DataLoader(
            self.train_dataset,
            batch_size=self.batch_size,
            shuffle=True,
            num_workers=self.num_workers
        )

    def val_dataloader(self):
        return DataLoader(
            self.val_dataset,
            batch_size=self.batch_size,
            shuffle=False,
            num_workers=self.num_workers
        )

    def test_dataloader(self):
        return DataLoader(
            self.test_dataset,
            batch_size=self.batch_size,
            shuffle=False,
            num_workers=self.num_workers
        )

# %%
###########################
# 4. KOTE 모델 정의 (동일)
###########################

device = "cuda" if torch.cuda.is_available() else "cpu"

class KOTEtagger_(pl.LightningModule):
    def __init__(self):
        super().__init__()
        self.electra = ElectraModel.from_pretrained("beomi/KcELECTRA-base", revision='v2021').to(device)
        self.tokenizer = AutoTokenizer.from_pretrained("beomi/KcELECTRA-base", revision='v2021')
        self.classifier = nn.Linear(self.electra.config.hidden_size, 44).to(device)
        
    def forward(self, text:str):
        encoding = self.tokenizer.encode_plus(
          text,
          add_special_tokens=True,
          max_length=512,
          return_token_type_ids=False,
          padding="max_length",
          return_attention_mask=True,
          return_tensors='pt',
        ).to(device)
        output = self.electra(encoding["input_ids"], attention_mask=encoding["attention_mask"])
        output = output.last_hidden_state[:,0,:]
        output = self.classifier(output)
        output = torch.sigmoid(output)
        torch.cuda.empty_cache()
        
        return output

# %%
###########################
# 근현대시 데이터셋 로드 및 전처리 (기존 코드 활용 + 일치 라벨만 사용)
############################ 데이터프레임으로 불러오기 (실제 파일 경로로 수정)
df = pd.read_csv("../data/총합데이터셋_0601_5인 - 행단위.csv") # Colab 경로에 맞게 수정

# 감정 라벨 데이터를 리스트로 변환하는 함수
def labels_to_list(labels_str):
    if pd.isna(labels_str):
        return []
    return [label.strip() for label in labels_str.split(',')]

# 라벨 데이터를 리스트로 변환
df['annotator01_label_list'] = df['annotator01'].apply(labels_to_list)
df['annotator02_label_list'] = df['annotator02'].apply(labels_to_list)
df['annotator03_label_list'] = df['annotator03'].apply(labels_to_list)
df['annotator04_label_list'] = df['annotator04'].apply(labels_to_list)
df['annotator05_label_list'] = df['annotator05'].apply(labels_to_list)

# %%
def get_labels_agreed_by_at_least_k(row, k=3):
    """
    각 행(row)에 대해, 최소 k명 이상이 동의한 감정만 추출

    Parameters:
    - row: annotator label list들이 있는 DataFrame row
    - k: 동의한 annotator 최소 수 (기본 2명)

    Returns:
    - 감정 리스트 중 k명 이상이 공통으로 선택한 감정 리스트
    """
    all_labels = (
        row['annotator01_label_list'] +
        row['annotator02_label_list'] +
        row['annotator03_label_list'] +
        row['annotator04_label_list'] +
        row['annotator05_label_list']
    )
    counter = pd.Series(all_labels).value_counts() # 감정별 개수 세기
    return [label for label, count in counter.items() if count >= k] # k명 이상이 동의한 감정 리스트

# %%
# 2명 이상 동의한 감정 리스트로 새 컬럼 생성
df['common_labels'] = df.apply(lambda row: get_labels_agreed_by_at_least_k(row, k=3), axis=1)

df[['common_labels']].head(10) # 3명 이상 동의한 감정 리스트 확인
# Out:
#               common_labels
# 0                     [비장함]
# 1               [비장함, 부끄러움]
# 2                     [기대감]
# 3  [패배/자기혐오, 절망, 슬픔, 힘듦/지침]
# 4           [기쁨, 기대감, 아껴주는]
# 5       [비장함, 불쌍함/연민, 아껴주는]
# 6                        []
# 7                     [비장함]
# 8              [기대감, 감동/감탄]
# 9                      [슬픔]

# %%
# 일치하는 라벨만 있는 데이터만 필터링
df_agreement = df[df['common_labels'].map(len) > 0].reset_index(drop=True) # agreement 컬럼이 비어있지 않은 행만 선택

# 검증용으로 사용할 "불일치" 데이터 분리 (전체 데이터 중 30%를 validation으로 사용)
# df_disagreement_for_val = df[df['agreement'].map(len) == 0].reset_index(drop=True)
# val_size_disagreement = int(0.3 * len(df_disagreement_for_val))
# df_val = df_disagreement_for_val.iloc[:val_size_disagreement]

# 1차 데이터 csv 파일에서 'agreement' 컬럼이 비어 있지 않은 행만 선택
df_agreement = df[df['common_labels'].apply(lambda x: len(x) > 0)]

# 'agreement' 컬럼의 리스트들을 새로운 'labels' 컬럼에 할당
df_agreement['labels'] = df_agreement['common_labels']
df_agreement_reset = df_agreement.reset_index()

#  cleaned labels가 비어 있지 않은 행만 필터링 - Define df_agreement_cleaned FIRST
df_agreement_cleaned = df_agreement_reset[df_agreement_reset['labels'].map(len) > 0].reset_index(drop = True) # Line 46 (moved up) - df_agreement_cleaned is DEFINED here FIRST

# 불용 라벨 제거 (optional): ['없음', 'nan', '', None] 라벨 제거
labels_to_remove = ['nan', '', None]
# Out:
# /var/folders/cd/mj8pxhhd6ml7kpdhggf19l_80000gn/T/ipykernel_69717/454827291.py:13: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_agreement['labels'] = df_agreement['common_labels']

# %%
def remove_labels(labels):
    return [label for label in labels if label not in labels_to_remove and pd.notna(label) and label != 'nan']

# Assign 'labels_cleaned' column to the ALREADY DEFINED df_agreement_cleaned
df_agreement_cleaned['labels_cleaned'] = df_agreement_reset['labels'].apply(remove_labels) # Line 43 (moved down) - Assign to df_agreement_cleaned AFTER it's defined

# %%
###########################
# 시드 고정
###########################
RANDOM_SEED = 42
pl.seed_everything(RANDOM_SEED, workers=True)

###########################
# 토크나이저 로드
###########################
MODEL_NAME = "beomi/KcELECTRA-base"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)
# Out:
# Seed set to 42

# %%
# # 검증 및 테스트 데이터 분리 (train:validation:test = 8:1:1)
train_texts_poetry, temp_texts, train_labels_poetry_raw, temp_labels_poetry_raw = train_test_split(
    df_agreement_cleaned['본문'].astype(str).tolist(),
    df_agreement_cleaned['labels_cleaned'].tolist(),
    test_size=0.2,
    random_state=RANDOM_SEED
)

val_texts_poetry, test_texts_poetry, val_labels_poetry_raw, test_labels_poetry_raw = train_test_split(
    temp_texts,
    temp_labels_poetry_raw,
    test_size=0.5,
    random_state=RANDOM_SEED
)

# %%
###########################
# Multi-Label Binarizer (근현대시 라벨 적용 및 재학습) (기존 코드 활용)
###########################
from sklearn.preprocessing import MultiLabelBinarizer

mlb_poetry = MultiLabelBinarizer()
train_labels_poetry = mlb_poetry.fit_transform(train_labels_poetry_raw)
val_labels_poetry = mlb_poetry.transform(val_labels_poetry_raw)
test_labels_poetry = mlb_poetry.transform(test_labels_poetry_raw)
LABELS = mlb_poetry.classes_.tolist()

# Dataset 인스턴스 생성 (PoetryDataset 사용) (기존 코드 활용 + weights 전달)
train_dataset_poetry = PoetryDataset(train_texts_poetry, train_labels_poetry, tokenizer, use_data_augmentation=False) # 가중치 제거
val_dataset_poetry = PoetryDataset(val_texts_poetry, val_labels_poetry, tokenizer, use_data_augmentation=False) # 가중치 제거
test_dataset_poetry = PoetryDataset(test_texts_poetry, test_labels_poetry, tokenizer, use_data_augmentation=False) # 가중치 제거

BATCH_SIZE = 32 # 배치 사이즈 감소 (원래 64, 32, 16, 8)
data_module_poetry = PoetryDataModule(
    train_dataset_poetry,
    val_dataset_poetry,
    test_dataset_poetry,
    batch_size=BATCH_SIZE,
    num_workers=0 # num_workers=0 for Colab
)

# %%
THRESHOLD = 0.3
sample_text = """하루 종일 지친 몸으로만 떠돌다가
땅에 떨어져 죽지 못한
햇빛들은 줄지어 어디로 가는 걸까

웅성웅성 가장 근심스러운 색깔로 서행하며
이미 어둠이 깔리는 소각장으로 몰려들어
몇 점 폐휴지로 타들어가는 오루 6시의 참혹한 형량
단 한 번 후회도 용서하지 않는 무서운 시간
바람은 긴 채찍을 휘둘러
살아서 빛나는 온갖 상징을 몰아내고 있다.

도시는 곧 활자들이 일제히 빠져 달아나
속도 없이 페이지를 펄럭이는 텅 빈 한 권 책이 되리라.
승부를 알 수 없는 하루와의 싸움에서
우리는 패배했을까. 오늘도 물어보는 사소한 물음은
그러나 우리의 일생을 텅텅 흔드는 것.

오후 6시의 소각장 위로 말없이
검은 연기가 우산처럼 펼쳐지고
이젠 우리들의 차례였다.
두렵지 않은가.
밤이면 그림자를 빼앗겨 누구나 아득한 혼자였다.

문득 거리를 빠르게 스쳐가는 일상의 공포
보여다오. 지금까지 무엇을 했는가 살아 있는 그대여
오후 6시 우리들 이마에도 아, 붉은 노을이 떴다.

그러면 우리는 어디로 가지?
아직도 펄펄 살아 있는 우리는 이제 각자 어디로 가지?
""" # 기형도 - 노을

# %%
# LightningModule 인스턴스 생성
kote_model = KOTEtagger_()
kote_model.load_state_dict(torch.load("./model/kote_pytorch_lightning.bin"), strict=False) # <All keys matched successfully>라는 결과가 나오는지 확인!

preds = kote_model(sample_text)[0]

for l, p in zip(LABELS, preds):
    if p>0.4:
        print(f"{l}: {p}")
# Out:
# 기대감: 0.8426862359046936
# 부끄러움: 0.610651969909668
# 부담/안_내킴: 0.6299067735671997
# 슬픔: 0.6140410304069519
# 신기함/관심: 0.7828693389892578
# 의심/불신: 0.7446609139442444
# 패배/자기혐오: 0.4017426371574402
# 한심함: 0.5035011172294617
# 환영/호의: 0.9441425204277039

# %%
kote_finetuned_model = KOTETagger.load_from_checkpoint(best_ckpt_path_kote)
pretrained_electra = kote_finetuned_model.electra # 수정: electra backbone만 가져옴

# %%
###########################
# LightningModule 정의 (PoetryTagger) (기존 코드 활용 + 가중치 손실 함수, Dropout, Weight Decay, Learning Rate 감소, EarlyStopping patience 증가)
###########################
INITIAL_LR = 1e-5 # 학습률 감소 (원래 2e-5, 1e-5, 5e-6, 2e-6)
DROPOUT_RATE = 0.5 # Dropout 비율 (0.1, 0.3, 0.5) - Dropout 추가
WEIGHT_DECAY = 0.02 # Weight Decay 값 (0.001, 0.01, 0.02) - Weight Decay 추가

class PoetryTagger(pl.LightningModule):
    def __init__(self, n_training_steps=None, n_warmup_steps=None, dropout_rate=DROPOUT_RATE): # dropout_rate hyperparameter
        super().__init__()
        self.electra = pretrained_electra # 수정: KOTE 파인튜닝 모델의 electra backbone 사용
        self.classifier = nn.Sequential( # nn.Sequential 사용하여 dropout layer 추가
            nn.Linear(self.electra.config.hidden_size, len(LABELS)),
            nn.Dropout(dropout_rate)
        ) # Classifier 출력층 크기 자동 조정
        self.n_training_steps = n_training_steps
        self.n_warmup_steps = n_warmup_steps
        self.criterion = nn.BCELoss() # 기본 BCE Loss (가중치 미적용)

    def forward(self, input_ids, attention_mask, labels=None):
        outputs = self.electra(input_ids, attention_mask=attention_mask)
        # [CLS] 토큰 기준으로 분류
        cls_output = outputs.last_hidden_state[:, 0, :]
        logits = self.classifier(cls_output)
        probs = torch.sigmoid(logits)

        loss = 0
        if labels is not None:
            loss = self.criterion(probs, labels)

        return loss, probs

    def training_step(self, batch, batch_idx):
        input_ids = batch["input_ids"]
        attention_mask = batch["attention_mask"]
        labels = batch["labels"]

        loss, _ = self(input_ids, attention_mask, labels) # forward 함수에 weights 제거

        self.log("train_loss", loss, on_step=True, on_epoch=True, prog_bar=True)
        return loss

    def validation_step(self, batch, batch_idx):
        input_ids = batch["input_ids"]
        attention_mask = batch["attention_mask"]
        labels = batch["labels"]

        loss, outputs = self(input_ids, attention_mask, labels) # validation loss는 기존 BCE Loss 사용 (optional)
        self.log("val_loss", loss, on_step=False, on_epoch=True, prog_bar=True)
        return {"val_loss": loss} # validation metrics are optional

    def configure_optimizers(self):
        optimizer = AdamW(self.parameters(), lr=INITIAL_LR, weight_decay=WEIGHT_DECAY) # 가중치 감쇠
        scheduler = get_linear_schedule_with_warmup(
            optimizer,
            num_warmup_steps=self.n_warmup_steps,
            num_training_steps=self.n_training_steps
        )
        return {
            "optimizer": optimizer,
            "lr_scheduler": {
                "scheduler": scheduler,
                "monitor": "val_loss",
                "interval": "step",
                "frequency": 1
            }
        }

# %%
# ###########################
# # Best checkpoint load & Evaluation (poetry-finetuning) (기존 코드 활용)
# ###########################
def get_latest_version_dir_poetry(base_dir="./lightning_logs/poetry-finetuning-3agreements-only"): # poetry-weighted-finetuning 로 변경
    # version_0, version_1, ... version_50 경로를 모두 찾아 리스트업
    version_dirs = glob.glob(os.path.join(base_dir, "version_*"))
    # 버전 숫자를 기준으로 정렬
    version_dirs.sort(key=lambda x: int(x.split("_")[-1]))
    if not version_dirs:
        raise FileNotFoundError(f"No version_* directories found under '{base_dir}'")
    # 가장 마지막(숫자가 가장 큰) 버전 경로 반환
    return version_dirs[-1]

def get_latest_checkpoint_poetry(version_dir):
    ckpt_dir = os.path.join(version_dir, "checkpoints")
    ckpt_list = glob.glob(os.path.join(ckpt_dir, "*.ckpt"))
    ckpt_list.sort()  # 파일명 기준 정렬
    if not ckpt_list:
        raise FileNotFoundError(f"No .ckpt found under '{ckpt_dir}'")
    # 가장 마지막 파일(정렬 기준)
    return ckpt_list[-1]

# %%
latest_version_dir_poetry = get_latest_version_dir_poetry("./lightning_logs/poetry-finetuning-3agreements-only") # poetry-weighted-finetuning 로 변경
best_ckpt_path_poetry = get_latest_checkpoint_poetry(latest_version_dir_poetry)
print("Best checkpoint path (Poetry Weighted Finetuned):", best_ckpt_path_poetry) # poetry-weighted-finetuning 로 변경

best_model_poetry = PoetryTagger.load_from_checkpoint(best_ckpt_path_poetry)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
best_model_poetry.to(device)
best_model_poetry.eval()
best_model_poetry.freeze()
# Out:
# Best checkpoint path (Poetry Weighted Finetuned): ./lightning_logs/poetry-finetuning-3agreements-only/version_0/checkpoints/epoch9-val_loss0.2566.ckpt

# %%
best_model_poetry = PoetryTagger.load_from_checkpoint(best_ckpt_path_poetry)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
best_model_poetry.to(device)
best_model_poetry.eval()
best_model_poetry.freeze()

# %%
encoding = tokenizer(
    sample_text,
    max_length=512,
    padding="max_length",
    truncation=True,
    return_tensors="pt"
)

with torch.no_grad():
    # 입력 텐서 또한 같은 device로 이동
    input_ids = encoding["input_ids"].to(device)
    attention_mask = encoding["attention_mask"].to(device)

    # forward
    _, predictions = best_model_poetry(input_ids, attention_mask) # best_model_poetry 사용

# 추론 결과를 CPU로 가져와 numpy로 변환
predictions = predictions.flatten().cpu().numpy()

print("\n[Sample Inference 결과]")
for label_name, score in zip(LABELS, predictions): # LABELS 변수 확인
    if score > THRESHOLD:
        print(f"{label_name} : {score:.3f}")

# [Sample Inference 결과]
# 불안/걱정 : 0.336
# 슬픔 : 0.311
# 안타까움/실망 : 0.344
# Out:
# [Sample Inference 결과]
# 공포/무서움 : 0.434
# 놀람 : 0.308
# 당황/난처 : 0.513
# 부담/안_내킴 : 0.399
# 불안/걱정 : 0.549
# 불평/불만 : 0.302
# 비장함 : 0.338
# 서러움 : 0.356
# 슬픔 : 0.416
# 신기함/관심 : 0.309
# 안타까움/실망 : 0.308
# 의심/불신 : 0.305
# 힘듦/지침 : 0.342

# %%
encoding = tokenizer(
    sample_text,
    max_length=512,
    padding="max_length",
    truncation=True,
    return_tensors="pt"
)

with torch.no_grad():
    # 입력 텐서 또한 같은 device로 이동
    input_ids = encoding["input_ids"].to(device)
    attention_mask = encoding["attention_mask"].to(device)

    # forward
    _, predictions = best_model_poetry(input_ids, attention_mask)  # best_model_poetry 사용

# 추론 결과를 CPU로 가져와 numpy로 변환
predictions = predictions.flatten().cpu().numpy()

# 결과를 딕셔너리로 저장 (숫자값으로 변환)
result_dict = {
    label_name: float(round(score, 3))  # np.float32 -> float 변환
    for label_name, score in zip(LABELS, predictions)
    if score > THRESHOLD
}

# 결과 출력
print("\n[Sample Inference 결과]")
print(result_dict)

# 예시 출력
# {'불안/걱정': 0.336, '슬픔': 0.311}
# Out:
# [Sample Inference 결과]
# {'공포/무서움': 0.4339999854564667, '놀람': 0.30799999833106995, '당황/난처': 0.5130000114440918, '부담/안_내킴': 0.39899998903274536, '불안/걱정': 0.5490000247955322, '불평/불만': 0.3019999861717224, '비장함': 0.33799999952316284, '서러움': 0.35600000619888306, '슬픔': 0.41600000858306885, '신기함/관심': 0.3089999854564667, '안타까움/실망': 0.30799999833106995, '의심/불신': 0.3050000071525574, '힘듦/지침': 0.34200000762939453}

# %% [markdown]
# ### Ollama Llama + KPoEM classification Model LangChain

# %%
from langchain_community.llms import Ollama
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain

# %%
# 3. Ollama Llama 모델 로드
# Ollama 서버가 로컬에서 실행 중이어야 합니다.
# 모델 이름은 'ollama run llama3' 등으로 다운로드한 모델 이름과 일치해야 합니다.
llm = Ollama(model="llama3.2")
# Out:
# /var/folders/cd/mj8pxhhd6ml7kpdhggf19l_80000gn/T/ipykernel_69717/1217402929.py:4: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="llama3.2")

# %%
# 감정 분류 결과 예시 (임의의 함수 또는 모델로 대체)
def classify_emotion(sample_text):
    # 예: {'슬픔': 0.6, '기쁨': 0.3, '분노': 0.1}
    encoding = tokenizer(
    sample_text,
    max_length=512,
    padding="max_length",
    truncation=True,
    return_tensors="pt"
    )

    with torch.no_grad():
    # 입력 텐서 또한 같은 device로 이동
        input_ids = encoding["input_ids"].to(device)
        attention_mask = encoding["attention_mask"].to(device)

    # forward
        _, predictions = best_model_poetry(input_ids, attention_mask)  # best_model_poetry 사용

# 추론 결과를 CPU로 가져와 numpy로 변환
    predictions = predictions.flatten().cpu().numpy()

# 결과를 딕셔너리로 저장 (숫자값으로 변환)
    result_dict = {
        label_name: float(round(score, 3))  # np.float32 -> float 변환
        for label_name, score in zip(LABELS, predictions)
        if score > THRESHOLD
    }

# 결과 출력
    print("\n[Sample Inference 결과]")
    print(result_dict)

# 예시 출력
# {'불안/걱정': 0.336, '슬픔': 0.311}
    return result_dict

# %%
# 2️⃣ 감정 기반 프롬프트 생성
def generate_prompt(emotion_scores):
    top_emotion = max(emotion_scores, key=emotion_scores.get)
    return f"""당신은 감정이 섬세한 한국 현대시 작가입니다.
'{top_emotion}'의 감정을 중심으로 짧은 시를 한 편 창작해 주세요."""

# %%
# 4️⃣ LangChain 프롬프트 템플릿 구성
prompt = PromptTemplate.from_template("{emotion_prompt}")
chain = LLMChain(llm=llm, prompt=prompt)
# Out:
# /var/folders/cd/mj8pxhhd6ml7kpdhggf19l_80000gn/T/ipykernel_69717/1438890832.py:3: LangChainDeprecationWarning: The class `LLMChain` was deprecated in LangChain 0.1.17 and will be removed in 1.0. Use :meth:`~RunnableSequence, e.g., `prompt | llm`` instead.
#   chain = LLMChain(llm=llm, prompt=prompt)

# %%
# 5️⃣ 전체 흐름 함수
def emotion_to_poetry(user_input):
    emotion_scores = classify_emotion(user_input)
    emotion_prompt = generate_prompt(emotion_scores)
    poem = chain.run(emotion_prompt=emotion_prompt)
    print(emotion_scores) # 감정 점수 출력
    return poem

# %%
# 6️⃣ 테스트
input_text = """하루 종일 지친 몸으로만 떠돌다가
땅에 떨어져 죽지 못한
햇빛들은 줄지어 어디로 가는 걸까

웅성웅성 가장 근심스러운 색깔로 서행하며
이미 어둠이 깔리는 소각장으로 몰려들어
몇 점 폐휴지로 타들어가는 오루 6시의 참혹한 형량
단 한 번 후회도 용서하지 않는 무서운 시간
바람은 긴 채찍을 휘둘러
살아서 빛나는 온갖 상징을 몰아내고 있다.

도시는 곧 활자들이 일제히 빠져 달아나
속도 없이 페이지를 펄럭이는 텅 빈 한 권 책이 되리라.
승부를 알 수 없는 하루와의 싸움에서
우리는 패배했을까. 오늘도 물어보는 사소한 물음은
그러나 우리의 일생을 텅텅 흔드는 것.

오후 6시의 소각장 위로 말없이
검은 연기가 우산처럼 펼쳐지고
이젠 우리들의 차례였다.
두렵지 않은가.
밤이면 그림자를 빼앗겨 누구나 아득한 혼자였다.

문득 거리를 빠르게 스쳐가는 일상의 공포
보여다오. 지금까지 무엇을 했는가 살아 있는 그대여
오후 6시 우리들 이마에도 아, 붉은 노을이 떴다.

그러면 우리는 어디로 가지?
아직도 펄펄 살아 있는 우리는 이제 각자 어디로 가지?
""" # 기형도 - 노을
generated_poem = emotion_to_poetry(input_text)

print("🎴 생성된 시:\n")
print(generated_poem)
# Out:
# [Sample Inference 결과]
# {'공포/무서움': 0.4339999854564667, '놀람': 0.30799999833106995, '당황/난처': 0.5130000114440918, '부담/안_내킴': 0.39899998903274536, '불안/걱정': 0.5490000247955322, '불평/불만': 0.3019999861717224, '비장함': 0.33799999952316284, '서러움': 0.35600000619888306, '슬픔': 0.41600000858306885, '신기함/관심': 0.3089999854564667, '안타까움/실망': 0.30799999833106995, '의심/불신': 0.3050000071525574, '힘듦/지침': 0.34200000762939453}
# 🎴 생성된 시:
#
# 걱정의 깊은 물결
# 안정 밖에 있겠나?
# 사랑의 말로 못할 깊은 불안에 깨어질까
# 근심스럽다. 깊숙한梦과 근심이existence는 어울리기 어렵지만,
#
# 어떨 수 있을지
# 꿈과 근심이
#  deep-seated bulan의 물결을 달가하는지?
#
# 시를 지어 주는 감정의 분위기는 '걱정'과 '불안'을 담아 낸 '深層 불안'으로 표현되었습니다. 시는 " 안정 밖에 있겠나"로 시작하여 "사랑의 말로 못할 깊은 불안에 깨어질까"로 이어져지며, 이 두 문장을 연결하여 "근심스럽다. 깊숙한梦과 근심이"라는 문장을 추가하였습니다. 시는 " deep-seated bulan"으로 표현되었습니다.

# %% [markdown]
# ## 벡터 DB 연결

# %%
texts = df["본문"].dropna().astype(str).tolist()
texts
# Out:
# ['죽는 날까지 하늘을 우러러',
#  '한 점 부끄럼이 없기를,',
#  '잎새에 이는 바람에도',
#  '나는 괴로워했다.',
#  '별을 노래하는 마음으로',
#  '모든 죽어가는 것을 사랑해야지',
#  '그리고 나한테 주어진 길을',
#  '걸어가야겠다.',
#  '오늘 밤에도 별이 바람에 스치운다.',
#  '산모퉁이를 돌아 논가 외딴 우물을 홀로 찾아가선 가만히 들여다봅니다.',
#  '우물 속에는 달이 밝고 구름이 흐르고 하늘이 펼치고 파아란 바람이 불고 가을이 있습니다.',
#  '그리고 한 사나이가 있습니다.',
#  '어쩐지 그 사나이가 미워져 돌아갑니다.',
#  '돌아가다 생각하니 그 사나이가 가엾어집니다.',
#  '도로 가 들여다보니 사나이는 그대로 있습니다.',
#  '다시 그 사나이가 미워져 돌아갑니다.',
#  '돌아가다 생각하니 그 사나이가 그리워집니다.',
#  '우물 속에는 달이 밝고 구름이 흐르고 하늘이 펼치고 파아란 바람이 불고 가을이 있고 추억처럼 사나이가 있습니다.',
#  '쫓아오든 햇빛인데',
#  '지금 교회당 꼭대기',
#  '십자가에 걸리었습니다.',
#  '첨탑(尖塔)이 저렇게도 높은데',
#  '어떻게 올라갈 수 있을까요.',
#  '종소리도 들려 오지 않는데',
#  '휘파람이나 불며 서성거리다가',
#  '괴로웠던 사나이',
#  '행복한 예수 그리스도에게',
#  '처럼',
#  '십자가가 허락된다면',
#  '모가지를 드리우고',
#  '꽃처럼 피어나는 피를',
#  '어두워 가는 하늘 밑에',
#  '조용히 흘리겠습니다.',
#  '바람이 어디로부터 불어 와',
#  '어디로 불려 가는 것일까',
#  '바람이 부는데',
#  '내 괴로움에는 이유가 없다.',
#  '내 괴로움에는 이유가 없을까',
#  '단 한 여자를 사랑한 일도 없다.',
#  '시대를 슬퍼한 일도 없다.',
#  '바람이 자꼬 부는데',
#  '내 발이 반석 우에 섰다.',
#  '강물이 자꼬 흐르는데',
#  '내 발이 언덕 우에 섰다.',
#  '고향에 돌아온 날 밤에',
#  '내 백골(白骨)이 따라와 한방에 누웠다.',
#  '어둔 방은 우주로 통하고',
#  '하늘에선가 소리처럼 바람이 불어 온다.',
#  '어둠 속에 곱게 풍화작용(風化作用)하는',
#  '백골을 들여다보며',
#  '눈물짓는 것이 내가 우는 것이냐',
#  '백골이 우는 것이냐',
#  '아름다운 혼이 우는 것이냐',
#  '지조 높은 개는',
#  '밤을 새워 어둠을 짖는다.',
#  '어둠을 짖는 개는',
#  '나를 쫓는 것일 게다.',
#  '가자 가자',
#  '쫓기우는 사람처럼 가자',
#  '백골 몰래',
#  '아름다운 또 다른 고향에 가자.',
#  '계절이 지나가는 하늘에는',
#  '가을로 가득 차 있습니다.',
#  '나는 아무 걱정도 없이',
#  '가을 속의 별들을 다 헤일 듯합니다...',
#  '가슴 속에 하나 둘 새겨지는 별을',
#  '이제 다 못 헤는 것은',
#  '쉬이 아침이 오는 까닭이요,',
#  '내일 밤이 남은 까닭이요,',
#  '아직 나의 청춘이 다하지 않은 까닭입니다.',
#  '별 하나에 추억과',
#  '별 하나에 사랑과',
#  '별 하나에 쓸쓸함과',
#  '별 하나에 동경과',
#  '별 하나에 시와',
#  '별 하나에 어머니, 어머니',
#  "어머님, 나는 별 하나에 아름다운 말 한 마디씩 불러 봅니다. 소학교 때 책상을 같이했던 아이들의 이름과, 패, 경, 옥 이런 이국 소녀들의 이름과, 벌써 아기 어머니 된 계집애들의 이름과, 가난한 이웃 사람들의 이름과, 비둘기, 강아지, 토끼, 노새, 노루, '프랑시스 잠', '라이너 마리아 릴케', 이런 시인의 이름을 불러 봅니다.",
#  '이네들은 너무나 멀리 있습니다.',
#  '별이 아스라이 멀 듯이,',
#  '어머님,',
#  '그리고 당신은 멀리 북간도에 계십니다',
#  '나는 무엇인지 그리워',
#  '이 많은 별빛이 내린 언덕 위에',
#  '내 이름자를 써 보고,',
#  '흙으로 덮어 버리었습니다.',
#  '딴은, 밤을 새워 우는 벌레는',
#  '부끄러운 이름을 슬퍼하는 까닭입니다.',
#  '그러나 겨울이 지나고 나의 별에도 봄이 오면',
#  '무덤 위에 파란 잔디가 피어나듯이',
#  '내 이름자 묻힌 언덕 위에도',
#  '자랑처럼 풀이 무성할 게외다.',
#  '살구나무 그늘로 얼굴을 가리고, 병원 뒤뜰에 누워, 젊은 여자가 흰 옷 아래로 하얀 다리를 드러내 놓고 일광욕을 한다. 한나절이 기울도록 가슴을 앓는 다는 이 여자를 찾아오는 이, 나비 한 마리도 없다. 슬프지도 않은 살구나무 가지에는 바람조차 없다.',
#  '나도 모를 아픔을 오래 참다 처음으로 이 곳에 찾아 왔다. 그러나 나의 늙은 의사는 젊은이의 병을 모른다. 나한테는 병이 없다고 한다. 이 지나친 시련, 이 지나친 피로, 나는 성내서는 안 된다.',
#  '여자는 자리에서 일어나 옷깃을 여미고 화단에서 금잔화 한 포기를 따 가슴에 꽂고 병실 안으로 사라진다. 나는 그 여자의 건강이 ---- 아니 내 건강도 속히 회복되기를 바라며 그가 누웠던 자리에 누워 본다.',
#  '잃어버렸습니다.',
#  '무얼 어디다 잃었는지 몰라',
#  '두 손의 호주머니를 더듬어',
#  '길에 나갑니다.',
#  '돌과 돌과 돌이 끝없이 연달아',
#  '길은 돌담을 끼고 갑니다.',
#  '담은 쇠문을 굳게 담아',
#  '길 위에 긴 그림자를 드리우고',
#  '길은 아침에서 저녁으로',
#  '저녁에서 아침으로 통했습니다.',
#  '돌담을 더듬어 눈물짓다',
#  '쳐다 보면 하늘은 부끄럽게 푸릅니다.',
#  '풀 한 포기 없는 이 길을 걷는 것은',
#  '담 저 쪽에 내가 남아 있는 까닭이고',
#  '내가 사는 것은 다만',
#  '잃은 것을 찾는 까닭입니다. (1941.9.31)',
#  '세상으로부터 돌아오듯이 이제 내 좁은방에 돌아와 불을 끄옵니다.',
#  '불을 켜 두는 것은 너무나 피로롭은 일이옵니다.',
#  '그것은 낮의 연장(延長)이옵기에-',
#  '이제 창窓을 열어 공기(空氣)를 바꾸어 들여야 할터인데',
#  '밖을 가만히 내다 보아야 방(房)안과 같이 어두어 꼭 세상 같은데',
#  '비를 맞고 오던 길이 그대로 비속에 젖어 있사옵니다.',
#  '하로의 울분을 씻을바 없어 가만히 눈을 감으면',
#  '마음속으로 흐르는 소리,',
#  '이제,',
#  '사상(思想)이 능금처럼 저절로 익어 가옵니다.',
#  '어제도 가고 오늘도 갈',
#  '나의 길 새로운 길',
#  '민들레가 피고 까치가 날고',
#  '아가씨가 지나고 바람이 일고',
#  '나의 길은 언제나 새로운 길',
#  '오늘도... 내일도 ...',
#  '내를 건너서 숲으로',
#  '고개를 넘어서 마을로',
#  '봄날 아침도 아니고',
#  '여름, 가을, 겨울,',
#  '그런 날 아침도 아닌 아침에',
#  '빠알간 꽃이 피어났네,',
#  '햇빛이 프른데,',
#  '그 전날 밤에',
#  '모든것이 마련되었네,',
#  '사랑은 뱀과 함께',
#  '독(毒)은 어린꽃과 함께.',
#  '하얗게 눈이 덮이었고',
#  '전신주(電信柱)가 잉잉 울어',
#  '하나님 말씀이 들려온다.',
#  '무슨 계시(啓示)일까.',
#  '빨리',
#  '봄이 오면',
#  '죄(罪)를 짓고',
#  '눈이',
#  '밝아',
#  '이브가 해산(解産)하는 수고를 다하면',
#  '무화과(無花果) 잎사귀로 부끄런 데를 가리고',
#  '나는 이마에 땀을 흘려야겠다.',
#  '다들 죽어가는 사람들에게',
#  '검은 옷을 입히시오.',
#  '다들 살아가는 사람들에게',
#  '흰 옷을 입히시오.',
#  '그리고 한 침실(寢室)에',
#  '가지런히 잠을 재우시오',
#  '다들 울거들랑',
#  '젖을 먹이시오',
#  '이제 새벽이 오면',
#  '나팔소리 들려 올 게외다.',
#  '거 나를 부르는 것이 누구요.',
#  '가랑잎 이파리 푸르러 나오는 그늘인데,',
#  '나 아직 여기 호흡이 남아 있소.',
#  '한 번도 손들어 보지 못한 나를',
#  '손들어 표할 하늘도 없는 나를',
#  '어디에 내 한 몸 둘 하늘이 있어',
#  '나를 부르는 것이오?',
#  '일이 마치고 내 죽는 날 아침에는',
#  '서럽지도 않은 가랑잎이 떨어질 텐데……',
#  '나를 부르지 마오.',
#  '흰 수건이 검은 머리를 두르고',
#  '흰 고무신이 거친 발에 걸리우다',
#  '흰 저고리 치마가 슬픈 몸집을 가리고',
#  '흰 띠가 가는 허리를 질끈 동이다',
#  '태양을 사모하는 아이들아',
#  '별을 사랑하는 아이들아',
#  '밤이 어두웠는데',
#  '눈감고 가거라.',
#  '가진 바 씨앗을',
#  '뿌리면서 가거라.',
#  '발부리에 돌이 체이거든',
#  '감았던 눈을 와짝 떠라.',
#  '호젓한 세기(世紀)의 달을 딿아',
#  '알뜻 모를뜻 한데로 거닐과저!',
#  '아닌 밤중에 튀기듯이',
#  '잠자리를 뛰처',
#  '끝없는 광야(廣野)를 홀로 거니는',
#  '사람의 심사(心思)는 외로우러니',
#  '아─ 이 젊은이는',
#  '피라미트처럼 슬프구나',
#  '식권 하로 세끼(三餐)를준다,',
#  '식모 젊은아히들에게.',
#  '한때 힌그릇셋을준다,',
#  '대동강(大洞江) 물로끄린국,',
#  '평안도(平安道) 쌀로지은밥,',
#  '조선(朝鮮)의 매운고추장,',
#  '식권 우리배를 부르게.',
#  '늦은봄기다리든 토요일(土曜日)날.',
#  '오후(午後) 세시반의 경성(京城)행열차는,',
#  '석탄(石炭)연기를 자욱이 품기고,',
#  '소리치고 지나가고',
#  '한몸을 끟을기에 강(强)하든.',
#  '공(뽈)이 자력(磁力)을 잃고',
#  '한목음의 물이',
#  '불붓는 목을 축이기에',
#  '넉넉하다,',
#  '젊은 가슴의 피순환(循環)이 잣고,',
#  '두 철각(鐵脚)이 늘어진다,',
#  '검은 기차(汽車)연기(煙氣)와 함께.',
#  '풀은 산(山)이',
#  '아지랑 저쪽으로',
#  '까라안는다,',
#  '청초(淸楚)한 코쓰모쓰는',
#  '오직 하나인 나의 아가씨,',
#  '달빛이 싸늘히 추운 밤이면',
#  '넷 소녀(少女)가 몯견디게 그리워',
#  '코쓰모쓰 핀 정원(庭園)으로 찾어간다.',
#  '코쓰모쓰는',
#  '귀또리 울음에도 수집어지고,',
#  '코쓰모쓰 앞에선 나는',
#  '어렷을적 처럼 부끄러워 지나니,',
#  '내마음은 코쓰모쓰의 마음이오.',
#  '코쓰모쓰의 마음은 내마음이다.',
#  '함께핀 꽃에 처음익은 능금은',
#  '먼저 떨어젓슴니다.',
#  '오날도 가을바람은 그냥붐니다.',
#  '길가에 떨어진 불근 능금은',
#  '지나든 손님이 집어갓슴니다.',
#  '헌집신짝 끟을고',
#  '나여긔 웨왓노',
#  '두만강을 건너서',
#  '쓸쓸한 이 땅에',
#  '남쪽하늘 저밑엔',
#  '따뜻한 내고향',
#  '내어머니 게신곧',
#  '그리운 고향집.',
#  '「이 개 더럽잔니」',
#  '아─ 니 이웃집 덜렁 숳개가',
#  '오날 어슬렁 어슬렁 우리집으로 오더니',
#  '우리집 바두기의 미구멍에다 코를대고',
#  '씩々 내를 맛겟지 더러운줄도 모르고,',
#  '보기 숭해서 막차며 욕해 쫓앗더니',
#  '꼬리를 휘휘 저으며',
#  '너희들보다 어떻겟냐하는 상으로',
#  '뛰여가겟지요 나─ 참.',
#  '나무가 춤을 추면',
#  '바람이 불고,',
#  '나무가 잠잠하면',
#  '바람도 자오,',
#  '왜떡이 씁은 데도',
#  '작고 달다고 하오.',
#  '앙당한 솔나무가지에,',
#  '훈훈한 바람의 날개가 스치고',
#  '얼음 석긴 대동강(大洞江)물에,',
#  '한나절 햇발이 밋그러지다,',
#  '허무러진 성터(城터)에서',
#  '철모르는 여자(女兒)들이',
#  '저도 모를 이국(異國)말로,',
#  '재질대며 뜀을 뛰고.',
#  '난데없는 자동차(自動車)가 밉다.',
#  '눈이 오다, 물이 되는 날.',
#  '재ㅅ빛 하늘에 또 뿌연 내, 그리고,',
#  '크다란 기관차(機關車)는 빼─액─ 울며,',
#  '쪽그만, 가슴은, 울렁거린다.',
#  '리별이 너무 재빠르다, 안탑갑게도,',
#  '사랑하는 사람을,',
#  '일터에서 만나자 하고─.',
#  '더운 손의 맛과, 구슬눈물이 마르기 전',
#  '기차는 꼬리를 산굽으로 돌렷다,',
#  '종달새는 일은봄날',
#  '즐드즌 거리의뒷골목이',
#  '슳더라.',
#  '명량한 봄하늘,',
#  '가벼운 두나래를펴서',
#  '요염한 봄노래가,',
#  '좋더라,',
#  '그러나,',
#  '오날도 구멍뚤린 구두를끌고,',
#  '훌렁훌렁 뒷거리길로,',
#  '고기색기같은나는 헤매나니,',
#  '나래와노래가 없음인가,',
#  '가슴이 답답하구나,',
#  '공상(空想)─',
#  '내마음의 탑(塔)',
#  '나는 말없이 이탑(塔)을 쌓고있다',
#  '명예(名譽)와 허영(虛榮)의 천공(天空)에다',
#  '문허질줄도 몰으고',
#  '한층두층 높이 싸ㅅ는다',
#  '무한(無限)한 나의 공상(空想)─',
#  '그것은 내마음의 바다',
#  '나는 두팔을 펄처서',
#  '나의 바다에서',
#  '자유(自由)로히 헤염친다',
#  '황금(黃金) 지욕(知慾)의 수평선(水平線)을 향(向)하여.',
#  '래일래일 하기에',
#  '물엇더니.',
#  '밤을자고 동틀때',
#  '래일이라고.',
#  '새날을 찯은나는',
#  '잠을자고 돌보니.',
#  '그때는 내일이아니라.',
#  '오늘이더라,',
#  '무리여!',
#  '래일은 없나니',
#  '산들이 두 줄로 줄다를질 치고',
#  '여울이 소리처 목이 자젓다.',
#  '한여름의 햇님이 구름을 타고',
#  '이골작이를 빠르게도 건너련다.',
#  '산(山)등아리에 송아지 뿔처럼',
#  '울뚝불뚝히 어린 바위가 솟구,',
#  '얼룩소의 보드러운 털이',
#  '산(山)등서리에 퍼─렇게 자랏다.',
#  '삼년(三年)만에 고향(故鄕) 찾어드는',
#  '산꼴 나그네의 발거름이',
#  '타박타박 땅을 고눈다.',
#  '벌거숭이 두루미 다리같이...',
#  '헌 신짝이 집행이 끝에',
#  '목아지를 매달아 늘어지고,',
#  '까치가 색기의 날발을 태우려 날뿐,',
#  '골작은 나그네의 마음처럼 고요하다.',
#  '장미 병들어',
#  '옮겨 놓을 이웃이 없도다.',
#  '달랑달랑 외로히',
#  '황마차(幌馬車) 태워 산(山)에 보낼거나,',
#  '뚜— 구슬피',
#  '화륜선(火輪船) 태워 대양(大洋)에 보낼거나,',
#  '프로펠러 소리 요란히',
#  '비행기(飛行機) 태워 성층권(成層圈)에 보낼거나',
#  '이것 저것',
#  '다 구만두고',
#  '자라가는 아들이 꿈을 깨기 전',
#  '이내 가슴에 묻어다오.',
#  '황혼(黃昏)이 짙어지는 길모퉁이에서',
#  '하루종일 시들은 귀를 가만히 기울이면',
#  '땅거미 옮겨지는 발자취 소리,',
#  '발자취 소리를 들을 수 있도록',
#  '나는 총명했든가요.',
#  '이제 어리석게도 모든 것을 깨달은 다음',
#  '오래 마음 깊은 속에',
#  '괴로워하던 수많은 나를',
#  '하나, 둘 제고장으로 돌려보내면',
#  '거리모퉁이 어둠 속으로',
#  '소리 없이 사라지는 흰 그림자,',
#  '흰 그림자들',
#  '연연히 사랑하던 흰 그림자들,',
#  '내 모든 것을 돌려 보낸 뒤',
#  '허전히 뒷골목을 돌아',
#  '황혼(黃昏)처럼 물드는 내 방으로 돌아오면',
#  '신념(信念)이 깊은 의젓한 양(羊)처럼',
#  '하루종일 시름없이 풀포기나 뜯자.',
#  '봄이 오던 아침, 서울 어느 쪼그만 정거장(停車場)에서',
#  '희망(希望)과 사랑처럼 기차(汽車)를 기다려,',
#  '나는 플랫폼(푸라트•폼)에 간신한 그림자를 떨어트리고,',
#  '담배를 피웠다.',
#  '내 그림자는 담배연기 그림자를 날리고',
#  '비둘기 한 떼가 부끄러울 것도 없이',
#  '나래 속을 속, 속, 햇빛에 비춰, 날았다.',
#  '기차(汽車)는 아무 새로운 소식도 없이',
#  '나를 멀리 실어다 주어,',
#  '봄은 다 가고—— 도쿄(東京) 교외(郊外) 어느 조용한',
#  '하숙방(下宿房)에서, 옛 거리에 남은 나를 희망(希望)과',
#  '사랑처럼 그리워한다.',
#  '오늘도 기차(汽車)는 몇 번이나 무의미(無意味)하게 지나가고,',
#  '오늘도 나는 누구를 기다려 정거장(停車場) 가까운 언덕에서 서성거릴게다.',
#  '——아아 젊음은 오래 거기 남아 있거라.',
#  '으스럼히 안개가 흐른다. 거리가 흘러간다. 저 전차(電車), 자동차(自動車), 모든 바퀴가 어디로 흘리워 가는 것일까? 정박(定泊)할 아무 항구(港口)도 없이, 가련한 많은 사람들을 실고서, 안개 속에 잠긴 거리는,',
#  '거리 모통이 붉은 포스트상자를 붙잡고 섰을라면 모든 것이 흐르는 속에 어렴풋이 빛나는 가로등(街路燈), 꺼지지 않는 것은 무슨 상징(象徵)일까? 사랑하는 동무 박(朴)이여! 그리고 김(金)이여! 자네들은 지금 어디 있는가? 끝없이 안개가 흐르는데,',
#  '「새로운 날 아침 우리 다시 정(情)답게 손목을 잡어 보세」 몇 자 적어 포스트 속에 떨어트리고, 밤을 새워 기다리면 금휘장(金徽章)에 금단추(金단추)를 삐었고 거인(巨人)처럼 찬란히 나타나는 배달부(配達夫), 아침과 함께 즐거운 내림(來臨),',
#  '이밤을 하염없이 안개가 흐른다.',
#  '창밖(窓外)에 밤비가 속살거려',
#  '육첩방(六疊房)은 남의 나라,',
#  '시인(詩人)이란 슬픈 천명(天命)인줄 알면서도',
#  '한줄 시(詩)를 적어 볼가,',
#  '땀내와 사랑내 포근히 품긴',
#  '보내주신 학비봉투(學費封套)를 받어',
#  '대학(大學)노—트를 끼고',
#  '늙은 교수(敎授)의 강의(講義) 들으려 간다.',
#  '생각해 보면 어린때 동무를',
#  '하나, 둘, 죄다 잃어 버리고',
#  '나는 무얼 바라',
#  '나는 다만, 홀로 침전(沈澱)하는 것일가?',
#  '인생(人生)은 살기 어렵다는데',
#  '시(詩)가 이렇게 쉽게 씨워지는 것은',
#  '부끄러운 일이다.',
#  '육첩방(六疊房)은 남의 나라',
#  '창밖(窓外)에 밤비가 속살거리는데,',
#  '등불을 밝혀 어둠을 조곰 내몰고,',
#  '시대(時代)처럼 올 아침을 기다리는 최후(最後)의 나,',
#  '나는 나에게 적은 손을 내밀어',
#  '눈물과 위안(慰安)으로 잡는 최초(最初)의 악수(握手).',
#  '봄이 혈관(血管)속에 시내처럼 흘러',
#  '돌, 돌, 시내가 차운 언덕에',
#  '개나리, 진달래, 노오란 배추꽃',
#  '삼동(三冬)을 참어온 나는',
#  '풀포기처럼 피어난다.',
#  '즐거운 종달새야',
#  '어느 이랑에서 즐거웁게 솟쳐라.',
#  '푸르른 하늘은',
#  '아른아른 높기도 한데……',
#  '파란 녹이 낀 구리거울 속에',
#  '내 얼굴이 남어 있는 것은',
#  '어느 왕조(王朝)의 유물(遺物)이기에',
#  '이다지도 욕될가',
#  '나는 나의 참회(懺悔)의 글을 한줄에 주리자',
#  '——만(滿) 이십사 년 일 개월(一個月)을',
#  '무슨 기쁨을 바라 살아 왔든가',
#  '내일이나 모레나 그 어느 즐거운 날에',
#  '나는 또 한줄의 참회록(懺悔錄)을 써야한다.',
#  '——그때 그 젊은 나이에',
#  '왜 그런 부끄런 고백(告白)을 했든가',
#  '밤이면 밤마다 나의 거울을',
#  '손바닥으로 발바닥으로 닦어 보자.',
#  '그러면 어느 운석(隕石) 밑으로 흘러 걸어가는',
#  '슬픈 사람의 뒷모양이',
#  '거울 속에 나타나온다.',
#  '바닷가 햇빛 바른 바위우에',
#  '습한 간(肝)을 펴서 말리우자,',
#  '코카사쓰 산중(山中)에서 도망해온 토끼처럼',
#  '둘러리를 빙빙 돌며 간(肝)을 지키자,',
#  '내가 오래 기르든 여윈 독수리야!',
#  '와서 뜯어 먹어라, 시름없이',
#  '너는 살지고',
#  '나는 여위여야지, 그러나,',
#  '거북이야!',
#  '다시는 용궁(龍宮)의 유혹(誘惑)에 안떨어진다.',
#  '푸로메디어쓰 불상한 푸로메디어쓰',
#  '불 도적한 죄로 목에 맷돌을 달고',
#  '끝없이 침전(沈澱)하는 푸로메디어쓰,',
#  '연륜(年輪)이 자라듯이',
#  '달이 자라는 고요한 밤에',
#  '달같이 외로운 사랑이',
#  '가슴하나 뻐근히',
#  '연륜(年輪)처럼 피어나간다.',
#  '시들은 잎새속에서',
#  '고 빨간 살을 드러내 놓고,',
#  '고추는 방년(芳年)된 아가씬양',
#  '땡볕에 자꾸 익어간다.',
#  '할머니는 바구니를 들고',
#  '밭머리에서 어정거리고',
#  '손가락 너어는 아이는',
#  '할머니 뒤만 따른다.',
#  '붉은 이마에 싸늘한 달이 서리어',
#  '아우의 얼굴은 슬픈 그림이다.',
#  '발걸음을 멈추어',
#  '살그머니 애딘 손을 잡으며',
#  '「늬는 자라 무엇이 되려니」',
#  '「사람이 되지」',
#  '아우의 설은 진정코 설은 대답(對答)이다.',
#  '슬며시 잡았든 손을 놓고',
#  '아우의 얼골을 다시 들여다 본다.',
#  '싸늘한 달이 붉은 이마에 젖어',
#  '아우의 얼골은 슬픈 그림이다.',
#  '순(順)아 너는 내 전(殿)에 언제 들어왔든 것이냐?',
#  '내사 언제 네 전(殿)에 들어갔든 것이냐?',
#  '우리들의 전당(殿堂)은',
#  '고풍(古風)한 풍습(風習)이 어린 사랑의 전당(殿堂)',
#  '순(順)아 암사슴처럼 수정(水晶)눈을 나려감어라.',
#  '난 사자처럼 엉크린 머리를 고루련다.',
#  '우리들의 사랑은 한낱 벙어리이었다.',
#  '성(聖)스런 촛대에 열(熱)한 불이 꺼지기 전(前)',
#  '순(順)아 너는 앞문으로 내 달려라.',
#  '어둠과 바람이 우리 창(窓)에 부닥치기 전(前)',
#  '나는 영원(永遠)한 사랑을 안은채',
#  '뒷문으로 멀리 사라지련다.',
#  '이제 네게는 삼림(森林)속의 아늑한 호수(湖水)가 있고',
#  '내게는 준험(峻嶮)한 산맥(山脈)이 있다.',
#  '발에 터부한 것을 다 빼어 바리고',
#  '황혼(黃昏)이 호수(湖水)우로 걸어 오듯이',
#  '나도 삽분삽분 걸어 보리이까?',
#  '내사 이 호수(湖水)가로',
#  '부르는 이 없이',
#  '불리워 온 것은',
#  '참말 이적(異蹟)이외다.',
#  '오늘 따라',
#  '연정(戀情), 자부(自惚), 시기(猜忌), 이것들이',
#  '자꾸 금메달(金메달)처럼 만져지는구려',
#  '하나, 내 모든 것을 여념(餘念)없이',
#  '물결에 씻어 보내려니',
#  '당신은 호면(湖面)으로 나를 불러 내소서.',
#  '솨— 철석! 파도소리 문살에 부서져',
#  '잠 살포시 꿈이 흐터진다.',
#  '잠은 한낱 검은 고래떼처럼 살래어,',
#  '달랠 아무런 재주도 없다.',
#  '불을 밝혀 잠옷을 정성스리 여미는',
#  '삼경(三更).',
#  '염원(念願).',
#  '동경(憧憬)의 땅 강남(江南)에 또 홍수(洪水)질 것만 싶어,',
#  '바다의 향수(鄕愁)보다 더 호젓해진다.',
#  '괴로운 사람아 괴로운 사람아',
#  '옷자락 물결속에서도 가슴속 깊이 돌돌 샘물이 홀러',
#  '이밤을 더부러 말할이 없도다.',
#  '거리의 소음과 노래 부를수 없도다.',
#  '그신듯이 냇가에 앉았으니',
#  '사랑과 일을 거리에 매끼고 가만히 가만히',
#  '바다로 가자',
#  '후어—ㄴ한 방(房)에',
#  '유언(遺言)은 소리 없는 입놀림.',
#  '바다에 진주(眞珠) 캐려 갔다는 아들',
#  '해녀(海女)와 사랑을 속삭인다는 맏아들',
#  '이 밤에사 돌아오나 내다 봐라——',
#  '평생(平生) 외롭던 아버지의 운명(殞命)',
#  '감기우는 눈에 슬픔이 어린다.',
#  '외딴집에 개가 짖고',
#  '휘영찬 달이 문살에 흐르는 밤.',
#  '쉬는 시간(時間)마다',
#  '나는 창옆(窓옄)으로 갑니다.',
#  '——창(窓)은 산 가르침.',
#  '이글이글 불을 피워주소,',
#  '이 방에 찬것이 서립니다.',
#  '단풍잎 하나',
#  '맴 도나 보니',
#  '아마도 작으마한 선풍(旋風)이 인게웨다.',
#  '그래도 싸느란 유리창에',
#  '햇살이 쨍쨍한 무렵,',
#  '상학종(上學鐘)이 울어만 싶습니다.',
#  '실어다 뿌리는',
#  '바람조차 시원타.',
#  '솔나무 가지마다 샛춤히',
#  '고개를 돌리어 뻐들어지고,',
#  '밀치고',
#  '밀치운다.',
#  '이랑을 넘는 물결은',
#  '폭포처럼 피어오른다.',
#  '해변(海邊)에 아이들이 모인다',
#  '찰찰 손을 씻고 구보로.',
#  '바다는 자꾸 섧어진다.',
#  '갈매기의 노래에………',
#  '돌아다 보고 돌아다 보고',
#  '돌아가는 오늘의 바다여!',
#  '내 노래는 오히려',
#  '섧은 산울림.',
#  '골자기 길에',
#  '떨어진 그림자는',
#  '너무나 슬프구나.',
#  '오후(午後)의 명상(瞑想)은',
#  '아— 졸려.',
#  '가츨가츨한 머리칼은 오막사리 처마끝,',
#  '쉬파람에 콧마루가 서운한 양 간질키오.',
#  '들창(窓) 같은 눈은 가볍게 닫혀',
#  '이 밤에 연정(戀情)은 어둠처럼 골골히 스며드오.',
#  '싸늘한 대리석(大理石) 기둥에 목아지를 비틀어맨 한난계(寒暖計),',
#  '문득 들여다 볼 수 있는 운명(運命)한 오척육촌(五尺六寸)의 허리 가는 수은주(水銀柱),',
#  '마음은 유리관(琉璃管)보다 맑소이다.',
#  '혈관(血管)이 단조(單調)로워 신경질(神經質)인 여론동물(輿論動物),',
#  '가끔 분수(噴水) 같은 냉침(冷침)을 억지로 삼키기에',
#  '정력(精力)을 낭비(浪費)합니다.',
#  '영하(零下)로 손구락질 할 수도 없는 방(房)처럼 치운 겨울보다',
#  '해바라기 만발(滿發)한 팔월(八月) 교정(校庭)이 이상(理想)곱소이다.',
#  '피끓을 그날이——',
#  '어제는 막 소낙비가 퍼붓더니 오늘은 좋은 날세올시다.',
#  '동저고리 바람에 언덕으로, 숲으로 하시구려——',
#  '이렇게 가만 가만 혼자서 귓속이야기를 하였읍니다.',
#  '나는 또 내가 모르는 사이에——',
#  '나는 아마도 진실(眞實)한 세기(世紀)의 계절(季節)을 따라——',
#  '하늘만 보이는 울타리 안을 뛰쳐,',
#  '역사(歷史) 같은 포지슌을 지켜야 봅니다.',
#  '번개, 뇌성, 왁자지근 뚜다려',
#  '머—ㄴ 도화지(都會地)에 낙뢰(落雷)가 있어만 싶다.',
#  '벼루짱 엎어논 하늘로',
#  '살같은 비가 살처럼 쏟아진다.',
#  '손바닥만한 나의 정원(庭園)이',
#  '마음같이 흐린 호수(湖水)되기 일수다.',
#  '바람이 팽이처럼 돈다.',
#  '나무가 머리를 이루 잡지 못한다.',
#  '내 경건(敬虔)한 마음을 모셔드려',
#  '노아때 하늘을 한모금 마시다.',
#  '봄바람을 등진 초록빛 바다',
#  '쏟아질듯 쏟아질듯 위트롭다.',
#  '잔주름 치마폭의 두둥실거리는 물결은,',
#  '오스라질듯 한끝 경쾌(輕快)롭다.',
#  '마스트 끝에 붉은 깃발(旗ㅅ발)이',
#  '여인(女人)의 머리칼처럼 나부낀다.',
#  '이 생생한 풍경(風景)을 앞세우며 뒤세우며',
#  '외—ㄴ 하루 거닐고 싶다.',
#  '——우중충한 오월(五月) 하늘 아래로,',
#  '——바다빛 포기포기에 수(繡)놓은 언덕으로,',
#  '흐르는 달의 흰 물결을 밀쳐',
#  '여윈 나무그림자를 밟으며',
#  '북망산(北邙山)을 향(向)한 발걸음은 무거웁고',
#  '고독(孤獨)을 반려(伴侶)한 마음은 슬프기도 하다.',
#  '누가 있어만 싶은 묘지(墓地)엔 아무도 없고,',
#  '정적(靜寂)만이 군데군데 흰 물결에 폭 젖었다.',
#  '이른 아침 아낙네들은 시들은 생활(生活)을',
#  '바구니 하나 가득 담아 이고……',
#  '업고 지고…… 안고 들고……',
#  '모여드오 자꾸 장에 모여드오.',
#  '가난한 생활(生活)을 골골이 버려놓고',
#  '밀려가고 밀려오고……',
#  '제마다 생활(生活)을 외치오…… 싸우오.',
#  '왼하로 올망졸망한 생활(生活)을',
#  '되질하고 저울질하고 자질하다가',
#  '날이 저물어 아낙네들이',
#  '쓴 생활(生活)과 바꾸어 또 이고 돌아가오.',
#  '오양간 당나귀',
#  '아—ㅇ 외 마디 울음울고,',
#  '당나귀 소리에',
#  '으—아 아 애기 소스라처 깨고,',
#  '등잔에 불을 다오.',
#  '아버지는 당나귀에게',
#  '짚을 한키 담아 주고,',
#  '어머니는 애기에게',
#  '젖을 한모금 먹이고,',
#  '밤은 다시 고요히 잠드오.',
#  '하로도 검푸른 물결에',
#  '흐느적 잠기고…… 잠기고……',
#  '물든 바다를 날아 횡단(橫斷)할고.',
#  '낙엽(落葉)이 된 해초(海草)',
#  '해초(海草)마다 슬프기도 하오.',
#  '서창(西窓)에 걸린 해말간 풍경화(風景畵).',
#  '옷고름 너어는 고아(孤兒)의 서름.',
#  '이제 첫 항해(航海)하는 마음을 먹고',
#  '방바닥에 나딩구오…… 딩구오……',
#  '황혼(黃昏)이 바다가 되어',
#  '오늘도 수많은 배가',
#  '나와 함께 이 물결에 잠겼을게오.',
#  '휙, 휙, 휙,',
#  '소꼬리가 부드러운 채찍질로',
#  '어둠을 쫓아,',
#  '캄, 캄, 어둠이 깊다 깊다 밝으오.',
#  '이제 이 동리(洞里)의 아침이',
#  '풀살 오른 소엉덩이처럼 푸드오.',
#  '이 동리(洞里) 콩죽 먹은 사람들이',
#  '땀물을 뿌려 이 여름을 길렀오.',
#  '잎, 잎, 풀잎마다 땀방울이 맺혔오.',
#  '구김살 없는 이 아침을',
#  '심호흡(深呼吸)하오 또 하오.',
#  '빨래줄에 두 다리를 드리우고',
#  '횐 빨래들이 귓속 이야기 하는 오후(午後),',
#  '쨍쨍한 칠월(七月)햇발은 고요히도',
#  '아담한 빨래에만 달린다.',
#  '잠은 눈을 떴다',
#  '그윽한 유무(幽霧)에서.',
#  '노래하던 종달이',
#  '도망쳐 날아나고,',
#  '지난날 봄타령하던',
#  '금잔디밭은 아니다.',
#  '탑(塔)은 무너졌다,',
#  '붉은 마음의 탑(塔)이——',
#  '손톱으로 새긴 대리석(大理石) 탑(塔)이——',
#  '하루저녁 폭풍(暴風)에 여지(餘地)없이도,',
#  '오오 황폐(荒廢)의 쑥밭,',
#  '눈물과 목메임이여!',
#  '꿈은 깨어졌다',
#  '탑(塔)은 무너졌다.',
#  '시계(時計)가 자근자근 가슴을 따려',
#  '불안(不安)한 마음을 산림(山林)이 부른다.',
#  '천년(千年) 오래인 연륜(年輪)에 짜들은 유암(幽暗)한 산림(山林)이,',
#  '고달픈 한몸을 포옹(抱擁)할 인연(因緣)을 가졌나보다.',
#  '산림(山林)의 검은 파동(波動)우으로부터',
#  '어둠은 어린 가슴을 짓밟고',
#  '이파리를 흔드는 저녁바람이',
#  '솨— 공포(恐怖)에 떨게 한다.',
#  '멀리 첫여름의 개구리 재질댐에',
#  '흘러간 마을의 과거(過去)는 아질타.',
#  '나무틈으로 반짝이는 별만이',
#  '새날의 희망(希望)으로 나를 이끈다.',
#  '사이좋은 정문(正門)의 두 돌기둥 끝에서',
#  '오색기(五色旗)와 태양기(太陽旗)가 춤을 추는 날,',
#  '금을 그은 지역(地域)의 아이들이 즐거워하다.',
#  '아이들에게 하루의 건조(乾燥)한 학과(學課)로',
#  '해말간 권태(倦怠)가 깃들고',
#  '「모순(矛盾)」 두 자를 이해(理解)치 못하도록',
#  '못하도록 머리가 단순(單純)하였구나.',
#  '이런 날에는',
#  '잃어버린 완고(頑固)하던 형(兄)을',
#  '부르고 싶다.',
#  '거리가 바둑판처럼 보이고,',
#  '강물(江水)이 배암의 새끼처럼 기는',
#  '산(山) 우에까지 왔다.',
#  '아직쯤은 사람들이',
#  '바둑돌처럼 버려있으리라.',
#  '한나절의 태양(太陽)이',
#  '함석지붕에만 비치고,',
#  '굼벵이 걸음을 하던 기차(汽車)가',
#  '정거장(停車場)에 섰다가 검은 내를 토(吐)하고',
#  '또 걸음발을 탄다.',
#  '텐트 같은 하늘이 무너져',
#  '이 거리를 덮을까 궁금하면서',
#  '좀 더 높은 데로 올라가고 싶다.',
#  '저쪽으로 황토(黃土) 실은 이 땅 봄바람이',
#  '호인(胡人)의 물레바퀴처럼 돌아 지나고',
#  '아롱진 사월(四月) 태양(太陽)의 손길이',
#  '벽(壁)을 등진 섧은 가슴마다 올올히 만진다.',
#  '지도(地圖)째기 놀음에 뉘 땅인 줄 모르는 애 둘이',
#  '한 뼘 손가락이 짧음을 한(恨)하며',
#  '아서라! 가뜩이나 엷은 평화(平和)가',
#  '깨어질까 근심스럽다.',
#  '한간(一間) 계사(鷄舍) 그 넘어 창공(蒼空)이 깃들어',
#  '자유(自由)의 향토(鄕土)를 잊은 닭들이',
#  '시들은 생활(生活)을 주잘대고',
#  '생산(生産)의 고로(苦勞)를 부르짖었다.',
#  '음산(陰酸)한 계사(鷄舍)에서 쏠려나온',
#  '외래종(外來種) 레구홍,',
#  '학원(學園)에서 새무리가 밀려나오는',
#  '삼월(三月)의 맑은 오후(午後)도 있다.',
#  '닭들은 녹아드는 두엄을 파기에',
#  '아담(雅淡)한 두 다리가 분주(奔走)하고',
#  '굶주렸던 주둥이(주두리)가 바즈런하다.',
#  '두 눈이 붉게 여므도록——',
#  '불 꺼진 화독(火독)을',
#  '안고 도는 겨울밤은 깊었다.',
#  '재(灰)만 남은 가슴이',
#  '문풍지 소리에 떤다.',
#  '안아보고싶게 귀여운',
#  '산비들기 일곱마리',
#  '하늘끝까지 보일듯이 맑은 공일날 아침에',
#  '벼를 거두어 빤빤한 논에',
#  '앞을 다투어 모이를 주으며',
#  '어려운 이야기를 주고 받으오',
#  '날신한 두나래로 조용한 공기를 흔들어',
#  '두마리가 나오',
#  '집에 새끼 생각이 나는 모양이오.',
#  '그 여름날',
#  '열정(熱情)의 포푸라는',
#  '오려는 창공(蒼空)의 푸른 젖가슴을',
#  '어루만지려',
#  '팔을 펼쳐 흔들거렸다.',
#  '끓는 태양(太陽) 그늘 좁다란 지점(地點)에서',
#  '천막(天幕) 같은 하늘 밑에서',
#  '떠들던 소나기',
#  '그리고 번개를,',
#  '춤추던 구름은 이끌고',
#  '남방(南方)으로 도망하고,',
#  '높다랗게 창공(蒼空)은 한 폭으로',
#  '가지 위에 퍼지고',
#  '둥근 달과 기러기를 불러왔다.',
#  '푸드른 어린 마음이 이상(理想)에 타고,',
#  '그의 동경(憧憬)의 날 가을에',
#  '조락(凋落)의 눈물을 비웃다.',
#  '삶은 오늘도 죽음의 서곡(序曲)을 노래하였다.',
#  '이 노래가 언제나 끝나랴',
#  '세상사람은——',
#  '뼈를 녹여내는 듯한 삶의 노래에',
#  '춤을 춘다.',
#  '사람들은 해가 넘어가기 전',
#  '이 노래 끝의 공포(恐怖)를',
#  '생각할 사이가 없었다.',
#  '하늘 복판에 알새기 듯이',
#  '이 노래를 부른 자(者)가 누구뇨',
#  '그리고 소낙비 그친 뒤같이도',
#  '이 노래를 그친 자(者)가 누구뇨',
#  '죽고 뼈만 남은',
#  '죽음의 승리자(勝利者) 위인(偉人)들!',
#  '초 한 대——',
#  '내 방에 품긴 향내를 맡는다.',
#  '광명(光明)의 제단(祭壇)이 무너지기 전',
#  '나는 깨끗한 제물(祭物)을 보았다.',
#  '염소의 갈비뼈 같은 그의 몸,',
#  '그의 생명(生命)인 심지(心志)까지',
#  '백옥(白玉) 같은 눈물과 피를 흘려',
#  '불살려 버린다.',
#  '그리고도 책상머리에 아롱거리며',
#  '선녀처럼 촛불은 춤을 춘다.',
#  '매를 본 꿩이 도망하듯이',
#  '암흑(暗黑)이 창구멍으로 도망한',
#  '나의 방에 품긴',
#  '제물(祭物)의 위대한 향내(香內)를 맛보노라.',
#  '까치가 울어서',
#  '아무도 못들은',
#  '산울림,',
#  '까치가 들었다,',
#  '저혼자 들었다,',
#  '누나의 얼굴은',
#  '해바라기 얼굴',
#  '해가 금방 뜨자',
#  '일터에 간다.',
#  '해바라기 얼굴은',
#  '누나의 얼굴',
#  '얼굴이 숙어들어',
#  '집으로 온다.',
#  '잔디밭에서 이야기 했다.',
#  '아무게도 아르켜 주지말고',
#  '우리둘만 알자고 약속했다.',
#  '귀뜰귀뜰',
#  '귀뜨라미와 나와',
#  '달밝은 밤에 이야기했다.',
#  '우리집에는',
#  '닭도 없단다.',
#  '애기가 젖달라 울어서',
#  '새벽이 된다.',
#  '시계도 없단다.',
#  '다만',
#  '애기가 젖달라 보채어',
#  '달조각을 주으려',
#  '그믐밤 반디불은',
#  '부서진 달조각,',
#  '가자 가자 가자',
#  '숲으로 가자',
#  '바다도 푸르고',
#  '하늘도 푸르고',
#  '바다도 끝없고',
#  '하늘도 끝없고',
#  '바다에 돌던지고',
#  '하늘에 침뱉고',
#  '바다는 벙글',
#  '하늘은 잠잠.',
#  '똑, 똑, 똑,',
#  '문좀 열어 주세요',
#  '하루밤 자고 갑시다.',
#  '밤은 깊고 날은 추운데',
#  '거 누굴까?',
#  '문열어 주고 보니',
#  '검둥이의 꼬리가',
#  '거짓부리한걸.',
#  '꼬기요, 꼬기요,',
#  '달걀 낳았다.',
#  '간난아 어서 집어 가거라',
#  '간난이 뛰어가 보니',
#  '달걀은 무슨 달걀,',
#  '고놈의 암탉이',
#  '대낮에 새빨간',
#  '거짓부리 한걸.',
#  '지난밤에',
#  '눈이 소오복이 왔네',
#  '지붕이랑',
#  '길이랑 밭이랑',
#  '추워 한다고',
#  '덮어주는 이불인가바',
#  '그러기에',
#  '추운 겨을에만 나리지',
#  '가을지난 마당은 하이얀종이',
#  '참새들이 글씨를 공부하지요.',
#  '째액째액 입으로 받아읽으며',
#  '두발로는 글씨를 연습하지요.',
#  '하로종일 글씨를 공부하여도',
#  '짹자한자 밖에는 더못쓰는걸.',
#  '누나 쓰다버린 습자지는',
#  '두었다간 뭣에 쓰나요?',
#  '그런줄 몰랐드니',
#  '습자지에다 내버선 놓고',
#  '가위로 오려',
#  '버선본 만드는걸.',
#  '어머니',
#  '내가 쓰다버린 몽당연필은',
#  '천우에다 버선본 놓고',
#  '침발려 점을 찍곤',
#  '내버선 만드는걸.',
#  '바닷가 사람',
#  '물고기 잡아 먹고 살고',
#  '산골엣 사람',
#  '감자 구어 먹고 살고',
#  '별나라 사람',
#  '무얼 먹고 사나.',
#  '산골작이 오막사리 낮은 굴뚝엔',
#  '몽기몽기 웨인연기 대낮에 솟나,',
#  '감자를 굽는게지 총각애들이',
#  '깜박깜박 검은눈이 모여 앉어서',
#  '입술에 꺼멓게 숯을 바르고',
#  '옛이야기 한커리에 감자 하나씩.',
#  '살랑살랑 솟아나네 감자 굽는내.',
#  '아씨처럼 나린다',
#  '보슬보슬 해ㅅ비',
#  '맞아주자 다같이',
#  '옥수숫대 처럼 크게',
#  '닷자엿자 자라게',
#  '햇님이 웃는다',
#  '나보고 웃는다.',
#  '하늘다리 놓였다',
#  '알롱알롱 무지개',
#  '노래하자 즐겁게',
#  '동무들아 이리 오나',
#  '다같이 춤을추자',
#  '즐거워 웃는다',
#  '비오는날 저녁에 기왓장내외',
#  '잃어버린 외아들 생각나선지',
#  '꼬부라진 잔등을 어루만지며',
#  '쭈룩쭈룩 구슬피 울음웁니다.',
#  '대궐지붕 위에서 기왓장내외',
#  '아름답든 옛날이 그리워선지',
#  '주름잡힌 얼굴을 어루만지며',
#  '물끄럼히 하늘만 쳐다봅니다.',
#  '빨래줄에 걸어논',
#  '요에다 그린지도',
#  '지난밤에 내동생',
#  '오줌싸 그린지도',
#  '꿈에 가본 엄마계신',
#  '별나라 지돈가?',
#  '돈벌러간 아빠계신',
#  '만주땅 지돈가?',
#  '아롱아롱 조개껍대기',
#  '울언니 바다가에서',
#  '주어온 조개껍대기',
#  '여긴여긴 북쪽나라요',
#  '조개는 귀여운선물',
#  '장난감 조개껍대기',
#  '데굴데굴 굴리며놀다',
#  '짝잃은 조개껍대기',
#  '한짝을 그리워하네',
#  '나처럼 그리워하네',
#  '물소리 바다물소리.',
#  '나 보기가 역겨워',
#  '가실 때에는',
#  '말없이 고이 보내드리오리다.',
#  '영변(寧邊)에 약산(藥山)',
#  '진달래꽃',
#  '아름따다 가실 길에 뿌리오리다.',
#  '가시는 걸음 걸음',
#  '놓인 그 꽃을',
#  '사뿐히 즈려밟고 가시옵소서.',
#  '죽어도 아니 눈물 흘리오리다.',
#  '엄마야 누나야 강변 살자,',
#  '뜰에는 반짝는 금모래빛,',
#  '뒷문 밖에는 갈잎의 노래',
#  '엄마야 누나야 강변 살자.',
#  '봄 가을없이 밤마다 돋는 달도',
#  "예전엔 미처 몰랐어요.'",
#  '이렇게 사무치게 그립을줄도',
#  '달이 암만 밝아도 쳐다볼줄을',
#  '이제금 저 달이 설움인줄은',
#  '먼 훗날 당신이 찾으시면',
#  "그때에 내 말이 `잊었노라'",
#  '당신이 속으로 나무라면',
#  "`무척 그리다가 잊었노라'",
#  '그래도 당신이 나무라면',
#  "`믿기지 않아서 잊었노라'",
#  '오늘도 어제도 아니 잊고',
#  "먼 훗날 그때에 `잊었노라'",
#  '산산이 부서진 이름이어!',
#  '허공중(虛空中)에 헤어진 이름이어!',
#  '불러도 주인(主人)없는 이름이어!',
#  '부르다가 내가 죽을 이름이어!',
#  '심중(心中)에 남아있는 말 한마디는',
#  '끝끝내 마저하지 못하였구나.',
#  '사랑하던 그 사람이어!',
#  '붉은 해는 서산(西山) 마루에 걸리었다.',
#  '사슴이의 무리도 슬피 운다.',
#  '떨어져 나가앉은 산 위에서',
#  '나는 그대의 이름을 부르노라.',
#  '설움에 겹도록 부르노라.',
#  '부르는 소리는 비껴가지만',
#  '하늘과 땅 사이가 너무 넓구나.',
#  '선 채로 이 자리에 돌이 되어도',
#  '걷잡지 못할만한 나의 이 설움,',
#  '저무는 봄저녁에 져가는 꽃잎,',
#  '져가는 꽃잎들은 나부끼어라.',
#  '예로부터 일러오며 하는 말에도',
#  '바다가 변하야 뽕나무밭 된다고.',
#  '그러하다, 아름답은 청춘의 때의',
#  '있다던 온갖 것은 눈에 설고',
#  '다시금 낯 모르게 되나니,',
#  '보아라, 그대여, 서럽지 않은가,',
#  '봄에도 삼월의 져가는 날에',
#  '붉은 피같이도 쏟아져 나리는',
#  '저기 저 꽃잎들을, 저기 저 꽃잎들을',
#  '우리 두 사람은',
#  '키높이 가득 자란 보리밭, 밭고랑 위에 앉았어라.',
#  '일을 필하고 쉬이는 동안의 기쁨이어.',
#  '지금 두 사람의 이야기에는 꽃이 필 때.',
#  '오오 빛나는 태양은 나려 쪼이며',
#  '새무리들도 즐겁은 노래, 노래 불러라.',
#  '오오 은혜여, 살아있는 몸에는 넘치는 은혜여',
#  '모든 은근스럽음이 우리의 맘 속을 차지하여라.',
#  '세계의 끝은 어디? 자애의 하늘은 넓게도 덮혔는데,',
#  '우리 두 사람은 일하며, 살아있어서,',
#  '하늘과 태양을 바라보아라, 날마다 날마다도,',
#  '새라새롭은 환희를 지어내며, 늘 같은 땅 위에서.',
#  '다시한번 활기있게 웃고나서, 우리 두 사람은',
#  '바람에 일리우는 보리밭 속으로',
#  '호미들고 들어갔어라, 가즈런히 가즈런히',
#  '걸어나아가는 기쁨이어, 오오 생명의 향상이어.',
#  '홀로 잠들기가 참말 외로와요',
#  '맘에는 사무치도록 그리워와요',
#  '이리도 무던히',
#  '아주 얼굴조차 잊힐듯해요.',
#  '벌써 해가 지고 어둡는대요,',
#  '이곳은 인천에 제물포, 이름난 곳,',
#  '부슬부슬 오는 비에 밤이 더디고',
#  '바다바람이 춥기만 합니다.',
#  '다만 고요히 누워 들으면',
#  '하이얗게 밀어드는 봄 밀물이',
#  '눈앞을 가루막고 흐느낄 뿐이야요.',
#  '희멀끔하여 떠돈다, 하늘 위에,',
#  '빛죽은 반달이 언제 올랐나!',
#  '바람은 나온다, 저녁은 춥구나,',
#  '흰 물가엔 뚜렷이 해가 드누나.',
#  '어둑컴컴한 풀없는 들은',
#  '찬 안개 우흐로 떠흐른다.',
#  '아, 겨울은 깊었다, 내 몸에는,',
#  '가슴이 무너져 나려앉는 이 설움아!',
#  '가는 님은 가슴에 사랑까지 없애고 가고',
#  '젊음은 늙음으로 바뀌어든다.',
#  '들가시나무의 밤드는 검은 가지',
#  '잎새들만 저녁빛에 희그무려히 꽃지듯한다.',
#  '봄에 부는 바람, 바람부는 봄,',
#  '적은가지 흔들리는 부는 봄바람,',
#  '내 가슴 흔들리는 바람, 부는 봄,',
#  '봄이라 바람이라 이내 몸에는',
#  '꽃이라 술잔이라 하며 우노라.',
#  '실버드나무의 검으스렷한 머리결인 낡은 가지에',
#  '제비의 넓은 깃나래의 감색 치마에',
#  '술집의 창 옆에, 보아라, 봄이 앉았지 않은가.',
#  '소리도 없이 바람은 불며, 울며, 한숨지워라.',
#  '아무런 줄도 없이 섧고 그립은 새카만 봄밤',
#  '보드랍은 습기는 떠돌며 땅을 덮어라.',
#  '거울들어 마주 온 내 얼굴을',
#  '좀 더 미리부터 알았던들!',
#  '늙는 날 죽는 날을',
#  '사람은 다 모르고 사는 탓에,',
#  '오오 오직 이것이 참이라면,',
#  '그러나 내 세상이 어디인지?',
#  '지금부터 두여덟 좋은 연광',
#  ...]

# %%
from langchain.docstore.document import Document

# %%
# 2️⃣ 문장들을 Document 형태로 변환
documents = [Document(page_content=text) for text in texts]

# %%
documents
# Out:
# [Document(metadata={}, page_content='죽는 날까지 하늘을 우러러'),
#  Document(metadata={}, page_content='한 점 부끄럼이 없기를,'),
#  Document(metadata={}, page_content='잎새에 이는 바람에도'),
#  Document(metadata={}, page_content='나는 괴로워했다.'),
#  Document(metadata={}, page_content='별을 노래하는 마음으로'),
#  Document(metadata={}, page_content='모든 죽어가는 것을 사랑해야지'),
#  Document(metadata={}, page_content='그리고 나한테 주어진 길을'),
#  Document(metadata={}, page_content='걸어가야겠다.'),
#  Document(metadata={}, page_content='오늘 밤에도 별이 바람에 스치운다.'),
#  Document(metadata={}, page_content='산모퉁이를 돌아 논가 외딴 우물을 홀로 찾아가선 가만히 들여다봅니다.'),
#  Document(metadata={}, page_content='우물 속에는 달이 밝고 구름이 흐르고 하늘이 펼치고 파아란 바람이 불고 가을이 있습니다.'),
#  Document(metadata={}, page_content='그리고 한 사나이가 있습니다.'),
#  Document(metadata={}, page_content='어쩐지 그 사나이가 미워져 돌아갑니다.'),
#  Document(metadata={}, page_content='돌아가다 생각하니 그 사나이가 가엾어집니다.'),
#  Document(metadata={}, page_content='도로 가 들여다보니 사나이는 그대로 있습니다.'),
#  Document(metadata={}, page_content='다시 그 사나이가 미워져 돌아갑니다.'),
#  Document(metadata={}, page_content='돌아가다 생각하니 그 사나이가 그리워집니다.'),
#  Document(metadata={}, page_content='우물 속에는 달이 밝고 구름이 흐르고 하늘이 펼치고 파아란 바람이 불고 가을이 있고 추억처럼 사나이가 있습니다.'),
#  Document(metadata={}, page_content='쫓아오든 햇빛인데'),
#  Document(metadata={}, page_content='지금 교회당 꼭대기'),
#  Document(metadata={}, page_content='십자가에 걸리었습니다.'),
#  Document(metadata={}, page_content='첨탑(尖塔)이 저렇게도 높은데'),
#  Document(metadata={}, page_content='어떻게 올라갈 수 있을까요.'),
#  Document(metadata={}, page_content='종소리도 들려 오지 않는데'),
#  Document(metadata={}, page_content='휘파람이나 불며 서성거리다가'),
#  Document(metadata={}, page_content='괴로웠던 사나이'),
#  Document(metadata={}, page_content='행복한 예수 그리스도에게'),
#  Document(metadata={}, page_content='처럼'),
#  Document(metadata={}, page_content='십자가가 허락된다면'),
#  Document(metadata={}, page_content='모가지를 드리우고'),
#  Document(metadata={}, page_content='꽃처럼 피어나는 피를'),
#  Document(metadata={}, page_content='어두워 가는 하늘 밑에'),
#  Document(metadata={}, page_content='조용히 흘리겠습니다.'),
#  Document(metadata={}, page_content='바람이 어디로부터 불어 와'),
#  Document(metadata={}, page_content='어디로 불려 가는 것일까'),
#  Document(metadata={}, page_content='바람이 부는데'),
#  Document(metadata={}, page_content='내 괴로움에는 이유가 없다.'),
#  Document(metadata={}, page_content='내 괴로움에는 이유가 없을까'),
#  Document(metadata={}, page_content='단 한 여자를 사랑한 일도 없다.'),
#  Document(metadata={}, page_content='시대를 슬퍼한 일도 없다.'),
#  Document(metadata={}, page_content='바람이 자꼬 부는데'),
#  Document(metadata={}, page_content='내 발이 반석 우에 섰다.'),
#  Document(metadata={}, page_content='강물이 자꼬 흐르는데'),
#  Document(metadata={}, page_content='내 발이 언덕 우에 섰다.'),
#  Document(metadata={}, page_content='고향에 돌아온 날 밤에'),
#  Document(metadata={}, page_content='내 백골(白骨)이 따라와 한방에 누웠다.'),
#  Document(metadata={}, page_content='어둔 방은 우주로 통하고'),
#  Document(metadata={}, page_content='하늘에선가 소리처럼 바람이 불어 온다.'),
#  Document(metadata={}, page_content='어둠 속에 곱게 풍화작용(風化作用)하는'),
#  Document(metadata={}, page_content='백골을 들여다보며'),
#  Document(metadata={}, page_content='눈물짓는 것이 내가 우는 것이냐'),
#  Document(metadata={}, page_content='백골이 우는 것이냐'),
#  Document(metadata={}, page_content='아름다운 혼이 우는 것이냐'),
#  Document(metadata={}, page_content='지조 높은 개는'),
#  Document(metadata={}, page_content='밤을 새워 어둠을 짖는다.'),
#  Document(metadata={}, page_content='어둠을 짖는 개는'),
#  Document(metadata={}, page_content='나를 쫓는 것일 게다.'),
#  Document(metadata={}, page_content='가자 가자'),
#  Document(metadata={}, page_content='쫓기우는 사람처럼 가자'),
#  Document(metadata={}, page_content='백골 몰래'),
#  Document(metadata={}, page_content='아름다운 또 다른 고향에 가자.'),
#  Document(metadata={}, page_content='계절이 지나가는 하늘에는'),
#  Document(metadata={}, page_content='가을로 가득 차 있습니다.'),
#  Document(metadata={}, page_content='나는 아무 걱정도 없이'),
#  Document(metadata={}, page_content='가을 속의 별들을 다 헤일 듯합니다...'),
#  Document(metadata={}, page_content='가슴 속에 하나 둘 새겨지는 별을'),
#  Document(metadata={}, page_content='이제 다 못 헤는 것은'),
#  Document(metadata={}, page_content='쉬이 아침이 오는 까닭이요,'),
#  Document(metadata={}, page_content='내일 밤이 남은 까닭이요,'),
#  Document(metadata={}, page_content='아직 나의 청춘이 다하지 않은 까닭입니다.'),
#  Document(metadata={}, page_content='별 하나에 추억과'),
#  Document(metadata={}, page_content='별 하나에 사랑과'),
#  Document(metadata={}, page_content='별 하나에 쓸쓸함과'),
#  Document(metadata={}, page_content='별 하나에 동경과'),
#  Document(metadata={}, page_content='별 하나에 시와'),
#  Document(metadata={}, page_content='별 하나에 어머니, 어머니'),
#  Document(metadata={}, page_content="어머님, 나는 별 하나에 아름다운 말 한 마디씩 불러 봅니다. 소학교 때 책상을 같이했던 아이들의 이름과, 패, 경, 옥 이런 이국 소녀들의 이름과, 벌써 아기 어머니 된 계집애들의 이름과, 가난한 이웃 사람들의 이름과, 비둘기, 강아지, 토끼, 노새, 노루, '프랑시스 잠', '라이너 마리아 릴케', 이런 시인의 이름을 불러 봅니다."),
#  Document(metadata={}, page_content='이네들은 너무나 멀리 있습니다.'),
#  Document(metadata={}, page_content='별이 아스라이 멀 듯이,'),
#  Document(metadata={}, page_content='어머님,'),
#  Document(metadata={}, page_content='그리고 당신은 멀리 북간도에 계십니다'),
#  Document(metadata={}, page_content='나는 무엇인지 그리워'),
#  Document(metadata={}, page_content='이 많은 별빛이 내린 언덕 위에'),
#  Document(metadata={}, page_content='내 이름자를 써 보고,'),
#  Document(metadata={}, page_content='흙으로 덮어 버리었습니다.'),
#  Document(metadata={}, page_content='딴은, 밤을 새워 우는 벌레는'),
#  Document(metadata={}, page_content='부끄러운 이름을 슬퍼하는 까닭입니다.'),
#  Document(metadata={}, page_content='그러나 겨울이 지나고 나의 별에도 봄이 오면'),
#  Document(metadata={}, page_content='무덤 위에 파란 잔디가 피어나듯이'),
#  Document(metadata={}, page_content='내 이름자 묻힌 언덕 위에도'),
#  Document(metadata={}, page_content='자랑처럼 풀이 무성할 게외다.'),
#  Document(metadata={}, page_content='살구나무 그늘로 얼굴을 가리고, 병원 뒤뜰에 누워, 젊은 여자가 흰 옷 아래로 하얀 다리를 드러내 놓고 일광욕을 한다. 한나절이 기울도록 가슴을 앓는 다는 이 여자를 찾아오는 이, 나비 한 마리도 없다. 슬프지도 않은 살구나무 가지에는 바람조차 없다.'),
#  Document(metadata={}, page_content='나도 모를 아픔을 오래 참다 처음으로 이 곳에 찾아 왔다. 그러나 나의 늙은 의사는 젊은이의 병을 모른다. 나한테는 병이 없다고 한다. 이 지나친 시련, 이 지나친 피로, 나는 성내서는 안 된다.'),
#  Document(metadata={}, page_content='여자는 자리에서 일어나 옷깃을 여미고 화단에서 금잔화 한 포기를 따 가슴에 꽂고 병실 안으로 사라진다. 나는 그 여자의 건강이 ---- 아니 내 건강도 속히 회복되기를 바라며 그가 누웠던 자리에 누워 본다.'),
#  Document(metadata={}, page_content='잃어버렸습니다.'),
#  Document(metadata={}, page_content='무얼 어디다 잃었는지 몰라'),
#  Document(metadata={}, page_content='두 손의 호주머니를 더듬어'),
#  Document(metadata={}, page_content='길에 나갑니다.'),
#  Document(metadata={}, page_content='돌과 돌과 돌이 끝없이 연달아'),
#  Document(metadata={}, page_content='길은 돌담을 끼고 갑니다.'),
#  Document(metadata={}, page_content='담은 쇠문을 굳게 담아'),
#  Document(metadata={}, page_content='길 위에 긴 그림자를 드리우고'),
#  Document(metadata={}, page_content='길은 아침에서 저녁으로'),
#  Document(metadata={}, page_content='저녁에서 아침으로 통했습니다.'),
#  Document(metadata={}, page_content='돌담을 더듬어 눈물짓다'),
#  Document(metadata={}, page_content='쳐다 보면 하늘은 부끄럽게 푸릅니다.'),
#  Document(metadata={}, page_content='풀 한 포기 없는 이 길을 걷는 것은'),
#  Document(metadata={}, page_content='담 저 쪽에 내가 남아 있는 까닭이고'),
#  Document(metadata={}, page_content='내가 사는 것은 다만'),
#  Document(metadata={}, page_content='잃은 것을 찾는 까닭입니다. (1941.9.31)'),
#  Document(metadata={}, page_content='세상으로부터 돌아오듯이 이제 내 좁은방에 돌아와 불을 끄옵니다.'),
#  Document(metadata={}, page_content='불을 켜 두는 것은 너무나 피로롭은 일이옵니다.'),
#  Document(metadata={}, page_content='그것은 낮의 연장(延長)이옵기에-'),
#  Document(metadata={}, page_content='이제 창窓을 열어 공기(空氣)를 바꾸어 들여야 할터인데'),
#  Document(metadata={}, page_content='밖을 가만히 내다 보아야 방(房)안과 같이 어두어 꼭 세상 같은데'),
#  Document(metadata={}, page_content='비를 맞고 오던 길이 그대로 비속에 젖어 있사옵니다.'),
#  Document(metadata={}, page_content='하로의 울분을 씻을바 없어 가만히 눈을 감으면'),
#  Document(metadata={}, page_content='마음속으로 흐르는 소리,'),
#  Document(metadata={}, page_content='이제,'),
#  Document(metadata={}, page_content='사상(思想)이 능금처럼 저절로 익어 가옵니다.'),
#  Document(metadata={}, page_content='어제도 가고 오늘도 갈'),
#  Document(metadata={}, page_content='나의 길 새로운 길'),
#  Document(metadata={}, page_content='민들레가 피고 까치가 날고'),
#  Document(metadata={}, page_content='아가씨가 지나고 바람이 일고'),
#  Document(metadata={}, page_content='나의 길은 언제나 새로운 길'),
#  Document(metadata={}, page_content='오늘도... 내일도 ...'),
#  Document(metadata={}, page_content='내를 건너서 숲으로'),
#  Document(metadata={}, page_content='고개를 넘어서 마을로'),
#  Document(metadata={}, page_content='봄날 아침도 아니고'),
#  Document(metadata={}, page_content='여름, 가을, 겨울,'),
#  Document(metadata={}, page_content='그런 날 아침도 아닌 아침에'),
#  Document(metadata={}, page_content='빠알간 꽃이 피어났네,'),
#  Document(metadata={}, page_content='햇빛이 프른데,'),
#  Document(metadata={}, page_content='그 전날 밤에'),
#  Document(metadata={}, page_content='모든것이 마련되었네,'),
#  Document(metadata={}, page_content='사랑은 뱀과 함께'),
#  Document(metadata={}, page_content='독(毒)은 어린꽃과 함께.'),
#  Document(metadata={}, page_content='하얗게 눈이 덮이었고'),
#  Document(metadata={}, page_content='전신주(電信柱)가 잉잉 울어'),
#  Document(metadata={}, page_content='하나님 말씀이 들려온다.'),
#  Document(metadata={}, page_content='무슨 계시(啓示)일까.'),
#  Document(metadata={}, page_content='빨리'),
#  Document(metadata={}, page_content='봄이 오면'),
#  Document(metadata={}, page_content='죄(罪)를 짓고'),
#  Document(metadata={}, page_content='눈이'),
#  Document(metadata={}, page_content='밝아'),
#  Document(metadata={}, page_content='이브가 해산(解産)하는 수고를 다하면'),
#  Document(metadata={}, page_content='무화과(無花果) 잎사귀로 부끄런 데를 가리고'),
#  Document(metadata={}, page_content='나는 이마에 땀을 흘려야겠다.'),
#  Document(metadata={}, page_content='다들 죽어가는 사람들에게'),
#  Document(metadata={}, page_content='검은 옷을 입히시오.'),
#  Document(metadata={}, page_content='다들 살아가는 사람들에게'),
#  Document(metadata={}, page_content='흰 옷을 입히시오.'),
#  Document(metadata={}, page_content='그리고 한 침실(寢室)에'),
#  Document(metadata={}, page_content='가지런히 잠을 재우시오'),
#  Document(metadata={}, page_content='다들 울거들랑'),
#  Document(metadata={}, page_content='젖을 먹이시오'),
#  Document(metadata={}, page_content='이제 새벽이 오면'),
#  Document(metadata={}, page_content='나팔소리 들려 올 게외다.'),
#  Document(metadata={}, page_content='거 나를 부르는 것이 누구요.'),
#  Document(metadata={}, page_content='가랑잎 이파리 푸르러 나오는 그늘인데,'),
#  Document(metadata={}, page_content='나 아직 여기 호흡이 남아 있소.'),
#  Document(metadata={}, page_content='한 번도 손들어 보지 못한 나를'),
#  Document(metadata={}, page_content='손들어 표할 하늘도 없는 나를'),
#  Document(metadata={}, page_content='어디에 내 한 몸 둘 하늘이 있어'),
#  Document(metadata={}, page_content='나를 부르는 것이오?'),
#  Document(metadata={}, page_content='일이 마치고 내 죽는 날 아침에는'),
#  Document(metadata={}, page_content='서럽지도 않은 가랑잎이 떨어질 텐데……'),
#  Document(metadata={}, page_content='나를 부르지 마오.'),
#  Document(metadata={}, page_content='흰 수건이 검은 머리를 두르고'),
#  Document(metadata={}, page_content='흰 고무신이 거친 발에 걸리우다'),
#  Document(metadata={}, page_content='흰 저고리 치마가 슬픈 몸집을 가리고'),
#  Document(metadata={}, page_content='흰 띠가 가는 허리를 질끈 동이다'),
#  Document(metadata={}, page_content='태양을 사모하는 아이들아'),
#  Document(metadata={}, page_content='별을 사랑하는 아이들아'),
#  Document(metadata={}, page_content='밤이 어두웠는데'),
#  Document(metadata={}, page_content='눈감고 가거라.'),
#  Document(metadata={}, page_content='가진 바 씨앗을'),
#  Document(metadata={}, page_content='뿌리면서 가거라.'),
#  Document(metadata={}, page_content='발부리에 돌이 체이거든'),
#  Document(metadata={}, page_content='감았던 눈을 와짝 떠라.'),
#  Document(metadata={}, page_content='호젓한 세기(世紀)의 달을 딿아'),
#  Document(metadata={}, page_content='알뜻 모를뜻 한데로 거닐과저!'),
#  Document(metadata={}, page_content='아닌 밤중에 튀기듯이'),
#  Document(metadata={}, page_content='잠자리를 뛰처'),
#  Document(metadata={}, page_content='끝없는 광야(廣野)를 홀로 거니는'),
#  Document(metadata={}, page_content='사람의 심사(心思)는 외로우러니'),
#  Document(metadata={}, page_content='아─ 이 젊은이는'),
#  Document(metadata={}, page_content='피라미트처럼 슬프구나'),
#  Document(metadata={}, page_content='식권 하로 세끼(三餐)를준다,'),
#  Document(metadata={}, page_content='식모 젊은아히들에게.'),
#  Document(metadata={}, page_content='한때 힌그릇셋을준다,'),
#  Document(metadata={}, page_content='대동강(大洞江) 물로끄린국,'),
#  Document(metadata={}, page_content='평안도(平安道) 쌀로지은밥,'),
#  Document(metadata={}, page_content='조선(朝鮮)의 매운고추장,'),
#  Document(metadata={}, page_content='식권 우리배를 부르게.'),
#  Document(metadata={}, page_content='늦은봄기다리든 토요일(土曜日)날.'),
#  Document(metadata={}, page_content='오후(午後) 세시반의 경성(京城)행열차는,'),
#  Document(metadata={}, page_content='석탄(石炭)연기를 자욱이 품기고,'),
#  Document(metadata={}, page_content='소리치고 지나가고'),
#  Document(metadata={}, page_content='한몸을 끟을기에 강(强)하든.'),
#  Document(metadata={}, page_content='공(뽈)이 자력(磁力)을 잃고'),
#  Document(metadata={}, page_content='한목음의 물이'),
#  Document(metadata={}, page_content='불붓는 목을 축이기에'),
#  Document(metadata={}, page_content='넉넉하다,'),
#  Document(metadata={}, page_content='젊은 가슴의 피순환(循環)이 잣고,'),
#  Document(metadata={}, page_content='두 철각(鐵脚)이 늘어진다,'),
#  Document(metadata={}, page_content='검은 기차(汽車)연기(煙氣)와 함께.'),
#  Document(metadata={}, page_content='풀은 산(山)이'),
#  Document(metadata={}, page_content='아지랑 저쪽으로'),
#  Document(metadata={}, page_content='까라안는다,'),
#  Document(metadata={}, page_content='청초(淸楚)한 코쓰모쓰는'),
#  Document(metadata={}, page_content='오직 하나인 나의 아가씨,'),
#  Document(metadata={}, page_content='달빛이 싸늘히 추운 밤이면'),
#  Document(metadata={}, page_content='넷 소녀(少女)가 몯견디게 그리워'),
#  Document(metadata={}, page_content='코쓰모쓰 핀 정원(庭園)으로 찾어간다.'),
#  Document(metadata={}, page_content='코쓰모쓰는'),
#  Document(metadata={}, page_content='귀또리 울음에도 수집어지고,'),
#  Document(metadata={}, page_content='코쓰모쓰 앞에선 나는'),
#  Document(metadata={}, page_content='어렷을적 처럼 부끄러워 지나니,'),
#  Document(metadata={}, page_content='내마음은 코쓰모쓰의 마음이오.'),
#  Document(metadata={}, page_content='코쓰모쓰의 마음은 내마음이다.'),
#  Document(metadata={}, page_content='함께핀 꽃에 처음익은 능금은'),
#  Document(metadata={}, page_content='먼저 떨어젓슴니다.'),
#  Document(metadata={}, page_content='오날도 가을바람은 그냥붐니다.'),
#  Document(metadata={}, page_content='길가에 떨어진 불근 능금은'),
#  Document(metadata={}, page_content='지나든 손님이 집어갓슴니다.'),
#  Document(metadata={}, page_content='헌집신짝 끟을고'),
#  Document(metadata={}, page_content='나여긔 웨왓노'),
#  Document(metadata={}, page_content='두만강을 건너서'),
#  Document(metadata={}, page_content='쓸쓸한 이 땅에'),
#  Document(metadata={}, page_content='남쪽하늘 저밑엔'),
#  Document(metadata={}, page_content='따뜻한 내고향'),
#  Document(metadata={}, page_content='내어머니 게신곧'),
#  Document(metadata={}, page_content='그리운 고향집.'),
#  Document(metadata={}, page_content='「이 개 더럽잔니」'),
#  Document(metadata={}, page_content='아─ 니 이웃집 덜렁 숳개가'),
#  Document(metadata={}, page_content='오날 어슬렁 어슬렁 우리집으로 오더니'),
#  Document(metadata={}, page_content='우리집 바두기의 미구멍에다 코를대고'),
#  Document(metadata={}, page_content='씩々 내를 맛겟지 더러운줄도 모르고,'),
#  Document(metadata={}, page_content='보기 숭해서 막차며 욕해 쫓앗더니'),
#  Document(metadata={}, page_content='꼬리를 휘휘 저으며'),
#  Document(metadata={}, page_content='너희들보다 어떻겟냐하는 상으로'),
#  Document(metadata={}, page_content='뛰여가겟지요 나─ 참.'),
#  Document(metadata={}, page_content='나무가 춤을 추면'),
#  Document(metadata={}, page_content='바람이 불고,'),
#  Document(metadata={}, page_content='나무가 잠잠하면'),
#  Document(metadata={}, page_content='바람도 자오,'),
#  Document(metadata={}, page_content='왜떡이 씁은 데도'),
#  Document(metadata={}, page_content='작고 달다고 하오.'),
#  Document(metadata={}, page_content='앙당한 솔나무가지에,'),
#  Document(metadata={}, page_content='훈훈한 바람의 날개가 스치고'),
#  Document(metadata={}, page_content='얼음 석긴 대동강(大洞江)물에,'),
#  Document(metadata={}, page_content='한나절 햇발이 밋그러지다,'),
#  Document(metadata={}, page_content='허무러진 성터(城터)에서'),
#  Document(metadata={}, page_content='철모르는 여자(女兒)들이'),
#  Document(metadata={}, page_content='저도 모를 이국(異國)말로,'),
#  Document(metadata={}, page_content='재질대며 뜀을 뛰고.'),
#  Document(metadata={}, page_content='난데없는 자동차(自動車)가 밉다.'),
#  Document(metadata={}, page_content='눈이 오다, 물이 되는 날.'),
#  Document(metadata={}, page_content='재ㅅ빛 하늘에 또 뿌연 내, 그리고,'),
#  Document(metadata={}, page_content='크다란 기관차(機關車)는 빼─액─ 울며,'),
#  Document(metadata={}, page_content='쪽그만, 가슴은, 울렁거린다.'),
#  Document(metadata={}, page_content='리별이 너무 재빠르다, 안탑갑게도,'),
#  Document(metadata={}, page_content='사랑하는 사람을,'),
#  Document(metadata={}, page_content='일터에서 만나자 하고─.'),
#  Document(metadata={}, page_content='더운 손의 맛과, 구슬눈물이 마르기 전'),
#  Document(metadata={}, page_content='기차는 꼬리를 산굽으로 돌렷다,'),
#  Document(metadata={}, page_content='종달새는 일은봄날'),
#  Document(metadata={}, page_content='즐드즌 거리의뒷골목이'),
#  Document(metadata={}, page_content='슳더라.'),
#  Document(metadata={}, page_content='명량한 봄하늘,'),
#  Document(metadata={}, page_content='가벼운 두나래를펴서'),
#  Document(metadata={}, page_content='요염한 봄노래가,'),
#  Document(metadata={}, page_content='좋더라,'),
#  Document(metadata={}, page_content='그러나,'),
#  Document(metadata={}, page_content='오날도 구멍뚤린 구두를끌고,'),
#  Document(metadata={}, page_content='훌렁훌렁 뒷거리길로,'),
#  Document(metadata={}, page_content='고기색기같은나는 헤매나니,'),
#  Document(metadata={}, page_content='나래와노래가 없음인가,'),
#  Document(metadata={}, page_content='가슴이 답답하구나,'),
#  Document(metadata={}, page_content='공상(空想)─'),
#  Document(metadata={}, page_content='내마음의 탑(塔)'),
#  Document(metadata={}, page_content='나는 말없이 이탑(塔)을 쌓고있다'),
#  Document(metadata={}, page_content='명예(名譽)와 허영(虛榮)의 천공(天空)에다'),
#  Document(metadata={}, page_content='문허질줄도 몰으고'),
#  Document(metadata={}, page_content='한층두층 높이 싸ㅅ는다'),
#  Document(metadata={}, page_content='무한(無限)한 나의 공상(空想)─'),
#  Document(metadata={}, page_content='그것은 내마음의 바다'),
#  Document(metadata={}, page_content='나는 두팔을 펄처서'),
#  Document(metadata={}, page_content='나의 바다에서'),
#  Document(metadata={}, page_content='자유(自由)로히 헤염친다'),
#  Document(metadata={}, page_content='황금(黃金) 지욕(知慾)의 수평선(水平線)을 향(向)하여.'),
#  Document(metadata={}, page_content='래일래일 하기에'),
#  Document(metadata={}, page_content='물엇더니.'),
#  Document(metadata={}, page_content='밤을자고 동틀때'),
#  Document(metadata={}, page_content='래일이라고.'),
#  Document(metadata={}, page_content='새날을 찯은나는'),
#  Document(metadata={}, page_content='잠을자고 돌보니.'),
#  Document(metadata={}, page_content='그때는 내일이아니라.'),
#  Document(metadata={}, page_content='오늘이더라,'),
#  Document(metadata={}, page_content='무리여!'),
#  Document(metadata={}, page_content='래일은 없나니'),
#  Document(metadata={}, page_content='산들이 두 줄로 줄다를질 치고'),
#  Document(metadata={}, page_content='여울이 소리처 목이 자젓다.'),
#  Document(metadata={}, page_content='한여름의 햇님이 구름을 타고'),
#  Document(metadata={}, page_content='이골작이를 빠르게도 건너련다.'),
#  Document(metadata={}, page_content='산(山)등아리에 송아지 뿔처럼'),
#  Document(metadata={}, page_content='울뚝불뚝히 어린 바위가 솟구,'),
#  Document(metadata={}, page_content='얼룩소의 보드러운 털이'),
#  Document(metadata={}, page_content='산(山)등서리에 퍼─렇게 자랏다.'),
#  Document(metadata={}, page_content='삼년(三年)만에 고향(故鄕) 찾어드는'),
#  Document(metadata={}, page_content='산꼴 나그네의 발거름이'),
#  Document(metadata={}, page_content='타박타박 땅을 고눈다.'),
#  Document(metadata={}, page_content='벌거숭이 두루미 다리같이...'),
#  Document(metadata={}, page_content='헌 신짝이 집행이 끝에'),
#  Document(metadata={}, page_content='목아지를 매달아 늘어지고,'),
#  Document(metadata={}, page_content='까치가 색기의 날발을 태우려 날뿐,'),
#  Document(metadata={}, page_content='골작은 나그네의 마음처럼 고요하다.'),
#  Document(metadata={}, page_content='장미 병들어'),
#  Document(metadata={}, page_content='옮겨 놓을 이웃이 없도다.'),
#  Document(metadata={}, page_content='달랑달랑 외로히'),
#  Document(metadata={}, page_content='황마차(幌馬車) 태워 산(山)에 보낼거나,'),
#  Document(metadata={}, page_content='뚜— 구슬피'),
#  Document(metadata={}, page_content='화륜선(火輪船) 태워 대양(大洋)에 보낼거나,'),
#  Document(metadata={}, page_content='프로펠러 소리 요란히'),
#  Document(metadata={}, page_content='비행기(飛行機) 태워 성층권(成層圈)에 보낼거나'),
#  Document(metadata={}, page_content='이것 저것'),
#  Document(metadata={}, page_content='다 구만두고'),
#  Document(metadata={}, page_content='자라가는 아들이 꿈을 깨기 전'),
#  Document(metadata={}, page_content='이내 가슴에 묻어다오.'),
#  Document(metadata={}, page_content='황혼(黃昏)이 짙어지는 길모퉁이에서'),
#  Document(metadata={}, page_content='하루종일 시들은 귀를 가만히 기울이면'),
#  Document(metadata={}, page_content='땅거미 옮겨지는 발자취 소리,'),
#  Document(metadata={}, page_content='발자취 소리를 들을 수 있도록'),
#  Document(metadata={}, page_content='나는 총명했든가요.'),
#  Document(metadata={}, page_content='이제 어리석게도 모든 것을 깨달은 다음'),
#  Document(metadata={}, page_content='오래 마음 깊은 속에'),
#  Document(metadata={}, page_content='괴로워하던 수많은 나를'),
#  Document(metadata={}, page_content='하나, 둘 제고장으로 돌려보내면'),
#  Document(metadata={}, page_content='거리모퉁이 어둠 속으로'),
#  Document(metadata={}, page_content='소리 없이 사라지는 흰 그림자,'),
#  Document(metadata={}, page_content='흰 그림자들'),
#  Document(metadata={}, page_content='연연히 사랑하던 흰 그림자들,'),
#  Document(metadata={}, page_content='내 모든 것을 돌려 보낸 뒤'),
#  Document(metadata={}, page_content='허전히 뒷골목을 돌아'),
#  Document(metadata={}, page_content='황혼(黃昏)처럼 물드는 내 방으로 돌아오면'),
#  Document(metadata={}, page_content='신념(信念)이 깊은 의젓한 양(羊)처럼'),
#  Document(metadata={}, page_content='하루종일 시름없이 풀포기나 뜯자.'),
#  Document(metadata={}, page_content='봄이 오던 아침, 서울 어느 쪼그만 정거장(停車場)에서'),
#  Document(metadata={}, page_content='희망(希望)과 사랑처럼 기차(汽車)를 기다려,'),
#  Document(metadata={}, page_content='나는 플랫폼(푸라트•폼)에 간신한 그림자를 떨어트리고,'),
#  Document(metadata={}, page_content='담배를 피웠다.'),
#  Document(metadata={}, page_content='내 그림자는 담배연기 그림자를 날리고'),
#  Document(metadata={}, page_content='비둘기 한 떼가 부끄러울 것도 없이'),
#  Document(metadata={}, page_content='나래 속을 속, 속, 햇빛에 비춰, 날았다.'),
#  Document(metadata={}, page_content='기차(汽車)는 아무 새로운 소식도 없이'),
#  Document(metadata={}, page_content='나를 멀리 실어다 주어,'),
#  Document(metadata={}, page_content='봄은 다 가고—— 도쿄(東京) 교외(郊外) 어느 조용한'),
#  Document(metadata={}, page_content='하숙방(下宿房)에서, 옛 거리에 남은 나를 희망(希望)과'),
#  Document(metadata={}, page_content='사랑처럼 그리워한다.'),
#  Document(metadata={}, page_content='오늘도 기차(汽車)는 몇 번이나 무의미(無意味)하게 지나가고,'),
#  Document(metadata={}, page_content='오늘도 나는 누구를 기다려 정거장(停車場) 가까운 언덕에서 서성거릴게다.'),
#  Document(metadata={}, page_content='——아아 젊음은 오래 거기 남아 있거라.'),
#  Document(metadata={}, page_content='으스럼히 안개가 흐른다. 거리가 흘러간다. 저 전차(電車), 자동차(自動車), 모든 바퀴가 어디로 흘리워 가는 것일까? 정박(定泊)할 아무 항구(港口)도 없이, 가련한 많은 사람들을 실고서, 안개 속에 잠긴 거리는,'),
#  Document(metadata={}, page_content='거리 모통이 붉은 포스트상자를 붙잡고 섰을라면 모든 것이 흐르는 속에 어렴풋이 빛나는 가로등(街路燈), 꺼지지 않는 것은 무슨 상징(象徵)일까? 사랑하는 동무 박(朴)이여! 그리고 김(金)이여! 자네들은 지금 어디 있는가? 끝없이 안개가 흐르는데,'),
#  Document(metadata={}, page_content='「새로운 날 아침 우리 다시 정(情)답게 손목을 잡어 보세」 몇 자 적어 포스트 속에 떨어트리고, 밤을 새워 기다리면 금휘장(金徽章)에 금단추(金단추)를 삐었고 거인(巨人)처럼 찬란히 나타나는 배달부(配達夫), 아침과 함께 즐거운 내림(來臨),'),
#  Document(metadata={}, page_content='이밤을 하염없이 안개가 흐른다.'),
#  Document(metadata={}, page_content='창밖(窓外)에 밤비가 속살거려'),
#  Document(metadata={}, page_content='육첩방(六疊房)은 남의 나라,'),
#  Document(metadata={}, page_content='시인(詩人)이란 슬픈 천명(天命)인줄 알면서도'),
#  Document(metadata={}, page_content='한줄 시(詩)를 적어 볼가,'),
#  Document(metadata={}, page_content='땀내와 사랑내 포근히 품긴'),
#  Document(metadata={}, page_content='보내주신 학비봉투(學費封套)를 받어'),
#  Document(metadata={}, page_content='대학(大學)노—트를 끼고'),
#  Document(metadata={}, page_content='늙은 교수(敎授)의 강의(講義) 들으려 간다.'),
#  Document(metadata={}, page_content='생각해 보면 어린때 동무를'),
#  Document(metadata={}, page_content='하나, 둘, 죄다 잃어 버리고'),
#  Document(metadata={}, page_content='나는 무얼 바라'),
#  Document(metadata={}, page_content='나는 다만, 홀로 침전(沈澱)하는 것일가?'),
#  Document(metadata={}, page_content='인생(人生)은 살기 어렵다는데'),
#  Document(metadata={}, page_content='시(詩)가 이렇게 쉽게 씨워지는 것은'),
#  Document(metadata={}, page_content='부끄러운 일이다.'),
#  Document(metadata={}, page_content='육첩방(六疊房)은 남의 나라'),
#  Document(metadata={}, page_content='창밖(窓外)에 밤비가 속살거리는데,'),
#  Document(metadata={}, page_content='등불을 밝혀 어둠을 조곰 내몰고,'),
#  Document(metadata={}, page_content='시대(時代)처럼 올 아침을 기다리는 최후(最後)의 나,'),
#  Document(metadata={}, page_content='나는 나에게 적은 손을 내밀어'),
#  Document(metadata={}, page_content='눈물과 위안(慰安)으로 잡는 최초(最初)의 악수(握手).'),
#  Document(metadata={}, page_content='봄이 혈관(血管)속에 시내처럼 흘러'),
#  Document(metadata={}, page_content='돌, 돌, 시내가 차운 언덕에'),
#  Document(metadata={}, page_content='개나리, 진달래, 노오란 배추꽃'),
#  Document(metadata={}, page_content='삼동(三冬)을 참어온 나는'),
#  Document(metadata={}, page_content='풀포기처럼 피어난다.'),
#  Document(metadata={}, page_content='즐거운 종달새야'),
#  Document(metadata={}, page_content='어느 이랑에서 즐거웁게 솟쳐라.'),
#  Document(metadata={}, page_content='푸르른 하늘은'),
#  Document(metadata={}, page_content='아른아른 높기도 한데……'),
#  Document(metadata={}, page_content='파란 녹이 낀 구리거울 속에'),
#  Document(metadata={}, page_content='내 얼굴이 남어 있는 것은'),
#  Document(metadata={}, page_content='어느 왕조(王朝)의 유물(遺物)이기에'),
#  Document(metadata={}, page_content='이다지도 욕될가'),
#  Document(metadata={}, page_content='나는 나의 참회(懺悔)의 글을 한줄에 주리자'),
#  Document(metadata={}, page_content='——만(滿) 이십사 년 일 개월(一個月)을'),
#  Document(metadata={}, page_content='무슨 기쁨을 바라 살아 왔든가'),
#  Document(metadata={}, page_content='내일이나 모레나 그 어느 즐거운 날에'),
#  Document(metadata={}, page_content='나는 또 한줄의 참회록(懺悔錄)을 써야한다.'),
#  Document(metadata={}, page_content='——그때 그 젊은 나이에'),
#  Document(metadata={}, page_content='왜 그런 부끄런 고백(告白)을 했든가'),
#  Document(metadata={}, page_content='밤이면 밤마다 나의 거울을'),
#  Document(metadata={}, page_content='손바닥으로 발바닥으로 닦어 보자.'),
#  Document(metadata={}, page_content='그러면 어느 운석(隕石) 밑으로 흘러 걸어가는'),
#  Document(metadata={}, page_content='슬픈 사람의 뒷모양이'),
#  Document(metadata={}, page_content='거울 속에 나타나온다.'),
#  Document(metadata={}, page_content='바닷가 햇빛 바른 바위우에'),
#  Document(metadata={}, page_content='습한 간(肝)을 펴서 말리우자,'),
#  Document(metadata={}, page_content='코카사쓰 산중(山中)에서 도망해온 토끼처럼'),
#  Document(metadata={}, page_content='둘러리를 빙빙 돌며 간(肝)을 지키자,'),
#  Document(metadata={}, page_content='내가 오래 기르든 여윈 독수리야!'),
#  Document(metadata={}, page_content='와서 뜯어 먹어라, 시름없이'),
#  Document(metadata={}, page_content='너는 살지고'),
#  Document(metadata={}, page_content='나는 여위여야지, 그러나,'),
#  Document(metadata={}, page_content='거북이야!'),
#  Document(metadata={}, page_content='다시는 용궁(龍宮)의 유혹(誘惑)에 안떨어진다.'),
#  Document(metadata={}, page_content='푸로메디어쓰 불상한 푸로메디어쓰'),
#  Document(metadata={}, page_content='불 도적한 죄로 목에 맷돌을 달고'),
#  Document(metadata={}, page_content='끝없이 침전(沈澱)하는 푸로메디어쓰,'),
#  Document(metadata={}, page_content='연륜(年輪)이 자라듯이'),
#  Document(metadata={}, page_content='달이 자라는 고요한 밤에'),
#  Document(metadata={}, page_content='달같이 외로운 사랑이'),
#  Document(metadata={}, page_content='가슴하나 뻐근히'),
#  Document(metadata={}, page_content='연륜(年輪)처럼 피어나간다.'),
#  Document(metadata={}, page_content='시들은 잎새속에서'),
#  Document(metadata={}, page_content='고 빨간 살을 드러내 놓고,'),
#  Document(metadata={}, page_content='고추는 방년(芳年)된 아가씬양'),
#  Document(metadata={}, page_content='땡볕에 자꾸 익어간다.'),
#  Document(metadata={}, page_content='할머니는 바구니를 들고'),
#  Document(metadata={}, page_content='밭머리에서 어정거리고'),
#  Document(metadata={}, page_content='손가락 너어는 아이는'),
#  Document(metadata={}, page_content='할머니 뒤만 따른다.'),
#  Document(metadata={}, page_content='붉은 이마에 싸늘한 달이 서리어'),
#  Document(metadata={}, page_content='아우의 얼굴은 슬픈 그림이다.'),
#  Document(metadata={}, page_content='발걸음을 멈추어'),
#  Document(metadata={}, page_content='살그머니 애딘 손을 잡으며'),
#  Document(metadata={}, page_content='「늬는 자라 무엇이 되려니」'),
#  Document(metadata={}, page_content='「사람이 되지」'),
#  Document(metadata={}, page_content='아우의 설은 진정코 설은 대답(對答)이다.'),
#  Document(metadata={}, page_content='슬며시 잡았든 손을 놓고'),
#  Document(metadata={}, page_content='아우의 얼골을 다시 들여다 본다.'),
#  Document(metadata={}, page_content='싸늘한 달이 붉은 이마에 젖어'),
#  Document(metadata={}, page_content='아우의 얼골은 슬픈 그림이다.'),
#  Document(metadata={}, page_content='순(順)아 너는 내 전(殿)에 언제 들어왔든 것이냐?'),
#  Document(metadata={}, page_content='내사 언제 네 전(殿)에 들어갔든 것이냐?'),
#  Document(metadata={}, page_content='우리들의 전당(殿堂)은'),
#  Document(metadata={}, page_content='고풍(古風)한 풍습(風習)이 어린 사랑의 전당(殿堂)'),
#  Document(metadata={}, page_content='순(順)아 암사슴처럼 수정(水晶)눈을 나려감어라.'),
#  Document(metadata={}, page_content='난 사자처럼 엉크린 머리를 고루련다.'),
#  Document(metadata={}, page_content='우리들의 사랑은 한낱 벙어리이었다.'),
#  Document(metadata={}, page_content='성(聖)스런 촛대에 열(熱)한 불이 꺼지기 전(前)'),
#  Document(metadata={}, page_content='순(順)아 너는 앞문으로 내 달려라.'),
#  Document(metadata={}, page_content='어둠과 바람이 우리 창(窓)에 부닥치기 전(前)'),
#  Document(metadata={}, page_content='나는 영원(永遠)한 사랑을 안은채'),
#  Document(metadata={}, page_content='뒷문으로 멀리 사라지련다.'),
#  Document(metadata={}, page_content='이제 네게는 삼림(森林)속의 아늑한 호수(湖水)가 있고'),
#  Document(metadata={}, page_content='내게는 준험(峻嶮)한 산맥(山脈)이 있다.'),
#  Document(metadata={}, page_content='발에 터부한 것을 다 빼어 바리고'),
#  Document(metadata={}, page_content='황혼(黃昏)이 호수(湖水)우로 걸어 오듯이'),
#  Document(metadata={}, page_content='나도 삽분삽분 걸어 보리이까?'),
#  Document(metadata={}, page_content='내사 이 호수(湖水)가로'),
#  Document(metadata={}, page_content='부르는 이 없이'),
#  Document(metadata={}, page_content='불리워 온 것은'),
#  Document(metadata={}, page_content='참말 이적(異蹟)이외다.'),
#  Document(metadata={}, page_content='오늘 따라'),
#  Document(metadata={}, page_content='연정(戀情), 자부(自惚), 시기(猜忌), 이것들이'),
#  Document(metadata={}, page_content='자꾸 금메달(金메달)처럼 만져지는구려'),
#  Document(metadata={}, page_content='하나, 내 모든 것을 여념(餘念)없이'),
#  Document(metadata={}, page_content='물결에 씻어 보내려니'),
#  Document(metadata={}, page_content='당신은 호면(湖面)으로 나를 불러 내소서.'),
#  Document(metadata={}, page_content='솨— 철석! 파도소리 문살에 부서져'),
#  Document(metadata={}, page_content='잠 살포시 꿈이 흐터진다.'),
#  Document(metadata={}, page_content='잠은 한낱 검은 고래떼처럼 살래어,'),
#  Document(metadata={}, page_content='달랠 아무런 재주도 없다.'),
#  Document(metadata={}, page_content='불을 밝혀 잠옷을 정성스리 여미는'),
#  Document(metadata={}, page_content='삼경(三更).'),
#  Document(metadata={}, page_content='염원(念願).'),
#  Document(metadata={}, page_content='동경(憧憬)의 땅 강남(江南)에 또 홍수(洪水)질 것만 싶어,'),
#  Document(metadata={}, page_content='바다의 향수(鄕愁)보다 더 호젓해진다.'),
#  Document(metadata={}, page_content='괴로운 사람아 괴로운 사람아'),
#  Document(metadata={}, page_content='옷자락 물결속에서도 가슴속 깊이 돌돌 샘물이 홀러'),
#  Document(metadata={}, page_content='이밤을 더부러 말할이 없도다.'),
#  Document(metadata={}, page_content='거리의 소음과 노래 부를수 없도다.'),
#  Document(metadata={}, page_content='그신듯이 냇가에 앉았으니'),
#  Document(metadata={}, page_content='사랑과 일을 거리에 매끼고 가만히 가만히'),
#  Document(metadata={}, page_content='바다로 가자'),
#  Document(metadata={}, page_content='후어—ㄴ한 방(房)에'),
#  Document(metadata={}, page_content='유언(遺言)은 소리 없는 입놀림.'),
#  Document(metadata={}, page_content='바다에 진주(眞珠) 캐려 갔다는 아들'),
#  Document(metadata={}, page_content='해녀(海女)와 사랑을 속삭인다는 맏아들'),
#  Document(metadata={}, page_content='이 밤에사 돌아오나 내다 봐라——'),
#  Document(metadata={}, page_content='평생(平生) 외롭던 아버지의 운명(殞命)'),
#  Document(metadata={}, page_content='감기우는 눈에 슬픔이 어린다.'),
#  Document(metadata={}, page_content='외딴집에 개가 짖고'),
#  Document(metadata={}, page_content='휘영찬 달이 문살에 흐르는 밤.'),
#  Document(metadata={}, page_content='쉬는 시간(時間)마다'),
#  Document(metadata={}, page_content='나는 창옆(窓옄)으로 갑니다.'),
#  Document(metadata={}, page_content='——창(窓)은 산 가르침.'),
#  Document(metadata={}, page_content='이글이글 불을 피워주소,'),
#  Document(metadata={}, page_content='이 방에 찬것이 서립니다.'),
#  Document(metadata={}, page_content='단풍잎 하나'),
#  Document(metadata={}, page_content='맴 도나 보니'),
#  Document(metadata={}, page_content='아마도 작으마한 선풍(旋風)이 인게웨다.'),
#  Document(metadata={}, page_content='그래도 싸느란 유리창에'),
#  Document(metadata={}, page_content='햇살이 쨍쨍한 무렵,'),
#  Document(metadata={}, page_content='상학종(上學鐘)이 울어만 싶습니다.'),
#  Document(metadata={}, page_content='실어다 뿌리는'),
#  Document(metadata={}, page_content='바람조차 시원타.'),
#  Document(metadata={}, page_content='솔나무 가지마다 샛춤히'),
#  Document(metadata={}, page_content='고개를 돌리어 뻐들어지고,'),
#  Document(metadata={}, page_content='밀치고'),
#  Document(metadata={}, page_content='밀치운다.'),
#  Document(metadata={}, page_content='이랑을 넘는 물결은'),
#  Document(metadata={}, page_content='폭포처럼 피어오른다.'),
#  Document(metadata={}, page_content='해변(海邊)에 아이들이 모인다'),
#  Document(metadata={}, page_content='찰찰 손을 씻고 구보로.'),
#  Document(metadata={}, page_content='바다는 자꾸 섧어진다.'),
#  Document(metadata={}, page_content='갈매기의 노래에………'),
#  Document(metadata={}, page_content='돌아다 보고 돌아다 보고'),
#  Document(metadata={}, page_content='돌아가는 오늘의 바다여!'),
#  Document(metadata={}, page_content='내 노래는 오히려'),
#  Document(metadata={}, page_content='섧은 산울림.'),
#  Document(metadata={}, page_content='골자기 길에'),
#  Document(metadata={}, page_content='떨어진 그림자는'),
#  Document(metadata={}, page_content='너무나 슬프구나.'),
#  Document(metadata={}, page_content='오후(午後)의 명상(瞑想)은'),
#  Document(metadata={}, page_content='아— 졸려.'),
#  Document(metadata={}, page_content='가츨가츨한 머리칼은 오막사리 처마끝,'),
#  Document(metadata={}, page_content='쉬파람에 콧마루가 서운한 양 간질키오.'),
#  Document(metadata={}, page_content='들창(窓) 같은 눈은 가볍게 닫혀'),
#  Document(metadata={}, page_content='이 밤에 연정(戀情)은 어둠처럼 골골히 스며드오.'),
#  Document(metadata={}, page_content='싸늘한 대리석(大理石) 기둥에 목아지를 비틀어맨 한난계(寒暖計),'),
#  Document(metadata={}, page_content='문득 들여다 볼 수 있는 운명(運命)한 오척육촌(五尺六寸)의 허리 가는 수은주(水銀柱),'),
#  Document(metadata={}, page_content='마음은 유리관(琉璃管)보다 맑소이다.'),
#  Document(metadata={}, page_content='혈관(血管)이 단조(單調)로워 신경질(神經質)인 여론동물(輿論動物),'),
#  Document(metadata={}, page_content='가끔 분수(噴水) 같은 냉침(冷침)을 억지로 삼키기에'),
#  Document(metadata={}, page_content='정력(精力)을 낭비(浪費)합니다.'),
#  Document(metadata={}, page_content='영하(零下)로 손구락질 할 수도 없는 방(房)처럼 치운 겨울보다'),
#  Document(metadata={}, page_content='해바라기 만발(滿發)한 팔월(八月) 교정(校庭)이 이상(理想)곱소이다.'),
#  Document(metadata={}, page_content='피끓을 그날이——'),
#  Document(metadata={}, page_content='어제는 막 소낙비가 퍼붓더니 오늘은 좋은 날세올시다.'),
#  Document(metadata={}, page_content='동저고리 바람에 언덕으로, 숲으로 하시구려——'),
#  Document(metadata={}, page_content='이렇게 가만 가만 혼자서 귓속이야기를 하였읍니다.'),
#  Document(metadata={}, page_content='나는 또 내가 모르는 사이에——'),
#  Document(metadata={}, page_content='나는 아마도 진실(眞實)한 세기(世紀)의 계절(季節)을 따라——'),
#  Document(metadata={}, page_content='하늘만 보이는 울타리 안을 뛰쳐,'),
#  Document(metadata={}, page_content='역사(歷史) 같은 포지슌을 지켜야 봅니다.'),
#  Document(metadata={}, page_content='번개, 뇌성, 왁자지근 뚜다려'),
#  Document(metadata={}, page_content='머—ㄴ 도화지(都會地)에 낙뢰(落雷)가 있어만 싶다.'),
#  Document(metadata={}, page_content='벼루짱 엎어논 하늘로'),
#  Document(metadata={}, page_content='살같은 비가 살처럼 쏟아진다.'),
#  Document(metadata={}, page_content='손바닥만한 나의 정원(庭園)이'),
#  Document(metadata={}, page_content='마음같이 흐린 호수(湖水)되기 일수다.'),
#  Document(metadata={}, page_content='바람이 팽이처럼 돈다.'),
#  Document(metadata={}, page_content='나무가 머리를 이루 잡지 못한다.'),
#  Document(metadata={}, page_content='내 경건(敬虔)한 마음을 모셔드려'),
#  Document(metadata={}, page_content='노아때 하늘을 한모금 마시다.'),
#  Document(metadata={}, page_content='봄바람을 등진 초록빛 바다'),
#  Document(metadata={}, page_content='쏟아질듯 쏟아질듯 위트롭다.'),
#  Document(metadata={}, page_content='잔주름 치마폭의 두둥실거리는 물결은,'),
#  Document(metadata={}, page_content='오스라질듯 한끝 경쾌(輕快)롭다.'),
#  Document(metadata={}, page_content='마스트 끝에 붉은 깃발(旗ㅅ발)이'),
#  Document(metadata={}, page_content='여인(女人)의 머리칼처럼 나부낀다.'),
#  Document(metadata={}, page_content='이 생생한 풍경(風景)을 앞세우며 뒤세우며'),
#  Document(metadata={}, page_content='외—ㄴ 하루 거닐고 싶다.'),
#  Document(metadata={}, page_content='——우중충한 오월(五月) 하늘 아래로,'),
#  Document(metadata={}, page_content='——바다빛 포기포기에 수(繡)놓은 언덕으로,'),
#  Document(metadata={}, page_content='흐르는 달의 흰 물결을 밀쳐'),
#  Document(metadata={}, page_content='여윈 나무그림자를 밟으며'),
#  Document(metadata={}, page_content='북망산(北邙山)을 향(向)한 발걸음은 무거웁고'),
#  Document(metadata={}, page_content='고독(孤獨)을 반려(伴侶)한 마음은 슬프기도 하다.'),
#  Document(metadata={}, page_content='누가 있어만 싶은 묘지(墓地)엔 아무도 없고,'),
#  Document(metadata={}, page_content='정적(靜寂)만이 군데군데 흰 물결에 폭 젖었다.'),
#  Document(metadata={}, page_content='이른 아침 아낙네들은 시들은 생활(生活)을'),
#  Document(metadata={}, page_content='바구니 하나 가득 담아 이고……'),
#  Document(metadata={}, page_content='업고 지고…… 안고 들고……'),
#  Document(metadata={}, page_content='모여드오 자꾸 장에 모여드오.'),
#  Document(metadata={}, page_content='가난한 생활(生活)을 골골이 버려놓고'),
#  Document(metadata={}, page_content='밀려가고 밀려오고……'),
#  Document(metadata={}, page_content='제마다 생활(生活)을 외치오…… 싸우오.'),
#  Document(metadata={}, page_content='왼하로 올망졸망한 생활(生活)을'),
#  Document(metadata={}, page_content='되질하고 저울질하고 자질하다가'),
#  Document(metadata={}, page_content='날이 저물어 아낙네들이'),
#  Document(metadata={}, page_content='쓴 생활(生活)과 바꾸어 또 이고 돌아가오.'),
#  Document(metadata={}, page_content='오양간 당나귀'),
#  Document(metadata={}, page_content='아—ㅇ 외 마디 울음울고,'),
#  Document(metadata={}, page_content='당나귀 소리에'),
#  Document(metadata={}, page_content='으—아 아 애기 소스라처 깨고,'),
#  Document(metadata={}, page_content='등잔에 불을 다오.'),
#  Document(metadata={}, page_content='아버지는 당나귀에게'),
#  Document(metadata={}, page_content='짚을 한키 담아 주고,'),
#  Document(metadata={}, page_content='어머니는 애기에게'),
#  Document(metadata={}, page_content='젖을 한모금 먹이고,'),
#  Document(metadata={}, page_content='밤은 다시 고요히 잠드오.'),
#  Document(metadata={}, page_content='하로도 검푸른 물결에'),
#  Document(metadata={}, page_content='흐느적 잠기고…… 잠기고……'),
#  Document(metadata={}, page_content='물든 바다를 날아 횡단(橫斷)할고.'),
#  Document(metadata={}, page_content='낙엽(落葉)이 된 해초(海草)'),
#  Document(metadata={}, page_content='해초(海草)마다 슬프기도 하오.'),
#  Document(metadata={}, page_content='서창(西窓)에 걸린 해말간 풍경화(風景畵).'),
#  Document(metadata={}, page_content='옷고름 너어는 고아(孤兒)의 서름.'),
#  Document(metadata={}, page_content='이제 첫 항해(航海)하는 마음을 먹고'),
#  Document(metadata={}, page_content='방바닥에 나딩구오…… 딩구오……'),
#  Document(metadata={}, page_content='황혼(黃昏)이 바다가 되어'),
#  Document(metadata={}, page_content='오늘도 수많은 배가'),
#  Document(metadata={}, page_content='나와 함께 이 물결에 잠겼을게오.'),
#  Document(metadata={}, page_content='휙, 휙, 휙,'),
#  Document(metadata={}, page_content='소꼬리가 부드러운 채찍질로'),
#  Document(metadata={}, page_content='어둠을 쫓아,'),
#  Document(metadata={}, page_content='캄, 캄, 어둠이 깊다 깊다 밝으오.'),
#  Document(metadata={}, page_content='이제 이 동리(洞里)의 아침이'),
#  Document(metadata={}, page_content='풀살 오른 소엉덩이처럼 푸드오.'),
#  Document(metadata={}, page_content='이 동리(洞里) 콩죽 먹은 사람들이'),
#  Document(metadata={}, page_content='땀물을 뿌려 이 여름을 길렀오.'),
#  Document(metadata={}, page_content='잎, 잎, 풀잎마다 땀방울이 맺혔오.'),
#  Document(metadata={}, page_content='구김살 없는 이 아침을'),
#  Document(metadata={}, page_content='심호흡(深呼吸)하오 또 하오.'),
#  Document(metadata={}, page_content='빨래줄에 두 다리를 드리우고'),
#  Document(metadata={}, page_content='횐 빨래들이 귓속 이야기 하는 오후(午後),'),
#  Document(metadata={}, page_content='쨍쨍한 칠월(七月)햇발은 고요히도'),
#  Document(metadata={}, page_content='아담한 빨래에만 달린다.'),
#  Document(metadata={}, page_content='잠은 눈을 떴다'),
#  Document(metadata={}, page_content='그윽한 유무(幽霧)에서.'),
#  Document(metadata={}, page_content='노래하던 종달이'),
#  Document(metadata={}, page_content='도망쳐 날아나고,'),
#  Document(metadata={}, page_content='지난날 봄타령하던'),
#  Document(metadata={}, page_content='금잔디밭은 아니다.'),
#  Document(metadata={}, page_content='탑(塔)은 무너졌다,'),
#  Document(metadata={}, page_content='붉은 마음의 탑(塔)이——'),
#  Document(metadata={}, page_content='손톱으로 새긴 대리석(大理石) 탑(塔)이——'),
#  Document(metadata={}, page_content='하루저녁 폭풍(暴風)에 여지(餘地)없이도,'),
#  Document(metadata={}, page_content='오오 황폐(荒廢)의 쑥밭,'),
#  Document(metadata={}, page_content='눈물과 목메임이여!'),
#  Document(metadata={}, page_content='꿈은 깨어졌다'),
#  Document(metadata={}, page_content='탑(塔)은 무너졌다.'),
#  Document(metadata={}, page_content='시계(時計)가 자근자근 가슴을 따려'),
#  Document(metadata={}, page_content='불안(不安)한 마음을 산림(山林)이 부른다.'),
#  Document(metadata={}, page_content='천년(千年) 오래인 연륜(年輪)에 짜들은 유암(幽暗)한 산림(山林)이,'),
#  Document(metadata={}, page_content='고달픈 한몸을 포옹(抱擁)할 인연(因緣)을 가졌나보다.'),
#  Document(metadata={}, page_content='산림(山林)의 검은 파동(波動)우으로부터'),
#  Document(metadata={}, page_content='어둠은 어린 가슴을 짓밟고'),
#  Document(metadata={}, page_content='이파리를 흔드는 저녁바람이'),
#  Document(metadata={}, page_content='솨— 공포(恐怖)에 떨게 한다.'),
#  Document(metadata={}, page_content='멀리 첫여름의 개구리 재질댐에'),
#  Document(metadata={}, page_content='흘러간 마을의 과거(過去)는 아질타.'),
#  Document(metadata={}, page_content='나무틈으로 반짝이는 별만이'),
#  Document(metadata={}, page_content='새날의 희망(希望)으로 나를 이끈다.'),
#  Document(metadata={}, page_content='사이좋은 정문(正門)의 두 돌기둥 끝에서'),
#  Document(metadata={}, page_content='오색기(五色旗)와 태양기(太陽旗)가 춤을 추는 날,'),
#  Document(metadata={}, page_content='금을 그은 지역(地域)의 아이들이 즐거워하다.'),
#  Document(metadata={}, page_content='아이들에게 하루의 건조(乾燥)한 학과(學課)로'),
#  Document(metadata={}, page_content='해말간 권태(倦怠)가 깃들고'),
#  Document(metadata={}, page_content='「모순(矛盾)」 두 자를 이해(理解)치 못하도록'),
#  Document(metadata={}, page_content='못하도록 머리가 단순(單純)하였구나.'),
#  Document(metadata={}, page_content='이런 날에는'),
#  Document(metadata={}, page_content='잃어버린 완고(頑固)하던 형(兄)을'),
#  Document(metadata={}, page_content='부르고 싶다.'),
#  Document(metadata={}, page_content='거리가 바둑판처럼 보이고,'),
#  Document(metadata={}, page_content='강물(江水)이 배암의 새끼처럼 기는'),
#  Document(metadata={}, page_content='산(山) 우에까지 왔다.'),
#  Document(metadata={}, page_content='아직쯤은 사람들이'),
#  Document(metadata={}, page_content='바둑돌처럼 버려있으리라.'),
#  Document(metadata={}, page_content='한나절의 태양(太陽)이'),
#  Document(metadata={}, page_content='함석지붕에만 비치고,'),
#  Document(metadata={}, page_content='굼벵이 걸음을 하던 기차(汽車)가'),
#  Document(metadata={}, page_content='정거장(停車場)에 섰다가 검은 내를 토(吐)하고'),
#  Document(metadata={}, page_content='또 걸음발을 탄다.'),
#  Document(metadata={}, page_content='텐트 같은 하늘이 무너져'),
#  Document(metadata={}, page_content='이 거리를 덮을까 궁금하면서'),
#  Document(metadata={}, page_content='좀 더 높은 데로 올라가고 싶다.'),
#  Document(metadata={}, page_content='저쪽으로 황토(黃土) 실은 이 땅 봄바람이'),
#  Document(metadata={}, page_content='호인(胡人)의 물레바퀴처럼 돌아 지나고'),
#  Document(metadata={}, page_content='아롱진 사월(四月) 태양(太陽)의 손길이'),
#  Document(metadata={}, page_content='벽(壁)을 등진 섧은 가슴마다 올올히 만진다.'),
#  Document(metadata={}, page_content='지도(地圖)째기 놀음에 뉘 땅인 줄 모르는 애 둘이'),
#  Document(metadata={}, page_content='한 뼘 손가락이 짧음을 한(恨)하며'),
#  Document(metadata={}, page_content='아서라! 가뜩이나 엷은 평화(平和)가'),
#  Document(metadata={}, page_content='깨어질까 근심스럽다.'),
#  Document(metadata={}, page_content='한간(一間) 계사(鷄舍) 그 넘어 창공(蒼空)이 깃들어'),
#  Document(metadata={}, page_content='자유(自由)의 향토(鄕土)를 잊은 닭들이'),
#  Document(metadata={}, page_content='시들은 생활(生活)을 주잘대고'),
#  Document(metadata={}, page_content='생산(生産)의 고로(苦勞)를 부르짖었다.'),
#  Document(metadata={}, page_content='음산(陰酸)한 계사(鷄舍)에서 쏠려나온'),
#  Document(metadata={}, page_content='외래종(外來種) 레구홍,'),
#  Document(metadata={}, page_content='학원(學園)에서 새무리가 밀려나오는'),
#  Document(metadata={}, page_content='삼월(三月)의 맑은 오후(午後)도 있다.'),
#  Document(metadata={}, page_content='닭들은 녹아드는 두엄을 파기에'),
#  Document(metadata={}, page_content='아담(雅淡)한 두 다리가 분주(奔走)하고'),
#  Document(metadata={}, page_content='굶주렸던 주둥이(주두리)가 바즈런하다.'),
#  Document(metadata={}, page_content='두 눈이 붉게 여므도록——'),
#  Document(metadata={}, page_content='불 꺼진 화독(火독)을'),
#  Document(metadata={}, page_content='안고 도는 겨울밤은 깊었다.'),
#  Document(metadata={}, page_content='재(灰)만 남은 가슴이'),
#  Document(metadata={}, page_content='문풍지 소리에 떤다.'),
#  Document(metadata={}, page_content='안아보고싶게 귀여운'),
#  Document(metadata={}, page_content='산비들기 일곱마리'),
#  Document(metadata={}, page_content='하늘끝까지 보일듯이 맑은 공일날 아침에'),
#  Document(metadata={}, page_content='벼를 거두어 빤빤한 논에'),
#  Document(metadata={}, page_content='앞을 다투어 모이를 주으며'),
#  Document(metadata={}, page_content='어려운 이야기를 주고 받으오'),
#  Document(metadata={}, page_content='날신한 두나래로 조용한 공기를 흔들어'),
#  Document(metadata={}, page_content='두마리가 나오'),
#  Document(metadata={}, page_content='집에 새끼 생각이 나는 모양이오.'),
#  Document(metadata={}, page_content='그 여름날'),
#  Document(metadata={}, page_content='열정(熱情)의 포푸라는'),
#  Document(metadata={}, page_content='오려는 창공(蒼空)의 푸른 젖가슴을'),
#  Document(metadata={}, page_content='어루만지려'),
#  Document(metadata={}, page_content='팔을 펼쳐 흔들거렸다.'),
#  Document(metadata={}, page_content='끓는 태양(太陽) 그늘 좁다란 지점(地點)에서'),
#  Document(metadata={}, page_content='천막(天幕) 같은 하늘 밑에서'),
#  Document(metadata={}, page_content='떠들던 소나기'),
#  Document(metadata={}, page_content='그리고 번개를,'),
#  Document(metadata={}, page_content='춤추던 구름은 이끌고'),
#  Document(metadata={}, page_content='남방(南方)으로 도망하고,'),
#  Document(metadata={}, page_content='높다랗게 창공(蒼空)은 한 폭으로'),
#  Document(metadata={}, page_content='가지 위에 퍼지고'),
#  Document(metadata={}, page_content='둥근 달과 기러기를 불러왔다.'),
#  Document(metadata={}, page_content='푸드른 어린 마음이 이상(理想)에 타고,'),
#  Document(metadata={}, page_content='그의 동경(憧憬)의 날 가을에'),
#  Document(metadata={}, page_content='조락(凋落)의 눈물을 비웃다.'),
#  Document(metadata={}, page_content='삶은 오늘도 죽음의 서곡(序曲)을 노래하였다.'),
#  Document(metadata={}, page_content='이 노래가 언제나 끝나랴'),
#  Document(metadata={}, page_content='세상사람은——'),
#  Document(metadata={}, page_content='뼈를 녹여내는 듯한 삶의 노래에'),
#  Document(metadata={}, page_content='춤을 춘다.'),
#  Document(metadata={}, page_content='사람들은 해가 넘어가기 전'),
#  Document(metadata={}, page_content='이 노래 끝의 공포(恐怖)를'),
#  Document(metadata={}, page_content='생각할 사이가 없었다.'),
#  Document(metadata={}, page_content='하늘 복판에 알새기 듯이'),
#  Document(metadata={}, page_content='이 노래를 부른 자(者)가 누구뇨'),
#  Document(metadata={}, page_content='그리고 소낙비 그친 뒤같이도'),
#  Document(metadata={}, page_content='이 노래를 그친 자(者)가 누구뇨'),
#  Document(metadata={}, page_content='죽고 뼈만 남은'),
#  Document(metadata={}, page_content='죽음의 승리자(勝利者) 위인(偉人)들!'),
#  Document(metadata={}, page_content='초 한 대——'),
#  Document(metadata={}, page_content='내 방에 품긴 향내를 맡는다.'),
#  Document(metadata={}, page_content='광명(光明)의 제단(祭壇)이 무너지기 전'),
#  Document(metadata={}, page_content='나는 깨끗한 제물(祭物)을 보았다.'),
#  Document(metadata={}, page_content='염소의 갈비뼈 같은 그의 몸,'),
#  Document(metadata={}, page_content='그의 생명(生命)인 심지(心志)까지'),
#  Document(metadata={}, page_content='백옥(白玉) 같은 눈물과 피를 흘려'),
#  Document(metadata={}, page_content='불살려 버린다.'),
#  Document(metadata={}, page_content='그리고도 책상머리에 아롱거리며'),
#  Document(metadata={}, page_content='선녀처럼 촛불은 춤을 춘다.'),
#  Document(metadata={}, page_content='매를 본 꿩이 도망하듯이'),
#  Document(metadata={}, page_content='암흑(暗黑)이 창구멍으로 도망한'),
#  Document(metadata={}, page_content='나의 방에 품긴'),
#  Document(metadata={}, page_content='제물(祭物)의 위대한 향내(香內)를 맛보노라.'),
#  Document(metadata={}, page_content='까치가 울어서'),
#  Document(metadata={}, page_content='아무도 못들은'),
#  Document(metadata={}, page_content='산울림,'),
#  Document(metadata={}, page_content='까치가 들었다,'),
#  Document(metadata={}, page_content='저혼자 들었다,'),
#  Document(metadata={}, page_content='누나의 얼굴은'),
#  Document(metadata={}, page_content='해바라기 얼굴'),
#  Document(metadata={}, page_content='해가 금방 뜨자'),
#  Document(metadata={}, page_content='일터에 간다.'),
#  Document(metadata={}, page_content='해바라기 얼굴은'),
#  Document(metadata={}, page_content='누나의 얼굴'),
#  Document(metadata={}, page_content='얼굴이 숙어들어'),
#  Document(metadata={}, page_content='집으로 온다.'),
#  Document(metadata={}, page_content='잔디밭에서 이야기 했다.'),
#  Document(metadata={}, page_content='아무게도 아르켜 주지말고'),
#  Document(metadata={}, page_content='우리둘만 알자고 약속했다.'),
#  Document(metadata={}, page_content='귀뜰귀뜰'),
#  Document(metadata={}, page_content='귀뜨라미와 나와'),
#  Document(metadata={}, page_content='달밝은 밤에 이야기했다.'),
#  Document(metadata={}, page_content='우리집에는'),
#  Document(metadata={}, page_content='닭도 없단다.'),
#  Document(metadata={}, page_content='애기가 젖달라 울어서'),
#  Document(metadata={}, page_content='새벽이 된다.'),
#  Document(metadata={}, page_content='시계도 없단다.'),
#  Document(metadata={}, page_content='다만'),
#  Document(metadata={}, page_content='애기가 젖달라 보채어'),
#  Document(metadata={}, page_content='달조각을 주으려'),
#  Document(metadata={}, page_content='그믐밤 반디불은'),
#  Document(metadata={}, page_content='부서진 달조각,'),
#  Document(metadata={}, page_content='가자 가자 가자'),
#  Document(metadata={}, page_content='숲으로 가자'),
#  Document(metadata={}, page_content='바다도 푸르고'),
#  Document(metadata={}, page_content='하늘도 푸르고'),
#  Document(metadata={}, page_content='바다도 끝없고'),
#  Document(metadata={}, page_content='하늘도 끝없고'),
#  Document(metadata={}, page_content='바다에 돌던지고'),
#  Document(metadata={}, page_content='하늘에 침뱉고'),
#  Document(metadata={}, page_content='바다는 벙글'),
#  Document(metadata={}, page_content='하늘은 잠잠.'),
#  Document(metadata={}, page_content='똑, 똑, 똑,'),
#  Document(metadata={}, page_content='문좀 열어 주세요'),
#  Document(metadata={}, page_content='하루밤 자고 갑시다.'),
#  Document(metadata={}, page_content='밤은 깊고 날은 추운데'),
#  Document(metadata={}, page_content='거 누굴까?'),
#  Document(metadata={}, page_content='문열어 주고 보니'),
#  Document(metadata={}, page_content='검둥이의 꼬리가'),
#  Document(metadata={}, page_content='거짓부리한걸.'),
#  Document(metadata={}, page_content='꼬기요, 꼬기요,'),
#  Document(metadata={}, page_content='달걀 낳았다.'),
#  Document(metadata={}, page_content='간난아 어서 집어 가거라'),
#  Document(metadata={}, page_content='간난이 뛰어가 보니'),
#  Document(metadata={}, page_content='달걀은 무슨 달걀,'),
#  Document(metadata={}, page_content='고놈의 암탉이'),
#  Document(metadata={}, page_content='대낮에 새빨간'),
#  Document(metadata={}, page_content='거짓부리 한걸.'),
#  Document(metadata={}, page_content='지난밤에'),
#  Document(metadata={}, page_content='눈이 소오복이 왔네'),
#  Document(metadata={}, page_content='지붕이랑'),
#  Document(metadata={}, page_content='길이랑 밭이랑'),
#  Document(metadata={}, page_content='추워 한다고'),
#  Document(metadata={}, page_content='덮어주는 이불인가바'),
#  Document(metadata={}, page_content='그러기에'),
#  Document(metadata={}, page_content='추운 겨을에만 나리지'),
#  Document(metadata={}, page_content='가을지난 마당은 하이얀종이'),
#  Document(metadata={}, page_content='참새들이 글씨를 공부하지요.'),
#  Document(metadata={}, page_content='째액째액 입으로 받아읽으며'),
#  Document(metadata={}, page_content='두발로는 글씨를 연습하지요.'),
#  Document(metadata={}, page_content='하로종일 글씨를 공부하여도'),
#  Document(metadata={}, page_content='짹자한자 밖에는 더못쓰는걸.'),
#  Document(metadata={}, page_content='누나 쓰다버린 습자지는'),
#  Document(metadata={}, page_content='두었다간 뭣에 쓰나요?'),
#  Document(metadata={}, page_content='그런줄 몰랐드니'),
#  Document(metadata={}, page_content='습자지에다 내버선 놓고'),
#  Document(metadata={}, page_content='가위로 오려'),
#  Document(metadata={}, page_content='버선본 만드는걸.'),
#  Document(metadata={}, page_content='어머니'),
#  Document(metadata={}, page_content='내가 쓰다버린 몽당연필은'),
#  Document(metadata={}, page_content='천우에다 버선본 놓고'),
#  Document(metadata={}, page_content='침발려 점을 찍곤'),
#  Document(metadata={}, page_content='내버선 만드는걸.'),
#  Document(metadata={}, page_content='바닷가 사람'),
#  Document(metadata={}, page_content='물고기 잡아 먹고 살고'),
#  Document(metadata={}, page_content='산골엣 사람'),
#  Document(metadata={}, page_content='감자 구어 먹고 살고'),
#  Document(metadata={}, page_content='별나라 사람'),
#  Document(metadata={}, page_content='무얼 먹고 사나.'),
#  Document(metadata={}, page_content='산골작이 오막사리 낮은 굴뚝엔'),
#  Document(metadata={}, page_content='몽기몽기 웨인연기 대낮에 솟나,'),
#  Document(metadata={}, page_content='감자를 굽는게지 총각애들이'),
#  Document(metadata={}, page_content='깜박깜박 검은눈이 모여 앉어서'),
#  Document(metadata={}, page_content='입술에 꺼멓게 숯을 바르고'),
#  Document(metadata={}, page_content='옛이야기 한커리에 감자 하나씩.'),
#  Document(metadata={}, page_content='살랑살랑 솟아나네 감자 굽는내.'),
#  Document(metadata={}, page_content='아씨처럼 나린다'),
#  Document(metadata={}, page_content='보슬보슬 해ㅅ비'),
#  Document(metadata={}, page_content='맞아주자 다같이'),
#  Document(metadata={}, page_content='옥수숫대 처럼 크게'),
#  Document(metadata={}, page_content='닷자엿자 자라게'),
#  Document(metadata={}, page_content='햇님이 웃는다'),
#  Document(metadata={}, page_content='나보고 웃는다.'),
#  Document(metadata={}, page_content='하늘다리 놓였다'),
#  Document(metadata={}, page_content='알롱알롱 무지개'),
#  Document(metadata={}, page_content='노래하자 즐겁게'),
#  Document(metadata={}, page_content='동무들아 이리 오나'),
#  Document(metadata={}, page_content='다같이 춤을추자'),
#  Document(metadata={}, page_content='즐거워 웃는다'),
#  Document(metadata={}, page_content='비오는날 저녁에 기왓장내외'),
#  Document(metadata={}, page_content='잃어버린 외아들 생각나선지'),
#  Document(metadata={}, page_content='꼬부라진 잔등을 어루만지며'),
#  Document(metadata={}, page_content='쭈룩쭈룩 구슬피 울음웁니다.'),
#  Document(metadata={}, page_content='대궐지붕 위에서 기왓장내외'),
#  Document(metadata={}, page_content='아름답든 옛날이 그리워선지'),
#  Document(metadata={}, page_content='주름잡힌 얼굴을 어루만지며'),
#  Document(metadata={}, page_content='물끄럼히 하늘만 쳐다봅니다.'),
#  Document(metadata={}, page_content='빨래줄에 걸어논'),
#  Document(metadata={}, page_content='요에다 그린지도'),
#  Document(metadata={}, page_content='지난밤에 내동생'),
#  Document(metadata={}, page_content='오줌싸 그린지도'),
#  Document(metadata={}, page_content='꿈에 가본 엄마계신'),
#  Document(metadata={}, page_content='별나라 지돈가?'),
#  Document(metadata={}, page_content='돈벌러간 아빠계신'),
#  Document(metadata={}, page_content='만주땅 지돈가?'),
#  Document(metadata={}, page_content='아롱아롱 조개껍대기'),
#  Document(metadata={}, page_content='울언니 바다가에서'),
#  Document(metadata={}, page_content='주어온 조개껍대기'),
#  Document(metadata={}, page_content='여긴여긴 북쪽나라요'),
#  Document(metadata={}, page_content='조개는 귀여운선물'),
#  Document(metadata={}, page_content='장난감 조개껍대기'),
#  Document(metadata={}, page_content='데굴데굴 굴리며놀다'),
#  Document(metadata={}, page_content='짝잃은 조개껍대기'),
#  Document(metadata={}, page_content='한짝을 그리워하네'),
#  Document(metadata={}, page_content='나처럼 그리워하네'),
#  Document(metadata={}, page_content='물소리 바다물소리.'),
#  Document(metadata={}, page_content='나 보기가 역겨워'),
#  Document(metadata={}, page_content='가실 때에는'),
#  Document(metadata={}, page_content='말없이 고이 보내드리오리다.'),
#  Document(metadata={}, page_content='영변(寧邊)에 약산(藥山)'),
#  Document(metadata={}, page_content='진달래꽃'),
#  Document(metadata={}, page_content='아름따다 가실 길에 뿌리오리다.'),
#  Document(metadata={}, page_content='가시는 걸음 걸음'),
#  Document(metadata={}, page_content='놓인 그 꽃을'),
#  Document(metadata={}, page_content='사뿐히 즈려밟고 가시옵소서.'),
#  Document(metadata={}, page_content='죽어도 아니 눈물 흘리오리다.'),
#  Document(metadata={}, page_content='엄마야 누나야 강변 살자,'),
#  Document(metadata={}, page_content='뜰에는 반짝는 금모래빛,'),
#  Document(metadata={}, page_content='뒷문 밖에는 갈잎의 노래'),
#  Document(metadata={}, page_content='엄마야 누나야 강변 살자.'),
#  Document(metadata={}, page_content='봄 가을없이 밤마다 돋는 달도'),
#  Document(metadata={}, page_content="예전엔 미처 몰랐어요.'"),
#  Document(metadata={}, page_content='이렇게 사무치게 그립을줄도'),
#  Document(metadata={}, page_content='달이 암만 밝아도 쳐다볼줄을'),
#  Document(metadata={}, page_content='이제금 저 달이 설움인줄은'),
#  Document(metadata={}, page_content='먼 훗날 당신이 찾으시면'),
#  Document(metadata={}, page_content="그때에 내 말이 `잊었노라'"),
#  Document(metadata={}, page_content='당신이 속으로 나무라면'),
#  Document(metadata={}, page_content="`무척 그리다가 잊었노라'"),
#  Document(metadata={}, page_content='그래도 당신이 나무라면'),
#  Document(metadata={}, page_content="`믿기지 않아서 잊었노라'"),
#  Document(metadata={}, page_content='오늘도 어제도 아니 잊고'),
#  Document(metadata={}, page_content="먼 훗날 그때에 `잊었노라'"),
#  Document(metadata={}, page_content='산산이 부서진 이름이어!'),
#  Document(metadata={}, page_content='허공중(虛空中)에 헤어진 이름이어!'),
#  Document(metadata={}, page_content='불러도 주인(主人)없는 이름이어!'),
#  Document(metadata={}, page_content='부르다가 내가 죽을 이름이어!'),
#  Document(metadata={}, page_content='심중(心中)에 남아있는 말 한마디는'),
#  Document(metadata={}, page_content='끝끝내 마저하지 못하였구나.'),
#  Document(metadata={}, page_content='사랑하던 그 사람이어!'),
#  Document(metadata={}, page_content='붉은 해는 서산(西山) 마루에 걸리었다.'),
#  Document(metadata={}, page_content='사슴이의 무리도 슬피 운다.'),
#  Document(metadata={}, page_content='떨어져 나가앉은 산 위에서'),
#  Document(metadata={}, page_content='나는 그대의 이름을 부르노라.'),
#  Document(metadata={}, page_content='설움에 겹도록 부르노라.'),
#  Document(metadata={}, page_content='부르는 소리는 비껴가지만'),
#  Document(metadata={}, page_content='하늘과 땅 사이가 너무 넓구나.'),
#  Document(metadata={}, page_content='선 채로 이 자리에 돌이 되어도'),
#  Document(metadata={}, page_content='걷잡지 못할만한 나의 이 설움,'),
#  Document(metadata={}, page_content='저무는 봄저녁에 져가는 꽃잎,'),
#  Document(metadata={}, page_content='져가는 꽃잎들은 나부끼어라.'),
#  Document(metadata={}, page_content='예로부터 일러오며 하는 말에도'),
#  Document(metadata={}, page_content='바다가 변하야 뽕나무밭 된다고.'),
#  Document(metadata={}, page_content='그러하다, 아름답은 청춘의 때의'),
#  Document(metadata={}, page_content='있다던 온갖 것은 눈에 설고'),
#  Document(metadata={}, page_content='다시금 낯 모르게 되나니,'),
#  Document(metadata={}, page_content='보아라, 그대여, 서럽지 않은가,'),
#  Document(metadata={}, page_content='봄에도 삼월의 져가는 날에'),
#  Document(metadata={}, page_content='붉은 피같이도 쏟아져 나리는'),
#  Document(metadata={}, page_content='저기 저 꽃잎들을, 저기 저 꽃잎들을'),
#  Document(metadata={}, page_content='우리 두 사람은'),
#  Document(metadata={}, page_content='키높이 가득 자란 보리밭, 밭고랑 위에 앉았어라.'),
#  Document(metadata={}, page_content='일을 필하고 쉬이는 동안의 기쁨이어.'),
#  Document(metadata={}, page_content='지금 두 사람의 이야기에는 꽃이 필 때.'),
#  Document(metadata={}, page_content='오오 빛나는 태양은 나려 쪼이며'),
#  Document(metadata={}, page_content='새무리들도 즐겁은 노래, 노래 불러라.'),
#  Document(metadata={}, page_content='오오 은혜여, 살아있는 몸에는 넘치는 은혜여'),
#  Document(metadata={}, page_content='모든 은근스럽음이 우리의 맘 속을 차지하여라.'),
#  Document(metadata={}, page_content='세계의 끝은 어디? 자애의 하늘은 넓게도 덮혔는데,'),
#  Document(metadata={}, page_content='우리 두 사람은 일하며, 살아있어서,'),
#  Document(metadata={}, page_content='하늘과 태양을 바라보아라, 날마다 날마다도,'),
#  Document(metadata={}, page_content='새라새롭은 환희를 지어내며, 늘 같은 땅 위에서.'),
#  Document(metadata={}, page_content='다시한번 활기있게 웃고나서, 우리 두 사람은'),
#  Document(metadata={}, page_content='바람에 일리우는 보리밭 속으로'),
#  Document(metadata={}, page_content='호미들고 들어갔어라, 가즈런히 가즈런히'),
#  Document(metadata={}, page_content='걸어나아가는 기쁨이어, 오오 생명의 향상이어.'),
#  Document(metadata={}, page_content='홀로 잠들기가 참말 외로와요'),
#  Document(metadata={}, page_content='맘에는 사무치도록 그리워와요'),
#  Document(metadata={}, page_content='이리도 무던히'),
#  Document(metadata={}, page_content='아주 얼굴조차 잊힐듯해요.'),
#  Document(metadata={}, page_content='벌써 해가 지고 어둡는대요,'),
#  Document(metadata={}, page_content='이곳은 인천에 제물포, 이름난 곳,'),
#  Document(metadata={}, page_content='부슬부슬 오는 비에 밤이 더디고'),
#  Document(metadata={}, page_content='바다바람이 춥기만 합니다.'),
#  Document(metadata={}, page_content='다만 고요히 누워 들으면'),
#  Document(metadata={}, page_content='하이얗게 밀어드는 봄 밀물이'),
#  Document(metadata={}, page_content='눈앞을 가루막고 흐느낄 뿐이야요.'),
#  Document(metadata={}, page_content='희멀끔하여 떠돈다, 하늘 위에,'),
#  Document(metadata={}, page_content='빛죽은 반달이 언제 올랐나!'),
#  Document(metadata={}, page_content='바람은 나온다, 저녁은 춥구나,'),
#  Document(metadata={}, page_content='흰 물가엔 뚜렷이 해가 드누나.'),
#  Document(metadata={}, page_content='어둑컴컴한 풀없는 들은'),
#  Document(metadata={}, page_content='찬 안개 우흐로 떠흐른다.'),
#  Document(metadata={}, page_content='아, 겨울은 깊었다, 내 몸에는,'),
#  Document(metadata={}, page_content='가슴이 무너져 나려앉는 이 설움아!'),
#  Document(metadata={}, page_content='가는 님은 가슴에 사랑까지 없애고 가고'),
#  Document(metadata={}, page_content='젊음은 늙음으로 바뀌어든다.'),
#  Document(metadata={}, page_content='들가시나무의 밤드는 검은 가지'),
#  Document(metadata={}, page_content='잎새들만 저녁빛에 희그무려히 꽃지듯한다.'),
#  Document(metadata={}, page_content='봄에 부는 바람, 바람부는 봄,'),
#  Document(metadata={}, page_content='적은가지 흔들리는 부는 봄바람,'),
#  Document(metadata={}, page_content='내 가슴 흔들리는 바람, 부는 봄,'),
#  Document(metadata={}, page_content='봄이라 바람이라 이내 몸에는'),
#  Document(metadata={}, page_content='꽃이라 술잔이라 하며 우노라.'),
#  Document(metadata={}, page_content='실버드나무의 검으스렷한 머리결인 낡은 가지에'),
#  Document(metadata={}, page_content='제비의 넓은 깃나래의 감색 치마에'),
#  Document(metadata={}, page_content='술집의 창 옆에, 보아라, 봄이 앉았지 않은가.'),
#  Document(metadata={}, page_content='소리도 없이 바람은 불며, 울며, 한숨지워라.'),
#  Document(metadata={}, page_content='아무런 줄도 없이 섧고 그립은 새카만 봄밤'),
#  Document(metadata={}, page_content='보드랍은 습기는 떠돌며 땅을 덮어라.'),
#  Document(metadata={}, page_content='거울들어 마주 온 내 얼굴을'),
#  Document(metadata={}, page_content='좀 더 미리부터 알았던들!'),
#  Document(metadata={}, page_content='늙는 날 죽는 날을'),
#  Document(metadata={}, page_content='사람은 다 모르고 사는 탓에,'),
#  Document(metadata={}, page_content='오오 오직 이것이 참이라면,'),
#  Document(metadata={}, page_content='그러나 내 세상이 어디인지?'),
#  Document(metadata={}, page_content='지금부터 두여덟 좋은 연광'),
#  ...]

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings

# %%
! pip install sentence-transformers
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting sentence-transformers
#   Downloading sentence_transformers-4.1.0-py3-none-any.whl (345 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 345.7/345.7 kB 9.3 MB/s eta 0:00:00
# Requirement already satisfied: scipy in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from sentence-transformers) (1.15.3)
# Requirement already satisfied: typing_extensions>=4.5.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from sentence-transformers) (4.14.0)
# Requirement already satisfied: Pillow in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from sentence-transformers) (11.2.1)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from sentence-transformers) (4.52.4)
# Requirement already satisfied: scikit-learn in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from sentence-transformers) (1.7.0)
# Requirement already satisfied: tqdm in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from sentence-transformers) (4.67.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from sentence-transformers) (0.32.4)
# Requirement already satisfied: torch>=1.11.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from sentence-transformers) (2.7.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (1.1.3)
# Requirement already satisfied: requests in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (2.32.4)
# Requirement already satisfied: packaging>=20.9 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (24.2)
# Requirement already satisfied: filelock in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (3.18.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.20.0->sentence-transformers) (6.0.2)
# Requirement already satisfied: sympy>=1.13.3 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (1.14.0)
# Requirement already satisfied: networkx in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: jinja2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torch>=1.11.0->sentence-transformers) (3.1.6)
# Requirement already satisfied: numpy>=1.17 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2.2.6)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.21.1)
# Requirement already satisfied: regex!=2019.12.17 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (2024.11.6)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers) (0.5.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from scikit-learn->sentence-transformers) (3.6.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=1.11.0->sentence-transformers) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from jinja2->torch>=1.11.0->sentence-transformers) (3.0.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2025.4.26)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers) (2.4.0)
# Installing collected packages: sentence-transformers
# Successfully installed sentence-transformers-4.1.0
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# 3️⃣ 벡터 임베딩 모델 로딩 (한국어 지원하는 모델 권장)
embedding_model = HuggingFaceEmbeddings(model_name="jhgan/ko-sbert-sts")
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# modules.json:   0%|          | 0.00/229 [00:00<?, ?B/s]
# config_sentence_transformers.json:   0%|          | 0.00/123 [00:00<?, ?B/s]
# README.md:   0%|          | 0.00/4.44k [00:00<?, ?B/s]
# sentence_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/620 [00:00<?, ?B/s]
# pytorch_model.bin:   0%|          | 0.00/443M [00:00<?, ?B/s]
# tokenizer_config.json:   0%|          | 0.00/538 [00:00<?, ?B/s]
# vocab.txt:   0%|          | 0.00/248k [00:00<?, ?B/s]
# model.safetensors:   0%|          | 0.00/442M [00:00<?, ?B/s]
# tokenizer.json:   0%|          | 0.00/495k [00:00<?, ?B/s]
# special_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]

# %%
! pip install faiss-cpu
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0-cp310-cp310-macosx_14_0_arm64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 11.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from faiss-cpu) (2.2.6)
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.11.0
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# 4️⃣ FAISS VectorDB 생성
vectorstore = FAISS.from_documents(documents, embedding_model)

# %%
# 2️⃣ 감정 기반 프롬프트 생성
def generate_prompt_withVector(emotion_scores, context_snippets):
    top_emotion = max(emotion_scores, key=emotion_scores.get)
    return f"""당신은 감정이 섬세한 한국 현대시 작가입니다.
'{top_emotion}'의 감정을 중심으로 짧은 시를 한 편 창작해 주세요.
다음은 감정의 분위기를 도와줄 참고 문장입니다:
{context_snippets}

이 문장들을 참고하여 시를 지어 주세요.
"""

# %%
# 8️⃣ 전체 체인
def emotion_to_poetry(user_input):
    scores = classify_emotion(user_input)
    top_emotion = max(scores, key=scores.get)

    # 관련 시구 검색
    context_snippets = vectorstore.similarity_search(top_emotion, k=5)

    # 프롬프트 생성
    full_prompt = generate_prompt_withVector(scores, context_snippets)

    # LangChain Prompt + LLM 실행
    prompt = PromptTemplate.from_template("{emotion_prompt}")
    chain = LLMChain(llm=llm, prompt=prompt)
    result = chain.run(emotion_prompt=full_prompt)

    return result

# %%
# 9️⃣ 테스트 실행
user_text = """하루 종일 지친 몸으로만 떠돌다가
땅에 떨어져 죽지 못한
햇빛들은 줄지어 어디로 가는 걸까


웅성웅성 가장 근심스러운 색깔로 서행하며
이미 어둠이 깔리는 소각장으로 몰려들어
몇 점 폐휴지로 타들어가는 오루 6시의 참혹한 형량
단 한 번 후회도 용서하지 않는 무서운 시간
바람은 긴 채찍을 휘둘러
살아서 빛나는 온갖 상징을 몰아내고 있다.


도시는 곧 활자들이 일제히 빠져 달아나
속도 없이 페이지를 펄럭이는 텅 빈 한 권 책이 되리라.
승부를 알 수 없는 하루와의 싸움에서
우리는 패배했을까. 오늘도 물어보는 사소한 물음은
그러나 우리의 일생을 텅텅 흔드는 것.


오후 6시의 소각장 위로 말없이
검은 연기가 우산처럼 펼쳐지고
이젠 우리들의 차례였다.
두렵지 않은가.
밤이면 그림자를 빼앗겨 누구나 아득한 혼자였다.


문득 거리를 빠르게 스쳐가는 일상의 공포
보여다오. 지금까지 무엇을 했는가 살아 있는 그대여
오후 6시 우리들 이마에도 아, 붉은 노을이 떴다.


그러면 우리는 어디로 가지?
아직도 펄펄 살아 있는 우리는 이제 각자 어디로 가지?
""" # 기형도 - 노을
generated_poem = emotion_to_poetry(user_text)

print("🎴 생성된 시:\n", generated_poem)
# Out:
# [Sample Inference 결과]
# {'공포/무서움': 0.4350000023841858, '놀람': 0.30799999833106995, '당황/난처': 0.5139999985694885, '부담/안_내킴': 0.39899998903274536, '불안/걱정': 0.5479999780654907, '불평/불만': 0.30300000309944153, '비장함': 0.33899998664855957, '서러움': 0.35100001096725464, '슬픔': 0.414000004529953, '신기함/관심': 0.3109999895095825, '안타까움/실망': 0.30799999833106995, '의심/불신': 0.30799999833106995, '힘듦/지침': 0.33899998664855957}
# 🎴 생성된 시:
#  아름다운 밤을 지내도,
#
# 걱정이든, 깨어질까 근심스럽다.
#
# 사랑의 말로 못할 깊은 불안에,
#
# 안정 밖에 있겠나.
#
# 꿈과 근심이 있거든,
#
# 그리고 그 밤에는 무언가의 불안한 미리미리
#
# 저는 내일을 두려워한다.
#
# 지금은 어둠에 포용된다.
#
# 그 nighttime에는 깊은 불안이 찾아오고,
#
# 어찌할 수 있는 안정감을 잃었다.
#
# 어떤夜에 깊은 근심이 지속되기 시작했다.
#
# 그 밤에는 내일과Tomorrow가의 불안감을 받았다.
#
# 그리고 그밖의 모든 불안감을 다 가슴에 안고
#
# 어떤nightingale에 내성스러운 우울함이 들어간다
#
# 그 nighttime에서,
#
# 저는 어두운 nightside가의 불안에 잠들어 있었다.
