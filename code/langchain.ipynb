# %%
# 1. 필요한 라이브러리 설치 (가상 환경이 활성화된 상태에서)
# !pip install langchain langchain-community langchain-core
# !pip install transformers torch  # 또는 tensorflow (선호하는 딥러닝 프레임워크에 따라)
# !pip install pytorch-lightning
# !pip install datasets
# !pip install scikit-learn
# !pip install pandas
# !pip install sentence-transformers
# Out:
# Requirement already satisfied: langchain in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (0.3.25)
# Requirement already satisfied: langchain-community in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (0.3.25)
# Requirement already satisfied: langchain-core in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (0.3.65)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langchain) (2.11.5)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langchain) (2.0.41)
# Requirement already satisfied: langchain-text-splitters<1.0.0,>=0.3.8 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langchain) (0.3.8)
# Requirement already satisfied: PyYAML>=5.3 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langchain) (6.0.2)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langchain) (4.0.3)
# Requirement already satisfied: langsmith<0.4,>=0.1.17 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langchain) (0.3.45)
# Requirement already satisfied: requests<3,>=2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langchain) (2.32.4)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langchain-community) (0.4.0)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.4.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langchain-community) (2.9.1)
# Requirement already satisfied: dataclasses-json<0.7,>=0.5.7 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: numpy>=1.26.2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langchain-community) (2.2.6)
# Requirement already satisfied: tenacity!=8.4.0,<10,>=8.1.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langchain-community) (9.1.2)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langchain-community) (3.12.12)
# Requirement already satisfied: typing-extensions>=4.7 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langchain-core) (4.14.0)
# Requirement already satisfied: packaging<25,>=23.2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langchain-core) (24.2)
# Requirement already satisfied: jsonpatch<2.0,>=1.33 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langchain-core) (1.33)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (25.3.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.7.0)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.20.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.3.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (0.9.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from dataclasses-json<0.7,>=0.5.7->langchain-community) (3.26.1)
# Requirement already satisfied: jsonpointer>=1.9 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from jsonpatch<2.0,>=1.33->langchain-core) (3.0.0)
# Requirement already satisfied: httpx<1,>=0.23.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.28.1)
# Requirement already satisfied: requests-toolbelt<2.0.0,>=1.0.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.17->langchain) (1.0.0)
# Requirement already satisfied: orjson<4.0.0,>=3.9.14 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.17->langchain) (3.10.18)
# Requirement already satisfied: zstandard<0.24.0,>=0.23.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from langsmith<0.4,>=0.1.17->langchain) (0.23.0)
# Requirement already satisfied: typing-inspection>=0.4.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.1)
# Requirement already satisfied: annotated-types>=0.6.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.33.2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.33.2)
# Requirement already satisfied: python-dotenv>=0.21.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from pydantic-settings<3.0.0,>=2.4.0->langchain-community) (1.1.0)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2025.4.26)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2.4.0)
# Requirement already satisfied: httpcore==1.* in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.0.9)
# Requirement already satisfied: anyio in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (4.9.0)
# Requirement already satisfied: h11>=0.16 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from httpcore==1.*->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (0.16.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7,>=0.5.7->langchain-community) (1.1.0)
# Requirement already satisfied: sniffio>=1.1 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.1)
# Requirement already satisfied: exceptiongroup>=1.0.2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from anyio->httpx<1,>=0.23.0->langsmith<0.4,>=0.1.17->langchain) (1.3.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: transformers in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (4.52.4)
# Requirement already satisfied: torch in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (2.7.1)
# Requirement already satisfied: filelock in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers) (3.18.0)
# Requirement already satisfied: regex!=2019.12.17 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: packaging>=20.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers) (24.2)
# Requirement already satisfied: numpy>=1.17 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers) (2.2.6)
# Requirement already satisfied: tqdm>=4.27 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: requests in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers) (2.32.4)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers) (0.32.4)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers) (0.21.1)
# Requirement already satisfied: jinja2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torch) (2025.3.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torch) (4.14.0)
# Requirement already satisfied: networkx in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: sympy>=1.13.3 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torch) (1.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.3)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests->transformers) (2.4.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests->transformers) (3.10)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pytorch-lightning in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (2.5.1.post0)
# Requirement already satisfied: fsspec[http]>=2022.5.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from pytorch-lightning) (2025.3.0)
# Requirement already satisfied: packaging>=20.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from pytorch-lightning) (24.2)
# Requirement already satisfied: torch>=2.1.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from pytorch-lightning) (2.7.1)
# Requirement already satisfied: tqdm>=4.57.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from pytorch-lightning) (4.67.1)
# Requirement already satisfied: torchmetrics>=0.7.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from pytorch-lightning) (1.7.2)
# Requirement already satisfied: lightning-utilities>=0.10.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from pytorch-lightning) (0.14.3)
# Requirement already satisfied: typing-extensions>=4.4.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from pytorch-lightning) (4.14.0)
# Requirement already satisfied: PyYAML>=5.4 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from pytorch-lightning) (6.0.2)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from fsspec[http]>=2022.5.0->pytorch-lightning) (3.12.12)
# Requirement already satisfied: setuptools in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from lightning-utilities>=0.10.0->pytorch-lightning) (65.5.0)
# Requirement already satisfied: jinja2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.1.6)
# Requirement already satisfied: sympy>=1.13.3 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (1.14.0)
# Requirement already satisfied: filelock in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.18.0)
# Requirement already satisfied: networkx in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torch>=2.1.0->pytorch-lightning) (3.4.2)
# Requirement already satisfied: numpy>1.20.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torchmetrics>=0.7.0->pytorch-lightning) (2.2.6)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.20.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (4.0.3)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (2.6.1)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (6.4.4)
# Requirement already satisfied: propcache>=0.2.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (0.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.7.0)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (1.3.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=2.1.0->pytorch-lightning) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from jinja2->torch>=2.1.0->pytorch-lightning) (3.0.2)
# Requirement already satisfied: idna>=2.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from yarl<2.0,>=1.17.0->aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]>=2022.5.0->pytorch-lightning) (3.10)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: datasets in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (3.6.0)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from datasets) (0.32.4)
# Requirement already satisfied: packaging in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from datasets) (24.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from datasets) (20.0.0)
# Requirement already satisfied: tqdm>=4.66.3 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from datasets) (4.67.1)
# Requirement already satisfied: multiprocess<0.70.17 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from datasets) (0.70.16)
# Requirement already satisfied: filelock in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from datasets) (3.18.0)
# Requirement already satisfied: xxhash in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from datasets) (3.5.0)
# Requirement already satisfied: fsspec[http]<=2025.3.0,>=2023.1.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from datasets) (2025.3.0)
# Requirement already satisfied: pyyaml>=5.1 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from datasets) (6.0.2)
# Requirement already satisfied: dill<0.3.9,>=0.3.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from datasets) (0.3.8)
# Requirement already satisfied: pandas in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from datasets) (2.3.0)
# Requirement already satisfied: requests>=2.32.2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from datasets) (2.32.4)
# Requirement already satisfied: numpy>=1.17 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from datasets) (2.2.6)
# Requirement already satisfied: aiohttp!=4.0.0a0,!=4.0.0a1 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (3.12.12)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.24.0->datasets) (4.14.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.24.0->datasets) (1.1.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2025.4.26)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests>=2.32.2->datasets) (2.4.0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from pandas->datasets) (2.9.0.post0)
# Requirement already satisfied: propcache>=0.2.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (0.3.2)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (6.4.4)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.3.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.20.1)
# Requirement already satisfied: async-timeout<6.0,>=4.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (4.0.3)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (1.7.0)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (2.6.1)
# Requirement already satisfied: attrs>=17.3.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from aiohttp!=4.0.0a0,!=4.0.0a1->fsspec[http]<=2025.3.0,>=2023.1.0->datasets) (25.3.0)
# Requirement already satisfied: six>=1.5 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: scikit-learn in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (1.7.0)
# Requirement already satisfied: numpy>=1.22.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from scikit-learn) (2.2.6)
# Requirement already satisfied: scipy>=1.8.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from scikit-learn) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from scikit-learn) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from scikit-learn) (3.6.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: pandas in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (2.3.0)
# Requirement already satisfied: tzdata>=2022.7 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: numpy>=1.22.4 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from pandas) (2.2.6)
# Requirement already satisfied: pytz>=2020.1 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from pandas) (2025.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from pandas) (2.9.0.post0)
# Requirement already satisfied: six>=1.5 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from python-dateutil>=2.8.2->pandas) (1.17.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
from langchain_core.runnables import RunnablePassthrough, RunnableLambda
from transformers import pipeline, AutoTokenizer, AutoModelForSequenceClassification
import os
from torch.utils.data import Dataset, DataLoader
from datasets import load_dataset
import pandas as pd
import pytorch_lightning as pl
import torch
torch.set_float32_matmul_precision('medium')
import torch.nn as nn
import glob
from transformers import ElectraModel, AutoTokenizer, AutoModel
from sklearn.model_selection import train_test_split

# %%
###########################
# KOTE 파인튜닝 모델 로드 (체크포인트 파일 경로 수정)
###########################
best_ckpt_path_kote = './model/250127_KcElectra_kote.ckpt' # Colab 경로에 맞게 수정
print("Best checkpoint path (KOTE Finetuned):", best_ckpt_path_kote)
# Out:
# Best checkpoint path (KOTE Finetuned): ./model/250127_KcElectra_kote.ckpt

# %%
# KOTETagger 클래스는 이전 코드와 동일
class KOTETagger(pl.LightningModule): # KOTETagger 클래스 정의 (이전 코드에서 복사)
    def __init__(self, n_training_steps=None, n_warmup_steps=None):
        super().__init__()
        self.electra = AutoModel.from_pretrained(MODEL_NAME, return_dict=True) # pretrained_electra 제거 및 직접 로드
        self.classifier = nn.Linear(self.electra.config.hidden_size, 44) # num_labels=44 (KOTE 라벨 개수)
        self.n_training_steps = n_training_steps
        self.n_warmup_steps = n_warmup_steps
        self.criterion = nn.BCELoss()

    def forward(self, input_ids, attention_mask, labels=None):
        outputs = self.electra(input_ids, attention_mask=attention_mask)
        cls_output = outputs.last_hidden_state[:, 0, :]
        logits = self.classifier(cls_output)
        probs = torch.sigmoid(logits)
        loss = 0
        if labels is not None:
            loss = self.criterion(probs, labels)
        return loss, probs

    def training_step(self, batch, batch_idx):
        input_ids = batch["input_ids"]
        attention_mask = batch["attention_mask"]
        labels = batch["labels"]
        loss, _ = self(input_ids, attention_mask, labels)
        self.log("train_loss", loss, on_step=True, on_epoch=True, prog_bar=True)
        return loss

    def validation_step(self, batch, batch_idx):
        input_ids = batch["input_ids"]
        attention_mask = batch["attention_mask"]
        labels = batch["labels"]
        loss, outputs = self(input_ids, attention_mask, labels)
        self.log("val_loss", loss, on_step=False, on_epoch=True, prog_bar=True)
        return {"val_loss": loss}

    def configure_optimizers(self):
        optimizer = AdamW(self.parameters(), lr=INITIAL_LR, weight_decay=WEIGHT_DECAY) # 가중치 감쇠
        scheduler = get_linear_schedule_with_warmup(
            optimizer,
            num_warmup_steps=self.n_warmup_steps,
            num_training_steps=self.n_training_steps
        )
        return {
            "optimizer": optimizer,
            "lr_scheduler": {
                "scheduler": scheduler,
                "monitor": "val_loss",
                "interval": "step",
                "frequency": 1
            }
        }

# %%
###########################
# 토크나이저 로드
###########################
MODEL_NAME = "beomi/KcELECTRA-base"
tokenizer = AutoTokenizer.from_pretrained(MODEL_NAME)

# %%
emotion_labels = [
    "감동/감탄", "경악", "고마움", "공포/무서움", "귀찮음", "기대감", "기쁨", "깨달음",
    "놀람", "당황/난처", "부끄러움", "부담/안_내킴", "불쌍함/연민", "불안/걱정", "불평/불만",
    "비장함", "뿌듯함", "서러움", "슬픔", "신기함/관심", "아껴주는", "안심/신뢰", "안타까움/실망",
    "어이없음", "없음", "역겨움/징그러움", "우쭐댐/무시함", "의심/불신", "재미없음", "절망",
    "존경", "죄책감", "즐거움/신남", "증오/혐오", "지긋지긋", "짜증", "패배/자기혐오",
    "편안/쾌적", "한심함", "행복", "화남/분노", "환영/호의", "흐뭇함(귀여움/예쁨)", "힘듦/지침"
]

# %%
kote_finetuned_model = KOTETagger.load_from_checkpoint(best_ckpt_path_kote)
pretrained_electra = kote_finetuned_model.electra # 수정: electra backbone만 가져옴

# %%
###########################
# LightningModule 정의 (PoetryTagger) (기존 코드 활용 + 가중치 손실 함수, Dropout, Weight Decay, Learning Rate 감소, EarlyStopping patience 증가)
###########################
INITIAL_LR = 1e-5 # 학습률 감소 (원래 2e-5, 1e-5, 5e-6, 2e-6)
DROPOUT_RATE = 0.5 # Dropout 비율 (0.1, 0.3, 0.5) - Dropout 추가
WEIGHT_DECAY = 0.02 # Weight Decay 값 (0.001, 0.01, 0.02) - Weight Decay 추가
THRESHOLD = 0.3

class PoetryTagger(pl.LightningModule):
    def __init__(self, n_training_steps=None, n_warmup_steps=None, dropout_rate=DROPOUT_RATE): # dropout_rate hyperparameter
        super().__init__()
        self.electra = pretrained_electra # 수정: KOTE 파인튜닝 모델의 electra backbone 사용
        self.classifier = nn.Sequential( # nn.Sequential 사용하여 dropout layer 추가
            nn.Linear(self.electra.config.hidden_size, len(emotion_labels)),
            nn.Dropout(dropout_rate)
        ) # Classifier 출력층 크기 자동 조정
        self.n_training_steps = n_training_steps
        self.n_warmup_steps = n_warmup_steps
        self.criterion = nn.BCELoss() # 기본 BCE Loss (가중치 미적용)

    def forward(self, input_ids, attention_mask, labels=None):
        outputs = self.electra(input_ids, attention_mask=attention_mask)
        # [CLS] 토큰 기준으로 분류
        cls_output = outputs.last_hidden_state[:, 0, :]
        logits = self.classifier(cls_output)
        probs = torch.sigmoid(logits)

        loss = 0
        if labels is not None:
            loss = self.criterion(probs, labels)

        return loss, probs

    def training_step(self, batch, batch_idx):
        input_ids = batch["input_ids"]
        attention_mask = batch["attention_mask"]
        labels = batch["labels"]

        loss, _ = self(input_ids, attention_mask, labels) # forward 함수에 weights 제거

        self.log("train_loss", loss, on_step=True, on_epoch=True, prog_bar=True)
        return loss

    def validation_step(self, batch, batch_idx):
        input_ids = batch["input_ids"]
        attention_mask = batch["attention_mask"]
        labels = batch["labels"]

        loss, outputs = self(input_ids, attention_mask, labels) # validation loss는 기존 BCE Loss 사용 (optional)
        self.log("val_loss", loss, on_step=False, on_epoch=True, prog_bar=True)
        return {"val_loss": loss} # validation metrics are optional

    def configure_optimizers(self):
        optimizer = AdamW(self.parameters(), lr=INITIAL_LR, weight_decay=WEIGHT_DECAY) # 가중치 감쇠
        scheduler = get_linear_schedule_with_warmup(
            optimizer,
            num_warmup_steps=self.n_warmup_steps,
            num_training_steps=self.n_training_steps
        )
        return {
            "optimizer": optimizer,
            "lr_scheduler": {
                "scheduler": scheduler,
                "monitor": "val_loss",
                "interval": "step",
                "frequency": 1
            }
        }

# %%
# ###########################
# # Best checkpoint load & Evaluation (poetry-finetuning) (기존 코드 활용)
# ###########################
def get_latest_version_dir_poetry(base_dir="./lightning_logs/poetry-finetuning-3agreements-only"): # poetry-weighted-finetuning 로 변경
    # version_0, version_1, ... version_50 경로를 모두 찾아 리스트업
    version_dirs = glob.glob(os.path.join(base_dir, "version_*"))
    # 버전 숫자를 기준으로 정렬
    version_dirs.sort(key=lambda x: int(x.split("_")[-1]))
    if not version_dirs:
        raise FileNotFoundError(f"No version_* directories found under '{base_dir}'")
    # 가장 마지막(숫자가 가장 큰) 버전 경로 반환
    return version_dirs[-1]

def get_latest_checkpoint_poetry(version_dir):
    ckpt_dir = os.path.join(version_dir, "checkpoints")
    ckpt_list = glob.glob(os.path.join(ckpt_dir, "*.ckpt"))
    ckpt_list.sort()  # 파일명 기준 정렬
    if not ckpt_list:
        raise FileNotFoundError(f"No .ckpt found under '{ckpt_dir}'")
    # 가장 마지막 파일(정렬 기준)
    return ckpt_list[-1]

# %%
latest_version_dir_poetry = get_latest_version_dir_poetry("./lightning_logs/poetry-finetuning-3agreements-only") # poetry-weighted-finetuning 로 변경
best_ckpt_path_poetry = get_latest_checkpoint_poetry(latest_version_dir_poetry)
print("Best checkpoint path (Poetry Weighted Finetuned):", best_ckpt_path_poetry) # poetry-weighted-finetuning 로 변경

best_model_poetry = PoetryTagger.load_from_checkpoint(best_ckpt_path_poetry)
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
best_model_poetry.to(device)
best_model_poetry.eval()
best_model_poetry.freeze()
# Out:
# Best checkpoint path (Poetry Weighted Finetuned): ./lightning_logs/poetry-finetuning-3agreements-only/version_0/checkpoints/epoch9-val_loss0.2566.ckpt

# %%
sample_text = """하루 종일 지친 몸으로만 떠돌다가
땅에 떨어져 죽지 못한
햇빛들은 줄지어 어디로 가는 걸까

웅성웅성 가장 근심스러운 색깔로 서행하며
이미 어둠이 깔리는 소각장으로 몰려들어
몇 점 폐휴지로 타들어가는 오루 6시의 참혹한 형량
단 한 번 후회도 용서하지 않는 무서운 시간
바람은 긴 채찍을 휘둘러
살아서 빛나는 온갖 상징을 몰아내고 있다.

도시는 곧 활자들이 일제히 빠져 달아나
속도 없이 페이지를 펄럭이는 텅 빈 한 권 책이 되리라.
승부를 알 수 없는 하루와의 싸움에서
우리는 패배했을까. 오늘도 물어보는 사소한 물음은
그러나 우리의 일생을 텅텅 흔드는 것.

오후 6시의 소각장 위로 말없이
검은 연기가 우산처럼 펼쳐지고
이젠 우리들의 차례였다.
두렵지 않은가.
밤이면 그림자를 빼앗겨 누구나 아득한 혼자였다.

문득 거리를 빠르게 스쳐가는 일상의 공포
보여다오. 지금까지 무엇을 했는가 살아 있는 그대여
오후 6시 우리들 이마에도 아, 붉은 노을이 떴다.

그러면 우리는 어디로 가지?
아직도 펄펄 살아 있는 우리는 이제 각자 어디로 가지?
""" # 기형도 - 노을

# %%
encoding = tokenizer(
    sample_text,
    max_length=512,
    padding="max_length",
    truncation=True,
    return_tensors="pt"
)

with torch.no_grad():
    # 입력 텐서 또한 같은 device로 이동
    input_ids = encoding["input_ids"].to(device)
    attention_mask = encoding["attention_mask"].to(device)

    # forward
    _, predictions = best_model_poetry(input_ids, attention_mask)  # best_model_poetry 사용

# 추론 결과를 CPU로 가져와 numpy로 변환
predictions = predictions.flatten().cpu().numpy()

# 결과를 딕셔너리로 저장 (숫자값으로 변환)
result_dict = {
    label_name: float(round(score, 3))  # np.float32 -> float 변환
    for label_name, score in zip(emotion_labels, predictions)
    if score > THRESHOLD
}

# 결과 출력
print("\n[Sample Inference 결과]")
print(result_dict)

# 예시 출력
# {'불안/걱정': 0.336, '슬픔': 0.311}
# Out:
# [Sample Inference 결과]
# {'공포/무서움': 0.4339999854564667, '놀람': 0.30799999833106995, '당황/난처': 0.5130000114440918, '부담/안_내킴': 0.39899998903274536, '불안/걱정': 0.5490000247955322, '불평/불만': 0.3019999861717224, '비장함': 0.33799999952316284, '서러움': 0.35600000619888306, '슬픔': 0.41600000858306885, '신기함/관심': 0.3089999854564667, '안타까움/실망': 0.30799999833106995, '의심/불신': 0.3050000071525574, '힘듦/지침': 0.34200000762939453}

# %% [markdown]
# ### Ollama Llama + KPoEM classification Model LangChain

# %%
from langchain_community.llms import Ollama
from langchain.prompts import PromptTemplate
from langchain.chains import LLMChain
from transformers import AutoTokenizer, AutoModelForCausalLM, pipeline
import torch

# %%
# !pip install accelerate
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting accelerate
#   Downloading accelerate-1.7.0-py3-none-any.whl (362 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 362.1/362.1 kB 3.6 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging>=20.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from accelerate) (24.2)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from accelerate) (0.5.3)
# Requirement already satisfied: huggingface-hub>=0.21.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from accelerate) (0.32.4)
# Requirement already satisfied: psutil in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from accelerate) (7.0.0)
# Requirement already satisfied: torch>=2.0.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from accelerate) (2.7.1)
# Requirement already satisfied: numpy<3.0.0,>=1.17 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from accelerate) (2.2.6)
# Requirement already satisfied: pyyaml in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from accelerate) (6.0.2)
# Requirement already satisfied: requests in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (2.32.4)
# Requirement already satisfied: tqdm>=4.42.1 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.67.1)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (4.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (2025.3.0)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (1.1.3)
# Requirement already satisfied: filelock in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from huggingface-hub>=0.21.0->accelerate) (3.18.0)
# Requirement already satisfied: sympy>=1.13.3 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (1.14.0)
# Requirement already satisfied: jinja2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (3.1.6)
# Requirement already satisfied: networkx in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torch>=2.0.0->accelerate) (3.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from sympy>=1.13.3->torch>=2.0.0->accelerate) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from jinja2->torch>=2.0.0->accelerate) (3.0.2)
# Requirement already satisfied: idna<4,>=2.5 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (2025.4.26)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests->huggingface-hub>=0.21.0->accelerate) (3.4.2)
# Installing collected packages: accelerate
# Successfully installed accelerate-1.7.0
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip install --upgrade torch
# !pip install --upgrade transformers
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: torch in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (2.7.1)
# Requirement already satisfied: sympy>=1.13.3 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torch) (1.14.0)
# Requirement already satisfied: filelock in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torch) (4.14.0)
# Requirement already satisfied: fsspec in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torch) (2025.3.0)
# Requirement already satisfied: jinja2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: networkx in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from sympy>=1.13.3->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Requirement already satisfied: transformers in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (4.52.4)
# Requirement already satisfied: safetensors>=0.4.3 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers) (0.5.3)
# Requirement already satisfied: numpy>=1.17 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers) (2.2.6)
# Requirement already satisfied: regex!=2019.12.17 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers) (2024.11.6)
# Requirement already satisfied: requests in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers) (2.32.4)
# Requirement already satisfied: tqdm>=4.27 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: tokenizers<0.22,>=0.21 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers) (0.21.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: filelock in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers) (3.18.0)
# Requirement already satisfied: packaging>=20.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers) (24.2)
# Requirement already satisfied: huggingface-hub<1.0,>=0.30.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from transformers) (0.32.4)
# Requirement already satisfied: hf-xet<2.0.0,>=1.1.2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (1.1.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (4.14.0)
# Requirement already satisfied: fsspec>=2023.5.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from huggingface-hub<1.0,>=0.30.0->transformers) (2025.3.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests->transformers) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests->transformers) (2025.4.26)
# Requirement already satisfied: charset_normalizer<4,>=2 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests->transformers) (3.4.2)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from requests->transformers) (2.4.0)
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# !pip show torch
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Name: torch
# Version: 2.7.1
# Summary: Tensors and Dynamic neural networks in Python with strong GPU acceleration
# Home-page: https://pytorch.org/
# Author: PyTorch Team
# Author-email: packages@pytorch.org
# License: BSD-3-Clause
# Location: /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages
# Requires: filelock, fsspec, jinja2, networkx, sympy, typing-extensions
# Required-by: accelerate, pytorch-lightning, sentence-transformers, torchaudio, torchmetrics, torchvision

# %%
model_id = "Bllossom/llama-3.2-Korean-Bllossom-3B"

# 토크나이저 로드
tokenizer = AutoTokenizer.from_pretrained(model_id)

# 모델 로드 (GPU가 없으면 device_map 제거)
model = AutoModelForCausalLM.from_pretrained(
    model_id,
    torch_dtype=torch.float32,  # CPU 환경에서는 float32 사용
    device_map=None  # GPU가 없으면 auto 대신 None 사용
)

# 파이프라인 생성
pipe = pipeline(
    "text-generation",
    model=model,
    tokenizer=tokenizer,
    temperature=0.7,
    max_new_tokens=512
)

# 테스트 출력
output = pipe("안녕하세요, 오늘 기분은 어떤가요?")
print(output)
# Out:
# Loading checkpoint shards:   0%|          | 0/2 [00:00<?, ?it/s]
# generation_config.json:   0%|          | 0.00/180 [00:00<?, ?B/s]
# Device set to use mps:0
# Setting `pad_token_id` to `eos_token_id`:128001 for open-end generation.
# [{'generated_text': "안녕하세요, 오늘 기분은 어떤가요? - '어디서나' (2021) - 1회 - 1회\n'어디서나'는 2021년에 방영된 한국의 TV 드라마입니다. 주연은 이한na, 이하늘입니다. 이 드라마는 1회가 끝나고, 기분을 묻는 질문으로 시작됩니다. 이하늘 주연의 소설 '어디서나'를 바탕으로 한 이 드라마는, 한 여자의 일상과 그녀의 감정에 집중하는 작품입니다. 주인공은 한 여자가 다른 사람의 일상 속에서 발견된 자신의 모습을 통해 herself를 찾으려는 과정을 그립니다.\n1회는 주인공의 일상과 그녀의 감정에 집중하는 작품으로, 다양한 장면을 통해 그녀의 마음을 드러내고 있습니다. 이 드라마는, 주인공이 자신의 감정을 표현하는 과정에서 발견하는 새로운 것들을 보여주며, 독자와 시청자의 마음을 자극하는 작품입니다.\n'어디서나'는, 주인공이 자신의 감정을 표현하는 과정에서 발견하는 새로운 것들을 보여주는 작품입니다. 이 드라마는, 주인공이 자신의 감정을 표현하는 과정에서 발견하는 새로운 것을 통해 독자와 시청자의 마음을 자극하는 작품입니다. 이하늘 주연의 소설 '어디서나'를 바탕으로 한 이 드라마는, 한 여자의 일상과 그녀의 감정에 집중하는 작품입니다.\n1회는 주인공의 일상과 그녀의 감정에 집중하는 작품으로, 다양한 장면을 통해 그녀의 마음을 드러내고 있습니다. 이 드라마는, 주인공이 자신의 감정을 표현하는 과정에서 발견하는 새로운 것들을 보여주며, 독자와 시청자의 마음을 자극하는 작품입니다. 이하늘 주연의 소설 '어디서나'를 바탕으로 한 이 드라마는, 한 여자의 일상과 그녀의 감정에 집중하는 작품입니다.\n1회는 주인공의 일상과 그녀의 감정에 집중하는 작품으로, 다양한 장면을 통해 그녀의 마음을 드러내고 있습니다. 이 드라마는, 주인공이 자신의 감정을 표현하는 과정에서 발견하는 새로운 것들을 보여주며, 독자와 시청자의 마음을 자극하는 작품입니다. 이하늘 주연의 소설 '어디"}]

# %%
tokenizer.add_special_tokens({'pad_token': '[PAD]'})
model.resize_token_embeddings(len(tokenizer))
# Out:
# The new embeddings will be initialized from a multivariate normal distribution that has old embeddings' mean and covariance. As described in this article: https://nlp.stanford.edu/~johnhew/vocab-expansion.html. To disable this, use `mean_resizing=False`
# Embedding(128257, 3072)

# %%
# 3. Ollama Llama 모델 로드
# Ollama 서버가 로컬에서 실행 중이어야 합니다.
# 모델 이름은 'ollama run llama3' 등으로 다운로드한 모델 이름과 일치해야 합니다.
# llm = Ollama(model="llama3.2")
# Out:
# /var/folders/cd/mj8pxhhd6ml7kpdhggf19l_80000gn/T/ipykernel_23423/1217402929.py:4: LangChainDeprecationWarning: The class `Ollama` was deprecated in LangChain 0.3.1 and will be removed in 1.0.0. An updated version of the class exists in the :class:`~langchain-ollama package and should be used instead. To use it run `pip install -U :class:`~langchain-ollama` and import as `from :class:`~langchain_ollama import OllamaLLM``.
#   llm = Ollama(model="llama3.2")

# %%
# 감정 분류 결과 예시 (임의의 함수 또는 모델로 대체)
def classify_emotion(sample_text):

    # 패딩 토큰 설정
    if tokenizer.pad_token is None:
        tokenizer.pad_token = tokenizer.eos_token  # eos_token을 패딩 토큰으로 설정

    # 모델 임베딩 크기 조정
    model.resize_token_embeddings(len(tokenizer))

        
    # 예: {'슬픔': 0.6, '기쁨': 0.3, '분노': 0.1}
    encoding = tokenizer(
    sample_text,
    max_length=512,
    padding="max_length",
    truncation=True,
    return_tensors="pt"
    )

    with torch.no_grad():
    # 입력 텐서 또한 같은 device로 이동
        input_ids = encoding["input_ids"].to(device)
        attention_mask = encoding["attention_mask"].to(device)

    # forward
        _, predictions = best_model_poetry(input_ids, attention_mask)  # best_model_poetry 사용

# 추론 결과를 CPU로 가져와 numpy로 변환
    predictions = predictions.flatten().cpu().numpy()

# 결과를 딕셔너리로 저장 (숫자값으로 변환)
    result_dict = {
        label_name: float(round(score, 3))  # np.float32 -> float 변환
        for label_name, score in zip(emotion_labels, predictions)
        if score > THRESHOLD
    }

# 결과 출력
    print("\n[Sample Inference 결과]")
    print(result_dict)

# 예시 출력
# {'불안/걱정': 0.336, '슬픔': 0.311}
    return result_dict

# %%
# 2️⃣ 감정 기반 프롬프트 생성
def generate_prompt(emotion_scores):
    top_emotion = max(emotion_scores, key=emotion_scores.get)
    return f"""당신은 감정이 섬세한 한국 현대시 작가입니다. 
'{top_emotion}'의 감정을 중심으로 짧은 시를 한 편 창작해 주세요."""

# %%
# 4️⃣ LangChain 프롬프트 템플릿 구성
prompt = PromptTemplate.from_template("{emotion_prompt}")
chain = LLMChain(llm=llm, prompt=prompt)

# %%
# 5️⃣ 전체 흐름 함수
def emotion_to_poetry(user_input): #sample text
    emotion_scores = classify_emotion(user_input)
    emotion_prompt = generate_prompt(emotion_scores)
    poem = chain.run(emotion_prompt=emotion_prompt)
    print(emotion_scores) # 감정 점수 출력
    return poem

# %%
# 6️⃣ 테스트
input_text = """하루 종일 지친 몸으로만 떠돌다가
땅에 떨어져 죽지 못한
햇빛들은 줄지어 어디로 가는 걸까

웅성웅성 가장 근심스러운 색깔로 서행하며
이미 어둠이 깔리는 소각장으로 몰려들어
몇 점 폐휴지로 타들어가는 오루 6시의 참혹한 형량
단 한 번 후회도 용서하지 않는 무서운 시간
바람은 긴 채찍을 휘둘러
살아서 빛나는 온갖 상징을 몰아내고 있다.

도시는 곧 활자들이 일제히 빠져 달아나
속도 없이 페이지를 펄럭이는 텅 빈 한 권 책이 되리라.
승부를 알 수 없는 하루와의 싸움에서
우리는 패배했을까. 오늘도 물어보는 사소한 물음은
그러나 우리의 일생을 텅텅 흔드는 것.

오후 6시의 소각장 위로 말없이
검은 연기가 우산처럼 펼쳐지고
이젠 우리들의 차례였다.
두렵지 않은가.
밤이면 그림자를 빼앗겨 누구나 아득한 혼자였다.

문득 거리를 빠르게 스쳐가는 일상의 공포
보여다오. 지금까지 무엇을 했는가 살아 있는 그대여
오후 6시 우리들 이마에도 아, 붉은 노을이 떴다.

그러면 우리는 어디로 가지?
아직도 펄펄 살아 있는 우리는 이제 각자 어디로 가지?
""" # 기형도 - 노을
generated_poem = emotion_to_poetry(input_text)

print("🎴 생성된 시:\n")
print(generated_poem)
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[78], line 32
#       1 # 6️⃣ 테스트
#       2 input_text = """하루 종일 지친 몸으로만 떠돌다가
#       3 땅에 떨어져 죽지 못한
#       4 햇빛들은 줄지어 어디로 가는 걸까
#    (...)
#      30 아직도 펄펄 살아 있는 우리는 이제 각자 어디로 가지?
#      31 """ # 기형도 - 노을
# ---> 32 generated_poem = emotion_to_poetry(input_text)
#      34 print("🎴 생성된 시:\n")
#      35 print(generated_poem)
#
# Cell In[77], line 3, in emotion_to_poetry(user_input)
#       2 def emotion_to_poetry(user_input): #sample text
# ----> 3     emotion_scores = classify_emotion(user_input)
#       4     emotion_prompt = generate_prompt(emotion_scores)
#       5     poem = chain.run(emotion_prompt=emotion_prompt)
#
# Cell In[75], line 27, in classify_emotion(sample_text)
#      24         attention_mask = encoding["attention_mask"].to(device)
#      26     # forward
# ---> 27         _, predictions = best_model_poetry(input_ids, attention_mask)  # best_model_poetry 사용
#      29 # 추론 결과를 CPU로 가져와 numpy로 변환
#      30     predictions = predictions.flatten().cpu().numpy()
#
# File ~/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# Cell In[7], line 22, in PoetryTagger.forward(self, input_ids, attention_mask, labels)
#      21 def forward(self, input_ids, attention_mask, labels=None):
# ---> 22     outputs = self.electra(input_ids, attention_mask=attention_mask)
#      23     # [CLS] 토큰 기준으로 분류
#      24     cls_output = outputs.last_hidden_state[:, 0, :]
#
# File ~/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages/transformers/models/electra/modeling_electra.py:801, in ElectraModel.forward(self, input_ids, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, past_key_values, use_cache, output_attentions, output_hidden_states, return_dict)
#     797     encoder_extended_attention_mask = None
#     799 head_mask = self.get_head_mask(head_mask, self.config.num_hidden_layers)
# --> 801 hidden_states = self.embeddings(
#     802     input_ids=input_ids,
#     803     position_ids=position_ids,
#     804     token_type_ids=token_type_ids,
#     805     inputs_embeds=inputs_embeds,
#     806     past_key_values_length=past_key_values_length,
#     807 )
#     809 if hasattr(self, "embeddings_project"):
#     810     hidden_states = self.embeddings_project(hidden_states)
#
# File ~/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages/transformers/models/electra/modeling_electra.py:188, in ElectraEmbeddings.forward(self, input_ids, token_type_ids, position_ids, inputs_embeds, past_key_values_length)
#     185         token_type_ids = torch.zeros(input_shape, dtype=torch.long, device=self.position_ids.device)
#     187 if inputs_embeds is None:
# --> 188     inputs_embeds = self.word_embeddings(input_ids)
#     189 token_type_embeddings = self.token_type_embeddings(token_type_ids)
#     191 embeddings = inputs_embeds + token_type_embeddings
#
# File ~/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1751, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1749     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1750 else:
# -> 1751     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1762, in Module._call_impl(self, *args, **kwargs)
#    1757 # If we don't have any hooks, we want to skip the rest of the logic in
#    1758 # this function, and just call forward.
#    1759 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1760         or _global_backward_pre_hooks or _global_backward_hooks
#    1761         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1762     return forward_call(*args, **kwargs)
#    1764 result = None
#    1765 called_always_called_hooks = set()
#
# File ~/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages/torch/nn/modules/sparse.py:190, in Embedding.forward(self, input)
#     189 def forward(self, input: Tensor) -> Tensor:
# --> 190     return F.embedding(
#     191         input,
#     192         self.weight,
#     193         self.padding_idx,
#     194         self.max_norm,
#     195         self.norm_type,
#     196         self.scale_grad_by_freq,
#     197         self.sparse,
#     198     )
#
# File ~/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages/torch/nn/functional.py:2551, in embedding(input, weight, padding_idx, max_norm, norm_type, scale_grad_by_freq, sparse)
#    2545     # Note [embedding_renorm set_grad_enabled]
#    2546     # XXX: equivalent to
#    2547     # with torch.no_grad():
#    2548     #   torch.embedding_renorm_
#    2549     # remove once script supports set_grad_enabled
#    2550     _no_grad_embedding_renorm_(weight, input, max_norm, norm_type)
# -> 2551 return torch.embedding(weight, input, padding_idx, scale_grad_by_freq, sparse)
#
# IndexError: index out of range in self

# %% [markdown]
# ## 벡터 DB 연결

# %%
###########################
# 근현대시 데이터셋 로드 및 전처리 (기존 코드 활용 + 일치 라벨만 사용)
############################ 데이터프레임으로 불러오기 (실제 파일 경로로 수정)
df = pd.read_csv("../data/총합데이터셋_0601_5인 - 행단위.csv") # Colab 경로에 맞게 수정

# 감정 라벨 데이터를 리스트로 변환하는 함수
def labels_to_list(labels_str):
    if pd.isna(labels_str):
        return []
    return [label.strip() for label in labels_str.split(',')]

# 라벨 데이터를 리스트로 변환
df['annotator01_label_list'] = df['annotator01'].apply(labels_to_list)
df['annotator02_label_list'] = df['annotator02'].apply(labels_to_list)
df['annotator03_label_list'] = df['annotator03'].apply(labels_to_list)
df['annotator04_label_list'] = df['annotator04'].apply(labels_to_list)
df['annotator05_label_list'] = df['annotator05'].apply(labels_to_list)

# %%
def get_labels_agreed_by_at_least_k(row, k=3):
    """
    각 행(row)에 대해, 최소 k명 이상이 동의한 감정만 추출

    Parameters:
    - row: annotator label list들이 있는 DataFrame row
    - k: 동의한 annotator 최소 수 (기본 2명)

    Returns:
    - 감정 리스트 중 k명 이상이 공통으로 선택한 감정 리스트
    """
    all_labels = (
        row['annotator01_label_list'] +
        row['annotator02_label_list'] +
        row['annotator03_label_list'] +
        row['annotator04_label_list'] +
        row['annotator05_label_list']
    )
    counter = pd.Series(all_labels).value_counts() # 감정별 개수 세기
    return [label for label, count in counter.items() if count >= k] # k명 이상이 동의한 감정 리스트

# %%
def get_labels_agreed_by_at_least_k(row, k=3):
    """
    각 행(row)에 대해, 최소 k명 이상이 동의한 감정만 추출

    Parameters:
    - row: annotator label list들이 있는 DataFrame row
    - k: 동의한 annotator 최소 수 (기본 2명)

    Returns:
    - 감정 리스트 중 k명 이상이 공통으로 선택한 감정 리스트
    """
    all_labels = (
        row['annotator01_label_list'] +
        row['annotator02_label_list'] +
        row['annotator03_label_list'] +
        row['annotator04_label_list'] +
        row['annotator05_label_list']
    )
    counter = pd.Series(all_labels).value_counts() # 감정별 개수 세기
    return [label for label, count in counter.items() if count >= k] # k명 이상이 동의한 감정 리스트

# %%
# 2명 이상 동의한 감정 리스트로 새 컬럼 생성
df['common_labels'] = df.apply(lambda row: get_labels_agreed_by_at_least_k(row, k=3), axis=1)

df[['common_labels']].head(10) # 3명 이상 동의한 감정 리스트 확인
# Out:
#               common_labels
# 0                     [비장함]
# 1               [비장함, 부끄러움]
# 2                     [기대감]
# 3  [패배/자기혐오, 절망, 슬픔, 힘듦/지침]
# 4           [기쁨, 기대감, 아껴주는]
# 5       [비장함, 불쌍함/연민, 아껴주는]
# 6                        []
# 7                     [비장함]
# 8              [기대감, 감동/감탄]
# 9                      [슬픔]

# %%
# 일치하는 라벨만 있는 데이터만 필터링
df_agreement = df[df['common_labels'].map(len) > 0].reset_index(drop=True) # agreement 컬럼이 비어있지 않은 행만 선택

# 1차 데이터 csv 파일에서 'agreement' 컬럼이 비어 있지 않은 행만 선택
df_agreement = df[df['common_labels'].apply(lambda x: len(x) > 0)]

# 'agreement' 컬럼의 리스트들을 새로운 'labels' 컬럼에 할당
df_agreement['labels'] = df_agreement['common_labels']
df_agreement_reset = df_agreement.reset_index()

#  cleaned labels가 비어 있지 않은 행만 필터링 - Define df_agreement_cleaned FIRST
df_agreement_cleaned = df_agreement_reset[df_agreement_reset['labels'].map(len) > 0].reset_index(drop = True) # Line 46 (moved up) - df_agreement_cleaned is DEFINED here FIRST

# 불용 라벨 제거 (optional): ['nan', '', None] 라벨 제거
labels_to_remove = ['nan', '', None]
# Out:
# /var/folders/cd/mj8pxhhd6ml7kpdhggf19l_80000gn/T/ipykernel_23423/3686308332.py:8: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_agreement['labels'] = df_agreement['common_labels']

# %%
def remove_labels(labels):
    return [label for label in labels if label not in labels_to_remove and pd.notna(label) and label != 'nan']

# Assign 'labels_cleaned' column to the ALREADY DEFINED df_agreement_cleaned
df_agreement_cleaned['labels_cleaned'] = df_agreement_reset['labels'].apply(remove_labels) # Line 43 (moved down) - Assign to df_agreement_cleaned AFTER it's defined

# %%
# 필터링된 데이터프레임
df_cleaned = df[df["common_labels"].apply(lambda x: len(x) > 0)].reset_index(drop=True)

# %%
df_cleaned.head(10)  # 필터링된 데이터프레임 확인
# Out:
#    lineID  poemID                                                 본문  소제목  \
# 0       1       1                                     죽는 날까지 하늘을 우러러  NaN
# 1       2       1                                      한 점 부끄럼이 없기를,  NaN
# 2       3       1                                        잎새에 이는 바람에도  NaN
# 3       4       1                                          나는 괴로워했다.  NaN
# 4       5       1                                       별을 노래하는 마음으로  NaN
# 5       6       1                                   모든 죽어가는 것을 사랑해야지  NaN
# 6       8       1                                            걸어가야겠다.  NaN
# 7       9       1                                오늘 밤에도 별이 바람에 스치운다.  NaN
# 8      10       2             산모퉁이를 돌아 논가 외딴 우물을 홀로 찾아가선 가만히 들여다봅니다.  NaN
# 9      11       2  우물 속에는 달이 밝고 구름이 흐르고 하늘이 펼치고 파아란 바람이 불고 가을이 있습니다.  NaN
#
#     제목   저자                           annotator01  \
# 0   서시  윤동주                                   비장함
# 1   서시  윤동주                             부끄러움, 비장함
# 2   서시  윤동주                           기대감, 신기함/관심
# 3   서시  윤동주                       절망, 슬픔, 패배/자기혐오
# 4   서시  윤동주  기쁨, 신기함/관심, 즐거움/신남, 흐뭇함(귀여움/예쁨), 뿌듯함
# 5   서시  윤동주                 비장함, 불쌍함/연민, 아껴주는, 기쁨
# 6   서시  윤동주                              비장함, 깨달음
# 7   서시  윤동주               흐뭇함(귀여움/예쁨), 기대감, 편안/쾌적
# 8  자화상  윤동주                           슬픔, 안타까움/실망
# 9  자화상  윤동주     흐뭇함(귀여움/예쁨), 환영/호의, 편안/쾌적, 신기함/관심
#
#                                          annotator02  \
# 0                                                비장함
# 1                     부끄러움, 비장함, 기대감, 불안/걱정, 서러움, 슬픔
# 2                                    기대감, 불안/걱정, 비장함
# 3                   절망, 슬픔, 패배/자기혐오, 죄책감, 힘듦/지침, 비장함
# 4          기쁨, 뿌듯함, 감동/감탄, 슬픔, 비장함, 아껴주는, 환영/호의, 기대감
# 5           비장함, 불쌍함/연민, 아껴주는, 슬픔, 환영/호의, 기대감, 안심/신뢰
# 6                                           비장함, 깨달음
# 7                  감동/감탄, 서러움, 슬픔, 아껴주는, 흐뭇함(귀여움/예쁨)
# 8                  슬픔, 안타까움/실망, 서러움, 기대감, 불안/걱정, 비장함
# 9  흐뭇함(귀여움/예쁨), 환영/호의, 편안/쾌적, 신기함/관심, 감동/감탄, 놀람, 서러움
#
#                        annotator03                     annotator04  \
# 0                         뿌듯함, 비장함                 비장함, 뿌듯함, 감동/감탄
# 1                    깨달음, 비장함, 뿌듯함                  비장함, 부끄러움, 기대감
# 2            슬픔, 서러움, 불안/걱정, 당황/난처                         비장함, 슬픔
# 3         당황/난처, 서러움, 죄책감, 패배/자기혐오     비장함, 슬픔, 패배/자기혐오, 절망, 힘듦/지침
# 4  고마움, 기대감, 기쁨, 아껴주는, 흐뭇함(귀여움/예쁨)        감동/감탄, 기대감, 기쁨, 아껴주는, 행복
# 5            불쌍함/연민, 비장함, 아껴주는, 존경                         비장함, 슬픔
# 6                               없음                        기대감, 비장함
# 7                   슬픔, 서러움, 불안/걱정    감동/감탄, 기대감, 기쁨, 신기함/관심, 아껴주는
# 8                     패배/자기혐오, 한심함                       힘듦/지침, 슬픔
# 9                    감동/감탄, 신기함/관심  감동/감탄, 신기함/관심, 아껴주는, 편안/쾌적, 행복
#
#                        annotator05                  annotator01_label_list  \
# 0                     비장함, 서러움, 슬픔                                   [비장함]
# 1                              비장함                             [부끄러움, 비장함]
# 2        감동/감탄, 신기함/관심, 편안/쾌적, 기대감                           [기대감, 신기함/관심]
# 3      슬픔, 서러움, 절망, 힘듦/지침, 패배/자기혐오                       [절망, 슬픔, 패배/자기혐오]
# 4              즐거움/신남, 기대감, 기쁨, 행복  [기쁨, 신기함/관심, 즐거움/신남, 흐뭇함(귀여움/예쁨), 뿌듯함]
# 5                      불쌍함/연민, 비장함                 [비장함, 불쌍함/연민, 아껴주는, 기쁨]
# 6                         기대감, 비장함                              [비장함, 깨달음]
# 7      감동/감탄, 기대감, 깨달음, 놀람, 신기함/관심               [흐뭇함(귀여움/예쁨), 기대감, 편안/쾌적]
# 8               기대감, 신기함/관심, 감동/감탄                           [슬픔, 안타까움/실망]
# 9  감동/감탄, 기대감, 신기함/관심, 흐뭇함(귀여움/예쁨)     [흐뭇함(귀여움/예쁨), 환영/호의, 편안/쾌적, 신기함/관심]
#
#                               annotator02_label_list  \
# 0                                              [비장함]
# 1                   [부끄러움, 비장함, 기대감, 불안/걱정, 서러움, 슬픔]
# 2                                  [기대감, 불안/걱정, 비장함]
# 3                 [절망, 슬픔, 패배/자기혐오, 죄책감, 힘듦/지침, 비장함]
# 4        [기쁨, 뿌듯함, 감동/감탄, 슬픔, 비장함, 아껴주는, 환영/호의, 기대감]
# 5         [비장함, 불쌍함/연민, 아껴주는, 슬픔, 환영/호의, 기대감, 안심/신뢰]
# 6                                         [비장함, 깨달음]
# 7                [감동/감탄, 서러움, 슬픔, 아껴주는, 흐뭇함(귀여움/예쁨)]
# 8                [슬픔, 안타까움/실망, 서러움, 기대감, 불안/걱정, 비장함]
# 9  [흐뭇함(귀여움/예쁨), 환영/호의, 편안/쾌적, 신기함/관심, 감동/감탄, 놀람,...
#
#               annotator03_label_list            annotator04_label_list  \
# 0                         [뿌듯함, 비장함]                 [비장함, 뿌듯함, 감동/감탄]
# 1                    [깨달음, 비장함, 뿌듯함]                  [비장함, 부끄러움, 기대감]
# 2            [슬픔, 서러움, 불안/걱정, 당황/난처]                         [비장함, 슬픔]
# 3         [당황/난처, 서러움, 죄책감, 패배/자기혐오]     [비장함, 슬픔, 패배/자기혐오, 절망, 힘듦/지침]
# 4  [고마움, 기대감, 기쁨, 아껴주는, 흐뭇함(귀여움/예쁨)]        [감동/감탄, 기대감, 기쁨, 아껴주는, 행복]
# 5            [불쌍함/연민, 비장함, 아껴주는, 존경]                         [비장함, 슬픔]
# 6                               [없음]                        [기대감, 비장함]
# 7                   [슬픔, 서러움, 불안/걱정]    [감동/감탄, 기대감, 기쁨, 신기함/관심, 아껴주는]
# 8                     [패배/자기혐오, 한심함]                       [힘듦/지침, 슬픔]
# 9                    [감동/감탄, 신기함/관심]  [감동/감탄, 신기함/관심, 아껴주는, 편안/쾌적, 행복]
#
#               annotator05_label_list                        common_labels
# 0                     [비장함, 서러움, 슬픔]                                [비장함]
# 1                              [비장함]                          [비장함, 부끄러움]
# 2        [감동/감탄, 신기함/관심, 편안/쾌적, 기대감]                                [기대감]
# 3      [슬픔, 서러움, 절망, 힘듦/지침, 패배/자기혐오]             [패배/자기혐오, 절망, 슬픔, 힘듦/지침]
# 4              [즐거움/신남, 기대감, 기쁨, 행복]                      [기쁨, 기대감, 아껴주는]
# 5                      [불쌍함/연민, 비장함]                  [비장함, 불쌍함/연민, 아껴주는]
# 6                         [기대감, 비장함]                                [비장함]
# 7      [감동/감탄, 기대감, 깨달음, 놀람, 신기함/관심]                         [기대감, 감동/감탄]
# 8               [기대감, 신기함/관심, 감동/감탄]                                 [슬픔]
# 9  [감동/감탄, 기대감, 신기함/관심, 흐뭇함(귀여움/예쁨)]  [신기함/관심, 감동/감탄, 흐뭇함(귀여움/예쁨), 편안/쾌적]

# %%
texts = df_cleaned["본문"].dropna().astype(str).tolist()
texts
# Out:
# ['죽는 날까지 하늘을 우러러',
#  '한 점 부끄럼이 없기를,',
#  '잎새에 이는 바람에도',
#  '나는 괴로워했다.',
#  '별을 노래하는 마음으로',
#  '모든 죽어가는 것을 사랑해야지',
#  '걸어가야겠다.',
#  '오늘 밤에도 별이 바람에 스치운다.',
#  '산모퉁이를 돌아 논가 외딴 우물을 홀로 찾아가선 가만히 들여다봅니다.',
#  '우물 속에는 달이 밝고 구름이 흐르고 하늘이 펼치고 파아란 바람이 불고 가을이 있습니다.',
#  '그리고 한 사나이가 있습니다.',
#  '어쩐지 그 사나이가 미워져 돌아갑니다.',
#  '돌아가다 생각하니 그 사나이가 가엾어집니다.',
#  '도로 가 들여다보니 사나이는 그대로 있습니다.',
#  '다시 그 사나이가 미워져 돌아갑니다.',
#  '돌아가다 생각하니 그 사나이가 그리워집니다.',
#  '우물 속에는 달이 밝고 구름이 흐르고 하늘이 펼치고 파아란 바람이 불고 가을이 있고 추억처럼 사나이가 있습니다.',
#  '지금 교회당 꼭대기',
#  '십자가에 걸리었습니다.',
#  '첨탑(尖塔)이 저렇게도 높은데',
#  '어떻게 올라갈 수 있을까요.',
#  '종소리도 들려 오지 않는데',
#  '괴로웠던 사나이',
#  '행복한 예수 그리스도에게',
#  '처럼',
#  '십자가가 허락된다면',
#  '모가지를 드리우고',
#  '꽃처럼 피어나는 피를',
#  '어두워 가는 하늘 밑에',
#  '조용히 흘리겠습니다.',
#  '어디로 불려 가는 것일까',
#  '바람이 부는데',
#  '내 괴로움에는 이유가 없다.',
#  '내 괴로움에는 이유가 없을까',
#  '단 한 여자를 사랑한 일도 없다.',
#  '시대를 슬퍼한 일도 없다.',
#  '바람이 자꼬 부는데',
#  '내 발이 반석 우에 섰다.',
#  '내 발이 언덕 우에 섰다.',
#  '고향에 돌아온 날 밤에',
#  '내 백골(白骨)이 따라와 한방에 누웠다.',
#  '어둔 방은 우주로 통하고',
#  '하늘에선가 소리처럼 바람이 불어 온다.',
#  '백골을 들여다보며',
#  '눈물짓는 것이 내가 우는 것이냐',
#  '백골이 우는 것이냐',
#  '아름다운 혼이 우는 것이냐',
#  '지조 높은 개는',
#  '밤을 새워 어둠을 짖는다.',
#  '어둠을 짖는 개는',
#  '나를 쫓는 것일 게다.',
#  '가자 가자',
#  '쫓기우는 사람처럼 가자',
#  '아름다운 또 다른 고향에 가자.',
#  '계절이 지나가는 하늘에는',
#  '가을로 가득 차 있습니다.',
#  '나는 아무 걱정도 없이',
#  '가을 속의 별들을 다 헤일 듯합니다...',
#  '가슴 속에 하나 둘 새겨지는 별을',
#  '이제 다 못 헤는 것은',
#  '내일 밤이 남은 까닭이요,',
#  '아직 나의 청춘이 다하지 않은 까닭입니다.',
#  '별 하나에 추억과',
#  '별 하나에 사랑과',
#  '별 하나에 쓸쓸함과',
#  '별 하나에 동경과',
#  '별 하나에 시와',
#  '별 하나에 어머니, 어머니',
#  "어머님, 나는 별 하나에 아름다운 말 한 마디씩 불러 봅니다. 소학교 때 책상을 같이했던 아이들의 이름과, 패, 경, 옥 이런 이국 소녀들의 이름과, 벌써 아기 어머니 된 계집애들의 이름과, 가난한 이웃 사람들의 이름과, 비둘기, 강아지, 토끼, 노새, 노루, '프랑시스 잠', '라이너 마리아 릴케', 이런 시인의 이름을 불러 봅니다.",
#  '이네들은 너무나 멀리 있습니다.',
#  '그리고 당신은 멀리 북간도에 계십니다',
#  '나는 무엇인지 그리워',
#  '이 많은 별빛이 내린 언덕 위에',
#  '딴은, 밤을 새워 우는 벌레는',
#  '부끄러운 이름을 슬퍼하는 까닭입니다.',
#  '그러나 겨울이 지나고 나의 별에도 봄이 오면',
#  '무덤 위에 파란 잔디가 피어나듯이',
#  '내 이름자 묻힌 언덕 위에도',
#  '자랑처럼 풀이 무성할 게외다.',
#  '살구나무 그늘로 얼굴을 가리고, 병원 뒤뜰에 누워, 젊은 여자가 흰 옷 아래로 하얀 다리를 드러내 놓고 일광욕을 한다. 한나절이 기울도록 가슴을 앓는 다는 이 여자를 찾아오는 이, 나비 한 마리도 없다. 슬프지도 않은 살구나무 가지에는 바람조차 없다.',
#  '나도 모를 아픔을 오래 참다 처음으로 이 곳에 찾아 왔다. 그러나 나의 늙은 의사는 젊은이의 병을 모른다. 나한테는 병이 없다고 한다. 이 지나친 시련, 이 지나친 피로, 나는 성내서는 안 된다.',
#  '여자는 자리에서 일어나 옷깃을 여미고 화단에서 금잔화 한 포기를 따 가슴에 꽂고 병실 안으로 사라진다. 나는 그 여자의 건강이 ---- 아니 내 건강도 속히 회복되기를 바라며 그가 누웠던 자리에 누워 본다.',
#  '잃어버렸습니다.',
#  '무얼 어디다 잃었는지 몰라',
#  '두 손의 호주머니를 더듬어',
#  '길에 나갑니다.',
#  '길은 돌담을 끼고 갑니다.',
#  '담은 쇠문을 굳게 담아',
#  '길 위에 긴 그림자를 드리우고',
#  '돌담을 더듬어 눈물짓다',
#  '쳐다 보면 하늘은 부끄럽게 푸릅니다.',
#  '풀 한 포기 없는 이 길을 걷는 것은',
#  '담 저 쪽에 내가 남아 있는 까닭이고',
#  '내가 사는 것은 다만',
#  '잃은 것을 찾는 까닭입니다. (1941.9.31)',
#  '세상으로부터 돌아오듯이 이제 내 좁은방에 돌아와 불을 끄옵니다.',
#  '불을 켜 두는 것은 너무나 피로롭은 일이옵니다.',
#  '그것은 낮의 연장(延長)이옵기에-',
#  '이제 창窓을 열어 공기(空氣)를 바꾸어 들여야 할터인데',
#  '밖을 가만히 내다 보아야 방(房)안과 같이 어두어 꼭 세상 같은데',
#  '비를 맞고 오던 길이 그대로 비속에 젖어 있사옵니다.',
#  '하로의 울분을 씻을바 없어 가만히 눈을 감으면',
#  '마음속으로 흐르는 소리,',
#  '이제,',
#  '사상(思想)이 능금처럼 저절로 익어 가옵니다.',
#  '어제도 가고 오늘도 갈',
#  '나의 길 새로운 길',
#  '민들레가 피고 까치가 날고',
#  '아가씨가 지나고 바람이 일고',
#  '나의 길은 언제나 새로운 길',
#  '내를 건너서 숲으로',
#  '고개를 넘어서 마을로',
#  '봄날 아침도 아니고',
#  '여름, 가을, 겨울,',
#  '그런 날 아침도 아닌 아침에',
#  '빠알간 꽃이 피어났네,',
#  '그 전날 밤에',
#  '모든것이 마련되었네,',
#  '사랑은 뱀과 함께',
#  '독(毒)은 어린꽃과 함께.',
#  '하얗게 눈이 덮이었고',
#  '전신주(電信柱)가 잉잉 울어',
#  '하나님 말씀이 들려온다.',
#  '무슨 계시(啓示)일까.',
#  '빨리',
#  '봄이 오면',
#  '죄(罪)를 짓고',
#  '눈이',
#  '밝아',
#  '이브가 해산(解産)하는 수고를 다하면',
#  '무화과(無花果) 잎사귀로 부끄런 데를 가리고',
#  '나는 이마에 땀을 흘려야겠다.',
#  '다들 죽어가는 사람들에게',
#  '다들 살아가는 사람들에게',
#  '흰 옷을 입히시오.',
#  '그리고 한 침실(寢室)에',
#  '가지런히 잠을 재우시오',
#  '다들 울거들랑',
#  '젖을 먹이시오',
#  '이제 새벽이 오면',
#  '나팔소리 들려 올 게외다.',
#  '거 나를 부르는 것이 누구요.',
#  '나 아직 여기 호흡이 남아 있소.',
#  '한 번도 손들어 보지 못한 나를',
#  '손들어 표할 하늘도 없는 나를',
#  '나를 부르는 것이오?',
#  '일이 마치고 내 죽는 날 아침에는',
#  '서럽지도 않은 가랑잎이 떨어질 텐데……',
#  '나를 부르지 마오.',
#  '흰 수건이 검은 머리를 두르고',
#  '흰 고무신이 거친 발에 걸리우다',
#  '흰 저고리 치마가 슬픈 몸집을 가리고',
#  '흰 띠가 가는 허리를 질끈 동이다',
#  '태양을 사모하는 아이들아',
#  '별을 사랑하는 아이들아',
#  '밤이 어두웠는데',
#  '눈감고 가거라.',
#  '가진 바 씨앗을',
#  '뿌리면서 가거라.',
#  '발부리에 돌이 체이거든',
#  '감았던 눈을 와짝 떠라.',
#  '알뜻 모를뜻 한데로 거닐과저!',
#  '아닌 밤중에 튀기듯이',
#  '잠자리를 뛰처',
#  '끝없는 광야(廣野)를 홀로 거니는',
#  '사람의 심사(心思)는 외로우러니',
#  '아─ 이 젊은이는',
#  '피라미트처럼 슬프구나',
#  '대동강(大洞江) 물로끄린국,',
#  '평안도(平安道) 쌀로지은밥,',
#  '조선(朝鮮)의 매운고추장,',
#  '식권 우리배를 부르게.',
#  '늦은봄기다리든 토요일(土曜日)날.',
#  '오후(午後) 세시반의 경성(京城)행열차는,',
#  '석탄(石炭)연기를 자욱이 품기고,',
#  '한몸을 끟을기에 강(强)하든.',
#  '공(뽈)이 자력(磁力)을 잃고',
#  '한목음의 물이',
#  '불붓는 목을 축이기에',
#  '넉넉하다,',
#  '젊은 가슴의 피순환(循環)이 잣고,',
#  '두 철각(鐵脚)이 늘어진다,',
#  '검은 기차(汽車)연기(煙氣)와 함께.',
#  '풀은 산(山)이',
#  '아지랑 저쪽으로',
#  '까라안는다,',
#  '청초(淸楚)한 코쓰모쓰는',
#  '오직 하나인 나의 아가씨,',
#  '달빛이 싸늘히 추운 밤이면',
#  '넷 소녀(少女)가 몯견디게 그리워',
#  '코쓰모쓰 핀 정원(庭園)으로 찾어간다.',
#  '코쓰모쓰는',
#  '귀또리 울음에도 수집어지고,',
#  '어렷을적 처럼 부끄러워 지나니,',
#  '코쓰모쓰의 마음은 내마음이다.',
#  '함께핀 꽃에 처음익은 능금은',
#  '먼저 떨어젓슴니다.',
#  '지나든 손님이 집어갓슴니다.',
#  '헌집신짝 끟을고',
#  '나여긔 웨왓노',
#  '두만강을 건너서',
#  '쓸쓸한 이 땅에',
#  '남쪽하늘 저밑엔',
#  '따뜻한 내고향',
#  '내어머니 게신곧',
#  '그리운 고향집.',
#  '「이 개 더럽잔니」',
#  '아─ 니 이웃집 덜렁 숳개가',
#  '오날 어슬렁 어슬렁 우리집으로 오더니',
#  '우리집 바두기의 미구멍에다 코를대고',
#  '씩々 내를 맛겟지 더러운줄도 모르고,',
#  '보기 숭해서 막차며 욕해 쫓앗더니',
#  '꼬리를 휘휘 저으며',
#  '너희들보다 어떻겟냐하는 상으로',
#  '뛰여가겟지요 나─ 참.',
#  '나무가 춤을 추면',
#  '바람이 불고,',
#  '나무가 잠잠하면',
#  '바람도 자오,',
#  '작고 달다고 하오.',
#  '앙당한 솔나무가지에,',
#  '훈훈한 바람의 날개가 스치고',
#  '한나절 햇발이 밋그러지다,',
#  '허무러진 성터(城터)에서',
#  '철모르는 여자(女兒)들이',
#  '저도 모를 이국(異國)말로,',
#  '난데없는 자동차(自動車)가 밉다.',
#  '눈이 오다, 물이 되는 날.',
#  '재ㅅ빛 하늘에 또 뿌연 내, 그리고,',
#  '크다란 기관차(機關車)는 빼─액─ 울며,',
#  '쪽그만, 가슴은, 울렁거린다.',
#  '리별이 너무 재빠르다, 안탑갑게도,',
#  '사랑하는 사람을,',
#  '일터에서 만나자 하고─.',
#  '더운 손의 맛과, 구슬눈물이 마르기 전',
#  '기차는 꼬리를 산굽으로 돌렷다,',
#  '종달새는 일은봄날',
#  '명량한 봄하늘,',
#  '가벼운 두나래를펴서',
#  '요염한 봄노래가,',
#  '좋더라,',
#  '그러나,',
#  '오날도 구멍뚤린 구두를끌고,',
#  '고기색기같은나는 헤매나니,',
#  '나래와노래가 없음인가,',
#  '가슴이 답답하구나,',
#  '내마음의 탑(塔)',
#  '나는 말없이 이탑(塔)을 쌓고있다',
#  '문허질줄도 몰으고',
#  '한층두층 높이 싸ㅅ는다',
#  '무한(無限)한 나의 공상(空想)─',
#  '그것은 내마음의 바다',
#  '나는 두팔을 펄처서',
#  '자유(自由)로히 헤염친다',
#  '황금(黃金) 지욕(知慾)의 수평선(水平線)을 향(向)하여.',
#  '밤을자고 동틀때',
#  '래일이라고.',
#  '새날을 찯은나는',
#  '오늘이더라,',
#  '무리여!',
#  '래일은 없나니',
#  '산들이 두 줄로 줄다를질 치고',
#  '여울이 소리처 목이 자젓다.',
#  '한여름의 햇님이 구름을 타고',
#  '이골작이를 빠르게도 건너련다.',
#  '산(山)등아리에 송아지 뿔처럼',
#  '울뚝불뚝히 어린 바위가 솟구,',
#  '얼룩소의 보드러운 털이',
#  '산(山)등서리에 퍼─렇게 자랏다.',
#  '삼년(三年)만에 고향(故鄕) 찾어드는',
#  '벌거숭이 두루미 다리같이...',
#  '목아지를 매달아 늘어지고,',
#  '까치가 색기의 날발을 태우려 날뿐,',
#  '골작은 나그네의 마음처럼 고요하다.',
#  '장미 병들어',
#  '옮겨 놓을 이웃이 없도다.',
#  '달랑달랑 외로히',
#  '황마차(幌馬車) 태워 산(山)에 보낼거나,',
#  '뚜— 구슬피',
#  '화륜선(火輪船) 태워 대양(大洋)에 보낼거나,',
#  '비행기(飛行機) 태워 성층권(成層圈)에 보낼거나',
#  '이것 저것',
#  '다 구만두고',
#  '자라가는 아들이 꿈을 깨기 전',
#  '이내 가슴에 묻어다오.',
#  '황혼(黃昏)이 짙어지는 길모퉁이에서',
#  '하루종일 시들은 귀를 가만히 기울이면',
#  '땅거미 옮겨지는 발자취 소리,',
#  '발자취 소리를 들을 수 있도록',
#  '나는 총명했든가요.',
#  '이제 어리석게도 모든 것을 깨달은 다음',
#  '괴로워하던 수많은 나를',
#  '하나, 둘 제고장으로 돌려보내면',
#  '거리모퉁이 어둠 속으로',
#  '소리 없이 사라지는 흰 그림자,',
#  '연연히 사랑하던 흰 그림자들,',
#  '내 모든 것을 돌려 보낸 뒤',
#  '허전히 뒷골목을 돌아',
#  '황혼(黃昏)처럼 물드는 내 방으로 돌아오면',
#  '신념(信念)이 깊은 의젓한 양(羊)처럼',
#  '하루종일 시름없이 풀포기나 뜯자.',
#  '봄이 오던 아침, 서울 어느 쪼그만 정거장(停車場)에서',
#  '희망(希望)과 사랑처럼 기차(汽車)를 기다려,',
#  '나는 플랫폼(푸라트•폼)에 간신한 그림자를 떨어트리고,',
#  '담배를 피웠다.',
#  '내 그림자는 담배연기 그림자를 날리고',
#  '비둘기 한 떼가 부끄러울 것도 없이',
#  '기차(汽車)는 아무 새로운 소식도 없이',
#  '나를 멀리 실어다 주어,',
#  '봄은 다 가고—— 도쿄(東京) 교외(郊外) 어느 조용한',
#  '하숙방(下宿房)에서, 옛 거리에 남은 나를 희망(希望)과',
#  '사랑처럼 그리워한다.',
#  '오늘도 기차(汽車)는 몇 번이나 무의미(無意味)하게 지나가고,',
#  '오늘도 나는 누구를 기다려 정거장(停車場) 가까운 언덕에서 서성거릴게다.',
#  '——아아 젊음은 오래 거기 남아 있거라.',
#  '으스럼히 안개가 흐른다. 거리가 흘러간다. 저 전차(電車), 자동차(自動車), 모든 바퀴가 어디로 흘리워 가는 것일까? 정박(定泊)할 아무 항구(港口)도 없이, 가련한 많은 사람들을 실고서, 안개 속에 잠긴 거리는,',
#  '거리 모통이 붉은 포스트상자를 붙잡고 섰을라면 모든 것이 흐르는 속에 어렴풋이 빛나는 가로등(街路燈), 꺼지지 않는 것은 무슨 상징(象徵)일까? 사랑하는 동무 박(朴)이여! 그리고 김(金)이여! 자네들은 지금 어디 있는가? 끝없이 안개가 흐르는데,',
#  '「새로운 날 아침 우리 다시 정(情)답게 손목을 잡어 보세」 몇 자 적어 포스트 속에 떨어트리고, 밤을 새워 기다리면 금휘장(金徽章)에 금단추(金단추)를 삐었고 거인(巨人)처럼 찬란히 나타나는 배달부(配達夫), 아침과 함께 즐거운 내림(來臨),',
#  '이밤을 하염없이 안개가 흐른다.',
#  '창밖(窓外)에 밤비가 속살거려',
#  '육첩방(六疊房)은 남의 나라,',
#  '시인(詩人)이란 슬픈 천명(天命)인줄 알면서도',
#  '한줄 시(詩)를 적어 볼가,',
#  '땀내와 사랑내 포근히 품긴',
#  '보내주신 학비봉투(學費封套)를 받어',
#  '대학(大學)노—트를 끼고',
#  '늙은 교수(敎授)의 강의(講義) 들으려 간다.',
#  '하나, 둘, 죄다 잃어 버리고',
#  '나는 무얼 바라',
#  '나는 다만, 홀로 침전(沈澱)하는 것일가?',
#  '인생(人生)은 살기 어렵다는데',
#  '시(詩)가 이렇게 쉽게 씨워지는 것은',
#  '부끄러운 일이다.',
#  '육첩방(六疊房)은 남의 나라',
#  '등불을 밝혀 어둠을 조곰 내몰고,',
#  '시대(時代)처럼 올 아침을 기다리는 최후(最後)의 나,',
#  '나는 나에게 적은 손을 내밀어',
#  '눈물과 위안(慰安)으로 잡는 최초(最初)의 악수(握手).',
#  '개나리, 진달래, 노오란 배추꽃',
#  '풀포기처럼 피어난다.',
#  '즐거운 종달새야',
#  '어느 이랑에서 즐거웁게 솟쳐라.',
#  '푸르른 하늘은',
#  '아른아른 높기도 한데……',
#  '파란 녹이 낀 구리거울 속에',
#  '내 얼굴이 남어 있는 것은',
#  '어느 왕조(王朝)의 유물(遺物)이기에',
#  '이다지도 욕될가',
#  '나는 나의 참회(懺悔)의 글을 한줄에 주리자',
#  '무슨 기쁨을 바라 살아 왔든가',
#  '내일이나 모레나 그 어느 즐거운 날에',
#  '나는 또 한줄의 참회록(懺悔錄)을 써야한다.',
#  '——그때 그 젊은 나이에',
#  '왜 그런 부끄런 고백(告白)을 했든가',
#  '슬픈 사람의 뒷모양이',
#  '거울 속에 나타나온다.',
#  '바닷가 햇빛 바른 바위우에',
#  '습한 간(肝)을 펴서 말리우자,',
#  '코카사쓰 산중(山中)에서 도망해온 토끼처럼',
#  '둘러리를 빙빙 돌며 간(肝)을 지키자,',
#  '내가 오래 기르든 여윈 독수리야!',
#  '와서 뜯어 먹어라, 시름없이',
#  '너는 살지고',
#  '나는 여위여야지, 그러나,',
#  '다시는 용궁(龍宮)의 유혹(誘惑)에 안떨어진다.',
#  '푸로메디어쓰 불상한 푸로메디어쓰',
#  '불 도적한 죄로 목에 맷돌을 달고',
#  '끝없이 침전(沈澱)하는 푸로메디어쓰,',
#  '연륜(年輪)이 자라듯이',
#  '달이 자라는 고요한 밤에',
#  '달같이 외로운 사랑이',
#  '가슴하나 뻐근히',
#  '연륜(年輪)처럼 피어나간다.',
#  '시들은 잎새속에서',
#  '고 빨간 살을 드러내 놓고,',
#  '고추는 방년(芳年)된 아가씬양',
#  '땡볕에 자꾸 익어간다.',
#  '할머니는 바구니를 들고',
#  '밭머리에서 어정거리고',
#  '손가락 너어는 아이는',
#  '할머니 뒤만 따른다.',
#  '붉은 이마에 싸늘한 달이 서리어',
#  '아우의 얼굴은 슬픈 그림이다.',
#  '발걸음을 멈추어',
#  '「늬는 자라 무엇이 되려니」',
#  '「사람이 되지」',
#  '아우의 설은 진정코 설은 대답(對答)이다.',
#  '아우의 얼골을 다시 들여다 본다.',
#  '싸늘한 달이 붉은 이마에 젖어',
#  '아우의 얼골은 슬픈 그림이다.',
#  '순(順)아 너는 내 전(殿)에 언제 들어왔든 것이냐?',
#  '내사 언제 네 전(殿)에 들어갔든 것이냐?',
#  '고풍(古風)한 풍습(風習)이 어린 사랑의 전당(殿堂)',
#  '순(順)아 암사슴처럼 수정(水晶)눈을 나려감어라.',
#  '난 사자처럼 엉크린 머리를 고루련다.',
#  '우리들의 사랑은 한낱 벙어리이었다.',
#  '성(聖)스런 촛대에 열(熱)한 불이 꺼지기 전(前)',
#  '순(順)아 너는 앞문으로 내 달려라.',
#  '어둠과 바람이 우리 창(窓)에 부닥치기 전(前)',
#  '나는 영원(永遠)한 사랑을 안은채',
#  '이제 네게는 삼림(森林)속의 아늑한 호수(湖水)가 있고',
#  '내게는 준험(峻嶮)한 산맥(山脈)이 있다.',
#  '발에 터부한 것을 다 빼어 바리고',
#  '황혼(黃昏)이 호수(湖水)우로 걸어 오듯이',
#  '내사 이 호수(湖水)가로',
#  '부르는 이 없이',
#  '불리워 온 것은',
#  '참말 이적(異蹟)이외다.',
#  '오늘 따라',
#  '연정(戀情), 자부(自惚), 시기(猜忌), 이것들이',
#  '자꾸 금메달(金메달)처럼 만져지는구려',
#  '하나, 내 모든 것을 여념(餘念)없이',
#  '당신은 호면(湖面)으로 나를 불러 내소서.',
#  '솨— 철석! 파도소리 문살에 부서져',
#  '잠 살포시 꿈이 흐터진다.',
#  '달랠 아무런 재주도 없다.',
#  '불을 밝혀 잠옷을 정성스리 여미는',
#  '삼경(三更).',
#  '염원(念願).',
#  '동경(憧憬)의 땅 강남(江南)에 또 홍수(洪水)질 것만 싶어,',
#  '괴로운 사람아 괴로운 사람아',
#  '옷자락 물결속에서도 가슴속 깊이 돌돌 샘물이 홀러',
#  '거리의 소음과 노래 부를수 없도다.',
#  '그신듯이 냇가에 앉았으니',
#  '바다로 가자',
#  '후어—ㄴ한 방(房)에',
#  '유언(遺言)은 소리 없는 입놀림.',
#  '바다에 진주(眞珠) 캐려 갔다는 아들',
#  '해녀(海女)와 사랑을 속삭인다는 맏아들',
#  '이 밤에사 돌아오나 내다 봐라——',
#  '평생(平生) 외롭던 아버지의 운명(殞命)',
#  '감기우는 눈에 슬픔이 어린다.',
#  '쉬는 시간(時間)마다',
#  '——창(窓)은 산 가르침.',
#  '이글이글 불을 피워주소,',
#  '이 방에 찬것이 서립니다.',
#  '맴 도나 보니',
#  '아마도 작으마한 선풍(旋風)이 인게웨다.',
#  '그래도 싸느란 유리창에',
#  '햇살이 쨍쨍한 무렵,',
#  '상학종(上學鐘)이 울어만 싶습니다.',
#  '실어다 뿌리는',
#  '바람조차 시원타.',
#  '솔나무 가지마다 샛춤히',
#  '밀치고',
#  '밀치운다.',
#  '이랑을 넘는 물결은',
#  '폭포처럼 피어오른다.',
#  '해변(海邊)에 아이들이 모인다',
#  '찰찰 손을 씻고 구보로.',
#  '바다는 자꾸 섧어진다.',
#  '돌아다 보고 돌아다 보고',
#  '돌아가는 오늘의 바다여!',
#  '섧은 산울림.',
#  '골자기 길에',
#  '떨어진 그림자는',
#  '너무나 슬프구나.',
#  '오후(午後)의 명상(瞑想)은',
#  '아— 졸려.',
#  '가츨가츨한 머리칼은 오막사리 처마끝,',
#  '쉬파람에 콧마루가 서운한 양 간질키오.',
#  '들창(窓) 같은 눈은 가볍게 닫혀',
#  '이 밤에 연정(戀情)은 어둠처럼 골골히 스며드오.',
#  '싸늘한 대리석(大理石) 기둥에 목아지를 비틀어맨 한난계(寒暖計),',
#  '문득 들여다 볼 수 있는 운명(運命)한 오척육촌(五尺六寸)의 허리 가는 수은주(水銀柱),',
#  '마음은 유리관(琉璃管)보다 맑소이다.',
#  '혈관(血管)이 단조(單調)로워 신경질(神經質)인 여론동물(輿論動物),',
#  '가끔 분수(噴水) 같은 냉침(冷침)을 억지로 삼키기에',
#  '정력(精力)을 낭비(浪費)합니다.',
#  '영하(零下)로 손구락질 할 수도 없는 방(房)처럼 치운 겨울보다',
#  '해바라기 만발(滿發)한 팔월(八月) 교정(校庭)이 이상(理想)곱소이다.',
#  '피끓을 그날이——',
#  '어제는 막 소낙비가 퍼붓더니 오늘은 좋은 날세올시다.',
#  '동저고리 바람에 언덕으로, 숲으로 하시구려——',
#  '나는 또 내가 모르는 사이에——',
#  '나는 아마도 진실(眞實)한 세기(世紀)의 계절(季節)을 따라——',
#  '하늘만 보이는 울타리 안을 뛰쳐,',
#  '역사(歷史) 같은 포지슌을 지켜야 봅니다.',
#  '번개, 뇌성, 왁자지근 뚜다려',
#  '머—ㄴ 도화지(都會地)에 낙뢰(落雷)가 있어만 싶다.',
#  '벼루짱 엎어논 하늘로',
#  '살같은 비가 살처럼 쏟아진다.',
#  '손바닥만한 나의 정원(庭園)이',
#  '마음같이 흐린 호수(湖水)되기 일수다.',
#  '바람이 팽이처럼 돈다.',
#  '나무가 머리를 이루 잡지 못한다.',
#  '내 경건(敬虔)한 마음을 모셔드려',
#  '봄바람을 등진 초록빛 바다',
#  '쏟아질듯 쏟아질듯 위트롭다.',
#  '잔주름 치마폭의 두둥실거리는 물결은,',
#  '오스라질듯 한끝 경쾌(輕快)롭다.',
#  '마스트 끝에 붉은 깃발(旗ㅅ발)이',
#  '여인(女人)의 머리칼처럼 나부낀다.',
#  '이 생생한 풍경(風景)을 앞세우며 뒤세우며',
#  '——우중충한 오월(五月) 하늘 아래로,',
#  '——바다빛 포기포기에 수(繡)놓은 언덕으로,',
#  '흐르는 달의 흰 물결을 밀쳐',
#  '여윈 나무그림자를 밟으며',
#  '북망산(北邙山)을 향(向)한 발걸음은 무거웁고',
#  '고독(孤獨)을 반려(伴侶)한 마음은 슬프기도 하다.',
#  '누가 있어만 싶은 묘지(墓地)엔 아무도 없고,',
#  '정적(靜寂)만이 군데군데 흰 물결에 폭 젖었다.',
#  '이른 아침 아낙네들은 시들은 생활(生活)을',
#  '바구니 하나 가득 담아 이고……',
#  '업고 지고…… 안고 들고……',
#  '모여드오 자꾸 장에 모여드오.',
#  '가난한 생활(生活)을 골골이 버려놓고',
#  '밀려가고 밀려오고……',
#  '제마다 생활(生活)을 외치오…… 싸우오.',
#  '왼하로 올망졸망한 생활(生活)을',
#  '날이 저물어 아낙네들이',
#  '쓴 생활(生活)과 바꾸어 또 이고 돌아가오.',
#  '오양간 당나귀',
#  '아—ㅇ 외 마디 울음울고,',
#  '당나귀 소리에',
#  '으—아 아 애기 소스라처 깨고,',
#  '등잔에 불을 다오.',
#  '아버지는 당나귀에게',
#  '짚을 한키 담아 주고,',
#  '어머니는 애기에게',
#  '젖을 한모금 먹이고,',
#  '밤은 다시 고요히 잠드오.',
#  '하로도 검푸른 물결에',
#  '흐느적 잠기고…… 잠기고……',
#  '물든 바다를 날아 횡단(橫斷)할고.',
#  '낙엽(落葉)이 된 해초(海草)',
#  '해초(海草)마다 슬프기도 하오.',
#  '서창(西窓)에 걸린 해말간 풍경화(風景畵).',
#  '옷고름 너어는 고아(孤兒)의 서름.',
#  '이제 첫 항해(航海)하는 마음을 먹고',
#  '방바닥에 나딩구오…… 딩구오……',
#  '황혼(黃昏)이 바다가 되어',
#  '오늘도 수많은 배가',
#  '나와 함께 이 물결에 잠겼을게오.',
#  '휙, 휙, 휙,',
#  '어둠을 쫓아,',
#  '캄, 캄, 어둠이 깊다 깊다 밝으오.',
#  '이제 이 동리(洞里)의 아침이',
#  '풀살 오른 소엉덩이처럼 푸드오.',
#  '땀물을 뿌려 이 여름을 길렀오.',
#  '잎, 잎, 풀잎마다 땀방울이 맺혔오.',
#  '구김살 없는 이 아침을',
#  '심호흡(深呼吸)하오 또 하오.',
#  '횐 빨래들이 귓속 이야기 하는 오후(午後),',
#  '아담한 빨래에만 달린다.',
#  '잠은 눈을 떴다',
#  '노래하던 종달이',
#  '도망쳐 날아나고,',
#  '금잔디밭은 아니다.',
#  '탑(塔)은 무너졌다,',
#  '붉은 마음의 탑(塔)이——',
#  '손톱으로 새긴 대리석(大理石) 탑(塔)이——',
#  '하루저녁 폭풍(暴風)에 여지(餘地)없이도,',
#  '오오 황폐(荒廢)의 쑥밭,',
#  '눈물과 목메임이여!',
#  '꿈은 깨어졌다',
#  '탑(塔)은 무너졌다.',
#  '시계(時計)가 자근자근 가슴을 따려',
#  '불안(不安)한 마음을 산림(山林)이 부른다.',
#  '천년(千年) 오래인 연륜(年輪)에 짜들은 유암(幽暗)한 산림(山林)이,',
#  '고달픈 한몸을 포옹(抱擁)할 인연(因緣)을 가졌나보다.',
#  '산림(山林)의 검은 파동(波動)우으로부터',
#  '어둠은 어린 가슴을 짓밟고',
#  '이파리를 흔드는 저녁바람이',
#  '솨— 공포(恐怖)에 떨게 한다.',
#  '멀리 첫여름의 개구리 재질댐에',
#  '흘러간 마을의 과거(過去)는 아질타.',
#  '나무틈으로 반짝이는 별만이',
#  '새날의 희망(希望)으로 나를 이끈다.',
#  '사이좋은 정문(正門)의 두 돌기둥 끝에서',
#  '오색기(五色旗)와 태양기(太陽旗)가 춤을 추는 날,',
#  '금을 그은 지역(地域)의 아이들이 즐거워하다.',
#  '아이들에게 하루의 건조(乾燥)한 학과(學課)로',
#  '해말간 권태(倦怠)가 깃들고',
#  '「모순(矛盾)」 두 자를 이해(理解)치 못하도록',
#  '못하도록 머리가 단순(單純)하였구나.',
#  '이런 날에는',
#  '잃어버린 완고(頑固)하던 형(兄)을',
#  '부르고 싶다.',
#  '거리가 바둑판처럼 보이고,',
#  '강물(江水)이 배암의 새끼처럼 기는',
#  '산(山) 우에까지 왔다.',
#  '바둑돌처럼 버려있으리라.',
#  '함석지붕에만 비치고,',
#  '굼벵이 걸음을 하던 기차(汽車)가',
#  '정거장(停車場)에 섰다가 검은 내를 토(吐)하고',
#  '텐트 같은 하늘이 무너져',
#  '이 거리를 덮을까 궁금하면서',
#  '좀 더 높은 데로 올라가고 싶다.',
#  '저쪽으로 황토(黃土) 실은 이 땅 봄바람이',
#  '아롱진 사월(四月) 태양(太陽)의 손길이',
#  '벽(壁)을 등진 섧은 가슴마다 올올히 만진다.',
#  '지도(地圖)째기 놀음에 뉘 땅인 줄 모르는 애 둘이',
#  '한 뼘 손가락이 짧음을 한(恨)하며',
#  '아서라! 가뜩이나 엷은 평화(平和)가',
#  '깨어질까 근심스럽다.',
#  '한간(一間) 계사(鷄舍) 그 넘어 창공(蒼空)이 깃들어',
#  '자유(自由)의 향토(鄕土)를 잊은 닭들이',
#  '시들은 생활(生活)을 주잘대고',
#  '생산(生産)의 고로(苦勞)를 부르짖었다.',
#  '음산(陰酸)한 계사(鷄舍)에서 쏠려나온',
#  '외래종(外來種) 레구홍,',
#  '학원(學園)에서 새무리가 밀려나오는',
#  '삼월(三月)의 맑은 오후(午後)도 있다.',
#  '닭들은 녹아드는 두엄을 파기에',
#  '아담(雅淡)한 두 다리가 분주(奔走)하고',
#  '굶주렸던 주둥이(주두리)가 바즈런하다.',
#  '두 눈이 붉게 여므도록——',
#  '안고 도는 겨울밤은 깊었다.',
#  '재(灰)만 남은 가슴이',
#  '문풍지 소리에 떤다.',
#  '안아보고싶게 귀여운',
#  '하늘끝까지 보일듯이 맑은 공일날 아침에',
#  '벼를 거두어 빤빤한 논에',
#  '앞을 다투어 모이를 주으며',
#  '날신한 두나래로 조용한 공기를 흔들어',
#  '두마리가 나오',
#  '집에 새끼 생각이 나는 모양이오.',
#  '그 여름날',
#  '열정(熱情)의 포푸라는',
#  '오려는 창공(蒼空)의 푸른 젖가슴을',
#  '어루만지려',
#  '팔을 펼쳐 흔들거렸다.',
#  '끓는 태양(太陽) 그늘 좁다란 지점(地點)에서',
#  '천막(天幕) 같은 하늘 밑에서',
#  '그리고 번개를,',
#  '춤추던 구름은 이끌고',
#  '남방(南方)으로 도망하고,',
#  '높다랗게 창공(蒼空)은 한 폭으로',
#  '가지 위에 퍼지고',
#  '푸드른 어린 마음이 이상(理想)에 타고,',
#  '그의 동경(憧憬)의 날 가을에',
#  '조락(凋落)의 눈물을 비웃다.',
#  '삶은 오늘도 죽음의 서곡(序曲)을 노래하였다.',
#  '이 노래가 언제나 끝나랴',
#  '뼈를 녹여내는 듯한 삶의 노래에',
#  '춤을 춘다.',
#  '사람들은 해가 넘어가기 전',
#  '이 노래 끝의 공포(恐怖)를',
#  '생각할 사이가 없었다.',
#  '이 노래를 부른 자(者)가 누구뇨',
#  '그리고 소낙비 그친 뒤같이도',
#  '이 노래를 그친 자(者)가 누구뇨',
#  '죽고 뼈만 남은',
#  '죽음의 승리자(勝利者) 위인(偉人)들!',
#  '초 한 대——',
#  '내 방에 품긴 향내를 맡는다.',
#  '광명(光明)의 제단(祭壇)이 무너지기 전',
#  '나는 깨끗한 제물(祭物)을 보았다.',
#  '염소의 갈비뼈 같은 그의 몸,',
#  '그의 생명(生命)인 심지(心志)까지',
#  '백옥(白玉) 같은 눈물과 피를 흘려',
#  '불살려 버린다.',
#  '선녀처럼 촛불은 춤을 춘다.',
#  '매를 본 꿩이 도망하듯이',
#  '제물(祭物)의 위대한 향내(香內)를 맛보노라.',
#  '까치가 울어서',
#  '아무도 못들은',
#  '산울림,',
#  '까치가 들었다,',
#  '저혼자 들었다,',
#  '누나의 얼굴은',
#  '해바라기 얼굴',
#  '해가 금방 뜨자',
#  '일터에 간다.',
#  '해바라기 얼굴은',
#  '누나의 얼굴',
#  '얼굴이 숙어들어',
#  '집으로 온다.',
#  '잔디밭에서 이야기 했다.',
#  '아무게도 아르켜 주지말고',
#  '우리둘만 알자고 약속했다.',
#  '귀뜰귀뜰',
#  '달밝은 밤에 이야기했다.',
#  '우리집에는',
#  '닭도 없단다.',
#  '애기가 젖달라 울어서',
#  '새벽이 된다.',
#  '시계도 없단다.',
#  '다만',
#  '애기가 젖달라 보채어',
#  '달조각을 주으려',
#  '그믐밤 반디불은',
#  '부서진 달조각,',
#  '가자 가자 가자',
#  '숲으로 가자',
#  '바다도 푸르고',
#  '하늘도 푸르고',
#  '바다도 끝없고',
#  '하늘도 끝없고',
#  '하늘에 침뱉고',
#  '하늘은 잠잠.',
#  '똑, 똑, 똑,',
#  '문좀 열어 주세요',
#  '하루밤 자고 갑시다.',
#  '밤은 깊고 날은 추운데',
#  '거 누굴까?',
#  '문열어 주고 보니',
#  '검둥이의 꼬리가',
#  '거짓부리한걸.',
#  '꼬기요, 꼬기요,',
#  '달걀 낳았다.',
#  '달걀은 무슨 달걀,',
#  '고놈의 암탉이',
#  '거짓부리 한걸.',
#  '지난밤에',
#  '눈이 소오복이 왔네',
#  '지붕이랑',
#  '길이랑 밭이랑',
#  '추워 한다고',
#  '덮어주는 이불인가바',
#  '그러기에',
#  '가을지난 마당은 하이얀종이',
#  '참새들이 글씨를 공부하지요.',
#  '째액째액 입으로 받아읽으며',
#  '두발로는 글씨를 연습하지요.',
#  '하로종일 글씨를 공부하여도',
#  '누나 쓰다버린 습자지는',
#  '두었다간 뭣에 쓰나요?',
#  '그런줄 몰랐드니',
#  '어머니',
#  '내가 쓰다버린 몽당연필은',
#  '내버선 만드는걸.',
#  '바닷가 사람',
#  '물고기 잡아 먹고 살고',
#  '감자 구어 먹고 살고',
#  '별나라 사람',
#  '무얼 먹고 사나.',
#  '산골작이 오막사리 낮은 굴뚝엔',
#  '몽기몽기 웨인연기 대낮에 솟나,',
#  '감자를 굽는게지 총각애들이',
#  '깜박깜박 검은눈이 모여 앉어서',
#  '옛이야기 한커리에 감자 하나씩.',
#  '살랑살랑 솟아나네 감자 굽는내.',
#  '아씨처럼 나린다',
#  '보슬보슬 해ㅅ비',
#  '맞아주자 다같이',
#  '옥수숫대 처럼 크게',
#  '닷자엿자 자라게',
#  '햇님이 웃는다',
#  '나보고 웃는다.',
#  '알롱알롱 무지개',
#  '노래하자 즐겁게',
#  '동무들아 이리 오나',
#  '다같이 춤을추자',
#  '즐거워 웃는다',
#  '비오는날 저녁에 기왓장내외',
#  '잃어버린 외아들 생각나선지',
#  '꼬부라진 잔등을 어루만지며',
#  '쭈룩쭈룩 구슬피 울음웁니다.',
#  '대궐지붕 위에서 기왓장내외',
#  '아름답든 옛날이 그리워선지',
#  '주름잡힌 얼굴을 어루만지며',
#  '물끄럼히 하늘만 쳐다봅니다.',
#  '지난밤에 내동생',
#  '오줌싸 그린지도',
#  '꿈에 가본 엄마계신',
#  '별나라 지돈가?',
#  '돈벌러간 아빠계신',
#  '만주땅 지돈가?',
#  '아롱아롱 조개껍대기',
#  '울언니 바다가에서',
#  '주어온 조개껍대기',
#  '조개는 귀여운선물',
#  '장난감 조개껍대기',
#  '데굴데굴 굴리며놀다',
#  '짝잃은 조개껍대기',
#  '한짝을 그리워하네',
#  '나처럼 그리워하네',
#  '물소리 바다물소리.',
#  '나 보기가 역겨워',
#  '가실 때에는',
#  '말없이 고이 보내드리오리다.',
#  '아름따다 가실 길에 뿌리오리다.',
#  '가시는 걸음 걸음',
#  '놓인 그 꽃을',
#  '사뿐히 즈려밟고 가시옵소서.',
#  '죽어도 아니 눈물 흘리오리다.',
#  '엄마야 누나야 강변 살자,',
#  '뜰에는 반짝는 금모래빛,',
#  '뒷문 밖에는 갈잎의 노래',
#  '엄마야 누나야 강변 살자.',
#  '봄 가을없이 밤마다 돋는 달도',
#  "예전엔 미처 몰랐어요.'",
#  '이렇게 사무치게 그립을줄도',
#  '달이 암만 밝아도 쳐다볼줄을',
#  '이제금 저 달이 설움인줄은',
#  '먼 훗날 당신이 찾으시면',
#  "그때에 내 말이 `잊었노라'",
#  '당신이 속으로 나무라면',
#  "`무척 그리다가 잊었노라'",
#  '그래도 당신이 나무라면',
#  "`믿기지 않아서 잊었노라'",
#  '오늘도 어제도 아니 잊고',
#  "먼 훗날 그때에 `잊었노라'",
#  '산산이 부서진 이름이어!',
#  '허공중(虛空中)에 헤어진 이름이어!',
#  '불러도 주인(主人)없는 이름이어!',
#  '부르다가 내가 죽을 이름이어!',
#  '심중(心中)에 남아있는 말 한마디는',
#  '끝끝내 마저하지 못하였구나.',
#  '사랑하던 그 사람이어!',
#  '붉은 해는 서산(西山) 마루에 걸리었다.',
#  '사슴이의 무리도 슬피 운다.',
#  '떨어져 나가앉은 산 위에서',
#  '나는 그대의 이름을 부르노라.',
#  '설움에 겹도록 부르노라.',
#  '부르는 소리는 비껴가지만',
#  '하늘과 땅 사이가 너무 넓구나.',
#  '선 채로 이 자리에 돌이 되어도',
#  '걷잡지 못할만한 나의 이 설움,',
#  '저무는 봄저녁에 져가는 꽃잎,',
#  '져가는 꽃잎들은 나부끼어라.',
#  '바다가 변하야 뽕나무밭 된다고.',
#  '있다던 온갖 것은 눈에 설고',
#  '다시금 낯 모르게 되나니,',
#  '보아라, 그대여, 서럽지 않은가,',
#  '붉은 피같이도 쏟아져 나리는',
#  '저기 저 꽃잎들을, 저기 저 꽃잎들을',
#  '우리 두 사람은',
#  '키높이 가득 자란 보리밭, 밭고랑 위에 앉았어라.',
#  '일을 필하고 쉬이는 동안의 기쁨이어.',
#  '지금 두 사람의 이야기에는 꽃이 필 때.',
#  '오오 빛나는 태양은 나려 쪼이며',
#  '새무리들도 즐겁은 노래, 노래 불러라.',
#  '오오 은혜여, 살아있는 몸에는 넘치는 은혜여',
#  '모든 은근스럽음이 우리의 맘 속을 차지하여라.',
#  '세계의 끝은 어디? 자애의 하늘은 넓게도 덮혔는데,',
#  '우리 두 사람은 일하며, 살아있어서,',
#  '하늘과 태양을 바라보아라, 날마다 날마다도,',
#  '새라새롭은 환희를 지어내며, 늘 같은 땅 위에서.',
#  '다시한번 활기있게 웃고나서, 우리 두 사람은',
#  '걸어나아가는 기쁨이어, 오오 생명의 향상이어.',
#  '홀로 잠들기가 참말 외로와요',
#  '맘에는 사무치도록 그리워와요',
#  '아주 얼굴조차 잊힐듯해요.',
#  '벌써 해가 지고 어둡는대요,',
#  '부슬부슬 오는 비에 밤이 더디고',
#  '바다바람이 춥기만 합니다.',
#  '다만 고요히 누워 들으면',
#  '하이얗게 밀어드는 봄 밀물이',
#  '눈앞을 가루막고 흐느낄 뿐이야요.',
#  '희멀끔하여 떠돈다, 하늘 위에,',
#  '빛죽은 반달이 언제 올랐나!',
#  '바람은 나온다, 저녁은 춥구나,',
#  '흰 물가엔 뚜렷이 해가 드누나.',
#  '어둑컴컴한 풀없는 들은',
#  '찬 안개 우흐로 떠흐른다.',
#  '아, 겨울은 깊었다, 내 몸에는,',
#  '가슴이 무너져 나려앉는 이 설움아!',
#  '가는 님은 가슴에 사랑까지 없애고 가고',
#  '젊음은 늙음으로 바뀌어든다.',
#  '들가시나무의 밤드는 검은 가지',
#  '잎새들만 저녁빛에 희그무려히 꽃지듯한다.',
#  '봄에 부는 바람, 바람부는 봄,',
#  '적은가지 흔들리는 부는 봄바람,',
#  '내 가슴 흔들리는 바람, 부는 봄,',
#  '봄이라 바람이라 이내 몸에는',
#  '꽃이라 술잔이라 하며 우노라.',
#  '실버드나무의 검으스렷한 머리결인 낡은 가지에',
#  '제비의 넓은 깃나래의 감색 치마에',
#  '술집의 창 옆에, 보아라, 봄이 앉았지 않은가.',
#  '소리도 없이 바람은 불며, 울며, 한숨지워라.',
#  '아무런 줄도 없이 섧고 그립은 새카만 봄밤',
#  '보드랍은 습기는 떠돌며 땅을 덮어라.',
#  '좀 더 미리부터 알았던들!',
#  '늙는 날 죽는 날을',
#  '사람은 다 모르고 사는 탓에,',
#  '오오 오직 이것이 참이라면,',
#  '지금부터 두여덟 좋은 연광',
#  '전보다 좀 더 전보다 좀 더',
#  '살음즉이 살런지 모르련만.',
#  '불운에 우는 그대여, 나는 아노라',
#  '무엇이 그대의 불운을 지었는지도,',
#  '밀물에 흘러,',
#  '굳어진 그대의 가슴 속도.',
#  '모다 지나간 나의 일이면.',
#  '다시금 또 다시금',
#  '적황의 포말은 북고여라, 그대의 가슴속의',
#  '암청의 이끼어, 거칠은 바위',
#  '치는 물가의.',
#  '바람에 밀려드는 저 붉은 조수',
#  '나는 저 바람 위에 올라서서',
#  '푸릇한 구름의 옷을 입고',
#  '불같은 저 해를 품에 안고',
#  '저 붉은 조수와 나는 함께',
#  '뛰놀고 싶구나, 저 붉은 조수와.',
#  '봄은 가나니 저문 날에,',
#  '꽃은 지나니 저문 봄에,',
#  '속없이 우나니, 지는 꽃을,',
#  '속없이 느끼나니 가는 봄을.',
#  '꽃지고 잎진 가지를 잡고',
#  '미친듯 우나니, 집난이는',
#  '허리에도 감은 첫치마를',
#  '눈물로 함빡이 쥐어짜며',
#  '속없이 우노나 지는 꽃을,',
#  '속없이 느끼노나 가는 봄을.',
#  '마치 천리만리나 가고도 싶은',
#  '맘이라고나 하여볼까.',
#  '한줄기 쏜살같이 벋은 이 길로',
#  '줄곧 치달아 올라가면',
#  '불붙는 산의, 불붙는 산의',
#  '나쁜 일까지라도 생의 노력,',
#  '그 사람은 선사도 하였어라',
#  '그러나 그것도 허사라고!',
#  '나 역시 알지마는, 우리들은',
#  '끝끝내 고개를 넘고 넘어',
#  '짐 싣고 닫던 말도 순막집의',
#  '허청가 석양 손에',
#  '고요히 조으는 한때는 다 있나니',
#  '닭은 꼬꾸요, 꼬꾸요 울 제,',
#  '헛잡으니 두 팔은 밀려났네.',
#  '애도 타리만치 기나긴 밤은……',
#  '꿈 깨친 뒤엔 감도록 잠 아니 오네.',
#  '엊저녁 대인 남포(南浦)뱃간.',
#  '몸을 잡고 뒤재며 누웠으면',
#  '솜솜하게도 감도록 그리워오네.',
#  '아무리 보아도',
#  '밝은 등(燈)불, 어스렷한데.',
#  '감으면 눈 속엔 흰 모래밭,',
#  '모래에 어린 안개는 물 위에 슬 제',
#  '대동강(大同江) 뱃나루에 해 돋아오네.',
#  '그대가 바람으로 생겨났으면!',
#  '우리가 굼벙이로 생겨났으면!',
#  '비오는 저녁 캄캄한 녕기슭의',
#  '만일에 그대가 바다난 끝의',
#  '벼랑에 돌로나 생겨났더면,',
#  '둘이 안고 굴며 떨어나지지.',
#  '만일에 나의 몸이 불귀신이면',
#  '그대의 가슴 속을 밤도와 태워',
#  '둘이 함께 재 되어 스러지지.',
#  '물은 희고 길구나, 하늘 보다도.',
#  '구름은 붉구나, 해 보다도.',
#  '서럽다, 높아가는 긴 들끝에',
#  '나는 떠돌며 울며 생각한다, 그대를.',
#  '그늘 깊어 오르는 발 앞으로',
#  '끝없이 나아가는 길은 앞으로.',
#  '성깃한 가지가지 새로 떠오른다.',
#  '그 누가 온다고 한 언약(言約)도 없건마는!',
#  '기다려 볼 사람도 없건마는!',
#  '나는 오히려 못물가를 싸고 떠돈다.',
#  '그 못물로는 놀이 잦을 때.',
#  '달 아래 시멋없이 섰던 그 여자,',
#  '서있던 그 여자의 해슥한 얼굴,',
#  '해슥한 그 얼굴 적이 파릇함.',
#  '다시금 실벗듯한 가지 아래서',
#  '시꺼먼 머릿길은 번쩍거리며.',
#  '다시금 하룻밤의 식는 강물을',
#  '오오 그 시멋없이 섰던 여자여!',
#  '그립다 그 한밤을 내게 가깝던',
#  '그대여 꿈이 깊던 그 한동안을',
#  '슬픔에 귀엽음에 다시 사랑의',
#  '눈물에 우리 몸이 맏기웠던 때.',
#  '다시금 고즈넉한 성밖 골목의',
#  '한두 등불 불빛은 울어새던 때.',
#  '저기 저 구름을 잡아타면',
#  '붉게도 피로 물든 저 구름을,',
#  '밤이면 새캄한 저 구름을.',
#  '잡아타고 내 몸은 저 멀리로',
#  '구만리(九萬里) 긴 하늘을 날아 건너',
#  '그대 잠든 품속에 안기렸더니,',
#  '애스러라, 그리는 못한대서,',
#  '그대여, 들으라 비가 되어',
#  '저 구름이 그대한테로 나리거든,',
#  '생각하라, 밤저녁, 내 눈물을.',
#  '황촉불, 그저도 까맣게',
#  '스러져가는 푸른 창(窓)을 기대고',
#  '소리조차 없는 흰 밤에,',
#  '나는 혼자 거울에 얼굴을 묻고',
#  "나는 이르노니, '우리 사람들",
#  '첫날밤은 꿈속으로 보내고',
#  '죽음은 조는 동안에 와서,',
#  "별(別) 좋은 일도 없이 스러지고 말어라'.",
#  '봄날이 오리라고 생각하면서',
#  '쓸쓸한 긴 겨울을 지나보내라.',
#  '오늘 보니 백양(白楊)의 뻗은 가지에',
#  '전(前)에 없이 흰새가 앉아 울어라.',
#  '그러나 눈이 깔린 언덕 밑에는',
#  '그늘이냐 안개냐 아지랑이냐.',
#  '마을들은 곳곳이 움직임 없이',
#  '저편(便) 하늘 아래서 평화(平和)롭건만.',
#  '새들께 지껄이는 까치의 무리.',
#  '바다를 바라보며 우는 까마귀.',
#  '어디로서 오는지 종경소리는',
#  '젊은 아기 나가는 조곡(吊曲)일러라.',
#  '보라 때에 길손도 머뭇거리며',
#  '지향없이 갈 발이 곳을 몰라라.',
#  '사무치는 눈물은 끝이 없어도',
#  '하늘을 쳐다보는 살음의 기쁨.',
#  '저마다 외롭음의 깊은 근심이',
#  '오도가도 못하는 망상거림에',
#  '오늘은 사람마다 님을 여의고',
#  '곳을 잡지 못하는 설움일러라.',
#  '오기를 기다리는 봄의 소리는',
#  '때로 여윈 손끝을 울릴지라도',
#  '수풀 밑에 서리운 머릿길들은',
#  '걸음걸음 괴로이 발에 감겨라.',
#  '그립은 우리님의 맑은 노래는',
#  '언제나 제 가슴에 젖어있어요',
#  '긴 날을 문밖에서 서서 들어도',
#  ...]

# %%
from langchain.docstore.document import Document

# %%
# 2️⃣ 문장들을 Document 형태로 변환
documents = [Document(page_content=text) for text in texts]

# %%
from typing import List
from dataclasses import dataclass

@dataclass
class Document:
    metadata: dict
    page_content: str

def add_common_labels_to_documents(documents: List[Document], df_cleaned, column_name="common_labels"):
    """
    documents의 metadata 딕셔너리에 df_cleaned의 'common_labels' 열 값을 추가하는 함수.
    
    Args:
        documents (List[Document]): Document 객체 리스트.
        df_cleaned (pd.DataFrame): 'common_labels' 열을 포함하는 데이터프레임.
        column_name (str): 추가할 열 이름. 기본값은 'common_labels'.
    
    Returns:
        List[Document]: metadata가 업데이트된 Document 객체 리스트.
    """
    for i, doc in enumerate(documents):
        if i < len(df_cleaned):
            # df_cleaned의 'common_labels' 값을 metadata에 추가
            doc.metadata[column_name] = df_cleaned[column_name].iloc[i]
        else:
            # df_cleaned에 없는 경우 빈 리스트 추가
            doc.metadata[column_name] = []
    return documents

# %%
# 함수 호출
updated_documents = add_common_labels_to_documents(documents, df_cleaned)

# 결과 출력
for doc in updated_documents:
    print(doc)
# Out:
# page_content='죽는 날까지 하늘을 우러러' metadata={'common_labels': ['비장함']}
# page_content='한 점 부끄럼이 없기를,' metadata={'common_labels': ['비장함', '부끄러움']}
# page_content='잎새에 이는 바람에도' metadata={'common_labels': ['기대감']}
# page_content='나는 괴로워했다.' metadata={'common_labels': ['패배/자기혐오', '절망', '슬픔', '힘듦/지침']}
# page_content='별을 노래하는 마음으로' metadata={'common_labels': ['기쁨', '기대감', '아껴주는']}
# page_content='모든 죽어가는 것을 사랑해야지' metadata={'common_labels': ['비장함', '불쌍함/연민', '아껴주는']}
# page_content='걸어가야겠다.' metadata={'common_labels': ['비장함']}
# page_content='오늘 밤에도 별이 바람에 스치운다.' metadata={'common_labels': ['기대감', '감동/감탄']}
# page_content='산모퉁이를 돌아 논가 외딴 우물을 홀로 찾아가선 가만히 들여다봅니다.' metadata={'common_labels': ['슬픔']}
# page_content='우물 속에는 달이 밝고 구름이 흐르고 하늘이 펼치고 파아란 바람이 불고 가을이 있습니다.' metadata={'common_labels': ['신기함/관심', '감동/감탄', '흐뭇함(귀여움/예쁨)', '편안/쾌적']}
# page_content='그리고 한 사나이가 있습니다.' metadata={'common_labels': ['비장함']}
# page_content='어쩐지 그 사나이가 미워져 돌아갑니다.' metadata={'common_labels': ['불쌍함/연민', '안타까움/실망']}
# page_content='돌아가다 생각하니 그 사나이가 가엾어집니다.' metadata={'common_labels': ['불쌍함/연민', '슬픔']}
# page_content='도로 가 들여다보니 사나이는 그대로 있습니다.' metadata={'common_labels': ['불쌍함/연민']}
# page_content='다시 그 사나이가 미워져 돌아갑니다.' metadata={'common_labels': ['불평/불만', '안타까움/실망']}
# page_content='돌아가다 생각하니 그 사나이가 그리워집니다.' metadata={'common_labels': ['불쌍함/연민', '슬픔', '서러움']}
# page_content='우물 속에는 달이 밝고 구름이 흐르고 하늘이 펼치고 파아란 바람이 불고 가을이 있고 추억처럼 사나이가 있습니다.' metadata={'common_labels': ['감동/감탄', '아껴주는', '신기함/관심']}
# page_content='지금 교회당 꼭대기' metadata={'common_labels': ['없음']}
# page_content='십자가에 걸리었습니다.' metadata={'common_labels': ['안타까움/실망', '불안/걱정', '놀람']}
# page_content='첨탑(尖塔)이 저렇게도 높은데' metadata={'common_labels': ['놀람', '신기함/관심']}
# page_content='어떻게 올라갈 수 있을까요.' metadata={'common_labels': ['불안/걱정', '힘듦/지침', '안타까움/실망']}
# page_content='종소리도 들려 오지 않는데' metadata={'common_labels': ['안타까움/실망']}
# page_content='괴로웠던 사나이' metadata={'common_labels': ['불쌍함/연민', '안타까움/실망', '힘듦/지침']}
# page_content='행복한 예수 그리스도에게' metadata={'common_labels': ['기대감', '존경']}
# page_content='처럼' metadata={'common_labels': ['없음']}
# page_content='십자가가 허락된다면' metadata={'common_labels': ['기대감', '비장함']}
# page_content='모가지를 드리우고' metadata={'common_labels': ['기대감']}
# page_content='꽃처럼 피어나는 피를' metadata={'common_labels': ['불안/걱정', '비장함']}
# page_content='어두워 가는 하늘 밑에' metadata={'common_labels': ['불안/걱정']}
# page_content='조용히 흘리겠습니다.' metadata={'common_labels': ['슬픔', '비장함', '서러움']}
# page_content='어디로 불려 가는 것일까' metadata={'common_labels': ['불안/걱정', '당황/난처']}
# page_content='바람이 부는데' metadata={'common_labels': ['없음']}
# page_content='내 괴로움에는 이유가 없다.' metadata={'common_labels': ['슬픔', '서러움', '힘듦/지침', '패배/자기혐오']}
# page_content='내 괴로움에는 이유가 없을까' metadata={'common_labels': ['슬픔', '서러움', '불안/걱정', '당황/난처']}
# page_content='단 한 여자를 사랑한 일도 없다.' metadata={'common_labels': ['한심함', '불쌍함/연민', '안타까움/실망']}
# page_content='시대를 슬퍼한 일도 없다.' metadata={'common_labels': ['서러움', '절망']}
# page_content='바람이 자꼬 부는데' metadata={'common_labels': ['지긋지긋', '불안/걱정', '당황/난처']}
# page_content='내 발이 반석 우에 섰다.' metadata={'common_labels': ['비장함', '깨달음']}
# page_content='내 발이 언덕 우에 섰다.' metadata={'common_labels': ['없음']}
# page_content='고향에 돌아온 날 밤에' metadata={'common_labels': ['편안/쾌적', '행복', '기쁨']}
# page_content='내 백골(白骨)이 따라와 한방에 누웠다.' metadata={'common_labels': ['불안/걱정', '공포/무서움', '당황/난처']}
# page_content='어둔 방은 우주로 통하고' metadata={'common_labels': ['기대감', '감동/감탄']}
# page_content='하늘에선가 소리처럼 바람이 불어 온다.' metadata={'common_labels': ['편안/쾌적']}
# page_content='백골을 들여다보며' metadata={'common_labels': ['신기함/관심', '공포/무서움', '불쌍함/연민', '슬픔']}
# page_content='눈물짓는 것이 내가 우는 것이냐' metadata={'common_labels': ['슬픔', '서러움']}
# page_content='백골이 우는 것이냐' metadata={'common_labels': ['슬픔', '서러움']}
# page_content='아름다운 혼이 우는 것이냐' metadata={'common_labels': ['슬픔', '불쌍함/연민', '불안/걱정']}
# page_content='지조 높은 개는' metadata={'common_labels': ['존경']}
# page_content='밤을 새워 어둠을 짖는다.' metadata={'common_labels': ['불안/걱정', '비장함']}
# page_content='어둠을 짖는 개는' metadata={'common_labels': ['공포/무서움', '불안/걱정']}
# page_content='나를 쫓는 것일 게다.' metadata={'common_labels': ['의심/불신']}
# page_content='가자 가자' metadata={'common_labels': ['비장함', '기대감']}
# page_content='쫓기우는 사람처럼 가자' metadata={'common_labels': ['비장함']}
# page_content='아름다운 또 다른 고향에 가자.' metadata={'common_labels': ['기대감', '기쁨', '즐거움/신남']}
# page_content='계절이 지나가는 하늘에는' metadata={'common_labels': ['신기함/관심']}
# page_content='가을로 가득 차 있습니다.' metadata={'common_labels': ['감동/감탄', '환영/호의', '기쁨', '기대감']}
# page_content='나는 아무 걱정도 없이' metadata={'common_labels': ['편안/쾌적', '안심/신뢰']}
# page_content='가을 속의 별들을 다 헤일 듯합니다...' metadata={'common_labels': ['신기함/관심']}
# page_content='가슴 속에 하나 둘 새겨지는 별을' metadata={'common_labels': ['기쁨', '감동/감탄', '기대감', '깨달음', '행복', '아껴주는']}
# page_content='이제 다 못 헤는 것은' metadata={'common_labels': ['안타까움/실망']}
# page_content='내일 밤이 남은 까닭이요,' metadata={'common_labels': ['기대감']}
# page_content='아직 나의 청춘이 다하지 않은 까닭입니다.' metadata={'common_labels': ['비장함', '기대감']}
# page_content='별 하나에 추억과' metadata={'common_labels': ['기쁨', '기대감', '행복']}
# page_content='별 하나에 사랑과' metadata={'common_labels': ['기쁨', '아껴주는', '감동/감탄']}
# page_content='별 하나에 쓸쓸함과' metadata={'common_labels': ['슬픔', '서러움']}
# page_content='별 하나에 동경과' metadata={'common_labels': ['감동/감탄', '존경']}
# page_content='별 하나에 시와' metadata={'common_labels': ['감동/감탄', '아껴주는', '기대감']}
# page_content='별 하나에 어머니, 어머니' metadata={'common_labels': ['아껴주는', '고마움', '서러움']}
# page_content='어머님, 나는 별 하나에 아름다운 말 한 마디씩 불러 봅니다. 소학교 때 책상을 같이했던 아이들의 이름과, 패, 경, 옥 이런 이국 소녀들의 이름과, 벌써 아기 어머니 된 계집애들의 이름과, 가난한 이웃 사람들의 이름과, 비둘기, 강아지, 토끼, 노새, 노루, '프랑시스 잠', '라이너 마리아 릴케', 이런 시인의 이름을 불러 봅니다.' metadata={'common_labels': ['아껴주는', '기쁨']}
# page_content='이네들은 너무나 멀리 있습니다.' metadata={'common_labels': ['서러움', '슬픔', '안타까움/실망', '불안/걱정']}
# page_content='그리고 당신은 멀리 북간도에 계십니다' metadata={'common_labels': ['안타까움/실망', '슬픔', '서러움', '아껴주는']}
# page_content='나는 무엇인지 그리워' metadata={'common_labels': ['불안/걱정', '슬픔', '서러움']}
# page_content='이 많은 별빛이 내린 언덕 위에' metadata={'common_labels': ['기대감', '감동/감탄', '흐뭇함(귀여움/예쁨)']}
# page_content='딴은, 밤을 새워 우는 벌레는' metadata={'common_labels': ['슬픔', '신기함/관심']}
# page_content='부끄러운 이름을 슬퍼하는 까닭입니다.' metadata={'common_labels': ['슬픔', '부끄러움', '서러움']}
# page_content='그러나 겨울이 지나고 나의 별에도 봄이 오면' metadata={'common_labels': ['기대감', '환영/호의']}
# page_content='무덤 위에 파란 잔디가 피어나듯이' metadata={'common_labels': ['환영/호의', '깨달음']}
# page_content='내 이름자 묻힌 언덕 위에도' metadata={'common_labels': ['슬픔']}
# page_content='자랑처럼 풀이 무성할 게외다.' metadata={'common_labels': ['기대감', '기쁨']}
# page_content='살구나무 그늘로 얼굴을 가리고, 병원 뒤뜰에 누워, 젊은 여자가 흰 옷 아래로 하얀 다리를 드러내 놓고 일광욕을 한다. 한나절이 기울도록 가슴을 앓는 다는 이 여자를 찾아오는 이, 나비 한 마리도 없다. 슬프지도 않은 살구나무 가지에는 바람조차 없다.' metadata={'common_labels': ['슬픔', '불쌍함/연민', '신기함/관심']}
# page_content='나도 모를 아픔을 오래 참다 처음으로 이 곳에 찾아 왔다. 그러나 나의 늙은 의사는 젊은이의 병을 모른다. 나한테는 병이 없다고 한다. 이 지나친 시련, 이 지나친 피로, 나는 성내서는 안 된다.' metadata={'common_labels': ['불평/불만', '힘듦/지침', '의심/불신', '불안/걱정']}
# page_content='여자는 자리에서 일어나 옷깃을 여미고 화단에서 금잔화 한 포기를 따 가슴에 꽂고 병실 안으로 사라진다. 나는 그 여자의 건강이 ---- 아니 내 건강도 속히 회복되기를 바라며 그가 누웠던 자리에 누워 본다.' metadata={'common_labels': ['신기함/관심', '기대감', '아껴주는']}
# page_content='잃어버렸습니다.' metadata={'common_labels': ['슬픔', '안타까움/실망', '당황/난처']}
# page_content='무얼 어디다 잃었는지 몰라' metadata={'common_labels': ['불안/걱정', '당황/난처', '슬픔']}
# page_content='두 손의 호주머니를 더듬어' metadata={'common_labels': ['없음']}
# page_content='길에 나갑니다.' metadata={'common_labels': ['비장함', '없음']}
# page_content='길은 돌담을 끼고 갑니다.' metadata={'common_labels': ['신기함/관심', '없음']}
# page_content='담은 쇠문을 굳게 담아' metadata={'common_labels': ['비장함', '안타까움/실망']}
# page_content='길 위에 긴 그림자를 드리우고' metadata={'common_labels': ['불안/걱정', '공포/무서움', '슬픔', '안타까움/실망', '절망']}
# page_content='돌담을 더듬어 눈물짓다' metadata={'common_labels': ['슬픔', '서러움']}
# page_content='쳐다 보면 하늘은 부끄럽게 푸릅니다.' metadata={'common_labels': ['부끄러움']}
# page_content='풀 한 포기 없는 이 길을 걷는 것은' metadata={'common_labels': ['불안/걱정']}
# page_content='담 저 쪽에 내가 남아 있는 까닭이고' metadata={'common_labels': ['안타까움/실망']}
# page_content='내가 사는 것은 다만' metadata={'common_labels': ['비장함']}
# page_content='잃은 것을 찾는 까닭입니다. (1941.9.31)' metadata={'common_labels': ['불안/걱정', '슬픔']}
# page_content='세상으로부터 돌아오듯이 이제 내 좁은방에 돌아와 불을 끄옵니다.' metadata={'common_labels': ['힘듦/지침', '편안/쾌적']}
# page_content='불을 켜 두는 것은 너무나 피로롭은 일이옵니다.' metadata={'common_labels': ['힘듦/지침', '부담/안_내킴']}
# page_content='그것은 낮의 연장(延長)이옵기에-' metadata={'common_labels': ['깨달음', '신기함/관심']}
# page_content='이제 창窓을 열어 공기(空氣)를 바꾸어 들여야 할터인데' metadata={'common_labels': ['불안/걱정']}
# page_content='밖을 가만히 내다 보아야 방(房)안과 같이 어두어 꼭 세상 같은데' metadata={'common_labels': ['절망', '불안/걱정']}
# page_content='비를 맞고 오던 길이 그대로 비속에 젖어 있사옵니다.' metadata={'common_labels': ['슬픔', '안타까움/실망', '불쌍함/연민', '불안/걱정']}
# page_content='하로의 울분을 씻을바 없어 가만히 눈을 감으면' metadata={'common_labels': ['힘듦/지침', '서러움', '슬픔']}
# page_content='마음속으로 흐르는 소리,' metadata={'common_labels': ['감동/감탄']}
# page_content='이제,' metadata={'common_labels': ['없음']}
# page_content='사상(思想)이 능금처럼 저절로 익어 가옵니다.' metadata={'common_labels': ['기쁨', '기대감', '뿌듯함']}
# page_content='어제도 가고 오늘도 갈' metadata={'common_labels': ['기대감']}
# page_content='나의 길 새로운 길' metadata={'common_labels': ['기대감']}
# page_content='민들레가 피고 까치가 날고' metadata={'common_labels': ['흐뭇함(귀여움/예쁨)', '신기함/관심', '기대감', '기쁨']}
# page_content='아가씨가 지나고 바람이 일고' metadata={'common_labels': ['신기함/관심']}
# page_content='나의 길은 언제나 새로운 길' metadata={'common_labels': ['기대감', '즐거움/신남']}
# page_content='내를 건너서 숲으로' metadata={'common_labels': ['기대감', '즐거움/신남']}
# page_content='고개를 넘어서 마을로' metadata={'common_labels': ['기대감']}
# page_content='봄날 아침도 아니고' metadata={'common_labels': ['안타까움/실망']}
# page_content='여름, 가을, 겨울,' metadata={'common_labels': ['없음']}
# page_content='그런 날 아침도 아닌 아침에' metadata={'common_labels': ['불안/걱정']}
# page_content='빠알간 꽃이 피어났네,' metadata={'common_labels': ['흐뭇함(귀여움/예쁨)']}
# page_content='그 전날 밤에' metadata={'common_labels': ['없음']}
# page_content='모든것이 마련되었네,' metadata={'common_labels': ['기대감', '기쁨']}
# page_content='사랑은 뱀과 함께' metadata={'common_labels': ['불안/걱정', '놀람']}
# page_content='독(毒)은 어린꽃과 함께.' metadata={'common_labels': ['불안/걱정', '의심/불신']}
# page_content='하얗게 눈이 덮이었고' metadata={'common_labels': ['없음']}
# page_content='전신주(電信柱)가 잉잉 울어' metadata={'common_labels': ['슬픔', '불안/걱정', '당황/난처']}
# page_content='하나님 말씀이 들려온다.' metadata={'common_labels': ['존경', '감동/감탄', '신기함/관심', '안심/신뢰', '기대감']}
# page_content='무슨 계시(啓示)일까.' metadata={'common_labels': ['기대감', '불안/걱정', '당황/난처', '깨달음', '신기함/관심']}
# page_content='빨리' metadata={'common_labels': ['기대감']}
# page_content='봄이 오면' metadata={'common_labels': ['기대감', '기쁨']}
# page_content='죄(罪)를 짓고' metadata={'common_labels': ['죄책감']}
# page_content='눈이' metadata={'common_labels': ['없음']}
# page_content='밝아' metadata={'common_labels': ['감동/감탄', '신기함/관심', '기쁨']}
# page_content='이브가 해산(解産)하는 수고를 다하면' metadata={'common_labels': ['기대감', '비장함']}
# page_content='무화과(無花果) 잎사귀로 부끄런 데를 가리고' metadata={'common_labels': ['부끄러움']}
# page_content='나는 이마에 땀을 흘려야겠다.' metadata={'common_labels': ['비장함', '기대감', '뿌듯함']}
# page_content='다들 죽어가는 사람들에게' metadata={'common_labels': ['불쌍함/연민', '안타까움/실망']}
# page_content='다들 살아가는 사람들에게' metadata={'common_labels': ['기대감']}
# page_content='흰 옷을 입히시오.' metadata={'common_labels': ['비장함']}
# page_content='그리고 한 침실(寢室)에' metadata={'common_labels': ['없음']}
# page_content='가지런히 잠을 재우시오' metadata={'common_labels': ['아껴주는', '편안/쾌적']}
# page_content='다들 울거들랑' metadata={'common_labels': ['불쌍함/연민']}
# page_content='젖을 먹이시오' metadata={'common_labels': ['비장함']}
# page_content='이제 새벽이 오면' metadata={'common_labels': ['기대감']}
# page_content='나팔소리 들려 올 게외다.' metadata={'common_labels': ['기대감', '환영/호의']}
# page_content='거 나를 부르는 것이 누구요.' metadata={'common_labels': ['부담/안_내킴', '놀람', '의심/불신']}
# page_content='나 아직 여기 호흡이 남아 있소.' metadata={'common_labels': ['슬픔', '힘듦/지침', '비장함']}
# page_content='한 번도 손들어 보지 못한 나를' metadata={'common_labels': ['서러움', '슬픔', '패배/자기혐오', '죄책감']}
# page_content='손들어 표할 하늘도 없는 나를' metadata={'common_labels': ['슬픔', '절망', '패배/자기혐오']}
# page_content='나를 부르는 것이오?' metadata={'common_labels': ['놀람', '당황/난처', '의심/불신']}
# page_content='일이 마치고 내 죽는 날 아침에는' metadata={'common_labels': ['비장함', '서러움']}
# page_content='서럽지도 않은 가랑잎이 떨어질 텐데……' metadata={'common_labels': ['슬픔', '불안/걱정']}
# page_content='나를 부르지 마오.' metadata={'common_labels': ['부담/안_내킴', '귀찮음']}
# page_content='흰 수건이 검은 머리를 두르고' metadata={'common_labels': ['비장함']}
# page_content='흰 고무신이 거친 발에 걸리우다' metadata={'common_labels': ['불쌍함/연민', '힘듦/지침', '슬픔']}
# page_content='흰 저고리 치마가 슬픈 몸집을 가리고' metadata={'common_labels': ['서러움', '슬픔', '불쌍함/연민']}
# page_content='흰 띠가 가는 허리를 질끈 동이다' metadata={'common_labels': ['비장함']}
# page_content='태양을 사모하는 아이들아' metadata={'common_labels': ['아껴주는']}
# page_content='별을 사랑하는 아이들아' metadata={'common_labels': ['흐뭇함(귀여움/예쁨)', '아껴주는', '기쁨']}
# page_content='밤이 어두웠는데' metadata={'common_labels': ['불안/걱정']}
# page_content='눈감고 가거라.' metadata={'common_labels': ['비장함', '불안/걱정']}
# page_content='가진 바 씨앗을' metadata={'common_labels': ['없음']}
# page_content='뿌리면서 가거라.' metadata={'common_labels': ['비장함']}
# page_content='발부리에 돌이 체이거든' metadata={'common_labels': ['당황/난처', '불안/걱정']}
# page_content='감았던 눈을 와짝 떠라.' metadata={'common_labels': ['비장함']}
# page_content='알뜻 모를뜻 한데로 거닐과저!' metadata={'common_labels': ['비장함']}
# page_content='아닌 밤중에 튀기듯이' metadata={'common_labels': ['놀람', '당황/난처', '불안/걱정']}
# page_content='잠자리를 뛰처' metadata={'common_labels': ['놀람']}
# page_content='끝없는 광야(廣野)를 홀로 거니는' metadata={'common_labels': ['서러움', '비장함', '슬픔', '불안/걱정']}
# page_content='사람의 심사(心思)는 외로우러니' metadata={'common_labels': ['슬픔', '서러움']}
# page_content='아─ 이 젊은이는' metadata={'common_labels': ['감동/감탄', '신기함/관심', '기대감']}
# page_content='피라미트처럼 슬프구나' metadata={'common_labels': ['슬픔', '서러움']}
# page_content='대동강(大洞江) 물로끄린국,' metadata={'common_labels': ['신기함/관심']}
# page_content='평안도(平安道) 쌀로지은밥,' metadata={'common_labels': ['기대감']}
# page_content='조선(朝鮮)의 매운고추장,' metadata={'common_labels': ['기대감']}
# page_content='식권 우리배를 부르게.' metadata={'common_labels': ['기대감', '고마움']}
# page_content='늦은봄기다리든 토요일(土曜日)날.' metadata={'common_labels': ['기대감', '불안/걱정']}
# page_content='오후(午後) 세시반의 경성(京城)행열차는,' metadata={'common_labels': ['없음']}
# page_content='석탄(石炭)연기를 자욱이 품기고,' metadata={'common_labels': ['없음', '불안/걱정', '놀람']}
# page_content='한몸을 끟을기에 강(强)하든.' metadata={'common_labels': ['비장함', '당황/난처']}
# page_content='공(뽈)이 자력(磁力)을 잃고' metadata={'common_labels': ['신기함/관심', '당황/난처']}
# page_content='한목음의 물이' metadata={'common_labels': ['기쁨', '편안/쾌적']}
# page_content='불붓는 목을 축이기에' metadata={'common_labels': ['힘듦/지침']}
# page_content='넉넉하다,' metadata={'common_labels': ['기쁨', '편안/쾌적', '행복', '뿌듯함']}
# page_content='젊은 가슴의 피순환(循環)이 잣고,' metadata={'common_labels': ['비장함', '신기함/관심']}
# page_content='두 철각(鐵脚)이 늘어진다,' metadata={'common_labels': ['신기함/관심', '불안/걱정']}
# page_content='검은 기차(汽車)연기(煙氣)와 함께.' metadata={'common_labels': ['기대감']}
# page_content='풀은 산(山)이' metadata={'common_labels': ['기쁨']}
# page_content='아지랑 저쪽으로' metadata={'common_labels': ['신기함/관심', '없음']}
# page_content='까라안는다,' metadata={'common_labels': ['안타까움/실망', '슬픔']}
# page_content='청초(淸楚)한 코쓰모쓰는' metadata={'common_labels': ['흐뭇함(귀여움/예쁨)', '신기함/관심', '기쁨']}
# page_content='오직 하나인 나의 아가씨,' metadata={'common_labels': ['아껴주는', '흐뭇함(귀여움/예쁨)', '기쁨']}
# page_content='달빛이 싸늘히 추운 밤이면' metadata={'common_labels': ['불안/걱정', '부담/안_내킴']}
# page_content='넷 소녀(少女)가 몯견디게 그리워' metadata={'common_labels': ['슬픔', '서러움', '안타까움/실망']}
# page_content='코쓰모쓰 핀 정원(庭園)으로 찾어간다.' metadata={'common_labels': ['기대감']}
# page_content='코쓰모쓰는' metadata={'common_labels': ['없음']}
# page_content='귀또리 울음에도 수집어지고,' metadata={'common_labels': ['부끄러움', '당황/난처']}
# page_content='어렷을적 처럼 부끄러워 지나니,' metadata={'common_labels': ['부끄러움', '당황/난처']}
# page_content='코쓰모쓰의 마음은 내마음이다.' metadata={'common_labels': ['깨달음', '아껴주는', '기쁨']}
# page_content='함께핀 꽃에 처음익은 능금은' metadata={'common_labels': ['신기함/관심', '흐뭇함(귀여움/예쁨)']}
# page_content='먼저 떨어젓슴니다.' metadata={'common_labels': ['안타까움/실망']}
# page_content='지나든 손님이 집어갓슴니다.' metadata={'common_labels': ['당황/난처', '안타까움/실망']}
# page_content='헌집신짝 끟을고' metadata={'common_labels': ['안타까움/실망']}
# page_content='나여긔 웨왓노' metadata={'common_labels': ['힘듦/지침', '당황/난처']}
# page_content='두만강을 건너서' metadata={'common_labels': ['없음']}
# page_content='쓸쓸한 이 땅에' metadata={'common_labels': ['슬픔', '서러움', '안타까움/실망', '불쌍함/연민', '불안/걱정']}
# page_content='남쪽하늘 저밑엔' metadata={'common_labels': ['없음', '기대감']}
# page_content='따뜻한 내고향' metadata={'common_labels': ['기쁨', '행복']}
# page_content='내어머니 게신곧' metadata={'common_labels': ['아껴주는', '서러움']}
# page_content='그리운 고향집.' metadata={'common_labels': ['환영/호의', '편안/쾌적']}
# page_content='「이 개 더럽잔니」' metadata={'common_labels': ['역겨움/징그러움', '불평/불만', '당황/난처']}
# page_content='아─ 니 이웃집 덜렁 숳개가' metadata={'common_labels': ['놀람', '짜증']}
# page_content='오날 어슬렁 어슬렁 우리집으로 오더니' metadata={'common_labels': ['신기함/관심']}
# page_content='우리집 바두기의 미구멍에다 코를대고' metadata={'common_labels': ['흐뭇함(귀여움/예쁨)', '아껴주는']}
# page_content='씩々 내를 맛겟지 더러운줄도 모르고,' metadata={'common_labels': ['한심함']}
# page_content='보기 숭해서 막차며 욕해 쫓앗더니' metadata={'common_labels': ['증오/혐오', '역겨움/징그러움', '화남/분노']}
# page_content='꼬리를 휘휘 저으며' metadata={'common_labels': ['즐거움/신남']}
# page_content='너희들보다 어떻겟냐하는 상으로' metadata={'common_labels': ['우쭐댐/무시함', '한심함']}
# page_content='뛰여가겟지요 나─ 참.' metadata={'common_labels': ['어이없음']}
# page_content='나무가 춤을 추면' metadata={'common_labels': ['즐거움/신남']}
# page_content='바람이 불고,' metadata={'common_labels': ['없음']}
# page_content='나무가 잠잠하면' metadata={'common_labels': ['신기함/관심']}
# page_content='바람도 자오,' metadata={'common_labels': ['편안/쾌적', '깨달음']}
# page_content='작고 달다고 하오.' metadata={'common_labels': ['기대감', '기쁨']}
# page_content='앙당한 솔나무가지에,' metadata={'common_labels': ['불쌍함/연민']}
# page_content='훈훈한 바람의 날개가 스치고' metadata={'common_labels': ['기쁨']}
# page_content='한나절 햇발이 밋그러지다,' metadata={'common_labels': ['감동/감탄']}
# page_content='허무러진 성터(城터)에서' metadata={'common_labels': ['불안/걱정']}
# page_content='철모르는 여자(女兒)들이' metadata={'common_labels': ['불쌍함/연민', '한심함', '불안/걱정']}
# page_content='저도 모를 이국(異國)말로,' metadata={'common_labels': ['당황/난처']}
# page_content='난데없는 자동차(自動車)가 밉다.' metadata={'common_labels': ['불평/불만', '증오/혐오']}
# page_content='눈이 오다, 물이 되는 날.' metadata={'common_labels': ['없음']}
# page_content='재ㅅ빛 하늘에 또 뿌연 내, 그리고,' metadata={'common_labels': ['불안/걱정', '안타까움/실망']}
# page_content='크다란 기관차(機關車)는 빼─액─ 울며,' metadata={'common_labels': ['놀람', '없음']}
# page_content='쪽그만, 가슴은, 울렁거린다.' metadata={'common_labels': ['슬픔', '놀람']}
# page_content='리별이 너무 재빠르다, 안탑갑게도,' metadata={'common_labels': ['안타까움/실망', '슬픔', '서러움', '부담/안_내킴']}
# page_content='사랑하는 사람을,' metadata={'common_labels': ['아껴주는']}
# page_content='일터에서 만나자 하고─.' metadata={'common_labels': ['기대감']}
# page_content='더운 손의 맛과, 구슬눈물이 마르기 전' metadata={'common_labels': ['슬픔', '힘듦/지침']}
# page_content='기차는 꼬리를 산굽으로 돌렷다,' metadata={'common_labels': ['안타까움/실망']}
# page_content='종달새는 일은봄날' metadata={'common_labels': ['흐뭇함(귀여움/예쁨)']}
# page_content='명량한 봄하늘,' metadata={'common_labels': ['감동/감탄', '흐뭇함(귀여움/예쁨)', '편안/쾌적', '기쁨']}
# page_content='가벼운 두나래를펴서' metadata={'common_labels': ['기대감']}
# page_content='요염한 봄노래가,' metadata={'common_labels': ['흐뭇함(귀여움/예쁨)', '기대감', '기쁨']}
# page_content='좋더라,' metadata={'common_labels': ['기쁨', '행복', '깨달음', '즐거움/신남']}
# page_content='그러나,' metadata={'common_labels': ['없음']}
# page_content='오날도 구멍뚤린 구두를끌고,' metadata={'common_labels': ['힘듦/지침', '불쌍함/연민']}
# page_content='고기색기같은나는 헤매나니,' metadata={'common_labels': ['패배/자기혐오', '불안/걱정', '한심함']}
# page_content='나래와노래가 없음인가,' metadata={'common_labels': ['불안/걱정', '당황/난처', '안타까움/실망']}
# page_content='가슴이 답답하구나,' metadata={'common_labels': ['서러움', '힘듦/지침', '안타까움/실망']}
# page_content='내마음의 탑(塔)' metadata={'common_labels': ['비장함']}
# page_content='나는 말없이 이탑(塔)을 쌓고있다' metadata={'common_labels': ['비장함']}
# page_content='문허질줄도 몰으고' metadata={'common_labels': ['안타까움/실망', '불안/걱정']}
# page_content='한층두층 높이 싸ㅅ는다' metadata={'common_labels': ['기대감']}
# page_content='무한(無限)한 나의 공상(空想)─' metadata={'common_labels': ['환영/호의', '기대감']}
# page_content='그것은 내마음의 바다' metadata={'common_labels': ['감동/감탄', '깨달음']}
# page_content='나는 두팔을 펄처서' metadata={'common_labels': ['기대감', '환영/호의', '비장함']}
# page_content='자유(自由)로히 헤염친다' metadata={'common_labels': ['기쁨', '행복']}
# page_content='황금(黃金) 지욕(知慾)의 수평선(水平線)을 향(向)하여.' metadata={'common_labels': ['비장함']}
# page_content='밤을자고 동틀때' metadata={'common_labels': ['기대감']}
# page_content='래일이라고.' metadata={'common_labels': ['없음']}
# page_content='새날을 찯은나는' metadata={'common_labels': ['기대감', '기쁨']}
# page_content='오늘이더라,' metadata={'common_labels': ['비장함']}
# page_content='무리여!' metadata={'common_labels': ['비장함']}
# page_content='래일은 없나니' metadata={'common_labels': ['안타까움/실망']}
# page_content='산들이 두 줄로 줄다를질 치고' metadata={'common_labels': ['신기함/관심']}
# page_content='여울이 소리처 목이 자젓다.' metadata={'common_labels': ['불쌍함/연민']}
# page_content='한여름의 햇님이 구름을 타고' metadata={'common_labels': ['흐뭇함(귀여움/예쁨)', '행복', '기쁨']}
# page_content='이골작이를 빠르게도 건너련다.' metadata={'common_labels': ['비장함']}
# page_content='산(山)등아리에 송아지 뿔처럼' metadata={'common_labels': ['신기함/관심']}
# page_content='울뚝불뚝히 어린 바위가 솟구,' metadata={'common_labels': ['기대감']}
# page_content='얼룩소의 보드러운 털이' metadata={'common_labels': ['흐뭇함(귀여움/예쁨)']}
# page_content='산(山)등서리에 퍼─렇게 자랏다.' metadata={'common_labels': ['신기함/관심', '흐뭇함(귀여움/예쁨)', '감동/감탄']}
# page_content='삼년(三年)만에 고향(故鄕) 찾어드는' metadata={'common_labels': ['기대감', '기쁨', '환영/호의']}
# page_content='벌거숭이 두루미 다리같이...' metadata={'common_labels': ['불안/걱정', '당황/난처']}
# page_content='목아지를 매달아 늘어지고,' metadata={'common_labels': ['공포/무서움', '불안/걱정', '경악']}
# page_content='까치가 색기의 날발을 태우려 날뿐,' metadata={'common_labels': ['신기함/관심']}
# page_content='골작은 나그네의 마음처럼 고요하다.' metadata={'common_labels': ['편안/쾌적']}
# page_content='장미 병들어' metadata={'common_labels': ['안타까움/실망', '불쌍함/연민', '불안/걱정', '슬픔']}
# page_content='옮겨 놓을 이웃이 없도다.' metadata={'common_labels': ['안타까움/실망', '절망']}
# page_content='달랑달랑 외로히' metadata={'common_labels': ['슬픔', '부담/안_내킴', '불쌍함/연민']}
# page_content='황마차(幌馬車) 태워 산(山)에 보낼거나,' metadata={'common_labels': ['기대감']}
# page_content='뚜— 구슬피' metadata={'common_labels': ['슬픔', '서러움']}
# page_content='화륜선(火輪船) 태워 대양(大洋)에 보낼거나,' metadata={'common_labels': ['기대감']}
# page_content='비행기(飛行機) 태워 성층권(成層圈)에 보낼거나' metadata={'common_labels': ['기대감']}
# page_content='이것 저것' metadata={'common_labels': ['없음']}
# page_content='다 구만두고' metadata={'common_labels': ['힘듦/지침', '패배/자기혐오', '절망', '재미없음', '귀찮음']}
# page_content='자라가는 아들이 꿈을 깨기 전' metadata={'common_labels': ['아껴주는', '불안/걱정', '흐뭇함(귀여움/예쁨)']}
# page_content='이내 가슴에 묻어다오.' metadata={'common_labels': ['기대감']}
# page_content='황혼(黃昏)이 짙어지는 길모퉁이에서' metadata={'common_labels': ['기대감']}
# page_content='하루종일 시들은 귀를 가만히 기울이면' metadata={'common_labels': ['신기함/관심']}
# page_content='땅거미 옮겨지는 발자취 소리,' metadata={'common_labels': ['신기함/관심']}
# page_content='발자취 소리를 들을 수 있도록' metadata={'common_labels': ['기대감', '신기함/관심']}
# page_content='나는 총명했든가요.' metadata={'common_labels': ['불안/걱정']}
# page_content='이제 어리석게도 모든 것을 깨달은 다음' metadata={'common_labels': ['깨달음', '안타까움/실망', '한심함', '불안/걱정']}
# page_content='괴로워하던 수많은 나를' metadata={'common_labels': ['슬픔', '불쌍함/연민', '서러움', '힘듦/지침']}
# page_content='하나, 둘 제고장으로 돌려보내면' metadata={'common_labels': ['기대감', '없음']}
# page_content='거리모퉁이 어둠 속으로' metadata={'common_labels': ['불안/걱정']}
# page_content='소리 없이 사라지는 흰 그림자,' metadata={'common_labels': ['불안/걱정', '경악']}
# page_content='연연히 사랑하던 흰 그림자들,' metadata={'common_labels': ['아껴주는', '슬픔']}
# page_content='내 모든 것을 돌려 보낸 뒤' metadata={'common_labels': ['비장함']}
# page_content='허전히 뒷골목을 돌아' metadata={'common_labels': ['재미없음']}
# page_content='황혼(黃昏)처럼 물드는 내 방으로 돌아오면' metadata={'common_labels': ['기대감']}
# page_content='신념(信念)이 깊은 의젓한 양(羊)처럼' metadata={'common_labels': ['존경']}
# page_content='하루종일 시름없이 풀포기나 뜯자.' metadata={'common_labels': ['재미없음']}
# page_content='봄이 오던 아침, 서울 어느 쪼그만 정거장(停車場)에서' metadata={'common_labels': ['기대감', '신기함/관심', '흐뭇함(귀여움/예쁨)']}
# page_content='희망(希望)과 사랑처럼 기차(汽車)를 기다려,' metadata={'common_labels': ['기대감', '기쁨', '행복']}
# page_content='나는 플랫폼(푸라트•폼)에 간신한 그림자를 떨어트리고,' metadata={'common_labels': ['힘듦/지침']}
# page_content='담배를 피웠다.' metadata={'common_labels': ['없음', '불안/걱정', '힘듦/지침']}
# page_content='내 그림자는 담배연기 그림자를 날리고' metadata={'common_labels': ['힘듦/지침', '슬픔', '불안/걱정']}
# page_content='비둘기 한 떼가 부끄러울 것도 없이' metadata={'common_labels': ['신기함/관심', '감동/감탄']}
# page_content='기차(汽車)는 아무 새로운 소식도 없이' metadata={'common_labels': ['안타까움/실망', '당황/난처', '슬픔']}
# page_content='나를 멀리 실어다 주어,' metadata={'common_labels': ['기대감', '고마움']}
# page_content='봄은 다 가고—— 도쿄(東京) 교외(郊外) 어느 조용한' metadata={'common_labels': ['신기함/관심']}
# page_content='하숙방(下宿房)에서, 옛 거리에 남은 나를 희망(希望)과' metadata={'common_labels': ['기대감']}
# page_content='사랑처럼 그리워한다.' metadata={'common_labels': ['아껴주는', '슬픔']}
# page_content='오늘도 기차(汽車)는 몇 번이나 무의미(無意味)하게 지나가고,' metadata={'common_labels': ['힘듦/지침', '재미없음']}
# page_content='오늘도 나는 누구를 기다려 정거장(停車場) 가까운 언덕에서 서성거릴게다.' metadata={'common_labels': ['기대감', '아껴주는']}
# page_content='——아아 젊음은 오래 거기 남아 있거라.' metadata={'common_labels': ['환영/호의', '아껴주는', '기대감', '감동/감탄']}
# page_content='으스럼히 안개가 흐른다. 거리가 흘러간다. 저 전차(電車), 자동차(自動車), 모든 바퀴가 어디로 흘리워 가는 것일까? 정박(定泊)할 아무 항구(港口)도 없이, 가련한 많은 사람들을 실고서, 안개 속에 잠긴 거리는,' metadata={'common_labels': ['불안/걱정', '불쌍함/연민', '신기함/관심']}
# page_content='거리 모통이 붉은 포스트상자를 붙잡고 섰을라면 모든 것이 흐르는 속에 어렴풋이 빛나는 가로등(街路燈), 꺼지지 않는 것은 무슨 상징(象徵)일까? 사랑하는 동무 박(朴)이여! 그리고 김(金)이여! 자네들은 지금 어디 있는가? 끝없이 안개가 흐르는데,' metadata={'common_labels': ['불안/걱정', '당황/난처', '안타까움/실망', '슬픔']}
# page_content='「새로운 날 아침 우리 다시 정(情)답게 손목을 잡어 보세」 몇 자 적어 포스트 속에 떨어트리고, 밤을 새워 기다리면 금휘장(金徽章)에 금단추(金단추)를 삐었고 거인(巨人)처럼 찬란히 나타나는 배달부(配達夫), 아침과 함께 즐거운 내림(來臨),' metadata={'common_labels': ['기대감', '즐거움/신남', '감동/감탄']}
# page_content='이밤을 하염없이 안개가 흐른다.' metadata={'common_labels': ['불안/걱정']}
# page_content='창밖(窓外)에 밤비가 속살거려' metadata={'common_labels': ['슬픔', '신기함/관심']}
# page_content='육첩방(六疊房)은 남의 나라,' metadata={'common_labels': ['불안/걱정', '패배/자기혐오']}
# page_content='시인(詩人)이란 슬픈 천명(天命)인줄 알면서도' metadata={'common_labels': ['슬픔', '서러움']}
# page_content='한줄 시(詩)를 적어 볼가,' metadata={'common_labels': ['비장함', '기대감']}
# page_content='땀내와 사랑내 포근히 품긴' metadata={'common_labels': ['기쁨', '행복', '아껴주는', '안심/신뢰', '감동/감탄']}
# page_content='보내주신 학비봉투(學費封套)를 받어' metadata={'common_labels': ['고마움', '기쁨']}
# page_content='대학(大學)노—트를 끼고' metadata={'common_labels': ['기대감', '없음']}
# page_content='늙은 교수(敎授)의 강의(講義) 들으려 간다.' metadata={'common_labels': ['부담/안_내킴']}
# page_content='하나, 둘, 죄다 잃어 버리고' metadata={'common_labels': ['슬픔', '힘듦/지침', '불안/걱정']}
# page_content='나는 무얼 바라' metadata={'common_labels': ['죄책감']}
# page_content='나는 다만, 홀로 침전(沈澱)하는 것일가?' metadata={'common_labels': ['불안/걱정', '부담/안_내킴', '패배/자기혐오']}
# page_content='인생(人生)은 살기 어렵다는데' metadata={'common_labels': ['힘듦/지침', '서러움', '슬픔', '불안/걱정']}
# page_content='시(詩)가 이렇게 쉽게 씨워지는 것은' metadata={'common_labels': ['놀람', '당황/난처']}
# page_content='부끄러운 일이다.' metadata={'common_labels': ['부끄러움', '패배/자기혐오']}
# page_content='육첩방(六疊房)은 남의 나라' metadata={'common_labels': ['슬픔', '서러움', '부담/안_내킴', '불평/불만']}
# page_content='등불을 밝혀 어둠을 조곰 내몰고,' metadata={'common_labels': ['비장함', '기대감']}
# page_content='시대(時代)처럼 올 아침을 기다리는 최후(最後)의 나,' metadata={'common_labels': ['비장함', '기대감']}
# page_content='나는 나에게 적은 손을 내밀어' metadata={'common_labels': ['불쌍함/연민', '안타까움/실망']}
# page_content='눈물과 위안(慰安)으로 잡는 최초(最初)의 악수(握手).' metadata={'common_labels': ['슬픔', '서러움', '비장함', '고마움']}
# page_content='개나리, 진달래, 노오란 배추꽃' metadata={'common_labels': ['흐뭇함(귀여움/예쁨)']}
# page_content='풀포기처럼 피어난다.' metadata={'common_labels': ['감동/감탄', '기쁨', '기대감']}
# page_content='즐거운 종달새야' metadata={'common_labels': ['즐거움/신남', '기쁨']}
# page_content='어느 이랑에서 즐거웁게 솟쳐라.' metadata={'common_labels': ['기대감', '즐거움/신남']}
# page_content='푸르른 하늘은' metadata={'common_labels': ['감동/감탄', '없음', '편안/쾌적']}
# page_content='아른아른 높기도 한데……' metadata={'common_labels': ['감동/감탄', '불안/걱정']}
# page_content='파란 녹이 낀 구리거울 속에' metadata={'common_labels': ['신기함/관심']}
# page_content='내 얼굴이 남어 있는 것은' metadata={'common_labels': ['부끄러움', '안타까움/실망', '당황/난처']}
# page_content='어느 왕조(王朝)의 유물(遺物)이기에' metadata={'common_labels': ['신기함/관심', '놀람']}
# page_content='이다지도 욕될가' metadata={'common_labels': ['부끄러움']}
# page_content='나는 나의 참회(懺悔)의 글을 한줄에 주리자' metadata={'common_labels': ['비장함']}
# page_content='무슨 기쁨을 바라 살아 왔든가' metadata={'common_labels': ['패배/자기혐오', '서러움', '슬픔']}
# page_content='내일이나 모레나 그 어느 즐거운 날에' metadata={'common_labels': ['행복', '기쁨', '즐거움/신남', '기대감']}
# page_content='나는 또 한줄의 참회록(懺悔錄)을 써야한다.' metadata={'common_labels': ['죄책감', '비장함', '슬픔']}
# page_content='——그때 그 젊은 나이에' metadata={'common_labels': ['슬픔']}
# page_content='왜 그런 부끄런 고백(告白)을 했든가' metadata={'common_labels': ['부끄러움']}
# page_content='슬픈 사람의 뒷모양이' metadata={'common_labels': ['슬픔', '불쌍함/연민']}
# page_content='거울 속에 나타나온다.' metadata={'common_labels': ['신기함/관심', '놀람']}
# page_content='바닷가 햇빛 바른 바위우에' metadata={'common_labels': ['편안/쾌적', '신기함/관심']}
# page_content='습한 간(肝)을 펴서 말리우자,' metadata={'common_labels': ['비장함', '힘듦/지침']}
# page_content='코카사쓰 산중(山中)에서 도망해온 토끼처럼' metadata={'common_labels': ['불안/걱정', '놀람', '불쌍함/연민']}
# page_content='둘러리를 빙빙 돌며 간(肝)을 지키자,' metadata={'common_labels': ['비장함']}
# page_content='내가 오래 기르든 여윈 독수리야!' metadata={'common_labels': ['불쌍함/연민', '아껴주는', '불안/걱정']}
# page_content='와서 뜯어 먹어라, 시름없이' metadata={'common_labels': ['비장함']}
# page_content='너는 살지고' metadata={'common_labels': ['아껴주는']}
# page_content='나는 여위여야지, 그러나,' metadata={'common_labels': ['비장함', '힘듦/지침', '절망']}
# page_content='다시는 용궁(龍宮)의 유혹(誘惑)에 안떨어진다.' metadata={'common_labels': ['비장함', '화남/분노', '깨달음']}
# page_content='푸로메디어쓰 불상한 푸로메디어쓰' metadata={'common_labels': ['불쌍함/연민', '안타까움/실망']}
# page_content='불 도적한 죄로 목에 맷돌을 달고' metadata={'common_labels': ['비장함', '불안/걱정', '공포/무서움', '불쌍함/연민']}
# page_content='끝없이 침전(沈澱)하는 푸로메디어쓰,' metadata={'common_labels': ['슬픔', '절망', '안타까움/실망']}
# page_content='연륜(年輪)이 자라듯이' metadata={'common_labels': ['깨달음']}
# page_content='달이 자라는 고요한 밤에' metadata={'common_labels': ['편안/쾌적']}
# page_content='달같이 외로운 사랑이' metadata={'common_labels': ['서러움', '슬픔']}
# page_content='가슴하나 뻐근히' metadata={'common_labels': ['슬픔', '불안/걱정']}
# page_content='연륜(年輪)처럼 피어나간다.' metadata={'common_labels': ['깨달음', '감동/감탄']}
# page_content='시들은 잎새속에서' metadata={'common_labels': ['불쌍함/연민', '불안/걱정']}
# page_content='고 빨간 살을 드러내 놓고,' metadata={'common_labels': ['신기함/관심', '흐뭇함(귀여움/예쁨)']}
# page_content='고추는 방년(芳年)된 아가씬양' metadata={'common_labels': ['즐거움/신남']}
# page_content='땡볕에 자꾸 익어간다.' metadata={'common_labels': ['신기함/관심', '흐뭇함(귀여움/예쁨)']}
# page_content='할머니는 바구니를 들고' metadata={'common_labels': ['아껴주는']}
# page_content='밭머리에서 어정거리고' metadata={'common_labels': ['신기함/관심']}
# page_content='손가락 너어는 아이는' metadata={'common_labels': ['아껴주는', '신기함/관심', '흐뭇함(귀여움/예쁨)']}
# page_content='할머니 뒤만 따른다.' metadata={'common_labels': ['안심/신뢰']}
# page_content='붉은 이마에 싸늘한 달이 서리어' metadata={'common_labels': ['불안/걱정', '서러움']}
# page_content='아우의 얼굴은 슬픈 그림이다.' metadata={'common_labels': ['슬픔', '불쌍함/연민', '아껴주는', '서러움']}
# page_content='발걸음을 멈추어' metadata={'common_labels': ['없음']}
# page_content='「늬는 자라 무엇이 되려니」' metadata={'common_labels': ['신기함/관심', '불안/걱정']}
# page_content='「사람이 되지」' metadata={'common_labels': ['깨달음']}
# page_content='아우의 설은 진정코 설은 대답(對答)이다.' metadata={'common_labels': ['아껴주는', '깨달음']}
# page_content='아우의 얼골을 다시 들여다 본다.' metadata={'common_labels': ['아껴주는', '신기함/관심']}
# page_content='싸늘한 달이 붉은 이마에 젖어' metadata={'common_labels': ['불안/걱정']}
# page_content='아우의 얼골은 슬픈 그림이다.' metadata={'common_labels': ['슬픔', '불쌍함/연민', '서러움']}
# page_content='순(順)아 너는 내 전(殿)에 언제 들어왔든 것이냐?' metadata={'common_labels': ['놀람', '신기함/관심', '당황/난처', '기대감', '아껴주는']}
# page_content='내사 언제 네 전(殿)에 들어갔든 것이냐?' metadata={'common_labels': ['당황/난처', '불안/걱정']}
# page_content='고풍(古風)한 풍습(風習)이 어린 사랑의 전당(殿堂)' metadata={'common_labels': ['아껴주는', '신기함/관심']}
# page_content='순(順)아 암사슴처럼 수정(水晶)눈을 나려감어라.' metadata={'common_labels': ['아껴주는']}
# page_content='난 사자처럼 엉크린 머리를 고루련다.' metadata={'common_labels': ['기대감', '비장함']}
# page_content='우리들의 사랑은 한낱 벙어리이었다.' metadata={'common_labels': ['서러움', '안타까움/실망', '슬픔']}
# page_content='성(聖)스런 촛대에 열(熱)한 불이 꺼지기 전(前)' metadata={'common_labels': ['비장함']}
# page_content='순(順)아 너는 앞문으로 내 달려라.' metadata={'common_labels': ['비장함', '불안/걱정']}
# page_content='어둠과 바람이 우리 창(窓)에 부닥치기 전(前)' metadata={'common_labels': ['불안/걱정', '당황/난처']}
# page_content='나는 영원(永遠)한 사랑을 안은채' metadata={'common_labels': ['기쁨', '행복', '기대감']}
# page_content='이제 네게는 삼림(森林)속의 아늑한 호수(湖水)가 있고' metadata={'common_labels': ['편안/쾌적', '기쁨']}
# page_content='내게는 준험(峻嶮)한 산맥(山脈)이 있다.' metadata={'common_labels': ['비장함']}
# page_content='발에 터부한 것을 다 빼어 바리고' metadata={'common_labels': ['비장함', '기대감']}
# page_content='황혼(黃昏)이 호수(湖水)우로 걸어 오듯이' metadata={'common_labels': ['감동/감탄', '놀람', '신기함/관심']}
# page_content='내사 이 호수(湖水)가로' metadata={'common_labels': ['없음']}
# page_content='부르는 이 없이' metadata={'common_labels': ['서러움', '불쌍함/연민', '절망']}
# page_content='불리워 온 것은' metadata={'common_labels': ['없음']}
# page_content='참말 이적(異蹟)이외다.' metadata={'common_labels': ['놀람', '경악']}
# page_content='오늘 따라' metadata={'common_labels': ['없음']}
# page_content='연정(戀情), 자부(自惚), 시기(猜忌), 이것들이' metadata={'common_labels': ['깨달음', '비장함']}
# page_content='자꾸 금메달(金메달)처럼 만져지는구려' metadata={'common_labels': ['기쁨', '행복']}
# page_content='하나, 내 모든 것을 여념(餘念)없이' metadata={'common_labels': ['비장함']}
# page_content='당신은 호면(湖面)으로 나를 불러 내소서.' metadata={'common_labels': ['기대감', '환영/호의']}
# page_content='솨— 철석! 파도소리 문살에 부서져' metadata={'common_labels': ['놀람']}
# page_content='잠 살포시 꿈이 흐터진다.' metadata={'common_labels': ['불안/걱정']}
# page_content='달랠 아무런 재주도 없다.' metadata={'common_labels': ['죄책감', '패배/자기혐오', '당황/난처']}
# page_content='불을 밝혀 잠옷을 정성스리 여미는' metadata={'common_labels': ['아껴주는']}
# page_content='삼경(三更).' metadata={'common_labels': ['없음']}
# page_content='염원(念願).' metadata={'common_labels': ['기대감', '비장함']}
# page_content='동경(憧憬)의 땅 강남(江南)에 또 홍수(洪水)질 것만 싶어,' metadata={'common_labels': ['불안/걱정']}
# page_content='괴로운 사람아 괴로운 사람아' metadata={'common_labels': ['불쌍함/연민', '슬픔', '서러움', '안타까움/실망']}
# page_content='옷자락 물결속에서도 가슴속 깊이 돌돌 샘물이 홀러' metadata={'common_labels': ['기쁨', '기대감', '행복', '신기함/관심']}
# page_content='거리의 소음과 노래 부를수 없도다.' metadata={'common_labels': ['절망', '비장함', '슬픔', '안타까움/실망']}
# page_content='그신듯이 냇가에 앉았으니' metadata={'common_labels': ['편안/쾌적']}
# page_content='바다로 가자' metadata={'common_labels': ['기대감', '비장함', '즐거움/신남', '기쁨']}
# page_content='후어—ㄴ한 방(房)에' metadata={'common_labels': ['편안/쾌적', '없음']}
# page_content='유언(遺言)은 소리 없는 입놀림.' metadata={'common_labels': ['깨달음']}
# page_content='바다에 진주(眞珠) 캐려 갔다는 아들' metadata={'common_labels': ['불안/걱정']}
# page_content='해녀(海女)와 사랑을 속삭인다는 맏아들' metadata={'common_labels': ['아껴주는', '흐뭇함(귀여움/예쁨)', '불안/걱정']}
# page_content='이 밤에사 돌아오나 내다 봐라——' metadata={'common_labels': ['불안/걱정', '기대감']}
# page_content='평생(平生) 외롭던 아버지의 운명(殞命)' metadata={'common_labels': ['불쌍함/연민', '존경', '안타까움/실망', '슬픔']}
# page_content='감기우는 눈에 슬픔이 어린다.' metadata={'common_labels': ['슬픔', '불쌍함/연민', '서러움']}
# page_content='쉬는 시간(時間)마다' metadata={'common_labels': ['없음']}
# page_content='——창(窓)은 산 가르침.' metadata={'common_labels': ['깨달음']}
# page_content='이글이글 불을 피워주소,' metadata={'common_labels': ['기대감']}
# page_content='이 방에 찬것이 서립니다.' metadata={'common_labels': ['불안/걱정']}
# page_content='맴 도나 보니' metadata={'common_labels': ['신기함/관심']}
# page_content='아마도 작으마한 선풍(旋風)이 인게웨다.' metadata={'common_labels': ['깨달음']}
# page_content='그래도 싸느란 유리창에' metadata={'common_labels': ['불안/걱정']}
# page_content='햇살이 쨍쨍한 무렵,' metadata={'common_labels': ['기대감', '신기함/관심', '기쁨']}
# page_content='상학종(上學鐘)이 울어만 싶습니다.' metadata={'common_labels': ['기대감']}
# page_content='실어다 뿌리는' metadata={'common_labels': ['없음']}
# page_content='바람조차 시원타.' metadata={'common_labels': ['편안/쾌적', '환영/호의', '기쁨']}
# page_content='솔나무 가지마다 샛춤히' metadata={'common_labels': ['신기함/관심']}
# page_content='밀치고' metadata={'common_labels': ['당황/난처']}
# page_content='밀치운다.' metadata={'common_labels': ['부담/안_내킴']}
# page_content='이랑을 넘는 물결은' metadata={'common_labels': ['불안/걱정']}
# page_content='폭포처럼 피어오른다.' metadata={'common_labels': ['감동/감탄', '놀람', '신기함/관심']}
# page_content='해변(海邊)에 아이들이 모인다' metadata={'common_labels': ['즐거움/신남', '기대감', '흐뭇함(귀여움/예쁨)', '기쁨']}
# page_content='찰찰 손을 씻고 구보로.' metadata={'common_labels': ['기대감']}
# page_content='바다는 자꾸 섧어진다.' metadata={'common_labels': ['슬픔', '서러움']}
# page_content='돌아다 보고 돌아다 보고' metadata={'common_labels': ['불안/걱정']}
# page_content='돌아가는 오늘의 바다여!' metadata={'common_labels': ['감동/감탄', '비장함']}
# page_content='섧은 산울림.' metadata={'common_labels': ['서러움', '불쌍함/연민', '슬픔']}
# page_content='골자기 길에' metadata={'common_labels': ['없음']}
# page_content='떨어진 그림자는' metadata={'common_labels': ['불안/걱정']}
# page_content='너무나 슬프구나.' metadata={'common_labels': ['슬픔', '서러움']}
# page_content='오후(午後)의 명상(瞑想)은' metadata={'common_labels': ['편안/쾌적', '없음']}
# page_content='아— 졸려.' metadata={'common_labels': ['부담/안_내킴', '편안/쾌적']}
# page_content='가츨가츨한 머리칼은 오막사리 처마끝,' metadata={'common_labels': ['불안/걱정']}
# page_content='쉬파람에 콧마루가 서운한 양 간질키오.' metadata={'common_labels': ['서러움']}
# page_content='들창(窓) 같은 눈은 가볍게 닫혀' metadata={'common_labels': ['없음']}
# page_content='이 밤에 연정(戀情)은 어둠처럼 골골히 스며드오.' metadata={'common_labels': ['아껴주는', '불안/걱정']}
# page_content='싸늘한 대리석(大理石) 기둥에 목아지를 비틀어맨 한난계(寒暖計),' metadata={'common_labels': ['공포/무서움', '불안/걱정']}
# page_content='문득 들여다 볼 수 있는 운명(運命)한 오척육촌(五尺六寸)의 허리 가는 수은주(水銀柱),' metadata={'common_labels': ['불안/걱정']}
# page_content='마음은 유리관(琉璃管)보다 맑소이다.' metadata={'common_labels': ['기쁨', '편안/쾌적']}
# page_content='혈관(血管)이 단조(單調)로워 신경질(神經質)인 여론동물(輿論動物),' metadata={'common_labels': ['불평/불만']}
# page_content='가끔 분수(噴水) 같은 냉침(冷침)을 억지로 삼키기에' metadata={'common_labels': ['부담/안_내킴']}
# page_content='정력(精力)을 낭비(浪費)합니다.' metadata={'common_labels': ['한심함', '부담/안_내킴', '불평/불만', '안타까움/실망']}
# page_content='영하(零下)로 손구락질 할 수도 없는 방(房)처럼 치운 겨울보다' metadata={'common_labels': ['불안/걱정', '슬픔', '힘듦/지침', '서러움']}
# page_content='해바라기 만발(滿發)한 팔월(八月) 교정(校庭)이 이상(理想)곱소이다.' metadata={'common_labels': ['흐뭇함(귀여움/예쁨)', '감동/감탄', '기쁨']}
# page_content='피끓을 그날이——' metadata={'common_labels': ['화남/분노', '비장함', '증오/혐오']}
# page_content='어제는 막 소낙비가 퍼붓더니 오늘은 좋은 날세올시다.' metadata={'common_labels': ['편안/쾌적', '기쁨', '행복', '감동/감탄']}
# page_content='동저고리 바람에 언덕으로, 숲으로 하시구려——' metadata={'common_labels': ['기쁨']}
# page_content='나는 또 내가 모르는 사이에——' metadata={'common_labels': ['당황/난처', '불안/걱정', '놀람']}
# page_content='나는 아마도 진실(眞實)한 세기(世紀)의 계절(季節)을 따라——' metadata={'common_labels': ['비장함', '기대감', '깨달음']}
# page_content='하늘만 보이는 울타리 안을 뛰쳐,' metadata={'common_labels': ['즐거움/신남', '기대감']}
# page_content='역사(歷史) 같은 포지슌을 지켜야 봅니다.' metadata={'common_labels': ['비장함', '신기함/관심']}
# page_content='번개, 뇌성, 왁자지근 뚜다려' metadata={'common_labels': ['놀람', '불안/걱정', '공포/무서움']}
# page_content='머—ㄴ 도화지(都會地)에 낙뢰(落雷)가 있어만 싶다.' metadata={'common_labels': ['놀람']}
# page_content='벼루짱 엎어논 하늘로' metadata={'common_labels': ['신기함/관심']}
# page_content='살같은 비가 살처럼 쏟아진다.' metadata={'common_labels': ['당황/난처', '놀람', '부담/안_내킴', '불안/걱정']}
# page_content='손바닥만한 나의 정원(庭園)이' metadata={'common_labels': ['아껴주는', '신기함/관심']}
# page_content='마음같이 흐린 호수(湖水)되기 일수다.' metadata={'common_labels': ['불안/걱정', '안타까움/실망']}
# page_content='바람이 팽이처럼 돈다.' metadata={'common_labels': ['당황/난처', '불안/걱정']}
# page_content='나무가 머리를 이루 잡지 못한다.' metadata={'common_labels': ['불안/걱정']}
# page_content='내 경건(敬虔)한 마음을 모셔드려' metadata={'common_labels': ['비장함']}
# page_content='봄바람을 등진 초록빛 바다' metadata={'common_labels': ['흐뭇함(귀여움/예쁨)', '신기함/관심']}
# page_content='쏟아질듯 쏟아질듯 위트롭다.' metadata={'common_labels': ['불안/걱정']}
# page_content='잔주름 치마폭의 두둥실거리는 물결은,' metadata={'common_labels': ['신기함/관심']}
# page_content='오스라질듯 한끝 경쾌(輕快)롭다.' metadata={'common_labels': ['기쁨', '즐거움/신남']}
# page_content='마스트 끝에 붉은 깃발(旗ㅅ발)이' metadata={'common_labels': ['신기함/관심']}
# page_content='여인(女人)의 머리칼처럼 나부낀다.' metadata={'common_labels': ['기대감', '신기함/관심']}
# page_content='이 생생한 풍경(風景)을 앞세우며 뒤세우며' metadata={'common_labels': ['신기함/관심', '기대감']}
# page_content='——우중충한 오월(五月) 하늘 아래로,' metadata={'common_labels': ['불안/걱정']}
# page_content='——바다빛 포기포기에 수(繡)놓은 언덕으로,' metadata={'common_labels': ['흐뭇함(귀여움/예쁨)', '감동/감탄', '기대감']}
# page_content='흐르는 달의 흰 물결을 밀쳐' metadata={'common_labels': ['신기함/관심']}
# page_content='여윈 나무그림자를 밟으며' metadata={'common_labels': ['불쌍함/연민', '불안/걱정', '힘듦/지침']}
# page_content='북망산(北邙山)을 향(向)한 발걸음은 무거웁고' metadata={'common_labels': ['힘듦/지침', '불안/걱정', '부담/안_내킴']}
# page_content='고독(孤獨)을 반려(伴侶)한 마음은 슬프기도 하다.' metadata={'common_labels': ['슬픔', '서러움', '불쌍함/연민']}
# page_content='누가 있어만 싶은 묘지(墓地)엔 아무도 없고,' metadata={'common_labels': ['당황/난처', '불안/걱정']}
# page_content='정적(靜寂)만이 군데군데 흰 물결에 폭 젖었다.' metadata={'common_labels': ['불안/걱정', '당황/난처']}
# page_content='이른 아침 아낙네들은 시들은 생활(生活)을' metadata={'common_labels': ['불쌍함/연민', '힘듦/지침']}
# page_content='바구니 하나 가득 담아 이고……' metadata={'common_labels': ['힘듦/지침']}
# page_content='업고 지고…… 안고 들고……' metadata={'common_labels': ['힘듦/지침']}
# page_content='모여드오 자꾸 장에 모여드오.' metadata={'common_labels': ['신기함/관심', '당황/난처']}
# page_content='가난한 생활(生活)을 골골이 버려놓고' metadata={'common_labels': ['불쌍함/연민', '불안/걱정']}
# page_content='밀려가고 밀려오고……' metadata={'common_labels': ['없음']}
# page_content='제마다 생활(生活)을 외치오…… 싸우오.' metadata={'common_labels': ['힘듦/지침', '불쌍함/연민', '불안/걱정']}
# page_content='왼하로 올망졸망한 생활(生活)을' metadata={'common_labels': ['불쌍함/연민', '흐뭇함(귀여움/예쁨)']}
# page_content='날이 저물어 아낙네들이' metadata={'common_labels': ['아껴주는']}
# page_content='쓴 생활(生活)과 바꾸어 또 이고 돌아가오.' metadata={'common_labels': ['힘듦/지침']}
# page_content='오양간 당나귀' metadata={'common_labels': ['없음']}
# page_content='아—ㅇ 외 마디 울음울고,' metadata={'common_labels': ['슬픔', '서러움']}
# page_content='당나귀 소리에' metadata={'common_labels': ['놀람', '신기함/관심']}
# page_content='으—아 아 애기 소스라처 깨고,' metadata={'common_labels': ['놀람', '당황/난처']}
# page_content='등잔에 불을 다오.' metadata={'common_labels': ['기대감']}
# page_content='아버지는 당나귀에게' metadata={'common_labels': ['신기함/관심']}
# page_content='짚을 한키 담아 주고,' metadata={'common_labels': ['뿌듯함']}
# page_content='어머니는 애기에게' metadata={'common_labels': ['아껴주는', '신기함/관심', '편안/쾌적']}
# page_content='젖을 한모금 먹이고,' metadata={'common_labels': ['아껴주는', '흐뭇함(귀여움/예쁨)', '뿌듯함']}
# page_content='밤은 다시 고요히 잠드오.' metadata={'common_labels': ['편안/쾌적']}
# page_content='하로도 검푸른 물결에' metadata={'common_labels': ['불안/걱정']}
# page_content='흐느적 잠기고…… 잠기고……' metadata={'common_labels': ['불안/걱정', '슬픔']}
# page_content='물든 바다를 날아 횡단(橫斷)할고.' metadata={'common_labels': ['기대감']}
# page_content='낙엽(落葉)이 된 해초(海草)' metadata={'common_labels': ['없음']}
# page_content='해초(海草)마다 슬프기도 하오.' metadata={'common_labels': ['슬픔', '불쌍함/연민', '서러움', '안타까움/실망']}
# page_content='서창(西窓)에 걸린 해말간 풍경화(風景畵).' metadata={'common_labels': ['흐뭇함(귀여움/예쁨)', '편안/쾌적', '감동/감탄']}
# page_content='옷고름 너어는 고아(孤兒)의 서름.' metadata={'common_labels': ['슬픔', '불쌍함/연민', '서러움', '안타까움/실망']}
# page_content='이제 첫 항해(航海)하는 마음을 먹고' metadata={'common_labels': ['기대감', '비장함']}
# page_content='방바닥에 나딩구오…… 딩구오……' metadata={'common_labels': ['불안/걱정', '힘듦/지침']}
# page_content='황혼(黃昏)이 바다가 되어' metadata={'common_labels': ['감동/감탄', '신기함/관심', '놀람']}
# page_content='오늘도 수많은 배가' metadata={'common_labels': ['신기함/관심', '기대감']}
# page_content='나와 함께 이 물결에 잠겼을게오.' metadata={'common_labels': ['불안/걱정', '서러움', '비장함', '슬픔']}
# page_content='휙, 휙, 휙,' metadata={'common_labels': ['없음']}
# page_content='어둠을 쫓아,' metadata={'common_labels': ['기대감']}
# page_content='캄, 캄, 어둠이 깊다 깊다 밝으오.' metadata={'common_labels': ['기대감', '불안/걱정']}
# page_content='이제 이 동리(洞里)의 아침이' metadata={'common_labels': ['기대감', '환영/호의']}
# page_content='풀살 오른 소엉덩이처럼 푸드오.' metadata={'common_labels': ['감동/감탄', '신기함/관심', '흐뭇함(귀여움/예쁨)']}
# page_content='땀물을 뿌려 이 여름을 길렀오.' metadata={'common_labels': ['뿌듯함', '즐거움/신남']}
# page_content='잎, 잎, 풀잎마다 땀방울이 맺혔오.' metadata={'common_labels': ['감동/감탄']}
# page_content='구김살 없는 이 아침을' metadata={'common_labels': ['기대감', '편안/쾌적', '기쁨']}
# page_content='심호흡(深呼吸)하오 또 하오.' metadata={'common_labels': ['불안/걱정']}
# page_content='횐 빨래들이 귓속 이야기 하는 오후(午後),' metadata={'common_labels': ['편안/쾌적', '흐뭇함(귀여움/예쁨)', '기쁨']}
# page_content='아담한 빨래에만 달린다.' metadata={'common_labels': ['흐뭇함(귀여움/예쁨)']}
# page_content='잠은 눈을 떴다' metadata={'common_labels': ['놀람']}
# page_content='노래하던 종달이' metadata={'common_labels': ['흐뭇함(귀여움/예쁨)']}
# page_content='도망쳐 날아나고,' metadata={'common_labels': ['안타까움/실망', '놀람', '불안/걱정']}
# page_content='금잔디밭은 아니다.' metadata={'common_labels': ['부담/안_내킴', '당황/난처']}
# page_content='탑(塔)은 무너졌다,' metadata={'common_labels': ['절망', '안타까움/실망']}
# page_content='붉은 마음의 탑(塔)이——' metadata={'common_labels': ['불안/걱정']}
# page_content='손톱으로 새긴 대리석(大理石) 탑(塔)이——' metadata={'common_labels': ['신기함/관심']}
# page_content='하루저녁 폭풍(暴風)에 여지(餘地)없이도,' metadata={'common_labels': ['불안/걱정']}
# page_content='오오 황폐(荒廢)의 쑥밭,' metadata={'common_labels': ['불안/걱정', '안타까움/실망', '경악', '놀람']}
# page_content='눈물과 목메임이여!' metadata={'common_labels': ['슬픔', '서러움', '불안/걱정']}
# page_content='꿈은 깨어졌다' metadata={'common_labels': ['슬픔', '절망']}
# page_content='탑(塔)은 무너졌다.' metadata={'common_labels': ['절망', '당황/난처']}
# page_content='시계(時計)가 자근자근 가슴을 따려' metadata={'common_labels': ['부담/안_내킴', '불안/걱정', '당황/난처']}
# page_content='불안(不安)한 마음을 산림(山林)이 부른다.' metadata={'common_labels': ['불안/걱정']}
# page_content='천년(千年) 오래인 연륜(年輪)에 짜들은 유암(幽暗)한 산림(山林)이,' metadata={'common_labels': ['존경', '감동/감탄']}
# page_content='고달픈 한몸을 포옹(抱擁)할 인연(因緣)을 가졌나보다.' metadata={'common_labels': ['아껴주는', '힘듦/지침', '신기함/관심', '기대감']}
# page_content='산림(山林)의 검은 파동(波動)우으로부터' metadata={'common_labels': ['놀람']}
# page_content='어둠은 어린 가슴을 짓밟고' metadata={'common_labels': ['공포/무서움', '서러움', '불쌍함/연민']}
# page_content='이파리를 흔드는 저녁바람이' metadata={'common_labels': ['신기함/관심', '불안/걱정']}
# page_content='솨— 공포(恐怖)에 떨게 한다.' metadata={'common_labels': ['공포/무서움', '경악', '당황/난처']}
# page_content='멀리 첫여름의 개구리 재질댐에' metadata={'common_labels': ['기대감', '신기함/관심']}
# page_content='흘러간 마을의 과거(過去)는 아질타.' metadata={'common_labels': ['안타까움/실망', '슬픔', '불안/걱정', '서러움']}
# page_content='나무틈으로 반짝이는 별만이' metadata={'common_labels': ['기대감', '감동/감탄']}
# page_content='새날의 희망(希望)으로 나를 이끈다.' metadata={'common_labels': ['기대감', '비장함']}
# page_content='사이좋은 정문(正門)의 두 돌기둥 끝에서' metadata={'common_labels': ['흐뭇함(귀여움/예쁨)', '기대감']}
# page_content='오색기(五色旗)와 태양기(太陽旗)가 춤을 추는 날,' metadata={'common_labels': ['기대감']}
# page_content='금을 그은 지역(地域)의 아이들이 즐거워하다.' metadata={'common_labels': ['기쁨', '불쌍함/연민', '신기함/관심']}
# page_content='아이들에게 하루의 건조(乾燥)한 학과(學課)로' metadata={'common_labels': ['아껴주는']}
# page_content='해말간 권태(倦怠)가 깃들고' metadata={'common_labels': ['불안/걱정', '부담/안_내킴']}
# page_content='「모순(矛盾)」 두 자를 이해(理解)치 못하도록' metadata={'common_labels': ['의심/불신', '불안/걱정', '당황/난처']}
# page_content='못하도록 머리가 단순(單純)하였구나.' metadata={'common_labels': ['깨달음', '한심함']}
# page_content='이런 날에는' metadata={'common_labels': ['기대감', '없음']}
# page_content='잃어버린 완고(頑固)하던 형(兄)을' metadata={'common_labels': ['슬픔', '서러움', '불안/걱정', '안타까움/실망']}
# page_content='부르고 싶다.' metadata={'common_labels': ['기대감', '아껴주는']}
# page_content='거리가 바둑판처럼 보이고,' metadata={'common_labels': ['신기함/관심', '놀람']}
# page_content='강물(江水)이 배암의 새끼처럼 기는' metadata={'common_labels': ['신기함/관심']}
# page_content='산(山) 우에까지 왔다.' metadata={'common_labels': ['뿌듯함', '기대감', '기쁨']}
# page_content='바둑돌처럼 버려있으리라.' metadata={'common_labels': ['패배/자기혐오', '비장함']}
# page_content='함석지붕에만 비치고,' metadata={'common_labels': ['없음']}
# page_content='굼벵이 걸음을 하던 기차(汽車)가' metadata={'common_labels': ['신기함/관심', '불안/걱정']}
# page_content='정거장(停車場)에 섰다가 검은 내를 토(吐)하고' metadata={'common_labels': ['경악', '불안/걱정', '놀람']}
# page_content='텐트 같은 하늘이 무너져' metadata={'common_labels': ['공포/무서움', '불안/걱정', '놀람']}
# page_content='이 거리를 덮을까 궁금하면서' metadata={'common_labels': ['신기함/관심', '불안/걱정', '기대감']}
# page_content='좀 더 높은 데로 올라가고 싶다.' metadata={'common_labels': ['비장함', '기대감']}
# page_content='저쪽으로 황토(黃土) 실은 이 땅 봄바람이' metadata={'common_labels': ['기대감', '기쁨']}
# page_content='아롱진 사월(四月) 태양(太陽)의 손길이' metadata={'common_labels': ['기대감', '흐뭇함(귀여움/예쁨)']}
# page_content='벽(壁)을 등진 섧은 가슴마다 올올히 만진다.' metadata={'common_labels': ['슬픔', '불쌍함/연민', '서러움']}
# page_content='지도(地圖)째기 놀음에 뉘 땅인 줄 모르는 애 둘이' metadata={'common_labels': ['안타까움/실망', '불안/걱정']}
# page_content='한 뼘 손가락이 짧음을 한(恨)하며' metadata={'common_labels': ['서러움']}
# page_content='아서라! 가뜩이나 엷은 평화(平和)가' metadata={'common_labels': ['불안/걱정', '부담/안_내킴', '안타까움/실망']}
# page_content='깨어질까 근심스럽다.' metadata={'common_labels': ['불안/걱정', '아껴주는']}
# page_content='한간(一間) 계사(鷄舍) 그 넘어 창공(蒼空)이 깃들어' metadata={'common_labels': ['감동/감탄', '깨달음', '신기함/관심']}
# page_content='자유(自由)의 향토(鄕土)를 잊은 닭들이' metadata={'common_labels': ['안타까움/실망', '불쌍함/연민', '한심함']}
# page_content='시들은 생활(生活)을 주잘대고' metadata={'common_labels': ['불쌍함/연민', '힘듦/지침', '불안/걱정']}
# page_content='생산(生産)의 고로(苦勞)를 부르짖었다.' metadata={'common_labels': ['슬픔', '힘듦/지침']}
# page_content='음산(陰酸)한 계사(鷄舍)에서 쏠려나온' metadata={'common_labels': ['공포/무서움', '놀람', '경악', '불안/걱정']}
# page_content='외래종(外來種) 레구홍,' metadata={'common_labels': ['의심/불신']}
# page_content='학원(學園)에서 새무리가 밀려나오는' metadata={'common_labels': ['신기함/관심', '놀람']}
# page_content='삼월(三月)의 맑은 오후(午後)도 있다.' metadata={'common_labels': ['기쁨', '기대감', '편안/쾌적', '감동/감탄']}
# page_content='닭들은 녹아드는 두엄을 파기에' metadata={'common_labels': ['신기함/관심', '없음']}
# page_content='아담(雅淡)한 두 다리가 분주(奔走)하고' metadata={'common_labels': ['신기함/관심', '흐뭇함(귀여움/예쁨)']}
# page_content='굶주렸던 주둥이(주두리)가 바즈런하다.' metadata={'common_labels': ['신기함/관심', '힘듦/지침', '불쌍함/연민']}
# ...
# page_content='초췌한결론우에아침햇살이자세히적힌다.' metadata={'common_labels': ['패배/자기혐오', '당황/난처', '부담/안_내킴']}
# page_content='영원히그코없는밤은오지않을듯이.' metadata={'common_labels': ['불안/걱정']}
# page_content='문을압만잡아단여도않열리는것은안에생활이모자라는까닭이다.' metadata={'common_labels': ['깨달음', '안타까움/실망']}
# page_content='밤이사나운꾸즈람으로나를졸른다.' metadata={'common_labels': ['공포/무서움', '부담/안_내킴', '당황/난처']}
# page_content='나는우리집내문패앞레서여간성가신게아니다.' metadata={'common_labels': ['부담/안_내킴', '당황/난처', '짜증', '불평/불만']}
# page_content='나는밤속에들어서서제웅처럼작구만감해간다.' metadata={'common_labels': ['불안/걱정', '힘듦/지침', '패배/자기혐오']}
# page_content='식구야봉한창호어데라도한구석터노아다고내가수입되여들어가야하지않나.' metadata={'common_labels': ['불안/걱정']}
# page_content='집웅에서리가나리고뾰족한데는침처럼월광이무덨다.' metadata={'common_labels': ['불안/걱정', '부담/안_내킴']}
# page_content='우리집이알나보다그러고누가힘에겨운도장을찍나보다.' metadata={'common_labels': ['불안/걱정']}
# page_content='수명을헐어서전당잡히나보다.' metadata={'common_labels': ['불안/걱정', '안타까움/실망']}
# page_content='나는그냥문고리에쇠사슬늘어지듯매여달렷다.' metadata={'common_labels': ['패배/자기혐오', '힘듦/지침', '절망']}
# page_content='문을열려고안열리는문을열려고.' metadata={'common_labels': ['비장함', '힘듦/지침', '안타까움/실망']}
# page_content='그이는백지우에다연필로한사람의운명을흐릿하게초를잡아놓았다.' metadata={'common_labels': ['불안/걱정', '의심/불신', '놀람', '신기함/관심']}
# page_content='돈과과거를거기다놓아두고잡답속으로몸을기입하야본다.' metadata={'common_labels': ['부담/안_내킴', '패배/자기혐오']}
# page_content='그러나거기는타인과약속된악수가있을뿐, 다행히공란을입어보면장광도맛지않고않들인다.' metadata={'common_labels': ['안타까움/실망', '부담/안_내킴']}
# page_content='어떤븬터전을찾어가서실컨잠잣고있어본다.' metadata={'common_labels': ['힘듦/지침']}
# page_content='배가압하들어온다.' metadata={'common_labels': ['당황/난처', '불안/걱정']}
# page_content='괴로운발음을다생켜버린까닭이다.' metadata={'common_labels': ['부담/안_내킴']}
# page_content='간사한문서를때려주고또멱살을잡고끌고와보면그이도돈도없어지고피곤한과거가멀건이앉어있다.' metadata={'common_labels': ['힘듦/지침', '절망']}
# page_content='여기다좌석을두어서는않된다고그사람은이로위치를파헤처놋는다.' metadata={'common_labels': ['당황/난처', '안타까움/실망']}
# page_content='비켜스는악취에허망과복수를느낀다.' metadata={'common_labels': ['화남/분노', '증오/혐오']}
# page_content='그이는앉은자리에서그사람이평생을살아보는것을보고는살작달아나버렸다.' metadata={'common_labels': ['안타까움/실망', '부담/안_내킴', '놀람']}
# page_content='기침이난다.' metadata={'common_labels': ['당황/난처']}
# page_content='공기속에공기를힘들여배앗하놋는다.' metadata={'common_labels': ['힘듦/지침']}
# page_content='답답하게걸어가는길이내스토오리요기침해서찍는구두를심심한공기가주믈러서삭여버린다.' metadata={'common_labels': ['패배/자기혐오', '힘듦/지침']}
# page_content='나는한장이나걸어서철로를건너질를적에그때누가내경로를듸듸는이가있다.' metadata={'common_labels': ['당황/난처', '놀람', '불안/걱정']}
# page_content='압흔것이비수에버어지면서철로와열십자로어얼린다.' metadata={'common_labels': ['공포/무서움', '당황/난처']}
# page_content='나는문어지느라고기침을떨어트린다.' metadata={'common_labels': ['슬픔', '패배/자기혐오', '힘듦/지침']}
# page_content='우슴소리가요란하게나드니자조하는표정우에독한잉크가끼언친다.' metadata={'common_labels': ['패배/자기혐오', '한심함', '당황/난처']}
# page_content='기침은사념우에그냥주저앉어서떠든다.' metadata={'common_labels': ['부담/안_내킴', '서러움']}
# page_content='기가탁막힌다.' metadata={'common_labels': ['당황/난처', '안타까움/실망', '어이없음']}
# page_content='내가치던개(狗)는튼튼하대서모조리실험동물로공양되고그중에서비타민E를지닌개(狗)는학구의미급과생물다운질투로해서박사에게흠씬얻어맞는다하고싶은말을개짖듯배앝아놓던세월은숨었다. 의과대학허전한마당에우뚝서서나는필사로금제를앓는(患)다. 논문에출석한억울한촉루에는천고에씨명이없는법이다.' metadata={'common_labels': ['불안/걱정', '불쌍함/연민', '공포/무서움', '서러움', '안타까움/실망']}
# page_content='안해를즐겁게할조건들이틈입하지못하도록나는창호를닫고밤낮으로꿈자리가사나와서나는가위를눌린다어둠속에서무슨내음새의꼬리를체포하여단서로내집내미답의흔적을추구한다.' metadata={'common_labels': ['공포/무서움', '불안/걱정']}
# page_content='안해는외출에서돌아오면방에들어서기전에세수를한다.' metadata={'common_labels': ['신기함/관심']}
# page_content='닮아온여러벌표정을벗어버리는추행이다.' metadata={'common_labels': ['의심/불신']}
# page_content='나는드디어한조각독한비누를발견하고그것을내허위뒤에다살짝감춰버렸다.' metadata={'common_labels': ['불안/걱정', '의심/불신']}
# page_content='그리고이번꿈자리를예기한다.' metadata={'common_labels': ['기대감', '불안/걱정']}
# page_content='죽고싶은마음이칼을찾는다.' metadata={'common_labels': ['절망', '패배/자기혐오']}
# page_content='칼은날이접혀서펴지지않으니날을노호하는초조가절벽에끊치려든다.' metadata={'common_labels': ['불안/걱정', '당황/난처', '안타까움/실망']}
# page_content='억지로이것을안에떠밀어놓고간곡히참으면어느결에날이어디를건드렸나보다.' metadata={'common_labels': ['불안/걱정', '당황/난처', '부담/안_내킴', '지긋지긋']}
# page_content='내출혈이뻑뻑해온다.' metadata={'common_labels': ['경악', '공포/무서움', '힘듦/지침', '부담/안_내킴', '패배/자기혐오', '당황/난처']}
# page_content='그러나피부에상채기를얻을길이없으니악령나갈문이없다.' metadata={'common_labels': ['공포/무서움', '절망', '경악', '당황/난처']}
# page_content='가친자수로하여체중은점점무겁다.' metadata={'common_labels': ['힘듦/지침', '부담/안_내킴', '불안/걱정', '패배/자기혐오', '당황/난처']}
# page_content='꽃이보이지않는다.' metadata={'common_labels': ['당황/난처', '안타까움/실망', '절망', '공포/무서움', '불안/걱정']}
# page_content='꽃이향기롭다.' metadata={'common_labels': ['감동/감탄', '환영/호의', '기쁨']}
# page_content='나는거기묘혈을판다.' metadata={'common_labels': ['불안/걱정', '슬픔', '비장함', '패배/자기혐오', '절망']}
# page_content='묘혈도보이지않는다.' metadata={'common_labels': ['불안/걱정', '당황/난처', '공포/무서움', '서러움']}
# page_content='보이지않는묘혈속에나는들어앉는다.' metadata={'common_labels': ['패배/자기혐오', '힘듦/지침', '공포/무서움', '절망']}
# page_content='나는눕는다.' metadata={'common_labels': ['힘듦/지침']}
# page_content='또꽃이향기롭다.' metadata={'common_labels': ['감동/감탄', '흐뭇함(귀여움/예쁨)', '기쁨', '행복']}
# page_content='꽃은보이지않는다.' metadata={'common_labels': ['안타까움/실망', '당황/난처', '불안/걱정', '슬픔']}
# page_content='향기가만개한다.' metadata={'common_labels': ['기쁨', '감동/감탄', '흐뭇함(귀여움/예쁨)', '행복']}
# page_content='나는잊어버리고재처거기묘혈을판다.' metadata={'common_labels': ['절망']}
# page_content='묘혈은보이지않는다.' metadata={'common_labels': ['불안/걱정', '당황/난처', '슬픔', '서러움', '안타까움/실망', '불평/불만']}
# page_content='보이지않는묘혈로나는꽃을깜빡잊어버리고들어간다.' metadata={'common_labels': ['비장함', '안타까움/실망', '불안/걱정']}
# page_content='나는정말눕는다.' metadata={'common_labels': ['힘듦/지침', '패배/자기혐오']}
# page_content='아아.' metadata={'common_labels': ['깨달음', '절망']}
# page_content='꽃이또향기롭다.' metadata={'common_labels': ['기쁨', '아껴주는', '감동/감탄', '행복', '흐뭇함(귀여움/예쁨)']}
# page_content='보이지도않는꽃이--보이지도않는꽃이.' metadata={'common_labels': ['불안/걱정', '안타까움/실망']}
# page_content='내두루마기깃에달린정조배지를내어보였더니들어가도좋다고그런다.' metadata={'common_labels': ['뿌듯함']}
# page_content='들어가도좋다던여인이바로제게좀선명한정조가있으니어떠냔다.' metadata={'common_labels': ['당황/난처']}
# page_content='나더러세상에서얼마짜리화폐노릇을하는셈이냐는뜻이다.' metadata={'common_labels': ['당황/난처', '패배/자기혐오']}
# page_content='그리고는칠면조처럼쩔쩔맨다.' metadata={'common_labels': ['불안/걱정', '당황/난처', '부담/안_내킴', '안타까움/실망']}
# page_content='분총에계신백골까지가내게혈청의원가상환을강청하고있다. 천하에달이밝아서나는오들오들떨면서도처에서들킨다. 당신의인감이이미실효된지오랜줄은꿈에도생각하지않으시나요―하고나는의젓이대꾸를해야겠는데나는이렇게싫은결산의함수를내몸에지닌내도장처럼쉽사리끌러버릴수가참없다.' metadata={'common_labels': ['불안/걱정', '한심함', '불평/불만', '패배/자기혐오']}
# page_content='중요한위치에서한성격의심술이비극을연역하고있을즈음범위에는타인이없었던가. 한주―분에심은외국어의관목이막돌아서서나가버리려는동기요화물의방법이와있는의자가주저앉아서귀먹은체할때마침내가구두처럼고사이에낑기어들어섰으니나는내책임의맵시를어떻게해보여야하나. 애화가주석됨을따라나는슬퍼할준비라도하노라면나는못견뎌모자를쓰고밖으로나가버렸는데웬사람하나가여기남아내분신제출할것을잊어버리고있다.' metadata={'common_labels': ['당황/난처', '슬픔', '부담/안_내킴', '패배/자기혐오']}
# page_content='기억을맡아보는기관이염천아래생선처럼상해들어가기시작이다. 조삼모사의싸이폰작용. 감정의망쇄.' metadata={'common_labels': ['공포/무서움', '경악', '역겨움/징그러움', '패배/자기혐오', '지긋지긋', '당황/난처']}
# page_content='나를넘어뜨릴피로는오는족족피해야겠지만이런때는대담하게나서서혼자서도넉넉히자웅보다별것이어야겠다.' metadata={'common_labels': ['비장함']}
# page_content='탈신. 신발을벗어버린발이허천에서실족한다.' metadata={'common_labels': ['당황/난처', '놀람', '경악', '불안/걱정']}
# page_content='내두통위에신부의장갑이정초되면서내려앉는다.' metadata={'common_labels': ['패배/자기혐오', '힘듦/지침']}
# page_content='써늘한무게때문에내두통이비켜설기력도없다.' metadata={'common_labels': ['힘듦/지침', '패배/자기혐오', '절망']}
# page_content='나는견디면서여왕봉처럼수동적인맵시를꾸며보인다.' metadata={'common_labels': ['힘듦/지침']}
# page_content='나는기왕이주춧돌밑에서평생이원한이거니와신부의생애를침식하는내음삼한손찌거미를불개아미와함께잊어버리지는않는다.' metadata={'common_labels': ['화남/분노', '증오/혐오']}
# page_content='그래서신부는그날그날까무러치거나웅봉처럼죽고죽고한다.' metadata={'common_labels': ['불쌍함/연민', '불안/걱정', '안타까움/실망']}
# page_content='두통은영원히비켜서는수가없다.' metadata={'common_labels': ['절망', '지긋지긋']}
# page_content='입안에짠맛이돈다.' metadata={'common_labels': ['불안/걱정', '당황/난처', '부담/안_내킴']}
# page_content='혈관으로임리한묵흔이몰려들어왔나보다.' metadata={'common_labels': ['공포/무서움']}
# page_content='참회로벗어놓은내구긴피부는백지로도오고붓지나간자리에피가아롱져맺혔다.' metadata={'common_labels': ['패배/자기혐오']}
# page_content='방대한묵흔의분류는온갖합음이리니분간할길이없고다물은입안에그득찬서언이캄캄하다.' metadata={'common_labels': ['당황/난처', '불안/걱정']}
# page_content='생각하는무력이이윽고입을뻐겨젖히지못하니심판받으려야진술할길이없고익애에잠기면버언져멸형하여버린전고만이죄업이되어이생리속에영원히기절하려나보다.' metadata={'common_labels': ['절망', '패배/자기혐오', '불안/걱정', '서러움', '힘듦/지침']}
# page_content='크리스트에혹사한한남루한사나이가있으니이이는그의종생과운명까지도내게떠맡기려는사나운마음씨다.' metadata={'common_labels': ['부담/안_내킴', '증오/혐오']}
# page_content='내시시각각에늘어서서한시대나눌변인트집으로나를위협한다.' metadata={'common_labels': ['불안/걱정', '공포/무서움']}
# page_content='은애―나의착실한경영이늘새파랗게질린다.' metadata={'common_labels': ['불안/걱정', '공포/무서움', '불쌍함/연민', '경악', '놀람', '당황/난처']}
# page_content='나는이육중한크리스트의별신을암살하지않고는내문벌과내음모를약탈당할까참걱정이다.' metadata={'common_labels': ['불안/걱정', '당황/난처', '공포/무서움', '의심/불신']}
# page_content='그러나내신선한도망이그끈적끈적한청각을벗어버릴수가없다.' metadata={'common_labels': ['안타까움/실망', '패배/자기혐오', '역겨움/징그러움', '불평/불만']}
# page_content='여기는어느나라의데드마스크다.' metadata={'common_labels': ['공포/무서움', '부담/안_내킴']}
# page_content='데드마스크는도적맞았다는소문도있다.' metadata={'common_labels': ['불안/걱정', '의심/불신', '당황/난처', '안타까움/실망']}
# page_content='풀이극북에서파과하지않던이수염은절망을알아차리고생식하지않는다.' metadata={'common_labels': ['불쌍함/연민', '불안/걱정', '절망', '깨달음', '서러움', '안타까움/실망', '힘듦/지침']}
# page_content='천고로창천이허방빠져있는함정에유언이석비처럼은근히침몰되어있다.' metadata={'common_labels': ['절망']}
# page_content='그러면이곁을생소한손짓발짓의신호가지나가면서무사히스스로와한다.' metadata={'common_labels': ['불안/걱정', '부담/안_내킴']}
# page_content='젊잖던내용이이래저래구기기시작이다.' metadata={'common_labels': ['지긋지긋', '당황/난처', '부담/안_내킴']}
# page_content='―어디갔는지모르는아내―' metadata={'common_labels': ['불안/걱정', '의심/불신']}
# page_content='○지비1' metadata={'common_labels': ['없음']}
# page_content='아내는 아침이면 외출한다 그날에 해당한 한남자를 속이려가는것이다 순서야 바뀌어도 하루에한남자이상은 대우하지않는다고 아내는 말한다 오늘이야말로 정말돌아오지않으려나보다하고 내가 완전히 절망하고나면 화장은있고 인상은없는얼굴로 아내는 형용처럼 간단히돌아온다 나는 물어보면 아내는 모두솔직히 이야기한다 나는 아내의일기에 만일 아내가나를 속이려들었을때 함직한속기를 남편된자격밖에서 민첩하게대서한다' metadata={'common_labels': ['불안/걱정', '절망', '서러움', '슬픔']}
# page_content='○지비2' metadata={'common_labels': ['없음']}
# page_content='아내는 정말 조류였던가보다' metadata={'common_labels': ['당황/난처']}
# page_content='아내가 그렇게 수척하고 거벼워졌는데도 날으지못한것은 그손까락에 낑기웠던 반지때문이다' metadata={'common_labels': ['불쌍함/연민', '패배/자기혐오']}
# page_content='오후에는 늘 분을바를때 벽한겹걸러서 나는 조롱을 느낀다 얼마 안가서 없어질때까지 그 파르스레한주둥이로 한번도 쌀알을 쪼으려들지않았다' metadata={'common_labels': ['패배/자기혐오', '한심함']}
# page_content='또 가끔 미닫이를열고 창공을 쳐다보면서도 고운목소리로 지저귀려들지않았다' metadata={'common_labels': ['안타까움/실망']}
# page_content='아내는 날을줄과 죽을줄이나 알았지 지상에 발자국을 남기지않았다' metadata={'common_labels': ['불쌍함/연민', '슬픔', '당황/난처']}
# page_content='비밀한발을 늘버선신고 남에게 안보이다가 어느날 정말 아내는 없어졌다 그제야 처음방안에 조분내음새가 풍기고 날개퍼덕이던 상처가 도배위에 은근하다' metadata={'common_labels': ['안타까움/실망', '슬픔', '당황/난처', '불안/걱정']}
# page_content='헤뜨러진 깃부스러기를 쓸어모으면서 나는 세상에도 이상스러운것을얻었다' metadata={'common_labels': ['신기함/관심', '의심/불신', '깨달음', '불안/걱정']}
# page_content='그리고 주저앉았었더라 산탄은 녹슬었고 솜털내음새도 나고 천근무게더라 아아' metadata={'common_labels': ['안타까움/실망', '힘듦/지침']}
# page_content='이방에는 문패가없다 개는이번에는 저쪽을 향하여짖는다 조소와같이 아내의벗어놓은 버선이 나같은공복을표정하면서 곧걸어갈것같다 나는 이방을 첩첩이닫치고 출타한다 그제야 개는 이쪽을향하여 마지막으로 슬프게 짖는다' metadata={'common_labels': ['슬픔', '부담/안_내킴', '서러움', '안타까움/실망']}
# page_content='훤조때문에마멸되는몸이다.' metadata={'common_labels': ['힘듦/지침', '안타까움/실망', '슬픔', '공포/무서움']}
# page_content='모두가소년이라고들그리는데노야인기색이많다.' metadata={'common_labels': ['안타까움/실망', '불쌍함/연민', '힘듦/지침']}
# page_content='그러니까육교위에서또하나의편안한대륙을내려다보고근근히산다.' metadata={'common_labels': ['힘듦/지침', '안타까움/실망']}
# page_content='동갑네가시시거리며떼를지어답교한다.' metadata={'common_labels': ['흐뭇함(귀여움/예쁨)', '아껴주는']}
# page_content='그렇지않아도육교는또월광으로충분히천칭처럼제무게에끄덱인다.' metadata={'common_labels': ['불안/걱정']}
# page_content='타인의그림자는위선넓다.' metadata={'common_labels': ['의심/불신', '증오/혐오']}
# page_content='미미한그림자들이얼떨김에모조리앉아버린다.' metadata={'common_labels': ['당황/난처', '놀람']}
# page_content='앵도가진다.' metadata={'common_labels': ['안타까움/실망']}
# page_content='종자도연멸한다.' metadata={'common_labels': ['안타까움/실망', '불쌍함/연민']}
# page_content='정탐도흐지부지─있어야옳을박수가어째서없느냐.' metadata={'common_labels': ['의심/불신', '불평/불만', '서러움', '불안/걱정']}
# page_content='아마아버지를반역한가싶다.' metadata={'common_labels': ['의심/불신', '불안/걱정', '부담/안_내킴']}
# page_content='묵묵히─기도를봉쇄한체하고말을하면사투리다.' metadata={'common_labels': ['불안/걱정']}
# page_content='아니─이무언이훤조의사투리리라.' metadata={'common_labels': ['놀람', '당황/난처', '깨달음']}
# page_content='쏟으려는노릇─날카로운신단이싱싱한육교그중심한구석을진단하듯어루만지기만한다.' metadata={'common_labels': ['불안/걱정']}
# page_content='나날이썩으면서가리키는지향으로기적히골목이뚫렸다.' metadata={'common_labels': ['기대감', '놀람', '부담/안_내킴']}
# page_content='썩는것들이낙차나며골목으로몰린다.' metadata={'common_labels': ['역겨움/징그러움', '당황/난처', '경악', '부담/안_내킴', '불안/걱정']}
# page_content='골목안에는치사스러워보이는문이있다.' metadata={'common_labels': ['불평/불만', '의심/불신']}
# page_content='문안에는금니가있다.' metadata={'common_labels': ['신기함/관심']}
# page_content='금니안에는추잡한혀가달린폐환이있다.' metadata={'common_labels': ['역겨움/징그러움', '불안/걱정', '증오/혐오']}
# page_content='오─오─.' metadata={'common_labels': ['놀람', '당황/난처', '감동/감탄']}
# page_content='들어가면서나오지못하는타입깊이가장부를닮는다.' metadata={'common_labels': ['깨달음', '안타까움/실망']}
# page_content='그위로짝바뀐구두가비철거린다.' metadata={'common_labels': ['불안/걱정', '힘듦/지침']}
# page_content='어느균이어느아랫배를앓게하는것이다.' metadata={'common_labels': ['불안/걱정', '공포/무서움']}
# page_content='질다.' metadata={'common_labels': ['힘듦/지침']}
# page_content='반추한다.' metadata={'common_labels': ['비장함']}
# page_content='노파니까.' metadata={'common_labels': ['불쌍함/연민', '안타까움/실망']}
# page_content='맞은편평활한유리위에해소된정체를도포한졸음오는혜택이뜬다.' metadata={'common_labels': ['재미없음']}
# page_content='꿈─꿈─ 꿈을짓밟는허망한노역─이세기의곤비와살기가바둑판처럼널리깔렸다.' metadata={'common_labels': ['절망', '힘듦/지침', '부담/안_내킴', '안타까움/실망']}
# page_content='먹어야사는입술이악의로꾸긴진창위에서슬며시식사흉내를낸다.' metadata={'common_labels': ['불안/걱정', '증오/혐오']}
# page_content='아들─여러아들─노파의결혼을걷어차는여러아들들의육중한구두─구두바닥의징이다.' metadata={'common_labels': ['경악']}
# page_content='층단을몇번이고아래로내려가면갈수록우물이드물다.' metadata={'common_labels': ['불안/걱정', '부담/안_내킴', '깨달음', '당황/난처']}
# page_content='좀지각해서는텁텁한바람이불고─하면학생들의지도가요일마다채색을고친다.' metadata={'common_labels': ['신기함/관심', '불안/걱정', '부담/안_내킴']}
# page_content='객지에서도리없이다수굿하던지붕들이어물어물한다.' metadata={'common_labels': ['불안/걱정', '안타까움/실망']}
# page_content='즉이취락은바로여드름돋는계절이래서으쓱거리다잠꼬대위에더운물을붓기도한다.' metadata={'common_labels': ['당황/난처', '놀람']}
# page_content='갈─이갈때문에견디지못하겠다.' metadata={'common_labels': ['지긋지긋', '짜증', '증오/혐오', '불평/불만']}
# page_content='태고의호수바탕이던지적이짜다. 막을버틴기둥이습해들어온다. 구름이근경에오지않고오락없는공기속에서가끔편도선들을앓는다. 화폐의스캔달─발처럼생긴손이염치없이노파의통고하는손을잡는다.' metadata={'common_labels': ['불안/걱정', '불쌍함/연민', '부담/안_내킴']}
# page_content='눈에띄우지않는폭군이잠입하였다는소문이있다. 아기들이번번이애총이되고되고한다. 어디로피해야저어른구두와어른구두가맞부딪는꼴을안볼수있으랴. 한창급한시각이면가가호호들이한데어우러져서멀리포성과시반이제법은은하다.' metadata={'common_labels': ['불안/걱정', '공포/무서움', '서러움', '당황/난처', '부담/안_내킴']}
# page_content='여기있는것들모두가그방대한방을쓸어생긴답답한쓰레기다. 낙뢰심한그방대한방안에는어디로선가질식한비둘기만한까마귀한마리가날아들어왔다. 그러니까강하던것들이역마잡듯픽픽쓰러지면서방은금시폭발할만큼정결하다. 반대로여기있는것들은통요사이의쓰레기다.' metadata={'common_labels': ['역겨움/징그러움', '공포/무서움', '불안/걱정', '증오/혐오', '부담/안_내킴', '불평/불만', '지긋지긋']}
# page_content='간다.' metadata={'common_labels': ['비장함']}
# page_content='『손자』도탑재한낙차가방을피하나보다.' metadata={'common_labels': ['깨달음', '불안/걱정', '놀람', '의심/불신']}
# page_content='속기를펴놓은상궤위에알뜰한접시가있고접시위에삶은계란한개─포-크로터뜨린노란자위겨드랑에서난데없이부화하는훈장형조류─푸드덕거리는바람에방안지가찢어지고빙원위에좌표잃은부첩떼가난무한다.' metadata={'common_labels': ['경악', '놀람', '당황/난처', '공포/무서움']}
# page_content='궐련에피가묻고그날밤에유곽도탔다.' metadata={'common_labels': ['공포/무서움', '패배/자기혐오']}
# page_content='번식하고거짓천사들이하늘을가리고온대로건넌다.' metadata={'common_labels': ['공포/무서움', '부담/안_내킴', '경악']}
# page_content='그러나여기있는것들은뜨뜻해지면서한꺼번에들떠든다.' metadata={'common_labels': ['신기함/관심']}
# page_content='방대한방은속으로곪아서벽지가가렵다.' metadata={'common_labels': ['안타까움/실망', '경악', '불안/걱정', '힘듦/지침']}
# page_content='쓰레기가막붙는다.' metadata={'common_labels': ['짜증', '지긋지긋', '불평/불만']}
# page_content='장난감신부살결에서 이따금 우유내음새가 나기도한다. 머(ㄹ)지아니하여 아기를낳으려나보다. 촉불을끄고 나는 장난감신부귀에다대이고 꾸지람처럼 속삭여본다.' metadata={'common_labels': ['신기함/관심', '아껴주는', '흐뭇함(귀여움/예쁨)']}
# page_content='그대는 꼭 갖난아기와같다고···············' metadata={'common_labels': ['아껴주는', '흐뭇함(귀여움/예쁨)']}
# page_content='장난감신부는 어둔데도 성을내이고대답한다.' metadata={'common_labels': ['화남/분노', '안타까움/실망']}
# page_content='목장까지 산보갔다왔답니다' metadata={'common_labels': ['편안/쾌적']}
# page_content='장난감신부에게 내가 바늘을주면 장난감신부는 아무것이나 막 찌른다.일력. 시집. 시계. 또 내몸 내 경험이들어앉아있음직한곳.' metadata={'common_labels': ['공포/무서움', '당황/난처', '불안/걱정', '놀람']}
# page_content='이것은 장난감신부마음속에 가시가 돋아있는증거다. 즉 장미꽃처럼···············' metadata={'common_labels': ['깨달음']}
# page_content='내 거벼운무장에서 피가좀난다.' metadata={'common_labels': ['당황/난처', '슬픔']}
# page_content='나는 이 상채기를고치기위하야 날만어두면 어둔속에서 싱싱한밀감을먹는다.' metadata={'common_labels': ['불안/걱정', '비장함']}
# page_content='몸에 반지밖에가지지않은 장난감신부는 어둠을 커―튼열듯하면서 나를찾는다.' metadata={'common_labels': ['불쌍함/연민', '공포/무서움']}
# page_content='얼른 나는 들킨다.' metadata={'common_labels': ['부담/안_내킴', '당황/난처']}
# page_content='반지가살에닿는것을 나는 바늘로잘못알고 아파한다.' metadata={'common_labels': ['당황/난처', '패배/자기혐오', '한심함', '놀람']}
# page_content='촉불을켜고 장난감신부가 밀감을찾는다.' metadata={'common_labels': ['신기함/관심']}

# %%
from langchain.vectorstores import FAISS
from langchain.embeddings import HuggingFaceEmbeddings

# %%
from transformers import AutoTokenizer, AutoModel
import torch
import numpy as np
from langchain.embeddings.base import Embeddings

class KcELECTRAEmbeddings(Embeddings):
    def __init__(self, model_name: str = "beomi/KcELECTRA-base", device: str = "cpu"):
        self.tokenizer = AutoTokenizer.from_pretrained(model_name)
        self.model = AutoModel.from_pretrained(model_name).to(device)
        self.device = device

    def _embed(self, text: str):
        inputs = self.tokenizer(text, return_tensors="pt", padding=True, truncation=True, max_length=128).to(self.device)
        with torch.no_grad():
            outputs = self.model(**inputs)
            cls_embedding = outputs.last_hidden_state[:, 0, :]
        return cls_embedding.squeeze().cpu().numpy()

    def embed_documents(self, texts: list[str]) -> list[list[float]]:
        return [self._embed(text).tolist() for text in texts]

    def embed_query(self, text: str) -> list[float]:
        return self._embed(text).tolist()

# %%
# 3️⃣ 벡터 임베딩 모델 로딩 (한국어 지원하는 모델 권장) KcElectra -> backbone 모델로 사용
embedding_model = KcELECTRAEmbeddings()
# embedding_model = HuggingFaceEmbeddings(model_name="jhgan/ko-sbert-sts")

# %%
! pip install faiss-cpu
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# Collecting faiss-cpu
#   Downloading faiss_cpu-1.11.0-cp310-cp310-macosx_14_0_arm64.whl (3.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 3.3/3.3 MB 11.1 MB/s eta 0:00:00a 0:00:01
# Requirement already satisfied: packaging in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from faiss-cpu) (24.2)
# Requirement already satisfied: numpy<3.0,>=1.25.0 in /Users/irolim/Documents/한중연/3차시/연구연계과제/langchain-llama-KPoEM/.venv/lib/python3.10/site-packages (from faiss-cpu) (2.2.6)
# Installing collected packages: faiss-cpu
# Successfully installed faiss-cpu-1.11.0
#
# [notice] A new release of pip is available: 23.0.1 -> 25.1.1
# [notice] To update, run: pip install --upgrade pip

# %%
# 4️⃣ FAISS VectorDB 생성
vectorstore = FAISS.from_documents(documents, embedding_model)

# %%
# 2️⃣ 감정 기반 프롬프트 생성
def generate_prompt_withVector(emotion_scores, context_snippets):
    top_emotion = max(emotion_scores, key=emotion_scores.get)
    return f"""당신은 감정이 섬세한 한국 근현대 시인입니다.
'{top_emotion}'의 감정을 중심으로 한국어로 짧은 시를 한 편 창작해 주세요.
다음은 감정의 분위기를 도와줄 참고 문장입니다:
{context_snippets} 이 문장들은 5명의 어노테이터가 44개 감정 라벨 중 최대 10개를 선택한 결과에서 3인 이상 공통된 감정만 추출한 신뢰도 높은 데이터셋입니다.
이 문장들의 정서와 단어, 옛스러운 한국 고유의 표현을 사용하여 시를 지어 주세요.
"""

# %%
# 8️⃣ 전체 체인
def emotion_to_poetry(user_input):
    scores = classify_emotion(user_input)
    top_emotion = max(scores, key=scores.get)

    # 관련 시구 검색
    context_snippets = vectorstore.similarity_search(top_emotion, k=10)  # k=100로 설정, 필요에 따라 조정 가능

    # 프롬프트 생성
    full_prompt = generate_prompt_withVector(scores, context_snippets)

    # LangChain Prompt + LLM 실행
    prompt = PromptTemplate.from_template("{emotion_prompt}")
    chain = LLMChain(llm=llm, prompt=prompt)
    result = chain.run(emotion_prompt=full_prompt)
    print(context_snippets)

    return result

# %%
# 9️⃣ 테스트 실행
user_text = """하루 종일 지친 몸으로만 떠돌다가
땅에 떨어져 죽지 못한
햇빛들은 줄지어 어디로 가는 걸까


웅성웅성 가장 근심스러운 색깔로 서행하며
이미 어둠이 깔리는 소각장으로 몰려들어
몇 점 폐휴지로 타들어가는 오루 6시의 참혹한 형량
단 한 번 후회도 용서하지 않는 무서운 시간
바람은 긴 채찍을 휘둘러
살아서 빛나는 온갖 상징을 몰아내고 있다.


도시는 곧 활자들이 일제히 빠져 달아나
속도 없이 페이지를 펄럭이는 텅 빈 한 권 책이 되리라.
승부를 알 수 없는 하루와의 싸움에서
우리는 패배했을까. 오늘도 물어보는 사소한 물음은
그러나 우리의 일생을 텅텅 흔드는 것.


오후 6시의 소각장 위로 말없이
검은 연기가 우산처럼 펼쳐지고
이젠 우리들의 차례였다.
두렵지 않은가.
밤이면 그림자를 빼앗겨 누구나 아득한 혼자였다.


문득 거리를 빠르게 스쳐가는 일상의 공포
보여다오. 지금까지 무엇을 했는가 살아 있는 그대여
오후 6시 우리들 이마에도 아, 붉은 노을이 떴다.


그러면 우리는 어디로 가지?
아직도 펄펄 살아 있는 우리는 이제 각자 어디로 가지?
""" # 기형도 - 노을
generated_poem = emotion_to_poetry(user_text)

print("🎴 생성된 시:\n", generated_poem)
# Out:
# [Sample Inference 결과]
# {'공포/무서움': 0.4350000023841858, '놀람': 0.30799999833106995, '당황/난처': 0.5139999985694885, '부담/안_내킴': 0.39899998903274536, '불안/걱정': 0.5479999780654907, '불평/불만': 0.30300000309944153, '비장함': 0.33899998664855957, '서러움': 0.35100001096725464, '슬픔': 0.414000004529953, '신기함/관심': 0.3109999895095825, '안타까움/실망': 0.30799999833106995, '의심/불신': 0.30799999833106995, '힘듦/지침': 0.33899998664855957}
# [Document(id='c937a09c-dc53-41d2-834d-685c8bbfe9c6', metadata={'common_labels': ['안타까움/실망']}, page_content='이밤이라도'), Document(id='dcd63fb7-88bc-4cb8-8ea7-45b82f99dd1e', metadata={'common_labels': ['기대감', '아껴주는', '환영/호의', '기쁨']}, page_content='당신님의 편지를'), Document(id='4ff70e58-d6f7-42a0-8ee8-b0ef848f345d', metadata={'common_labels': ['슬픔', '절망']}, page_content='꿈은 깨어졌다'), Document(id='0c9f35b0-59ec-4f16-ad55-44bbfa42a1cd', metadata={'common_labels': ['편안/쾌적']}, page_content='바람자는 이 저녁'), Document(id='03bcb272-1967-4172-90e3-2f0309c93bb1', metadata={'common_labels': ['신기함/관심', '불안/걱정']}, page_content='밀물에 흘러,'), Document(id='74c25084-4ee6-4f20-9ad3-2b9b1bcd3a99', metadata={'common_labels': ['신기함/관심', '없음']}, page_content='모퉁이마다'), Document(id='746aa9a3-d7f3-4b3a-9af5-849d33c88e23', metadata={'common_labels': ['아껴주는', '환영/호의']}, page_content='어루만지듯'), Document(id='f9e5ae11-51ae-4d7a-bbda-982263d43baa', metadata={'common_labels': ['힘듦/지침', '부담/안_내킴']}, page_content='괴롬의 거리'), Document(id='028411a7-21ec-41bc-ae08-8d2f8bb91dfa', metadata={'common_labels': ['놀람', '불안/걱정']}, page_content='놀라 깨어 내다 보니'), Document(id='fa079b88-1863-4340-bccf-bca700cd26df', metadata={'common_labels': ['기대감', '불안/걱정']}, page_content='만일 님에게도'), Document(id='5a50ae84-9515-4199-a775-88bb23d93de6', metadata={'common_labels': ['슬픔', '서러움']}, page_content='고향이 탓이되어'), Document(id='85fb61b3-e03a-4a6a-99da-e9bb7939cfdf', metadata={'common_labels': ['신기함/관심', '흐뭇함(귀여움/예쁨)']}, page_content='병아리 소리.'), Document(id='3576fd51-c37e-4ce0-b4f6-4e6fe2ab09ee', metadata={'common_labels': ['흐뭇함(귀여움/예쁨)', '기대감']}, page_content='새처럼 나래를'), Document(id='24b799c7-5994-449b-a038-0cee8fdb3159', metadata={'common_labels': ['즐거움/신남', '기쁨', '행복']}, page_content='살음에 즐거워서,'), Document(id='51f9b93e-4548-4b73-99d4-18bbc137f228', metadata={'common_labels': ['불안/걱정']}, page_content='어둔 뒤 아무데나,'), Document(id='6ad0791b-667f-4753-b7eb-500878277076', metadata={'common_labels': ['감동/감탄']}, page_content='육체의 곡조를'), Document(id='2d3772c9-b533-4e6d-a032-903a6dea574c', metadata={'common_labels': ['놀람']}, page_content='잠은 눈을 떴다'), Document(id='d6016edc-01dd-43df-b655-c84e90882991', metadata={'common_labels': ['기대감']}, page_content='내일이라도'), Document(id='30a384a2-1cd4-4ac0-8477-e9f3a5783581', metadata={'common_labels': ['신기함/관심']}, page_content='어항 속에'), Document(id='758c73ee-4bb7-4cf4-ab28-580a5457a7e9', metadata={'common_labels': ['깨달음', '감동/감탄']}, page_content='물보다 깊으니라'), Document(id='3a40f12d-58db-47c7-9366-a356acd2d85a', metadata={'common_labels': ['안타까움/실망']}, page_content='래일은 없나니'), Document(id='1b13ffe8-98d0-48dd-849c-6697f260112f', metadata={'common_labels': ['기대감']}, page_content='눈앞에 보이는'), Document(id='f8195118-69dc-4b87-ab0e-3059e70f471a', metadata={'common_labels': ['비장함', '뿌듯함', '기대감']}, page_content='나의 용기 위에'), Document(id='72cb8aec-ec12-427e-88a4-19c95f3cfff3', metadata={'common_labels': ['신기함/관심', '흐뭇함(귀여움/예쁨)']}, page_content='종달새들이'), Document(id='40b556e1-3969-48b0-b939-5f743d4eb2a3', metadata={'common_labels': ['흐뭇함(귀여움/예쁨)', '감동/감탄']}, page_content='해바라기 얼굴'), Document(id='403d3bb6-c6a9-41bc-b617-aacb5a8d9a98', metadata={'common_labels': ['아껴주는']}, page_content='어루만지려'), Document(id='158b6041-38bf-402c-bd68-2cf557fd87a5', metadata={'common_labels': ['슬픔']}, page_content='가라앉듯 멀리'), Document(id='a399e251-f235-4388-9ff3-057631cdbec9', metadata={'common_labels': ['없음']}, page_content='저혼자 들었다,'), Document(id='d52fbcdf-ba58-45c7-ba43-97ad473d10e7', metadata={'common_labels': ['기쁨', '편안/쾌적']}, page_content='한목음의 물이'), Document(id='318bd637-0e4b-4fd8-97c0-23660ce57c5c', metadata={'common_labels': ['없음']}, page_content='불리워 온 것은'), Document(id='c475b8e5-db36-4214-9109-f75df5fa25d3', metadata={'common_labels': ['안타까움/실망']}, page_content='팔매 친 돌처럼'), Document(id='808c9b52-17e1-4d3c-9cff-c7b2fba2cffb', metadata={'common_labels': ['기대감']}, page_content='들에나 나려오면'), Document(id='e0f046a4-695b-4a8b-a6b6-9f05e6375e75', metadata={'common_labels': ['서러움']}, page_content='아아! 나는'), Docume ...
# 🎴 생성된 시:
#  적용된 감정 라벨은 다음과 같습니다.
#
# 1.  **아껴주는** : 어머니가 애기에게 하늘과 바다 사이의美しく 아름다운 풍경을 보고자 주무시지 않게 할 수 있는 힘을 주는 감정입니다.
# 2.  **슬픔** : 원활한 일상을 지속할 수 없고, 혼이 들리는 세계로 빠져들게 할 수 있는 감정입니다.
# 3.  **비장함** : 가가아름답고 상상할 수 없는 세계로 빠져들게 할 수 있는 감정입니다.
#
# 시를 지어주면 다음과 같습니다.
#
# \[ 시의 한 쪼리 ]
#
# 아머니가 애기에게
# 하늘과 바다 사이의
# 아름다운 풍경을 보고자 주무시지 않게
# 힘을 줄 수 있는
# 비장함의力量
#
# 이 worlds에서
# 슬픔이 들지
# 않는 힘을 주는
# 아mother의 손
#
# 어머니의 손 안에서
# 가아름답고 상상할 수 없는
# 비장함을 찾아다니며
# 세계를 느끼다
#
# 하늘과 바다 사이의
# 아름다운 풍경
# 애기에게 물려줄
# 비장함의 힘
#
# 이 worlds에서
# 슬픔이 들지
# 않는 힘을 주는
# 아mother의 손
#
# 어머니의 사랑에
# 가아름답고 상상할 수 없는
# 비장함을 발견한다.
#
# \[ 시의 한 쪼리 ]
#
# 이 시는 어노테이터들이 선택한 감정 라벨 중 최대 3개를 공통으로 사용하여 지어졌습니다. 그들은 "비장함", "아 mother's love" , "슬픔"으로 가득 차 있는 시를 지어주었습니다.
